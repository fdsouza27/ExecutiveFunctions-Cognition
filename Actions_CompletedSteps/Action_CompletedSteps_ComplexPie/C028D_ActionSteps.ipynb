# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C028 D/'
file_name = 'C028_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type   Interacted Object
# 0     19.339697     Right Hand Grab                 NaN
# 1     20.253622      Left Hand Grab                 NaN
# 2     34.985489      Left Hand Grab  StaticMeshActor_31
# 3     35.318920  Left Hand Released  StaticMeshActor_31
# 4     38.362747      Left Hand Grab  StaticMeshActor_31

# %%
df1.shape
# Out:
# (204, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    186
# 1     18
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       19.339697  Right Hand Grab               NaN                    1
# 1       20.253622   Left Hand Grab               NaN                    1
# 13     171.172028  Right Hand Grab               NaN                    1
# 14     174.129044  Right Hand Grab               NaN                    1
# 15     178.792343  Right Hand Grab               NaN                    1
# 24     267.836609  Right Hand Grab               NaN                    1
# 58     394.064606  Right Hand Grab               NaN                    1
# 72     421.582092  Right Hand Grab               NaN                    1
# 108    486.079590  Right Hand Grab               NaN                    1
# 156    578.467529  Right Hand Grab               NaN                    1
# 157    579.551697  Right Hand Grab               NaN                    1
# 163    622.717712  Right Hand Grab               NaN                    1
# 170    693.205872  Right Hand Grab               NaN                    1
# 171    694.520020  Right Hand Grab               NaN                    1
# 178    735.819153  Right Hand Grab               NaN                    1
# 182    847.269897  Right Hand Grab               NaN                    1
# 183    850.892517  Right Hand Grab               NaN                    1
# 184    852.246643  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type   Interacted Object  Missed Interactions
# 0     19.339697     Right Hand Grab                 NaN                    1
# 1     20.253622      Left Hand Grab                 NaN                    1
# 2     34.985489      Left Hand Grab  StaticMeshActor_31                    0
# 3     35.318920  Left Hand Released  StaticMeshActor_31                    0
# 4     38.362747      Left Hand Grab  StaticMeshActor_31                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C028 D/'
file_name = 'C028_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    229.446335         Add Sugar
# 1    306.162506         Add butter
# 2    311.577148         Add butter
# 3    324.543640          Add water
# 4    457.154053  Add apples to pan
# 5    459.889313  Add apples to pan
# 6    462.435211  Add apples to pan
# 7    464.985748  Add apples to pan
# 8    467.588104  Add apples to pan
# 9    469.386536  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (229, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       19.339697      Right Hand Grab                           NaN
# 1       20.253622       Left Hand Grab                           NaN
# 2       34.985489       Left Hand Grab            StaticMeshActor_31
# 3       35.318920   Left Hand Released            StaticMeshActor_31
# 4       38.362747       Left Hand Grab            StaticMeshActor_31
# 5       39.140110   Left Hand Released            StaticMeshActor_31
# 6       39.806679       Left Hand Grab            StaticMeshActor_31
# 7       44.805378   Left Hand Released            StaticMeshActor_31
# 8       48.585842      Right Hand Grab            StaticMeshActor_84
# 9       51.806652  Right Hand Released            StaticMeshActor_84
# 10     104.714249      Right Hand Grab          ApplePieCookbook_C_0
# 11     163.251862       Left Hand Grab         SugarJar_C_2147482370
# 12     164.800217   Left Hand Released         SugarJar_C_2147482370
# 13     171.172028      Right Hand Grab                           NaN
# 14     174.129044      Right Hand Grab                           NaN
# 15     178.792343      Right Hand Grab                           NaN
# 16     181.840057      Right Hand Grab          ApplePieCookbook_C_0
# 17     224.731934       Left Hand Grab  NewMeasuringCup_C_2147482375
# 204    229.446335                  NaN                           NaN
# 18     232.223602   Left Hand Released  NewMeasuringCup_C_2147482375
# 19     240.805405      Right Hand Grab     WaterPitcher_C_2147482369
# 20     247.024704  Right Hand Released     WaterPitcher_C_2147482369
# 21     249.991745      Right Hand Grab          ApplePieCookbook_C_0
# 22     251.555222      Right Hand Grab     WaterPitcher_C_2147482369
# 23     263.789642  Right Hand Released     WaterPitcher_C_2147482369
# 24     267.836609      Right Hand Grab                           NaN
# 25     271.023773       Left Hand Grab          ApplePieCookbook_C_0
# 26     293.268005       Left Hand Grab     ButterHolder_C_2147482372
# 27     295.304077   Left Hand Released     ButterHolder_C_2147482372
# 28     296.898529       Left Hand Grab           Butter_C_2147482371
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   1.0            NaN
# 14                   1.0            NaN
# 15                   1.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 204                  NaN     Add Sugar
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   1.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        87
# Right Hand Released    54
# Chopped                31
# Left Hand Grab         17
# Left Hand Released     15
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 204

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482351                16
# PiePan_C_2147482366                 14
# Knife_C_1                           12
# ApplePieCookbook_C_0                 9
# Apple_Slice2_C_2147482314            9
# WaterPitcher_C_2147482369            8
# Apple_Slice_C_2147482315             8
# oven_C_1                             6
# Apple_Slice4_C_2147482335            6
# StaticMeshActor_31                   6
# Apple_Slice_C_2147482338             5
# Apple_C_2147482385                   4
# Apple_Slice_C_2147482313             4
# Apple_C_2147482334                   3
# Apple_C_2147482344                   3
# Apple_Slice2_C_2147482312            3
# Apple_C_2147482341                   3
# Apple_Slice2_C_2147482337            3
# Apple_C_2147482321                   3
# CinnyShakerGrabable_C_2147482373     2
# Apple_Slice3_C_2147482307            2
# SaucePot_C_2147482374                2
# Apple_C_2147482349                   2
# Apple_Slice4_C_2147482306            2
# StaticMeshActor_23                   2
# Apple_Slice4_C_2147482310            2
# Apple_Slice3_C_2147482311            2
# StirSpoonPie_C_2147482368            2
# SugarJar_C_2147482370                2
# NewMeasuringCup_C_2147482375         2
# ButterHolder_C_2147482372            2
# Apple_Half2_C_2147482316             2
# Apple_C_2147482381                   2
# Apple_Slice3_C_2147482329            2
# Butter_C_2147482371                  2
# UnecessaryLime_C_2147482386          2
# Apple_C_2147482347                   2
# Apple_C_2147482348                   2
# Apple_C_2147482345                   2
# Butter_C_2147482355                  2
# Apple_Slice2_C_2147482326            2
# Apple_Slice3_C_2147482336            2
# StaticMeshActor_84                   2
# Apple_Slice_C_2147482327             2
# Apple_Slice4_C_2147482328            2
# Apple_Half_C_2147482331              1
# Apple_Half2_C_2147482318             1
# Apple_Half2_C_2147482339             1
# Apple_Half_C_2147482340              1
# Apple_Half_C_2147482319              1
# PillsberryDoughGirl_C_2147482296     1
# PillsberryDoughBoy_C_2147482297      1
# Apple_Half_C_2147482317              1
# Apple_Half2_C_2147482330             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              18  210.106638                  5.0
# 1          Add butter             12   73.938904                  1.0
# 2          Add butter              2    2.438201                  0.0
# 3           Add water              1    5.416260                  0.0
# 4   Add apples to pan             57  127.739258                  2.0
# 5   Add apples to pan              2    1.436981                  0.0
# 6   Add apples to pan              2    1.214783                  0.0
# 7   Add apples to pan              2    1.299438                  0.0
# 8   Add apples to pan              2    1.171234                  0.0
# 9   Add apples to pan              2    1.001343                  0.0
# 10  Add apples to pan              4    5.900970                  0.0
# 11  Add apples to pan              2    1.899536                  0.0
# 12  Add apples to pan             36   73.955536                  1.0
# 13  Add apples to pan              2    2.368103                  0.0
# 14  Add apples to pan              2    2.031067                  0.0
# 15  Add apples to pan              2    2.198974                  0.0
# 16  Add apples to pan              2    1.400207                  0.0
# 17  Add apples to pan              2    1.298157                  0.0
# 18  Add apples to pan              2    1.301575                  0.0
# 19  Add apples to pan              2    1.199951                  0.0
# 20       Add cinnamon              4   15.170899                  2.0
# 21         Pour syrup              2   18.962769                  0.0
# 22          Stir bowl              6   50.131043                  1.0
# 23   Add bottom crust              2   15.576172                  0.0
# 24      Add crust top              6   22.741455                  2.0
# 25    Put pie in oven             24  199.065186                  4.0
# 26     Post last step              4   17.529785                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 204

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C028',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C028            204        858.494425                       18.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        7.555556   31.796090             0.666667
# std        12.759109   58.177875             1.300887
# min         1.000000    1.001343             0.000000
# 25%         2.000000    1.350891             0.000000
# 50%         2.000000    2.438201             0.000000
# 75%         5.000000   20.852112             1.000000
# max        57.000000  210.106638             5.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  227.417113
# 1         Add butter      2   76.377105
# 2         Add Sugar       1  210.106638
# 3          Add water      1    5.416260
# 4       Add cinnamon      1   15.170899
# 5         Pour syrup      1   18.962769
# 6          Stir bowl      1   50.131043
# 7   Add bottom crust      1   15.576172
# 8      Add crust top      1   22.741455
# 9    Put pie in oven      1  199.065186

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add butter             0                 2       4             2
# Add cinnamon           0                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 2       0             0
# Add water              0                 0       0             0
# Add apples to pan     91                 0       0             0
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                1        0
# Add butter                           0      0                1        0
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      0                0        0
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        2
# Add water                            0      0                0        0
# Add apples to pan                    0     12                0       12
# Pour syrup                           1      0                0        0
# Add bottom crust                     0      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   1                    0         0
# Put pie in oven        12                   0                    0         0
# Add water               0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   0                    1         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  UnecessaryLime  \
# Add Sugar                        8             0         2               0
# Add butter                       0             0         0               0
# Add cinnamon                     0             0         0               0
# Stir bowl                        2             1         0               0
# Add crust top                    0             0         0               0
# Put pie in oven                  0             0         0               0
# Add water                        0             0         0               0
# Add apples to pan                0             0         0               2
# Pour syrup                       0             0         0               0
# Add bottom crust                 0             1         0               0
#
#                    WaterPitcher  oven  Interacted Objects
# Add Sugar                     0     0                  13
# Add butter                    4     0                  13
# Add cinnamon                  0     0                   2
# Stir bowl                     0     0                   5
# Add crust top                 0     0                   4
# Put pie in oven               0     4                  20
# Add water                     1     0                   1
# Add apples to pan             3     0                 120
# Pour syrup                    0     0                   2
# Add bottom crust              0     0                   2

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        87
# Right Hand Released    54
# Chopped                31
# Left Hand Grab         17
# Left Hand Released     15
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          1.0
# Left Hand Released      0.0
# Right Hand Grab        17.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            87                       17.0
# 4  Right Hand Released            54                        0.0
# 0              Chopped            31                        0.0
# 1       Left Hand Grab            17                        1.0
# 2   Left Hand Released            15                        0.0
