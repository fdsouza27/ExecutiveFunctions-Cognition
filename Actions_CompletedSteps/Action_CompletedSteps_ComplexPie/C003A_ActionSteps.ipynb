# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C003 A/'
file_name = 'C003_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type             Interacted Object
# 0     40.555130     Right Hand Grab          ApplePieCookbook_C_0
# 1     52.393337     Right Hand Grab          ApplePieCookbook_C_0
# 2     64.114876      Left Hand Grab         SugarJar_C_2147482384
# 3     65.311211  Left Hand Released         SugarJar_C_2147482384
# 4     66.661186      Left Hand Grab  NewMeasuringCup_C_2147482389

# %%
df1.shape
# Out:
# (172, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    162
# 1     10
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 39     147.752640  Right Hand Grab               NaN                    1
# 43     156.027283  Right Hand Grab               NaN                    1
# 60     176.582413  Right Hand Grab               NaN                    1
# 119    256.088379  Right Hand Grab               NaN                    1
# 120    257.128113  Right Hand Grab               NaN                    1
# 124    286.706146  Right Hand Grab               NaN                    1
# 125    288.290833  Right Hand Grab               NaN                    1
# 156    408.188385  Right Hand Grab               NaN                    1
# 159    425.402985  Right Hand Grab               NaN                    1
# 163    439.203400  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type             Interacted Object  \
# 0     40.555130     Right Hand Grab          ApplePieCookbook_C_0
# 1     52.393337     Right Hand Grab          ApplePieCookbook_C_0
# 2     64.114876      Left Hand Grab         SugarJar_C_2147482384
# 3     65.311211  Left Hand Released         SugarJar_C_2147482384
# 4     66.661186      Left Hand Grab  NewMeasuringCup_C_2147482389
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C003 A/'
file_name = 'C003_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     71.752319         Add Sugar
# 1     80.057709          Add water
# 2    104.938232         Add butter
# 3    108.170227         Add butter
# 4    167.214493  Add apples to pan
# 5    184.654739  Add apples to pan
# 6    186.420486  Add apples to pan
# 7    189.885757  Add apples to pan
# 8    192.519516  Add apples to pan
# 9    201.583420  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (189, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       40.555130      Right Hand Grab          ApplePieCookbook_C_0
# 1       52.393337      Right Hand Grab          ApplePieCookbook_C_0
# 2       64.114876       Left Hand Grab         SugarJar_C_2147482384
# 3       65.311211   Left Hand Released         SugarJar_C_2147482384
# 4       66.661186       Left Hand Grab  NewMeasuringCup_C_2147482389
# 172     71.752319                  NaN                           NaN
# 5       74.032539   Left Hand Released  NewMeasuringCup_C_2147482389
# 6       76.458061      Right Hand Grab     WaterPitcher_C_2147482383
# 173     80.057709                  NaN                           NaN
# 7       85.942383  Right Hand Released     WaterPitcher_C_2147482383
# 8       96.910492       Left Hand Grab            StaticMeshActor_31
# 9      100.002861   Left Hand Released            StaticMeshActor_31
# 10     101.206329       Left Hand Grab     ButterHolder_C_2147482386
# 11     102.242561   Left Hand Released     ButterHolder_C_2147482386
# 12     103.073532       Left Hand Grab           Butter_C_2147482385
# 13     104.639000   Left Hand Released           Butter_C_2147482385
# 174    104.938232                  NaN                           NaN
# 14     106.308830       Left Hand Grab           Butter_C_2147482377
# 15     107.869019   Left Hand Released           Butter_C_2147482377
# 175    108.170227                  NaN                           NaN
# 16     118.637650      Right Hand Grab            StaticMeshActor_31
# 17     119.800316  Right Hand Released            StaticMeshActor_31
# 18     123.611458      Right Hand Grab            Apple_C_2147482406
# 19     124.521988  Right Hand Released            Apple_C_2147482406
# 20     125.259392      Right Hand Grab            Apple_C_2147482374
# 21     126.174225  Right Hand Released            Apple_C_2147482374
# 22     126.792793      Right Hand Grab            Apple_C_2147482373
# 23     128.241776  Right Hand Released            Apple_C_2147482373
# 24     129.266876      Right Hand Grab            Apple_C_2147482373
# 25     130.314774  Right Hand Released            Apple_C_2147482373
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 172                  NaN     Add Sugar
# 5                    0.0            NaN
# 6                    0.0            NaN
# 173                  NaN      Add water
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 174                  NaN     Add butter
# 14                   0.0            NaN
# 15                   0.0            NaN
# 175                  NaN     Add butter
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        70
# Right Hand Released    48
# Chopped                24
# Left Hand Grab         15
# Left Hand Released     15
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 172

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                           22
# PieBowl_C_2147482375                16
# PiePan_C_2147482380                 12
# StaticMeshActor_23                   8
# ApplePieCookbook_C_0                 7
# Apple_Slice4_C_2147482363            7
# StirSpoonPie_C_2147482382            6
# Apple_C_2147482373                   5
# Apple_Half2_C_2147482353             5
# oven_C_1                             4
# StaticMeshActor_31                   4
# PillsberryDoughBoy_C_2147482336      4
# PillsberryDoughGirl_C_2147482335     4
# Apple_Slice2_C_2147482343            3
# Apple_Slice3_C_2147482364            3
# Apple_Slice4_C_2147482355            3
# Apple_Slice_C_2147482358             3
# Apple_C_2147482374                   3
# Apple_C_2147482406                   3
# Apple_C_2147482409                   3
# Apple_Slice2_C_2147482361            2
# CinnyShakerGrabable_C_2147482387     2
# SaucePot_C_2147482388                2
# Apple_Slice3_C_2147482356            2
# Apple_Slice2_C_2147482357            2
# Apple_Slice_C_2147482362             2
# Apple_Slice4_C_2147482345            2
# StaticMeshActor_84                   2
# Butter_C_2147482385                  2
# ButterHolder_C_2147482386            2
# SugarJar_C_2147482384                2
# WaterPitcher_C_2147482383            2
# NewMeasuringCup_C_2147482389         2
# Butter_C_2147482377                  2
# Apple_Half_C_2147482370              1
# Apple_Half_C_2147482366              1
# Apple_Half_C_2147482354              1
# Apple_Half2_C_2147482367             1
# Apple_Half2_C_2147482365             1
# Apple_Slice4_C_2147482351            1
# Apple_Half_C_2147482368              1
# Apple_Half2_C_2147482369             1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               5   31.197189                  0.0
# 1           Add water              2    6.025170                  0.0
# 2          Add butter              7   18.995849                  0.0
# 3          Add butter              2    1.861397                  0.0
# 4   Add apples to pan             40   48.576843                  2.0
# 5   Add apples to pan             11   17.003784                  1.0
# 6   Add apples to pan              2    1.199539                  0.0
# 7   Add apples to pan              1    3.032775                  0.0
# 8   Add apples to pan              3    2.532669                  0.0
# 9   Add apples to pan              8    8.301468                  0.0
# 10  Add apples to pan             26   27.769012                  0.0
# 11  Add apples to pan             12   16.963424                  0.0
# 12       Add cinnamon              4    8.605255                  2.0
# 13         Pour syrup              4   41.206573                  2.0
# 14          Stir bowl              9   28.341126                  0.0
# 15   Add bottom crust              7   18.700104                  0.0
# 16      Add crust top              5    7.507629                  0.0
# 17    Put pie in oven             10   46.154480                  1.0
# 18     Post last step             14   28.377502                  2.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 172

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C003',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C003            172        362.351788                       10.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        9.052632   19.071147             0.526316
# std         9.507153   15.227749             0.841191
# min         1.000000    1.199539             0.000000
# 25%         3.500000    6.766400             0.000000
# 50%         7.000000   17.003784             0.000000
# 75%        10.500000   28.359314             1.000000
# max        40.000000   48.576843             2.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add cinnamon           0                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add water              0                 0       0             0
# Add butter             0                 0       4             2
# Add apples to pan     56                 0       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                1        0
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      0                0        2
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Add water                            0      0                1        0
# Add butter                           0      0                0        0
# Add apples to pan                    0     20                0       12
# Add bottom crust                     0      0                0        0
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   0                    2         0
# Put pie in oven         6                   0                    0         0
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add bottom crust        0                   4                    2         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add cinnamon                     0             0         0             0
# Stir bowl                        2             3         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add water                        0             0         0             1
# Add butter                       2             0         0             1
# Add apples to pan               10             2         0             0
# Add bottom crust                 0             1         0             0
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   5
# Add cinnamon          0                   2
# Stir bowl             0                   9
# Add crust top         0                   5
# Put pie in oven       2                   9
# Add water             0                   2
# Add butter            0                   9
# Add apples to pan     0                 100
# Add bottom crust      0                   7
# Pour syrup            0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8  125.379514
# 1         Add butter      2   20.857246
# 2         Add Sugar       1   31.197189
# 3          Add water      1    6.025170
# 4       Add cinnamon      1    8.605255
# 5         Pour syrup      1   41.206573
# 6          Stir bowl      1   28.341126
# 7   Add bottom crust      1   18.700104
# 8      Add crust top      1    7.507629
# 9    Put pie in oven      1   46.154480

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        70
# Right Hand Released    48
# Chopped                24
# Left Hand Grab         15
# Left Hand Released     15
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          0.0
# Left Hand Released      0.0
# Right Hand Grab        10.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            70                       10.0
# 4  Right Hand Released            48                        0.0
# 0              Chopped            24                        0.0
# 1       Left Hand Grab            15                        0.0
# 2   Left Hand Released            15                        0.0
