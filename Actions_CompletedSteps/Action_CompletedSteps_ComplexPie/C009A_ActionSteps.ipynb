# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C009 A/'
file_name = 'C009_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type          Interacted Object
# 0      7.245441      Right Hand Grab       ApplePieCookbook_C_0
# 1     25.269350      Right Hand Grab       ApplePieCookbook_C_0
# 2     31.977760      Right Hand Grab      SugarJar_C_2147482372
# 3     34.503105  Right Hand Released      SugarJar_C_2147482372
# 4     38.653286      Right Hand Grab  WaterPitcher_C_2147482371

# %%
df1.shape
# Out:
# (198, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    196
# 1      2
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 58     219.928436  Right Hand Grab               NaN                    1
# 193    505.087524  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type          Interacted Object  \
# 0      7.245441      Right Hand Grab       ApplePieCookbook_C_0
# 1     25.269350      Right Hand Grab       ApplePieCookbook_C_0
# 2     31.977760      Right Hand Grab      SugarJar_C_2147482372
# 3     34.503105  Right Hand Released      SugarJar_C_2147482372
# 4     38.653286      Right Hand Grab  WaterPitcher_C_2147482371
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C009 A/'
file_name = 'C009_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    111.911964         Add Sugar
# 1    126.883026          Add water
# 2    166.994873         Add butter
# 3    171.810074         Add butter
# 4    206.102890  Add apples to pan
# 5    212.490417  Add apples to pan
# 6    218.129364  Add apples to pan
# 7    263.125671  Add apples to pan
# 8    265.351654  Add apples to pan
# 9    275.948181  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (223, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0        7.245441      Right Hand Grab          ApplePieCookbook_C_0
# 1       25.269350      Right Hand Grab          ApplePieCookbook_C_0
# 2       31.977760      Right Hand Grab         SugarJar_C_2147482372
# 3       34.503105  Right Hand Released         SugarJar_C_2147482372
# 4       38.653286      Right Hand Grab     WaterPitcher_C_2147482371
# 5       39.768280  Right Hand Released     WaterPitcher_C_2147482371
# 6       52.550171      Right Hand Grab            StaticMeshActor_31
# 7       54.602020  Right Hand Released            StaticMeshActor_31
# 8       55.757069      Right Hand Grab  NewMeasuringCup_C_2147482377
# 9       63.234276  Right Hand Released  NewMeasuringCup_C_2147482377
# 10      91.419289      Right Hand Grab  NewMeasuringCup_C_2147482377
# 198    111.911964                  NaN                           NaN
# 11     113.650520  Right Hand Released  NewMeasuringCup_C_2147482377
# 12     119.434814      Right Hand Grab     WaterPitcher_C_2147482371
# 199    126.883026                  NaN                           NaN
# 13     131.890823  Right Hand Released     WaterPitcher_C_2147482371
# 14     132.380447      Right Hand Grab            StaticMeshActor_84
# 15     133.964294  Right Hand Released            StaticMeshActor_84
# 16     134.631775      Right Hand Grab     WaterPitcher_C_2147482371
# 17     135.927750  Right Hand Released     WaterPitcher_C_2147482371
# 18     136.994736      Right Hand Grab     WaterPitcher_C_2147482371
# 19     139.573959  Right Hand Released     WaterPitcher_C_2147482371
# 20     152.842087      Right Hand Grab            StaticMeshActor_31
# 21     153.672058  Right Hand Released            StaticMeshActor_31
# 22     154.708618      Right Hand Grab         SugarJar_C_2147482372
# 23     157.742722  Right Hand Released         SugarJar_C_2147482372
# 24     159.471466      Right Hand Grab     ButterHolder_C_2147482374
# 25     160.879486  Right Hand Released     ButterHolder_C_2147482374
# 26     162.077911      Right Hand Grab     ButterHolder_C_2147482374
# 27     163.080627  Right Hand Released     ButterHolder_C_2147482374
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 198                  NaN     Add Sugar
# 11                   0.0            NaN
# 12                   0.0            NaN
# 199                  NaN      Add water
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        89
# Right Hand Released    74
# Chopped                21
# Left Hand Grab          7
# Left Hand Released      7
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 198

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482361                  16
# WaterPitcher_C_2147482371             14
# Knife_C_1                             14
# SaucePot_C_2147482376                 12
# StaticMeshActor_23                    10
# ApplePieCookbook_C_0                   7
# StaticMeshActor_31                     6
# ButterHolder_C_2147482374              6
# StirSpoonPie_C_2147482370              6
# Apple_Slice4_C_2147482347              5
# Apple_Half_C_2147482352                4
# PillsberryDoughBoy_C_2147482317        4
# oven_C_1                               4
# Apple_Slice3_C_2147482328              4
# SugarJar_C_2147482372                  4
# CinnyShakerGrabable_C_2147482375       4
# Apple_Slice3_C_2147482321              4
# PiePan_C_2147482368                    4
# Apple_Slice_C_2147482355               4
# NewMeasuringCup_C_2147482377           4
# Apple_C_2147482342                     3
# Apple_C_2147482394                     3
# Apple_C_2147482395                     3
# Apple_C_2147482335                     3
# Apple_C_2147482360                     3
# Apple_Slice2_C_2147482345              3
# Apple_Slice_C_2147482346               2
# Apple_Half2_C_2147482331               2
# StaticMeshActor_84                     2
# Butter_C_2147482373                    2
# UnecessaryPomegranate_C_2147482378     2
# Apple_Slice4_C_2147482356              2
# Apple_Slice2_C_2147482354              2
# Apple_Slice4_C_2147482327              2
# Apple_Slice_C_2147482330               2
# Apple_Slice2_C_2147482329              2
# Apple_Slice3_C_2147482348              2
# Apple_Slice4_C_2147482336              2
# Apple_Slice3_C_2147482337              2
# Apple_Slice2_C_2147482338              2
# Apple_Slice_C_2147482339               2
# Apple_Half2_C_2147482340               2
# Apple_Slice3_C_2147482357              2
# Apple_Half_C_2147482332                1
# Apple_Half_C_2147482359                1
# Apple_Half2_C_2147482358               1
# Apple_Half2_C_2147482322               1
# Butter_C_2147482363                    1
# Apple_Half_C_2147482341                1
# PillsberryDoughGirl_C_2147482316       1
# Apple_Half2_C_2147482351               1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              11  104.666523                  0.0
# 1           Add water              2   13.232506                  0.0
# 2          Add butter             17   35.104050                  0.0
# 3          Add butter              3    3.508011                  0.0
# 4   Add apples to pan             17   29.507217                  0.0
# 5   Add apples to pan              6    5.787689                  0.0
# 6   Add apples to pan              2    2.232758                  0.0
# 7   Add apples to pan             29   43.197235                  1.0
# 8   Add apples to pan              1    1.363647                  0.0
# 9   Add apples to pan              7   10.396393                  0.0
# 10  Add apples to pan              2    1.339631                  0.0
# 11  Add apples to pan             10   13.016266                  0.0
# 12  Add apples to pan              2    1.095794                  0.0
# 13  Add apples to pan              4    5.059906                  0.0
# 14  Add apples to pan              2    1.032989                  0.0
# 15  Add apples to pan             12   15.796112                  0.0
# 16  Add apples to pan              2    0.929596                  0.0
# 17  Add apples to pan              4    1.330262                  0.0
# 18  Add apples to pan              2    1.533478                  0.0
# 19  Add apples to pan             12   18.817810                  0.0
# 20       Add cinnamon              4   11.566071                  0.0
# 21         Pour syrup              3   11.191041                  0.0
# 22          Stir bowl             17   36.298431                  0.0
# 23   Add bottom crust              5   17.494324                  0.0
# 24      Add crust top              9   17.157135                  0.0
# 25    Put pie in oven              5   21.599487                  0.0
# 26     Post last step              8   14.171051                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 198

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C009',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C009            198        438.425413                        2.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        7.333333   16.237978             0.074074
# std         6.621643   21.297172             0.266880
# min         1.000000    0.929596             0.000000
# 25%         2.000000    1.883118             0.000000
# 50%         5.000000   11.566071             0.000000
# 75%        10.500000   18.156067             0.000000
# max        29.000000  104.666523             1.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  152.436783
# 1         Add butter      2   38.612061
# 2         Add Sugar       1  104.666523
# 3          Add water      1   13.232506
# 4       Add cinnamon      1   11.566071
# 5         Pour syrup      1   11.191041
# 6          Stir bowl      1   36.298431
# 7   Add bottom crust      1   17.494324
# 8      Add crust top      1   17.157135
# 9    Put pie in oven      1   21.599487

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                 0       0             0
# Add cinnamon           0                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add butter             0                 0       3             6
# Add apples to pan     73                 0       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                3        0
# Add water                            0      0                1        0
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      0                0        1
# Add crust top                        0      0                0        4
# Put pie in oven                      0      0                0        0
# Add butter                           0      0                0        0
# Add apples to pan                    2     14                0        6
# Add bottom crust                     0      0                0        3
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0        10
# Add crust top           0                   4                    0         0
# Put pie in oven         2                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add bottom crust        0                   0                    1         0
# Pour syrup              0                   0                    0         2
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  \
# Add Sugar                        2             0         2
# Add water                        0             0         0
# Add cinnamon                     0             0         0
# Stir bowl                        2             3         0
# Add crust top                    0             0         0
# Put pie in oven                  0             0         0
# Add butter                       4             0         2
# Add apples to pan               10             2         0
# Add bottom crust                 0             1         0
# Pour syrup                       0             0         0
#
#                    UnecessaryPomegranate  WaterPitcher  oven  \
# Add Sugar                              0             2     0
# Add water                              0             1     0
# Add cinnamon                           2             0     0
# Stir bowl                              0             0     0
# Add crust top                          0             0     0
# Put pie in oven                        0             0     2
# Add butter                             0             5     0
# Add apples to pan                      0             6     0
# Add bottom crust                       0             0     0
# Pour syrup                             0             0     0
#
#                    Interacted Objects
# Add Sugar                          11
# Add water                           2
# Add cinnamon                        4
# Stir bowl                          17
# Add crust top                       9
# Put pie in oven                     5
# Add butter                         20
# Add apples to pan                 113
# Add bottom crust                    5
# Pour syrup                          3

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        89
# Right Hand Released    74
# Chopped                21
# Left Hand Grab          7
# Left Hand Released      7
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         0.0
# Left Hand Released     0.0
# Right Hand Grab        2.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            89                        2.0
# 4  Right Hand Released            74                        0.0
# 0              Chopped            21                        0.0
# 1       Left Hand Grab             7                        0.0
# 2   Left Hand Released             7                        0.0
