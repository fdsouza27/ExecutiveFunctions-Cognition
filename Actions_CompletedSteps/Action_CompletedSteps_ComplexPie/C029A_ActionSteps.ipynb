# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C029 A/'
file_name = 'C029_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object
# 0     23.728117      Right Hand Grab          ApplePieCookbook_C_0
# 1     34.069511      Right Hand Grab          ApplePieCookbook_C_0
# 2     46.021538      Right Hand Grab     WaterPitcher_C_2147482383
# 3     55.342896  Right Hand Released     WaterPitcher_C_2147482383
# 4     59.194679       Left Hand Grab  NewMeasuringCup_C_2147482389

# %%
df1.shape
# Out:
# (142, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    136
# 1      6
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 14      87.396744  Right Hand Grab               NaN                    1
# 15      89.262543  Right Hand Grab               NaN                    1
# 20      94.660591   Left Hand Grab               NaN                    1
# 25     133.624481   Left Hand Grab               NaN                    1
# 26     157.898880   Left Hand Grab               NaN                    1
# 122    364.862091  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object  \
# 0     23.728117      Right Hand Grab          ApplePieCookbook_C_0
# 1     34.069511      Right Hand Grab          ApplePieCookbook_C_0
# 2     46.021538      Right Hand Grab     WaterPitcher_C_2147482383
# 3     55.342896  Right Hand Released     WaterPitcher_C_2147482383
# 4     59.194679       Left Hand Grab  NewMeasuringCup_C_2147482389
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C029 A/'
file_name = 'C029_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     52.216682          Add water
# 1    187.178589         Add Sugar
# 2    201.921478         Add butter
# 3    206.553406         Add butter
# 4    237.198868  Add apples to pan
# 5    239.093613  Add apples to pan
# 6    247.566727  Add apples to pan
# 7    249.763916  Add apples to pan
# 8    267.315369  Add apples to pan
# 9    269.844788  Add apples to pan

# %%
df2.shape
# Out:
# (14, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (155, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       23.728117      Right Hand Grab          ApplePieCookbook_C_0
# 1       34.069511      Right Hand Grab          ApplePieCookbook_C_0
# 2       46.021538      Right Hand Grab     WaterPitcher_C_2147482383
# 142     52.216682                  NaN                           NaN
# 3       55.342896  Right Hand Released     WaterPitcher_C_2147482383
# 4       59.194679       Left Hand Grab  NewMeasuringCup_C_2147482389
# 5       62.991528   Left Hand Released  NewMeasuringCup_C_2147482389
# 6       63.859840       Left Hand Grab         SugarJar_C_2147482384
# 7       65.687859   Left Hand Released         SugarJar_C_2147482384
# 8       69.226837      Right Hand Grab            StaticMeshActor_31
# 9       70.297714  Right Hand Released            StaticMeshActor_31
# 10      71.030785      Right Hand Grab  NewMeasuringCup_C_2147482389
# 11      74.436790  Right Hand Released  NewMeasuringCup_C_2147482389
# 12      75.301758      Right Hand Grab  NewMeasuringCup_C_2147482389
# 13      85.832870  Right Hand Released  NewMeasuringCup_C_2147482389
# 14      87.396744      Right Hand Grab                           NaN
# 15      89.262543      Right Hand Grab                           NaN
# 16      90.797623      Right Hand Grab  NewMeasuringCup_C_2147482389
# 17      91.660454  Right Hand Released  NewMeasuringCup_C_2147482389
# 18      93.030037       Left Hand Grab  NewMeasuringCup_C_2147482389
# 19      94.261391   Left Hand Released  NewMeasuringCup_C_2147482389
# 20      94.660591       Left Hand Grab                           NaN
# 21     100.692047       Left Hand Grab  NewMeasuringCup_C_2147482389
# 22     112.552040   Left Hand Released  NewMeasuringCup_C_2147482389
# 23     119.592987       Left Hand Grab  NewMeasuringCup_C_2147482389
# 24     120.988441   Left Hand Released  NewMeasuringCup_C_2147482389
# 25     133.624481       Left Hand Grab                           NaN
# 26     157.898880       Left Hand Grab                           NaN
# 27     158.930893      Right Hand Grab         SugarJar_C_2147482384
# 28     160.879578  Right Hand Released         SugarJar_C_2147482384
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 142                  NaN      Add water
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   1.0            NaN
# 15                   1.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   1.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   1.0            NaN
# 26                   1.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        47
# Right Hand Released    40
# Left Hand Grab         24
# Left Hand Released     20
# Chopped                11
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 142

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482371                22
# NewMeasuringCup_C_2147482389        20
# SugarJar_C_2147482384               12
# StaticMeshActor_84                  10
# Knife_C_1                           10
# StirSpoonPie_C_2147482382           10
# ApplePieCookbook_C_0                 4
# Apple_C_2147482370                   3
# Apple_Slice3_C_2147482365            3
# Apple_Slice4_C_2147482364            3
# Apple_Slice3_C_2147482358            3
# Apple_Slice4_C_2147482357            3
# Apple_C_2147482406                   3
# Apple_Slice_C_2147482363             2
# StaticMeshActor_23                   2
# SaucePot_C_2147482388                2
# CinnyShakerGrabable_C_2147482387     2
# Apple_Slice_C_2147482356             2
# Apple_Slice2_C_2147482355            2
# StaticMeshActor_118                  2
# Apple_Slice2_C_2147482362            2
# WaterPitcher_C_2147482383            2
# Apple_Half2_C_2147482366             2
# StaticMeshActor_31                   2
# ButterHolder_C_2147482386            2
# Butter_C_2147482385                  2
# Apple_Half2_C_2147482359             1
# Apple_Half_C_2147482367              1
# Apple_Half_C_2147482360              1
# Butter_C_2147482373                  1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add water            1
# Add Sugar            1
# Add cinnamon         1
# Pour syrup           1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0           Add water              3   28.488565                  0.0
# 1          Add Sugar              35  131.835693                  5.0
# 2          Add butter              5    8.961380                  0.0
# 3          Add butter              1    1.844864                  0.0
# 4   Add apples to pan             21   23.153412                  0.0
# 5   Add apples to pan              2    0.997132                  0.0
# 6   Add apples to pan              8    7.543701                  0.0
# 7   Add apples to pan              2    2.163467                  0.0
# 8   Add apples to pan             14   17.484391                  0.0
# 9   Add apples to pan              2    1.433228                  0.0
# 10  Add apples to pan              6    7.299347                  0.0
# 11  Add apples to pan              4    4.181427                  0.0
# 12       Add cinnamon              6   12.521698                  0.0
# 13         Pour syrup              2    9.396606                  0.0
# 14     Post last step             31   91.550232                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 142

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C029',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C029            142        348.855143                        6.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      15.000000   15.000000            15.000000
# mean        9.466667   23.257010             0.400000
# std        10.960101   37.575021             1.298351
# min         1.000000    0.997132             0.000000
# 25%         2.000000    3.172447             0.000000
# 50%         5.000000    8.961380             0.000000
# 75%        11.000000   20.318901             0.000000
# max        35.000000  131.835693             5.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   64.256105
# 1         Add butter      2   10.806244
# 2          Add water      1   28.488565
# 3         Add Sugar       1  131.835693
# 4       Add cinnamon      1   12.521698
# 5         Pour syrup      1    9.396606

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add water              0                 2       0             0
# Add cinnamon           0                 1       0             0
# Add Sugar              0                 0       0             0
# Add butter             0                 0       3             2
# Add apples to pan     31                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add water                            0      0                0        0
# Add cinnamon                         1      0                0        4
# Add Sugar                            0      0               19        0
# Add butter                           0      0                1        0
# Add apples to pan                    0     10                0        6
# Pour syrup                           1      0                0        0
#
#                    SaucePot  StaticMeshActor  StirSpoonPie  SugarJar  \
# Add water                 0                0             0         0
# Add cinnamon              0                0             0         0
# Add Sugar                 0                2             0         8
# Add butter                0                0             0         0
# Add apples to pan         0                4             4         4
# Pour syrup                1                0             0         0
#
#                    WaterPitcher  Interacted Objects
# Add water                     1                   3
# Add cinnamon                  0                   6
# Add Sugar                     1                  30
# Add butter                    0                   6
# Add apples to pan             0                  59
# Pour syrup                    0                   2

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        47
# Right Hand Released    40
# Left Hand Grab         24
# Left Hand Released     20
# Chopped                11
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         3.0
# Left Hand Released     0.0
# Right Hand Grab        3.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            47                        3.0
# 4  Right Hand Released            40                        0.0
# 1       Left Hand Grab            24                        3.0
# 2   Left Hand Released            20                        0.0
# 0              Chopped            11                        0.0
