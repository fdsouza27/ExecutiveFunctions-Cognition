# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C001 A/'
file_name = 'C001_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type                 Interacted Object
# 0     10.901902      Right Hand Grab              ApplePieCookbook_C_0
# 1     23.811054      Right Hand Grab              ApplePieCookbook_C_0
# 2     28.716713      Right Hand Grab  CinnyShakerGrabable_C_2147482387
# 3     52.664757  Right Hand Released  CinnyShakerGrabable_C_2147482387
# 4     57.375877      Right Hand Grab      NewMeasuringCup_C_2147482389

# %%
df1.shape
# Out:
# (171, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    161
# 1     10
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 18     101.840286  Right Hand Grab               NaN                    1
# 19     108.474449   Left Hand Grab               NaN                    1
# 20     108.507584  Right Hand Grab               NaN                    1
# 21     109.944252  Right Hand Grab               NaN                    1
# 159    336.273163  Right Hand Grab               NaN                    1
# 162    343.120422  Right Hand Grab               NaN                    1
# 163    344.035309  Right Hand Grab               NaN                    1
# 164    344.679199  Right Hand Grab               NaN                    1
# 165    345.280121  Right Hand Grab               NaN                    1
# 168    359.960876  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type                 Interacted Object  \
# 0     10.901902      Right Hand Grab              ApplePieCookbook_C_0
# 1     23.811054      Right Hand Grab              ApplePieCookbook_C_0
# 2     28.716713      Right Hand Grab  CinnyShakerGrabable_C_2147482387
# 3     52.664757  Right Hand Released  CinnyShakerGrabable_C_2147482387
# 4     57.375877      Right Hand Grab      NewMeasuringCup_C_2147482389
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C001 A/'
file_name = 'C001_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     66.886040         Add Sugar
# 1     75.193596          Add water
# 2    131.437195         Add butter
# 3    134.539017         Add butter
# 4    200.600174  Add apples to pan
# 5    202.908615  Add apples to pan
# 6    206.515823  Add apples to pan
# 7    209.115768  Add apples to pan
# 8    209.713699  Add apples to pan
# 9    212.337479  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                 Interacted Object  \
# 0      10.901902      Right Hand Grab              ApplePieCookbook_C_0
# 1      23.811054      Right Hand Grab              ApplePieCookbook_C_0
# 2      28.716713      Right Hand Grab  CinnyShakerGrabable_C_2147482387
# 3      52.664757  Right Hand Released  CinnyShakerGrabable_C_2147482387
# 4      57.375877      Right Hand Grab      NewMeasuringCup_C_2147482389
# 5      57.886059  Right Hand Released      NewMeasuringCup_C_2147482389
# 6      58.529934      Right Hand Grab             SugarJar_C_2147482384
# 7      59.595268  Right Hand Released             SugarJar_C_2147482384
# 8      60.347271      Right Hand Grab                StaticMeshActor_31
# 9      60.859337  Right Hand Released                StaticMeshActor_31
# 10     61.594402      Right Hand Grab      NewMeasuringCup_C_2147482389
# 11     66.618767  Right Hand Released      NewMeasuringCup_C_2147482389
# 12     67.708466      Right Hand Grab      NewMeasuringCup_C_2147482389
# 13     70.201225  Right Hand Released      NewMeasuringCup_C_2147482389
# 14     73.104141      Right Hand Grab         WaterPitcher_C_2147482383
# 15     78.992149  Right Hand Released         WaterPitcher_C_2147482383
# 16     98.850914      Right Hand Grab      NewMeasuringCup_C_2147482389
# 17    101.176483  Right Hand Released      NewMeasuringCup_C_2147482389
# 18    101.840286      Right Hand Grab                               NaN
# 19    108.474449       Left Hand Grab                               NaN
# 20    108.507584      Right Hand Grab                               NaN
# 21    109.944252      Right Hand Grab                               NaN
# 22    116.646851      Right Hand Grab         WaterPitcher_C_2147482383
# 23    117.938850  Right Hand Released         WaterPitcher_C_2147482383
# 24    123.808304       Left Hand Grab      NewMeasuringCup_C_2147482389
# 25    124.704239   Left Hand Released      NewMeasuringCup_C_2147482389
# 26    125.568932      Right Hand Grab         ButterHolder_C_2147482386
# 27    127.063889  Right Hand Released         ButterHolder_C_2147482386
# 28    127.966789      Right Hand Grab               Butter_C_2147482385
# 29    131.269547  Right Hand Released               Butter_C_2147482385
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  1.0            NaN
# 19                  1.0            NaN
# 20                  1.0            NaN
# 21                  1.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (187, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                 Interacted Object  \
# 0       10.901902      Right Hand Grab              ApplePieCookbook_C_0
# 1       23.811054      Right Hand Grab              ApplePieCookbook_C_0
# 2       28.716713      Right Hand Grab  CinnyShakerGrabable_C_2147482387
# 3       52.664757  Right Hand Released  CinnyShakerGrabable_C_2147482387
# 4       57.375877      Right Hand Grab      NewMeasuringCup_C_2147482389
# 5       57.886059  Right Hand Released      NewMeasuringCup_C_2147482389
# 6       58.529934      Right Hand Grab             SugarJar_C_2147482384
# 7       59.595268  Right Hand Released             SugarJar_C_2147482384
# 8       60.347271      Right Hand Grab                StaticMeshActor_31
# 9       60.859337  Right Hand Released                StaticMeshActor_31
# 10      61.594402      Right Hand Grab      NewMeasuringCup_C_2147482389
# 11      66.618767  Right Hand Released      NewMeasuringCup_C_2147482389
# 171     66.886040                  NaN                               NaN
# 12      67.708466      Right Hand Grab      NewMeasuringCup_C_2147482389
# 13      70.201225  Right Hand Released      NewMeasuringCup_C_2147482389
# 14      73.104141      Right Hand Grab         WaterPitcher_C_2147482383
# 172     75.193596                  NaN                               NaN
# 15      78.992149  Right Hand Released         WaterPitcher_C_2147482383
# 16      98.850914      Right Hand Grab      NewMeasuringCup_C_2147482389
# 17     101.176483  Right Hand Released      NewMeasuringCup_C_2147482389
# 18     101.840286      Right Hand Grab                               NaN
# 19     108.474449       Left Hand Grab                               NaN
# 20     108.507584      Right Hand Grab                               NaN
# 21     109.944252      Right Hand Grab                               NaN
# 22     116.646851      Right Hand Grab         WaterPitcher_C_2147482383
# 23     117.938850  Right Hand Released         WaterPitcher_C_2147482383
# 24     123.808304       Left Hand Grab      NewMeasuringCup_C_2147482389
# 25     124.704239   Left Hand Released      NewMeasuringCup_C_2147482389
# 26     125.568932      Right Hand Grab         ButterHolder_C_2147482386
# 27     127.063889  Right Hand Released         ButterHolder_C_2147482386
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 171                  NaN     Add Sugar
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 172                  NaN      Add water
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   1.0            NaN
# 20                   1.0            NaN
# 21                   1.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        72
# Right Hand Released    51
# Chopped                21
# Left Hand Grab         14
# Left Hand Released     13
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     34.200000
# std      26.185874
# min      13.000000
# 25%      14.000000
# 50%      21.000000
# 75%      51.000000
# max      72.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 171

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# NewMeasuringCup_C_2147482389        16
# PieBowl_C_2147482375                12
# Knife_C_1                           12
# ApplePieCookbook_C_0                 6
# StaticMeshActor_23                   6
# StirSpoonPie_C_2147482382            6
# Apple_Slice3_C_2147482369            5
# Apple_Slice2_C_2147482356            4
# Apple_Slice3_C_2147482364            4
# Apple_Slice4_C_2147482363            4
# CinnyShakerGrabable_C_2147482387     4
# StaticMeshActor_84                   4
# PiePan_C_2147482380                  4
# WaterPitcher_C_2147482383            4
# ButterHolder_C_2147482386            4
# Apple_C_2147482360                   3
# Apple_Slice4_C_2147482347            3
# Apple_C_2147482409                   3
# oven_C_1                             3
# Apple_C_2147482405                   3
# Apple_Slice4_C_2147482368            3
# Apple_C_2147482372                   3
# Apple_Slice3_C_2147482348            3
# Apple_Half_C_2147482371              2
# Apple_Slice_C_2147482346             2
# Apple_Slice4_C_2147482354            2
# SugarJar_C_2147482384                2
# Apple_Slice_C_2147482357             2
# Apple_Slice3_C_2147482355            2
# Butter_C_2147482376                  2
# Butter_C_2147482344                  2
# SaucePot_C_2147482388                2
# Apple_Slice2_C_2147482345            2
# Apple_Half2_C_2147482370             2
# Apple_Slice_C_2147482362             2
# StaticMeshActor_31                   2
# Apple_Half2_C_2147482349             2
# Butter_C_2147482385                  2
# Apple_Half2_C_2147482358             2
# Apple_Half2_C_2147482365             2
# Apple_Slice2_C_2147482361            2
# Apple_Half_C_2147482350              1
# Apple_Half_C_2147482359              1
# Apple_Half_C_2147482366              1
# PillsberryDoughGirl_C_2147482336     1
# PillsberryDoughBoy_C_2147482337      1
# Butter_C_2147482377                  1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 161

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              12   55.984138                  0.0
# 1           Add water              3    7.485130                  0.0
# 2          Add butter             15   52.445046                  4.0
# 3          Add butter              1    2.405838                  0.0
# 4   Add apples to pan             59   58.849884                  0.0
# 5   Add apples to pan              2    1.341446                  0.0
# 6   Add apples to pan              4    2.673172                  0.0
# 7   Add apples to pan              2    1.466400                  0.0
# 8   Add apples to pan              2    0.263717                  0.0
# 9   Add apples to pan              3    1.460755                  0.0
# 10  Add apples to pan              1    0.133408                  0.0
# 11  Add apples to pan              2    1.434219                  0.0
# 12       Add cinnamon             26   33.037109                  0.0
# 13         Pour syrup              2   13.074173                  0.0
# 14          Stir bowl             11   28.208069                  0.0
# 15   Add bottom crust              2   10.883575                  0.0
# 16      Add crust top             10   12.837036                  0.0
# 17    Put pie in oven             10   29.308258                  5.0
# 18     Post last step              4    6.265198                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 171

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C001',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C001            171        319.556571                       10.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        9.000000   16.818767             0.526316
# std        13.711309   20.124895             1.428613
# min         1.000000    0.133408             0.000000
# 25%         2.000000    1.463577             0.000000
# 50%         3.000000    7.485130             0.000000
# 75%        10.500000   28.758164             0.000000
# max        59.000000   58.849884             5.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                 0       0             0
# Add butter             0                 0       3             2
# Add apples to pan     49                 0       0             0
# Add cinnamon          16                 1       4             0
# Add crust top          0                 1       0             2
# Stir bowl              0                 1       0             0
# Put pie in oven        0                 1       0             0
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            2      0                4        0
# Add water                            0      0                2        0
# Add butter                           0      0                4        0
# Add apples to pan                    0     10                2        2
# Add cinnamon                         1      0                2        2
# Add crust top                        0      0                2        4
# Stir bowl                            0      2                0        4
# Put pie in oven                      0      0                0        0
# Pour syrup                           1      0                0        0
# Add bottom crust                     0      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Add crust top           0                   1                    0         0
# Stir bowl               0                   0                    0         1
# Put pie in oven         2                   0                    0         0
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   0                    1         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        2             0         2             0
# Add water                        0             0         0             1
# Add butter                       0             0         0             3
# Add apples to pan               10             2         0             0
# Add cinnamon                     0             0         0             0
# Add crust top                    0             0         0             0
# Stir bowl                        0             3         0             0
# Put pie in oven                  0             0         0             0
# Pour syrup                       0             0         0             0
# Add bottom crust                 0             1         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                  12
# Add water             0                   3
# Add butter            0                  12
# Add apples to pan     0                  75
# Add cinnamon          0                  26
# Add crust top         0                  10
# Stir bowl             0                  11
# Put pie in oven       2                   5
# Pour syrup            0                   2
# Add bottom crust      0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   67.623001
# 1         Add butter      2   54.850884
# 2         Add Sugar       1   55.984138
# 3          Add water      1    7.485130
# 4       Add cinnamon      1   33.037109
# 5         Pour syrup      1   13.074173
# 6          Stir bowl      1   28.208069
# 7   Add bottom crust      1   10.883575
# 8      Add crust top      1   12.837036
# 9    Put pie in oven      1   29.308258

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                 Interacted Object  \
# 0       10.901902      Right Hand Grab              ApplePieCookbook_C_0
# 1       23.811054      Right Hand Grab              ApplePieCookbook_C_0
# 2       28.716713      Right Hand Grab  CinnyShakerGrabable_C_2147482387
# 3       52.664757  Right Hand Released  CinnyShakerGrabable_C_2147482387
# 4       57.375877      Right Hand Grab      NewMeasuringCup_C_2147482389
# ..            ...                  ...                               ...
# 182    357.205017                  NaN                               NaN
# 183    358.492767      Right Hand Grab                          oven_C_1
# 184    359.960876      Right Hand Grab                               NaN
# 185    361.008209      Right Hand Grab               PiePan_C_2147482380
# 186    364.757965  Right Hand Released               PiePan_C_2147482380
#
#      Missed Interactions   Completed Step
# 0                    0.0              NaN
# 1                    0.0              NaN
# 2                    0.0              NaN
# 3                    0.0              NaN
# 4                    0.0              NaN
# ..                   ...              ...
# 182                  NaN  Put pie in oven
# 183                  0.0              NaN
# 184                  1.0              NaN
# 185                  0.0              NaN
# 186                  0.0              NaN
#
# [187 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        72
# Right Hand Released    51
# Chopped                21
# Left Hand Grab         14
# Left Hand Released     13
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        9.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            72                        9.0
# 4  Right Hand Released            51                        0.0
# 0              Chopped            21                        0.0
# 1       Left Hand Grab            14                        1.0
# 2   Left Hand Released            13                        0.0
