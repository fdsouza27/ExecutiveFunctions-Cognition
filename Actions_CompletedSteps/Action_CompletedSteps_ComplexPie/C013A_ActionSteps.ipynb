# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C013 A/'
file_name = 'C013_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type             Interacted Object
# 0     12.712020     Right Hand Grab          ApplePieCookbook_C_0
# 1     49.602230      Left Hand Grab                           NaN
# 2     51.764648      Left Hand Grab          ApplePieCookbook_C_0
# 3     59.627254      Left Hand Grab  NewMeasuringCup_C_2147482377
# 4     62.200829  Left Hand Released  NewMeasuringCup_C_2147482377

# %%
df1.shape
# Out:
# (266, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    244
# 1     22
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       49.602230   Left Hand Grab               NaN                    1
# 42     141.106247  Right Hand Grab               NaN                    1
# 134    278.592926   Left Hand Grab               NaN                    1
# 166    328.485352  Right Hand Grab               NaN                    1
# 185    359.625000  Right Hand Grab               NaN                    1
# 200    379.594391  Right Hand Grab               NaN                    1
# 201    381.463989  Right Hand Grab               NaN                    1
# 207    396.612183   Left Hand Grab               NaN                    1
# 218    436.338898  Right Hand Grab               NaN                    1
# 219    437.933929  Right Hand Grab               NaN                    1
# 220    439.384979  Right Hand Grab               NaN                    1
# 221    441.939148  Right Hand Grab               NaN                    1
# 222    446.247650   Left Hand Grab               NaN                    1
# 241    538.931396  Right Hand Grab               NaN                    1
# 243    546.639221   Left Hand Grab               NaN                    1
# 248    565.767334  Right Hand Grab               NaN                    1
# 249    600.124939   Left Hand Grab               NaN                    1
# 250    601.256226   Left Hand Grab               NaN                    1
# 258    626.496460  Right Hand Grab               NaN                    1
# 262    638.284546  Right Hand Grab               NaN                    1
# 263    644.114563  Right Hand Grab               NaN                    1
# 264    644.780090  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type             Interacted Object  \
# 0     12.712020     Right Hand Grab          ApplePieCookbook_C_0
# 1     49.602230      Left Hand Grab                           NaN
# 2     51.764648      Left Hand Grab          ApplePieCookbook_C_0
# 3     59.627254      Left Hand Grab  NewMeasuringCup_C_2147482377
# 4     62.200829  Left Hand Released  NewMeasuringCup_C_2147482377
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C013 A/'
file_name = 'C013_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     74.912819         Add Sugar
# 1     96.818832          Add water
# 2    128.937866         Add butter
# 3    131.329514         Add butter
# 4    177.203888  Add apples to pan
# 5    234.603638  Add apples to pan
# 6    261.029205  Add apples to pan
# 7    267.697266  Add apples to pan
# 8    297.332489  Add apples to pan
# 9    299.799835  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (292, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       12.712020      Right Hand Grab          ApplePieCookbook_C_0
# 1       49.602230       Left Hand Grab                           NaN
# 2       51.764648       Left Hand Grab          ApplePieCookbook_C_0
# 3       59.627254       Left Hand Grab  NewMeasuringCup_C_2147482377
# 4       62.200829   Left Hand Released  NewMeasuringCup_C_2147482377
# 5       63.535778       Left Hand Grab         SugarJar_C_2147482372
# 6       64.928711   Left Hand Released         SugarJar_C_2147482372
# 7       66.977882       Left Hand Grab  NewMeasuringCup_C_2147482377
# 266     74.912819                  NaN                           NaN
# 8       77.270096   Left Hand Released  NewMeasuringCup_C_2147482377
# 9       78.199684       Left Hand Grab            StaticMeshActor_31
# 10      79.757683   Left Hand Released            StaticMeshActor_31
# 11      80.586235      Right Hand Grab         SugarJar_C_2147482372
# 12      81.689453  Right Hand Released         SugarJar_C_2147482372
# 13      82.957108       Left Hand Grab            StaticMeshActor_31
# 14      84.322113   Left Hand Released            StaticMeshActor_31
# 15      84.991257       Left Hand Grab  NewMeasuringCup_C_2147482377
# 16      86.526787   Left Hand Released  NewMeasuringCup_C_2147482377
# 17      88.996941       Left Hand Grab         SugarJar_C_2147482372
# 18      90.712700   Left Hand Released         SugarJar_C_2147482372
# 19      94.164261      Right Hand Grab     WaterPitcher_C_2147482371
# 267     96.818832                  NaN                           NaN
# 20     101.535889  Right Hand Released     WaterPitcher_C_2147482371
# 21     101.917847      Right Hand Grab     WaterPitcher_C_2147482371
# 22     102.985741  Right Hand Released     WaterPitcher_C_2147482371
# 23     104.580566      Right Hand Grab     WaterPitcher_C_2147482371
# 24     105.316704  Right Hand Released     WaterPitcher_C_2147482371
# 25     112.766747       Left Hand Grab            StaticMeshActor_31
# 26     114.038055   Left Hand Released            StaticMeshActor_31
# 27     114.638100       Left Hand Grab  NewMeasuringCup_C_2147482377
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 266                  NaN     Add Sugar
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 267                  NaN      Add water
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Left Hand Grab         66
# Left Hand Released     51
# Right Hand Released    51
# Chopped                22
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 266

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                           26
# StaticMeshActor_31                  22
# StirSpoonPie_C_2147482370           14
# PieBowl_C_2147482361                14
# CinnyShakerGrabable_C_2147482375    14
# NewMeasuringCup_C_2147482377        10
# Butter_C_2147482362                  8
# PiePan_C_2147482368                  8
# ApplePieCookbook_C_0                 7
# Apple_Slice2_C_2147482334            6
# Apple_Slice_C_2147482355             6
# oven_C_1                             6
# SugarJar_C_2147482372                6
# WaterPitcher_C_2147482371            6
# SaucePot_C_2147482376                4
# Apple_Slice2_C_2147482354            4
# ButterHolder_C_2147482374            4
# Apple_Slice3_C_2147482348            4
# Apple_C_2147482322                   3
# Apple_C_2147482340                   3
# Apple_Slice3_C_2147482337            3
# Apple_Slice4_C_2147482313            3
# Apple_C_2147482351                   3
# Apple_C_2147482331                   3
# Apple_C_2147482397                   3
# Apple_C_2147482360                   3
# Apple_Slice4_C_2147482347            3
# Apple_Slice2_C_2147482325            2
# Apple_Half2_C_2147482315             2
# Apple_Slice3_C_2147482324            2
# Apple_Slice_C_2147482326             2
# Apple_Slice4_C_2147482336            2
# Apple_Slice4_C_2147482323            2
# Apple_Half_C_2147482321              2
# Apple_Slice3_C_2147482314            2
# Apple_Slice_C_2147482335             2
# Apple_Half_C_2147482316              2
# Apple_Slice2_C_2147482345            2
# Apple_Slice4_C_2147482318            2
# Apple_Half2_C_2147482349             2
# Apple_Slice3_C_2147482357            2
# Apple_Half_C_2147482359              2
# StaticMeshActor_84                   2
# Butter_C_2147482373                  2
# Apple_Slice3_C_2147482319            2
# PillsberryDoughGirl_C_2147482304     1
# Apple_Half2_C_2147482338             1
# Apple_Half2_C_2147482320             1
# Apple_Half2_C_2147482329             1
# Apple_Half_C_2147482330              1
# Apple_Half_C_2147482339              1
# Apple_Slice_C_2147482346             1
# Apple_Half_C_2147482350              1
# Apple_Slice4_C_2147482356            1
# Apple_Half2_C_2147482358             1
# Butter_C_2147482363                  1
# PillsberryDoughBoy_C_2147482305      1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               8   62.200799                  1.0
# 1           Add water             12   19.548736                  0.0
# 2          Add butter             19   27.401977                  0.0
# 3          Add butter              1    1.262131                  0.0
# 4   Add apples to pan             33   43.262833                  1.0
# 5   Add apples to pan             30   57.166535                  0.0
# 6   Add apples to pan             18   24.560577                  0.0
# 7   Add apples to pan              6    6.001801                  0.0
# 8   Add apples to pan             16   28.903839                  1.0
# 9   Add apples to pan              2    1.702667                  0.0
# 10  Add apples to pan             13   14.609589                  0.0
# 11  Add apples to pan              2    1.800568                  0.0
# 12  Add apples to pan              4    3.134491                  0.0
# 13  Add apples to pan              2    1.467652                  0.0
# 14  Add apples to pan             11   14.517120                  1.0
# 15  Add apples to pan              2    3.016235                  0.0
# 16  Add apples to pan              2    1.652436                  0.0
# 17  Add apples to pan              4    4.344787                  0.0
# 18  Add apples to pan             13   13.138031                  1.0
# 19  Add apples to pan              2    1.892303                  0.0
# 20       Add cinnamon              9   21.116241                  3.0
# 21         Pour syrup              4   19.138671                  0.0
# 22          Stir bowl             18   54.897033                  5.0
# 23   Add bottom crust              6   29.298706                  0.0
# 24      Add crust top              4   20.518677                  0.0
# 25    Put pie in oven              7   24.752259                  2.0
# 26     Post last step             18   79.523376                  7.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 266

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C013',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C013            266         580.83007                       22.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        9.851852   21.512225             0.814815
# std         8.583095   21.316398             1.687899
# min         1.000000    1.262131             0.000000
# 25%         3.000000    3.075363             0.000000
# 50%         7.000000   19.138671             0.000000
# 75%        14.500000   28.152908             1.000000
# max        33.000000   79.523376             7.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summarydf_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                 0       0             0
# Add butter             0                 0       3             2
# Add apples to pan     88                 0       0             0
# Add cinnamon           0                 1       4             0
# Stir bowl              0                 1       0             2
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                3        0
# Add water                            0      0                3        0
# Add butter                           0      0                2        0
# Add apples to pan                   12     26                2        8
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      0                0        0
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Pour syrup                           1      0                0        2
# Add bottom crust                     0      0                0        2
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       2                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         3
# Add crust top           0                   1                    0         0
# Put pie in oven         2                   0                    0         0
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   0                    1         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add water                        4             0         4             1
# Add butter                       8             0         0             5
# Add apples to pan               12             4         0             0
# Add cinnamon                     0             0         0             0
# Stir bowl                        0             7         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Pour syrup                       0             0         0             0
# Add bottom crust                 0             3         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   7
# Add water             0                  12
# Add butter            0                  20
# Add apples to pan     2                 156
# Add cinnamon          0                   6
# Stir bowl             0                  13
# Add crust top         0                   4
# Put pie in oven       2                   5
# Pour syrup            0                   4
# Add bottom crust      0                   6

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Left Hand Grab         66
# Left Hand Released     51
# Right Hand Released    51
# Chopped                22
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          7.0
# Left Hand Released      0.0
# Right Hand Grab        15.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            76                       15.0
# 1       Left Hand Grab            66                        7.0
# 2   Left Hand Released            51                        0.0
# 4  Right Hand Released            51                        0.0
# 0              Chopped            22                        0.0
