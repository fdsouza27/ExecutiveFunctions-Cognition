# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C024 D/'
file_name = 'C024_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0     17.005449  Right Hand Grab                   NaN
# 1     17.027256   Left Hand Grab  ApplePieCookbook_C_0
# 2     22.684793  Right Hand Grab                   NaN
# 3     23.640717  Right Hand Grab                   NaN
# 4     25.013935  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (194, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    176
# 1     18
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       17.005449  Right Hand Grab               NaN                    1
# 2       22.684793  Right Hand Grab               NaN                    1
# 3       23.640717  Right Hand Grab               NaN                    1
# 4       25.013935  Right Hand Grab               NaN                    1
# 74     126.634567  Right Hand Grab               NaN                    1
# 87     140.485855   Left Hand Grab               NaN                    1
# 128    180.545746  Right Hand Grab               NaN                    1
# 134    215.952347  Right Hand Grab               NaN                    1
# 136    223.677246  Right Hand Grab               NaN                    1
# 159    271.844879  Right Hand Grab               NaN                    1
# 171    291.253876  Right Hand Grab               NaN                    1
# 180    318.363068  Right Hand Grab               NaN                    1
# 184    325.132568  Right Hand Grab               NaN                    1
# 185    326.644073  Right Hand Grab               NaN                    1
# 187    342.926117  Right Hand Grab               NaN                    1
# 190    351.675995  Right Hand Grab               NaN                    1
# 191    352.678284  Right Hand Grab               NaN                    1
# 192    353.997498  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0     17.005449  Right Hand Grab                   NaN                    1
# 1     17.027256   Left Hand Grab  ApplePieCookbook_C_0                    0
# 2     22.684793  Right Hand Grab                   NaN                    1
# 3     23.640717  Right Hand Grab                   NaN                    1
# 4     25.013935  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C024 D/'
file_name = 'C024_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     36.873615         Add Sugar
# 1     48.041317         Add butter
# 2     50.204899         Add butter
# 3     58.446449          Add water
# 4     93.433914  Add apples to pan
# 5     97.841042  Add apples to pan
# 6     99.872833  Add apples to pan
# 7    112.264923  Add apples to pan
# 8    114.657410  Add apples to pan
# 9    122.590591  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                 Interacted Object  \
# 0      17.005449      Right Hand Grab                               NaN
# 1      17.027256       Left Hand Grab              ApplePieCookbook_C_0
# 2      22.684793      Right Hand Grab                               NaN
# 3      23.640717      Right Hand Grab                               NaN
# 4      25.013935      Right Hand Grab                               NaN
# 5      26.148018      Right Hand Grab              ApplePieCookbook_C_0
# 6      28.855427      Right Hand Grab             SugarJar_C_2147482372
# 7      30.544991  Right Hand Released             SugarJar_C_2147482372
# 8      32.895542      Right Hand Grab      NewMeasuringCup_C_2147482377
# 9      39.126251  Right Hand Released      NewMeasuringCup_C_2147482377
# 10     41.684147      Right Hand Grab         ButterHolder_C_2147482374
# 11     43.246780  Right Hand Released         ButterHolder_C_2147482374
# 12     44.382965      Right Hand Grab                StaticMeshActor_31
# 13     45.379116  Right Hand Released                StaticMeshActor_31
# 14     46.308735      Right Hand Grab               Butter_C_2147482373
# 15     47.674923  Right Hand Released               Butter_C_2147482373
# 16     48.776588      Right Hand Grab               Butter_C_2147482367
# 17     50.037800  Right Hand Released               Butter_C_2147482367
# 18     55.658543      Right Hand Grab         WaterPitcher_C_2147482371
# 19     61.376469  Right Hand Released         WaterPitcher_C_2147482371
# 20     63.579407      Right Hand Grab                StaticMeshActor_31
# 21     65.142242  Right Hand Released                StaticMeshActor_31
# 22     67.301361      Right Hand Grab              PieBowl_C_2147482365
# 23     68.641228  Right Hand Released              PieBowl_C_2147482365
# 24     70.409721      Right Hand Grab                Apple_C_2147482397
# 25     72.034241  Right Hand Released                Apple_C_2147482397
# 26     73.382591      Right Hand Grab                Apple_C_2147482393
# 27     75.065414  Right Hand Released                Apple_C_2147482393
# 28     76.970390      Right Hand Grab  CinnyShakerGrabable_C_2147482375
# 29     77.900726  Right Hand Released  CinnyShakerGrabable_C_2147482375
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   1.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (218, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       17.005449      Right Hand Grab                           NaN
# 1       17.027256       Left Hand Grab          ApplePieCookbook_C_0
# 2       22.684793      Right Hand Grab                           NaN
# 3       23.640717      Right Hand Grab                           NaN
# 4       25.013935      Right Hand Grab                           NaN
# 5       26.148018      Right Hand Grab          ApplePieCookbook_C_0
# 6       28.855427      Right Hand Grab         SugarJar_C_2147482372
# 7       30.544991  Right Hand Released         SugarJar_C_2147482372
# 8       32.895542      Right Hand Grab  NewMeasuringCup_C_2147482377
# 194     36.873615                  NaN                           NaN
# 9       39.126251  Right Hand Released  NewMeasuringCup_C_2147482377
# 10      41.684147      Right Hand Grab     ButterHolder_C_2147482374
# 11      43.246780  Right Hand Released     ButterHolder_C_2147482374
# 12      44.382965      Right Hand Grab            StaticMeshActor_31
# 13      45.379116  Right Hand Released            StaticMeshActor_31
# 14      46.308735      Right Hand Grab           Butter_C_2147482373
# 15      47.674923  Right Hand Released           Butter_C_2147482373
# 195     48.041317                  NaN                           NaN
# 16      48.776588      Right Hand Grab           Butter_C_2147482367
# 17      50.037800  Right Hand Released           Butter_C_2147482367
# 196     50.204899                  NaN                           NaN
# 18      55.658543      Right Hand Grab     WaterPitcher_C_2147482371
# 197     58.446449                  NaN                           NaN
# 19      61.376469  Right Hand Released     WaterPitcher_C_2147482371
# 20      63.579407      Right Hand Grab            StaticMeshActor_31
# 21      65.142242  Right Hand Released            StaticMeshActor_31
# 22      67.301361      Right Hand Grab          PieBowl_C_2147482365
# 23      68.641228  Right Hand Released          PieBowl_C_2147482365
# 24      70.409721      Right Hand Grab            Apple_C_2147482397
# 25      72.034241  Right Hand Released            Apple_C_2147482397
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 194                  NaN     Add Sugar
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 195                  NaN     Add butter
# 16                   0.0            NaN
# 17                   0.0            NaN
# 196                  NaN     Add butter
# 18                   0.0            NaN
# 197                  NaN      Add water
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        86
# Right Hand Released    58
# Left Hand Grab         18
# Chopped                18
# Left Hand Released     14
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 194

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482365                30
# Knife_C_1                           16
# PiePan_C_2147482368                  8
# Apple_C_2147482348                   7
# ApplePieCookbook_C_0                 7
# Apple_Slice_C_2147482345             5
# CinnyShakerGrabable_C_2147482375     4
# StirSpoonPie_C_2147482370            4
# Apple_Slice3_C_2147482356            4
# ButterHolder_C_2147482374            4
# SaucePot_C_2147482376                4
# StaticMeshActor_31                   4
# Apple_C_2147482393                   3
# Apple_C_2147482397                   3
# Apple_Slice4_C_2147482355            3
# oven_C_1                             3
# Apple_C_2147482361                   3
# Apple_Slice3_C_2147482352            3
# Apple_Slice2_C_2147482328            3
# Apple_C_2147482339                   3
# NewMeasuringCup_C_2147482377         2
# Apple_Slice3_C_2147482336            2
# Apple_Slice_C_2147482334             2
# Apple_Slice2_C_2147482333            2
# Butter_C_2147482373                  2
# Apple_Slice4_C_2147482335            2
# Apple_Slice_C_2147482329             2
# Apple_Half2_C_2147482330             2
# Apple_Slice2_C_2147482344            2
# PillsberryDoughGirl_C_2147482324     2
# PillsberryDoughBoy_C_2147482325      2
# Apple_Slice3_C_2147482343            2
# Apple_C_2147482396                   2
# Apple_Slice4_C_2147482342            2
# StaticMeshActor_84                   2
# WaterPitcher_C_2147482371            2
# Butter_C_2147482367                  2
# SugarJar_C_2147482372                2
# Apple_Slice_C_2147482350             2
# Apple_Slice2_C_2147482349            2
# Apple_Slice_C_2147482358             2
# Apple_Slice4_C_2147482351            2
# Apple_Slice2_C_2147482357            2
# Apple_Half_C_2147482360              1
# Apple_Half2_C_2147482359             1
# Apple_Half_C_2147482331              1
# Apple_Half2_C_2147482353             1
# Apple_Half2_C_2147482346             1
# Apple_Half_C_2147482354              1
# Apple_Half_C_2147482338              1
# Apple_Half2_C_2147482337             1
# Apple_Half_C_2147482347              1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               9   19.868166                  4.0
# 1          Add butter              7    8.915066                  0.0
# 2          Add butter              2    1.428311                  0.0
# 3           Add water              1    2.787906                  0.0
# 4   Add apples to pan             26   32.057445                  0.0
# 5   Add apples to pan              5    4.307419                  0.0
# 6   Add apples to pan              1    1.235580                  0.0
# 7   Add apples to pan              9   12.057793                  0.0
# 8   Add apples to pan              2    2.358734                  0.0
# 9   Add apples to pan              8    7.700157                  0.0
# 10  Add apples to pan              2    1.399209                  0.0
# 11  Add apples to pan             15   13.766495                  1.0
# 12  Add apples to pan              0    0.000000                  0.0
# 13  Add apples to pan              7    4.623886                  1.0
# 14  Add apples to pan              1    1.100418                  0.0
# 15  Add apples to pan             16   13.988052                  0.0
# 16  Add apples to pan              0    0.000000                  0.0
# 17  Add apples to pan              4    1.465652                  0.0
# 18  Add apples to pan              0    0.000000                  0.0
# 19  Add apples to pan              8    7.879715                  0.0
# 20       Add cinnamon              8   18.394302                  1.0
# 21         Pour syrup              2   10.079025                  0.0
# 22          Stir bowl             10   26.540085                  2.0
# 23   Add bottom crust             16   23.593887                  0.0
# 24      Add crust top             12   15.846832                  1.0
# 25    Put pie in oven             15   40.541412                  4.0
# 26     Post last step              8   16.851196                  4.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 194

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C024',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C024            194        288.786743                       18.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        7.185185   10.695805             0.666667
# std         6.397337   10.754033             1.300887
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.446982             0.000000
# 50%         7.000000    7.879715             0.000000
# 75%         9.500000   16.349014             1.000000
# max        26.000000   40.541412             4.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  103.940555
# 1         Add butter      2   10.343377
# 2         Add Sugar       1   19.868166
# 3          Add water      1    2.787906
# 4       Add cinnamon      1   18.394302
# 5         Pour syrup      1   10.079025
# 6          Stir bowl      1   26.540085
# 7   Add bottom crust      1   23.593887
# 8      Add crust top      1   15.846832
# 9    Put pie in oven      1   40.541412

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add cinnamon           5                 1       0             0
# Stir bowl              0                 1       0             2
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add butter             0                 0       4             2
# Add apples to pan     71                 0       0             0
# Add water              0                 0       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                1        0
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      0                0        1
# Add crust top                        0      0                0        8
# Put pie in oven                      0      0                0        0
# Add butter                           0      0                1        0
# Add apples to pan                    2     16                0        8
# Add water                            0      0                0        0
# Add bottom crust                     0      0                0       13
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   2                    0         0
# Put pie in oven         6                   0                    0         2
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add water               0                   0                    0         0
# Add bottom crust        0                   0                    2         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add cinnamon                     0             0         0             0
# Stir bowl                        0             3         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add butter                       2             0         0             0
# Add apples to pan                4             0         0             1
# Add water                        0             0         0             1
# Add bottom crust                 0             1         0             0
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   5
# Add cinnamon          0                   7
# Stir bowl             0                   8
# Add crust top         0                  11
# Put pie in oven       2                  11
# Add butter            0                   9
# Add apples to pan     0                 102
# Add water             0                   1
# Add bottom crust      0                  16
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type     Interacted Object  \
# 0       17.005449      Right Hand Grab                   NaN
# 1       17.027256       Left Hand Grab  ApplePieCookbook_C_0
# 2       22.684793      Right Hand Grab                   NaN
# 3       23.640717      Right Hand Grab                   NaN
# 4       25.013935      Right Hand Grab                   NaN
# ..            ...                  ...                   ...
# 213    350.235046  Right Hand Released   PiePan_C_2147482368
# 214    351.675995      Right Hand Grab                   NaN
# 215    352.678284      Right Hand Grab                   NaN
# 216    353.997498      Right Hand Grab                   NaN
# 217    357.701263      Right Hand Grab  ApplePieCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 213                  0.0            NaN
# 214                  1.0            NaN
# 215                  1.0            NaN
# 216                  1.0            NaN
# 217                  0.0            NaN
#
# [218 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        86
# Right Hand Released    58
# Left Hand Grab         18
# Chopped                18
# Left Hand Released     14
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          1.0
# Left Hand Released      0.0
# Right Hand Grab        17.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            86                       17.0
# 4  Right Hand Released            58                        0.0
# 0              Chopped            18                        0.0
# 1       Left Hand Grab            18                        1.0
# 2   Left Hand Released            14                        0.0
