# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C006 D/'
file_name = 'C006_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type   Interacted Object
# 0    285.454407      Left Hand Grab                 NaN
# 1    287.335297      Left Hand Grab                 NaN
# 2    288.423981      Left Hand Grab                 NaN
# 3    290.644379      Left Hand Grab  StaticMeshActor_23
# 4    291.447998  Left Hand Released  StaticMeshActor_23

# %%
df1.shape
# Out:
# (199, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    175
# 1     24
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0      285.454407   Left Hand Grab               NaN                    1
# 1      287.335297   Left Hand Grab               NaN                    1
# 2      288.423981   Left Hand Grab               NaN                    1
# 6      362.735718  Right Hand Grab               NaN                    1
# 33     428.234619   Left Hand Grab               NaN                    1
# 51     475.481293  Right Hand Grab               NaN                    1
# 52     477.303619  Right Hand Grab               NaN                    1
# 61     482.946777  Right Hand Grab               NaN                    1
# 64     491.402008  Right Hand Grab               NaN                    1
# 82     521.850342  Right Hand Grab               NaN                    1
# 83     523.808594  Right Hand Grab               NaN                    1
# 84     524.834412  Right Hand Grab               NaN                    1
# 86     538.648560  Right Hand Grab               NaN                    1
# 109    635.967163  Right Hand Grab               NaN                    1
# 110    637.015015  Right Hand Grab               NaN                    1
# 129    664.150208   Left Hand Grab               NaN                    1
# 142    697.299988  Right Hand Grab               NaN                    1
# 156    772.246826   Left Hand Grab               NaN                    1
# 157    772.934509   Left Hand Grab               NaN                    1
# 158    773.513733   Left Hand Grab               NaN                    1
# 186    860.383606  Right Hand Grab               NaN                    1
# 187    861.085022  Right Hand Grab               NaN                    1
# 189    865.305847  Right Hand Grab               NaN                    1
# 192    877.033386  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type   Interacted Object  Missed Interactions
# 0    285.454407      Left Hand Grab                 NaN                    1
# 1    287.335297      Left Hand Grab                 NaN                    1
# 2    288.423981      Left Hand Grab                 NaN                    1
# 3    290.644379      Left Hand Grab  StaticMeshActor_23                    0
# 4    291.447998  Left Hand Released  StaticMeshActor_23                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C006 D/'
file_name = 'C006_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    403.565033         Add Sugar
# 1    450.793671          Add water
# 2    468.502228         Add butter
# 3    470.835480         Add butter
# 4    612.709412  Add apples to pan
# 5    612.709412  Add apples to pan
# 6    612.709412  Add apples to pan
# 7    612.709412  Add apples to pan
# 8    654.267517  Add apples to pan
# 9    656.157349  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time         Action Type             Interacted Object  \
# 0     285.454407      Left Hand Grab                           NaN
# 1     287.335297      Left Hand Grab                           NaN
# 2     288.423981      Left Hand Grab                           NaN
# 3     290.644379      Left Hand Grab            StaticMeshActor_23
# 4     291.447998  Left Hand Released            StaticMeshActor_23
# 5     337.734772     Right Hand Grab          ApplePieCookbook_C_0
# 6     362.735718     Right Hand Grab                           NaN
# 7     367.672394     Right Hand Grab          ApplePieCookbook_C_0
# 8     380.438171      Left Hand Grab  NewMeasuringCup_C_2147482373
# 9     383.902435  Left Hand Released  NewMeasuringCup_C_2147482373
# 10    385.509369      Left Hand Grab         SugarJar_C_2147482368
# 11    387.991272  Left Hand Released         SugarJar_C_2147482368
# 12    389.864380      Left Hand Grab  NewMeasuringCup_C_2147482373
# 13    396.340942  Left Hand Released  NewMeasuringCup_C_2147482373
# 14    401.112274      Left Hand Grab  NewMeasuringCup_C_2147482373
# 15    404.188995  Left Hand Released  NewMeasuringCup_C_2147482373
# 16    406.071686      Left Hand Grab          ApplePieCookbook_C_0
# 17    407.178101      Left Hand Grab          ApplePieCookbook_C_0
# 18    407.656372      Left Hand Grab          ApplePieCookbook_C_0
# 19    408.904938      Left Hand Grab          ApplePieCookbook_C_0
# 20    409.885590      Left Hand Grab          ApplePieCookbook_C_0
# 21    411.022400      Left Hand Grab          ApplePieCookbook_C_0
# 22    412.224792      Left Hand Grab         SaucePot_C_2147482372
# 23    413.759216  Left Hand Released         SaucePot_C_2147482372
# 24    414.959290      Left Hand Grab          ApplePieCookbook_C_0
# 25    416.313721      Left Hand Grab          ApplePieCookbook_C_0
# 26    418.291901     Right Hand Grab          ApplePieCookbook_C_0
# 27    419.002991     Right Hand Grab          ApplePieCookbook_C_0
# 28    419.958466     Right Hand Grab          ApplePieCookbook_C_0
# 29    420.981445     Right Hand Grab          ApplePieCookbook_C_0
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   1.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (217, 5)

# %%
df.head(30)
# Out:
#      Session Time         Action Type             Interacted Object  \
# 0      285.454407      Left Hand Grab                           NaN
# 1      287.335297      Left Hand Grab                           NaN
# 2      288.423981      Left Hand Grab                           NaN
# 3      290.644379      Left Hand Grab            StaticMeshActor_23
# 4      291.447998  Left Hand Released            StaticMeshActor_23
# 5      337.734772     Right Hand Grab          ApplePieCookbook_C_0
# 6      362.735718     Right Hand Grab                           NaN
# 7      367.672394     Right Hand Grab          ApplePieCookbook_C_0
# 8      380.438171      Left Hand Grab  NewMeasuringCup_C_2147482373
# 9      383.902435  Left Hand Released  NewMeasuringCup_C_2147482373
# 10     385.509369      Left Hand Grab         SugarJar_C_2147482368
# 11     387.991272  Left Hand Released         SugarJar_C_2147482368
# 12     389.864380      Left Hand Grab  NewMeasuringCup_C_2147482373
# 13     396.340942  Left Hand Released  NewMeasuringCup_C_2147482373
# 14     401.112274      Left Hand Grab  NewMeasuringCup_C_2147482373
# 199    403.565033                 NaN                           NaN
# 15     404.188995  Left Hand Released  NewMeasuringCup_C_2147482373
# 16     406.071686      Left Hand Grab          ApplePieCookbook_C_0
# 17     407.178101      Left Hand Grab          ApplePieCookbook_C_0
# 18     407.656372      Left Hand Grab          ApplePieCookbook_C_0
# 19     408.904938      Left Hand Grab          ApplePieCookbook_C_0
# 20     409.885590      Left Hand Grab          ApplePieCookbook_C_0
# 21     411.022400      Left Hand Grab          ApplePieCookbook_C_0
# 22     412.224792      Left Hand Grab         SaucePot_C_2147482372
# 23     413.759216  Left Hand Released         SaucePot_C_2147482372
# 24     414.959290      Left Hand Grab          ApplePieCookbook_C_0
# 25     416.313721      Left Hand Grab          ApplePieCookbook_C_0
# 26     418.291901     Right Hand Grab          ApplePieCookbook_C_0
# 27     419.002991     Right Hand Grab          ApplePieCookbook_C_0
# 28     419.958466     Right Hand Grab          ApplePieCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 199                  NaN     Add Sugar
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        69
# Left Hand Grab         54
# Right Hand Released    36
# Left Hand Released     27
# Chopped                13
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 199

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# ApplePieCookbook_C_0                27
# PieBowl_C_2147482353                18
# NewMeasuringCup_C_2147482373        14
# Knife_C_1                           10
# StirSpoonPie_C_2147482366            8
# StaticMeshActor_84                   8
# PiePan_C_2147482364                  8
# WaterPitcher_C_2147482367            8
# SaucePot_C_2147482372                8
# StaticMeshActor_31                   6
# oven_C_1                             6
# SugarJar_C_2147482368                4
# Apple_C_2147482352                   4
# Apple_C_2147482393                   3
# Apple_C_2147482389                   3
# Apple_Slice4_C_2147482323            3
# Apple_C_2147482336                   3
# Apple_Half_C_2147482326              2
# Apple_Slice3_C_2147482333            2
# Apple_Half2_C_2147482325             2
# Apple_Slice3_C_2147482324            2
# CinnyShakerGrabable_C_2147482371     2
# Apple_Slice2_C_2147482330            2
# Apple_Slice4_C_2147482332            2
# StaticMeshActor_23                   2
# Apple_Slice_C_2147482331             2
# Apple_Half2_C_2147482334             2
# Butter_C_2147482355                  2
# Butter_C_2147482369                  2
# ButterHolder_C_2147482370            2
# Apple_Half_C_2147482335              1
# Apple_Half2_C_2147482348             1
# Apple_Slice_C_2147482347             1
# Apple_Slice2_C_2147482346            1
# Apple_Half_C_2147482349              1
# PillsberryDoughGirl_C_2147482315     1
# PillsberryDoughBoy_C_2147482316      1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    
    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              15  118.110626                  4.0
# 1           Add water             25   46.604676                  1.0
# 2          Add butter              7   14.427613                  0.0
# 3          Add butter              2    1.376801                  0.0
# 4   Add apples to pan             50  139.650208                  8.0
# 5   Add apples to pan              0    0.000000                  0.0
# 6   Add apples to pan              0    0.000000                  0.0
# 7   Add apples to pan              0    0.000000                  0.0
# 8   Add apples to pan             26   39.234070                  2.0
# 9   Add apples to pan              2    1.104126                  0.0
# 10  Add apples to pan              2    1.147217                  0.0
# 11  Add apples to pan              3    2.413879                  1.0
# 12       Add cinnamon             12   31.934326                  1.0
# 13         Pour syrup              2   15.447265                  0.0
# 14          Stir bowl             27   84.640747                  3.0
# 15   Add bottom crust              3   15.726929                  0.0
# 16      Add crust top              4   13.067017                  0.0
# 17    Put pie in oven             11   26.710999                  3.0
# 18     Post last step              8   18.640136                  1.0

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C006',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C006            199        570.236635                       24.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 199

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       10.473684   30.012454             1.263158
# std        13.120672   40.939869             2.050531
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.262009             0.000000
# 50%         4.000000   15.447265             0.000000
# 75%        13.500000   35.584198             1.500000
# max        50.000000  139.650208             8.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8  183.549500
# 1         Add butter      2   15.804414
# 2         Add Sugar       1  118.110626
# 3          Add water      1   46.604676
# 4       Add cinnamon      1   31.934326
# 5         Pour syrup      1   15.447265
# 6          Stir bowl      1   84.640747
# 7   Add bottom crust      1   15.726929
# 8      Add crust top      1   13.067017
# 9    Put pie in oven      1   26.710999

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                18       0             0
# Add apples to pan     25                 0       0             0
# Add cinnamon           6                 1       0             0
# Stir bowl              6                 3       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 2       0             0
# Add butter             0                 0       4             2
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                5        0
# Add water                            0      0                3        0
# Add apples to pan                    0      9                6        8
# Add cinnamon                         1      1                0        2
# Stir bowl                            0      0                0        3
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Add butter                           0      0                0        0
# Pour syrup                           1      0                0        0
# Add bottom crust                     0      0                0        1
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         2
# Add apples to pan       2                   0                    0         2
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   1                    0         0
# Put pie in oven         4                   0                    0         0
# Add butter              0                   0                    0         2
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   0                    1         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        2             0         2             0
# Add water                        0             0         0             1
# Add apples to pan               10             0         2             6
# Add cinnamon                     0             0         0             0
# Stir bowl                        4             7         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add butter                       0             0         0             1
# Pour syrup                       0             0         0             0
# Add bottom crust                 0             1         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                  11
# Add water             0                  24
# Add apples to pan     2                  72
# Add cinnamon          0                  11
# Stir bowl             0                  24
# Add crust top         0                   4
# Put pie in oven       2                   8
# Add butter            0                   9
# Pour syrup            0                   2
# Add bottom crust      0                   3

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type     Interacted Object  \
# 0      285.454407       Left Hand Grab                   NaN
# 1      287.335297       Left Hand Grab                   NaN
# 2      288.423981       Left Hand Grab                   NaN
# 3      290.644379       Left Hand Grab    StaticMeshActor_23
# 4      291.447998   Left Hand Released    StaticMeshActor_23
# ..            ...                  ...                   ...
# 212    882.326477       Left Hand Grab              oven_C_1
# 213    885.269226       Left Hand Grab  PieBowl_C_2147482353
# 214    886.919067  Right Hand Released   PiePan_C_2147482364
# 215    888.560242   Left Hand Released  PieBowl_C_2147482353
# 216    894.290344      Right Hand Grab              Exit_C_0
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 212                  0.0            NaN
# 213                  0.0            NaN
# 214                  0.0            NaN
# 215                  0.0            NaN
# 216                  0.0            NaN
#
# [217 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        69
# Left Hand Grab         54
# Right Hand Released    36
# Left Hand Released     27
# Chopped                13
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          8.0
# Left Hand Released      0.0
# Right Hand Grab        16.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            69                       16.0
# 1       Left Hand Grab            54                        8.0
# 4  Right Hand Released            36                        0.0
# 2   Left Hand Released            27                        0.0
# 0              Chopped            13                        0.0
