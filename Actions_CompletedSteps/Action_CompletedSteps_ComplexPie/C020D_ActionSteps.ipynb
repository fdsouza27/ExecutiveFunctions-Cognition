# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C020 D/'
file_name = 'C020_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type     Interacted Object
# 0    133.193970      Right Hand Grab    StaticMeshActor_84
# 1    136.790375  Right Hand Released    StaticMeshActor_84
# 2    155.651657      Right Hand Grab                   NaN
# 3    157.429382      Right Hand Grab  ApplePieCookbook_C_0
# 4    172.081207      Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (222, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    215
# 1      7
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 2      155.651657  Right Hand Grab               NaN                    1
# 4      172.081207  Right Hand Grab               NaN                    1
# 164    515.466919  Right Hand Grab               NaN                    1
# 165    516.751953  Right Hand Grab               NaN                    1
# 212    668.335083  Right Hand Grab               NaN                    1
# 217    721.571228   Left Hand Grab               NaN                    1
# 219    735.833191  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type     Interacted Object  \
# 0    133.193970      Right Hand Grab    StaticMeshActor_84
# 1    136.790375  Right Hand Released    StaticMeshActor_84
# 2    155.651657      Right Hand Grab                   NaN
# 3    157.429382      Right Hand Grab  ApplePieCookbook_C_0
# 4    172.081207      Right Hand Grab                   NaN
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    1
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C020 D/'
file_name = 'C020_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    214.371704         Add Sugar
# 1    254.664200         Add butter
# 2    262.361542         Add butter
# 3    280.164185          Add water
# 4    319.989502  Add apples to pan
# 5    325.493683  Add apples to pan
# 6    348.213837  Add apples to pan
# 7    350.678741  Add apples to pan
# 8    369.665741  Add apples to pan
# 9    371.636383  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type             Interacted Object  \
# 0     133.193970      Right Hand Grab            StaticMeshActor_84
# 1     136.790375  Right Hand Released            StaticMeshActor_84
# 2     155.651657      Right Hand Grab                           NaN
# 3     157.429382      Right Hand Grab          ApplePieCookbook_C_0
# 4     172.081207      Right Hand Grab                           NaN
# 5     174.834259      Right Hand Grab          ApplePieCookbook_C_0
# 6     184.623062      Right Hand Grab         SugarJar_C_2147482380
# 7     187.144943  Right Hand Released         SugarJar_C_2147482380
# 8     196.861649      Right Hand Grab            StaticMeshActor_31
# 9     197.614349  Right Hand Released            StaticMeshActor_31
# 10    198.432037       Left Hand Grab  NewMeasuringCup_C_2147482385
# 11    212.156342   Left Hand Released  NewMeasuringCup_C_2147482385
# 12    213.643158       Left Hand Grab  NewMeasuringCup_C_2147482385
# 13    214.968231   Left Hand Released  NewMeasuringCup_C_2147482385
# 14    216.372665       Left Hand Grab  NewMeasuringCup_C_2147482385
# 15    220.405777   Left Hand Released  NewMeasuringCup_C_2147482385
# 16    237.856491       Left Hand Grab         SugarJar_C_2147482380
# 17    239.289902   Left Hand Released         SugarJar_C_2147482380
# 18    240.093887       Left Hand Grab  NewMeasuringCup_C_2147482385
# 19    241.063553   Left Hand Released  NewMeasuringCup_C_2147482385
# 20    241.764404       Left Hand Grab         SugarJar_C_2147482380
# 21    243.201355   Left Hand Released         SugarJar_C_2147482380
# 22    244.767136       Left Hand Grab  NewMeasuringCup_C_2147482385
# 23    246.300385   Left Hand Released  NewMeasuringCup_C_2147482385
# 24    247.864319       Left Hand Grab     ButterHolder_C_2147482382
# 25    249.796875   Left Hand Released     ButterHolder_C_2147482382
# 26    251.811325       Left Hand Grab           Butter_C_2147482381
# 27    258.127258       Left Hand Grab           Butter_C_2147482371
# 28    267.630859       Left Hand Grab         SugarJar_C_2147482380
# 29    270.153900   Left Hand Released         SugarJar_C_2147482380
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   1.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (240, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0      133.193970      Right Hand Grab            StaticMeshActor_84
# 1      136.790375  Right Hand Released            StaticMeshActor_84
# 2      155.651657      Right Hand Grab                           NaN
# 3      157.429382      Right Hand Grab          ApplePieCookbook_C_0
# 4      172.081207      Right Hand Grab                           NaN
# 5      174.834259      Right Hand Grab          ApplePieCookbook_C_0
# 6      184.623062      Right Hand Grab         SugarJar_C_2147482380
# 7      187.144943  Right Hand Released         SugarJar_C_2147482380
# 8      196.861649      Right Hand Grab            StaticMeshActor_31
# 9      197.614349  Right Hand Released            StaticMeshActor_31
# 10     198.432037       Left Hand Grab  NewMeasuringCup_C_2147482385
# 11     212.156342   Left Hand Released  NewMeasuringCup_C_2147482385
# 12     213.643158       Left Hand Grab  NewMeasuringCup_C_2147482385
# 222    214.371704                  NaN                           NaN
# 13     214.968231   Left Hand Released  NewMeasuringCup_C_2147482385
# 14     216.372665       Left Hand Grab  NewMeasuringCup_C_2147482385
# 15     220.405777   Left Hand Released  NewMeasuringCup_C_2147482385
# 16     237.856491       Left Hand Grab         SugarJar_C_2147482380
# 17     239.289902   Left Hand Released         SugarJar_C_2147482380
# 18     240.093887       Left Hand Grab  NewMeasuringCup_C_2147482385
# 19     241.063553   Left Hand Released  NewMeasuringCup_C_2147482385
# 20     241.764404       Left Hand Grab         SugarJar_C_2147482380
# 21     243.201355   Left Hand Released         SugarJar_C_2147482380
# 22     244.767136       Left Hand Grab  NewMeasuringCup_C_2147482385
# 23     246.300385   Left Hand Released  NewMeasuringCup_C_2147482385
# 24     247.864319       Left Hand Grab     ButterHolder_C_2147482382
# 25     249.796875   Left Hand Released     ButterHolder_C_2147482382
# 26     251.811325       Left Hand Grab           Butter_C_2147482381
# 223    254.664200                  NaN                           NaN
# 27     258.127258       Left Hand Grab           Butter_C_2147482371
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 222                  NaN     Add Sugar
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 223                  NaN     Add butter
# 27                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        84
# Right Hand Released    60
# Left Hand Grab         29
# Left Hand Released     26
# Chopped                23
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 222

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                           32
# NewMeasuringCup_C_2147482385        12
# PieBowl_C_2147482367                10
# WaterPitcher_C_2147482379           10
# StirSpoonPie_C_2147482378           10
# oven_C_1                             8
# StaticMeshActor_31                   8
# SugarJar_C_2147482380                8
# ApplePieCookbook_C_0                 7
# PiePan_C_2147482376                  6
# StaticMeshActor_23                   6
# PillsberryDoughBoy_C_2147482319      5
# Apple_Half_C_2147482361              5
# Apple_Slice2_C_2147482326            5
# Apple_Slice2_C_2147482342            4
# Apple_Slice_C_2147482332             4
# CinnyShakerGrabable_C_2147482383     4
# Apple_Slice_C_2147482327             4
# Apple_Slice3_C_2147482350            3
# Apple_Slice4_C_2147482349            3
# Apple_C_2147482337                   3
# Apple_C_2147482353                   3
# Apple_C_2147482362                   3
# Apple_C_2147482405                   3
# Apple_C_2147482402                   3
# Apple_Half2_C_2147482328             2
# Apple_Slice2_C_2147482331            2
# Apple_Slice4_C_2147482333            2
# Apple_Slice4_C_2147482340            2
# Apple_Slice3_C_2147482334            2
# SaucePot_C_2147482384                2
# Apple_Half2_C_2147482335             2
# StaticMeshActor_84                   2
# Apple_Slice_C_2147482343             2
# Apple_Slice3_C_2147482341            2
# ButterHolder_C_2147482382            2
# Apple_Half2_C_2147482360             2
# Apple_Slice3_C_2147482359            2
# Apple_Slice4_C_2147482358            2
# Apple_Slice2_C_2147482356            2
# Apple_Slice_C_2147482357             2
# Apple_Slice_C_2147482348             2
# Apple_Slice2_C_2147482347            2
# Apple_Half_C_2147482329              1
# Apple_Half2_C_2147482351             1
# Apple_Half_C_2147482352              1
# Apple_Half_C_2147482345              1
# Apple_Half2_C_2147482344             1
# Butter_C_2147482371                  1
# PillsberryDoughGirl_C_2147482318     1
# Butter_C_2147482381                  1
# Apple_Half_C_2147482336              1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              13   81.177734                  2.0
# 1          Add butter             14   39.695969                  0.0
# 2          Add butter              1    4.234284                  0.0
# 3           Add water              3   12.533326                  0.0
# 4   Add apples to pan             11   36.080505                  0.0
# 5   Add apples to pan              5    5.003388                  0.0
# 6   Add apples to pan             15   20.661042                  0.0
# 7   Add apples to pan              2    1.469421                  0.0
# 8   Add apples to pan             12   15.048706                  0.0
# 9   Add apples to pan              3    1.937286                  0.0
# 10  Add apples to pan              2    1.670379                  0.0
# 11  Add apples to pan              2    1.632111                  0.0
# 12       Add cinnamon             78  111.876434                  0.0
# 13         Pour syrup              2   10.826050                  0.0
# 14          Stir bowl             21   47.944214                  2.0
# 15   Add bottom crust              8   29.395263                  0.0
# 16      Add crust top              8   15.874023                  0.0
# 17    Put pie in oven             11   35.608887                  0.0
# 18     Post last step             11   93.298645                  3.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 222

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C020',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C020            222        565.967667                        7.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       11.684211   29.787772             0.368421
# std        17.023032   32.909067             0.895081
# min         1.000000    1.469421             0.000000
# 25%         2.500000    4.618836             0.000000
# 50%         8.000000   15.874023             0.000000
# 75%        12.500000   37.888237             0.000000
# max        78.000000  111.876434             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   83.502838
# 1         Add butter      2   43.930253
# 2         Add Sugar       1   81.177734
# 3          Add water      1   12.533326
# 4       Add cinnamon      1  111.876434
# 5         Pour syrup      1   10.826050
# 6          Stir bowl      1   47.944214
# 7   Add bottom crust      1   29.395263
# 8      Add crust top      1   15.874023
# 9    Put pie in oven      1   35.608887

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add butter             0                 0       2             2
# Put pie in oven        0                 1       0             0
# Add cinnamon          46                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 1       0             0
# Add water              0                 0       0             0
# Add apples to pan     33                 0       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                3        0
# Add butter                           0      0                7        0
# Put pie in oven                      0      0                2        0
# Add cinnamon                         3     16                0        2
# Stir bowl                            0      4                0        1
# Add crust top                        0      0                0        6
# Add water                            0      0                0        0
# Add apples to pan                    0     12                0        0
# Add bottom crust                     0      0                0        1
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add butter              0                   0                    0         0
# Put pie in oven         6                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   0                    1         0
# Add water               0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add bottom crust        0                   5                    0         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        4             0         2             0
# Add butter                       0             0         4             0
# Put pie in oven                  0             0         0             0
# Add cinnamon                     4             0         0             6
# Stir bowl                        6             6         0             0
# Add crust top                    0             0         0             0
# Add water                        0             0         2             1
# Add apples to pan                2             2         0             3
# Add bottom crust                 0             2         0             0
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                  11
# Add butter            0                  15
# Put pie in oven       2                  11
# Add cinnamon          0                  78
# Stir bowl             0                  19
# Add crust top         0                   8
# Add water             0                   3
# Add apples to pan     0                  52
# Add bottom crust      0                   8
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type     Interacted Object  \
# 0      133.193970      Right Hand Grab    StaticMeshActor_84
# 1      136.790375  Right Hand Released    StaticMeshActor_84
# 2      155.651657      Right Hand Grab                   NaN
# 3      157.429382      Right Hand Grab  ApplePieCookbook_C_0
# 4      172.081207      Right Hand Grab                   NaN
# ..            ...                  ...                   ...
# 235    721.571228       Left Hand Grab                   NaN
# 236    725.542297      Right Hand Grab              oven_C_1
# 237    735.833191      Right Hand Grab                   NaN
# 238    737.036438      Right Hand Grab  ApplePieCookbook_C_0
# 239    746.168762      Right Hand Grab              Exit_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 235                  1.0            NaN
# 236                  0.0            NaN
# 237                  1.0            NaN
# 238                  0.0            NaN
# 239                  0.0            NaN
#
# [240 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        84
# Right Hand Released    60
# Left Hand Grab         29
# Left Hand Released     26
# Chopped                23
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        6.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            84                        6.0
# 4  Right Hand Released            60                        0.0
# 1       Left Hand Grab            29                        1.0
# 2   Left Hand Released            26                        0.0
# 0              Chopped            23                        0.0
