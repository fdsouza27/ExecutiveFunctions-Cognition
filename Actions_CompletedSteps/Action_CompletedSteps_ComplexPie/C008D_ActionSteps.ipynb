# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C008 D/'
file_name = 'C008_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object
# 0      7.583424      Right Hand Grab          ApplePieCookbook_C_0
# 1     19.554117      Right Hand Grab  NewMeasuringCup_C_2147482377
# 2     21.771404       Left Hand Grab         SugarJar_C_2147482372
# 3     22.812439  Right Hand Released  NewMeasuringCup_C_2147482377
# 4     23.434345      Right Hand Grab                           NaN

# %%
df1.shape
# Out:
# (254, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    227
# 1     27
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 4       23.434345  Right Hand Grab               NaN                    1
# 5       24.596210  Right Hand Grab               NaN                    1
# 7       26.259014   Left Hand Grab               NaN                    1
# 10      38.530552  Right Hand Grab               NaN                    1
# 11      39.822750  Right Hand Grab               NaN                    1
# 12      40.690914  Right Hand Grab               NaN                    1
# 16      52.451881  Right Hand Grab               NaN                    1
# 19      74.425758  Right Hand Grab               NaN                    1
# 34     119.301979  Right Hand Grab               NaN                    1
# 35     120.408791  Right Hand Grab               NaN                    1
# 36     122.442436  Right Hand Grab               NaN                    1
# 37     124.024010   Left Hand Grab               NaN                    1
# 40     135.529266  Right Hand Grab               NaN                    1
# 42     141.601410  Right Hand Grab               NaN                    1
# 53     163.987335   Left Hand Grab               NaN                    1
# 97     224.182617  Right Hand Grab               NaN                    1
# 126    263.200989   Left Hand Grab               NaN                    1
# 167    302.987915  Right Hand Grab               NaN                    1
# 182    322.458130  Right Hand Grab               NaN                    1
# 201    353.787598  Right Hand Grab               NaN                    1
# 207    390.849854  Right Hand Grab               NaN                    1
# 215    409.205750  Right Hand Grab               NaN                    1
# 226    442.088531   Left Hand Grab               NaN                    1
# 241    491.865356  Right Hand Grab               NaN                    1
# 242    493.196472  Right Hand Grab               NaN                    1
# 243    493.994843  Right Hand Grab               NaN                    1
# 252    520.262085  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object  \
# 0      7.583424      Right Hand Grab          ApplePieCookbook_C_0
# 1     19.554117      Right Hand Grab  NewMeasuringCup_C_2147482377
# 2     21.771404       Left Hand Grab         SugarJar_C_2147482372
# 3     22.812439  Right Hand Released  NewMeasuringCup_C_2147482377
# 4     23.434345      Right Hand Grab                           NaN
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C008 D/'
file_name = 'C008_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(30)
# Out:
#     Session Time     Completed Step
# 0      49.237339         Add Sugar
# 1      63.330273          Add water
# 2      96.614586         Add butter
# 3     113.489136         Add butter
# 4     257.766418  Add apples to pan
# 5     259.999115  Add apples to pan
# 6     262.231537  Add apples to pan
# 7     272.993622  Add apples to pan
# 8     274.562744  Add apples to pan
# 9     275.864502  Add apples to pan
# 10    277.364716  Add apples to pan
# 11    278.765411  Add apples to pan
# 12    280.495148  Add apples to pan
# 13    282.060913  Add apples to pan
# 14    283.661591  Add apples to pan
# 15    299.495544  Add apples to pan
# 16    300.460266  Add apples to pan
# 17    338.595184  Add apples to pan
# 18    338.728241  Add apples to pan
# 19    341.960876  Add apples to pan
# 20    367.397430       Add cinnamon
# 21    384.989838         Pour syrup
# 22    431.187256          Stir bowl
# 23    445.383270   Add bottom crust
# 24    469.429169      Add crust top
# 25    505.795624    Put pie in oven

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (279, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0        7.583424      Right Hand Grab          ApplePieCookbook_C_0
# 1       19.554117      Right Hand Grab  NewMeasuringCup_C_2147482377
# 2       21.771404       Left Hand Grab         SugarJar_C_2147482372
# 3       22.812439  Right Hand Released  NewMeasuringCup_C_2147482377
# 4       23.434345      Right Hand Grab                           NaN
# 5       24.596210      Right Hand Grab                           NaN
# 6       25.330690   Left Hand Released         SugarJar_C_2147482372
# 7       26.259014       Left Hand Grab                           NaN
# 8       26.281521      Right Hand Grab  NewMeasuringCup_C_2147482377
# 9       30.393005  Right Hand Released  NewMeasuringCup_C_2147482377
# 10      38.530552      Right Hand Grab                           NaN
# 11      39.822750      Right Hand Grab                           NaN
# 12      40.690914      Right Hand Grab                           NaN
# 13      41.824482      Right Hand Grab          ApplePieCookbook_C_0
# 14      47.486237      Right Hand Grab  NewMeasuringCup_C_2147482377
# 254     49.237339                  NaN                           NaN
# 15      49.778030  Right Hand Released  NewMeasuringCup_C_2147482377
# 16      52.451881      Right Hand Grab                           NaN
# 17      58.446964      Right Hand Grab     WaterPitcher_C_2147482371
# 255     63.330273                  NaN                           NaN
# 18      66.643898  Right Hand Released     WaterPitcher_C_2147482371
# 19      74.425758      Right Hand Grab                           NaN
# 20      86.198082      Right Hand Grab            StaticMeshActor_31
# 21      89.095695  Right Hand Released            StaticMeshActor_31
# 22      92.057800      Right Hand Grab     ButterHolder_C_2147482374
# 23      94.154175  Right Hand Released     ButterHolder_C_2147482374
# 24      94.816605      Right Hand Grab           Butter_C_2147482373
# 25      96.385872  Right Hand Released           Butter_C_2147482373
# 256     96.614586                  NaN                           NaN
# 26     102.303780      Right Hand Grab           Butter_C_2147482365
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   1.0            NaN
# 11                   1.0            NaN
# 12                   1.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 254                  NaN     Add Sugar
# 15                   0.0            NaN
# 16                   1.0            NaN
# 17                   0.0            NaN
# 255                  NaN      Add water
# 18                   0.0            NaN
# 19                   1.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 256                  NaN     Add butter
# 26                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        114
# Right Hand Released     77
# Chopped                 25
# Left Hand Grab          22
# Left Hand Released      16
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 254

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                    30
# PieBowl_C_2147482360         16
# StirSpoonPie_C_2147482370    12
# ApplePieCookbook_C_0          9
# StaticMeshActor_84            8
#                              ..
# Apple_Half2_C_2147482337      1
# Apple_Half_C_2147482338       1
# Apple_Half_C_2147482331       1
# Apple_Half_C_2147482320       1
# Apple_Half2_C_2147482330      1
# Name: count, Length: 62, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              15   41.653915                  6.0
# 1           Add water              3   13.552243                  1.0
# 2          Add butter              8   29.970688                  1.0
# 3          Add butter              8   11.185356                  0.0
# 4   Add apples to pan             88  138.464439                  8.0
# 5   Add apples to pan              2    1.602783                  0.0
# 6   Add apples to pan              2    1.399902                  0.0
# 7   Add apples to pan             13    9.792633                  1.0
# 8   Add apples to pan              2    0.931518                  0.0
# 9   Add apples to pan              2    0.835175                  0.0
# 10  Add apples to pan              2    0.966828                  0.0
# 11  Add apples to pan              2    0.901153                  0.0
# 12  Add apples to pan              2    0.996949                  0.0
# 13  Add apples to pan              2    1.266083                  0.0
# 14  Add apples to pan              2    1.029847                  0.0
# 15  Add apples to pan             12   10.106140                  0.0
# 16  Add apples to pan              0    0.000000                  0.0
# 17  Add apples to pan             30   37.868805                  2.0
# 18  Add apples to pan              0    0.000000                  0.0
# 19  Add apples to pan              3    2.533874                  0.0
# 20       Add cinnamon              6   25.368682                  1.0
# 21         Pour syrup              2   14.826203                  0.0
# 22          Stir bowl             18   43.968140                  2.0
# 23   Add bottom crust              4   11.598053                  1.0
# 24      Add crust top              7   19.957367                  0.0
# 25    Put pie in oven             10   33.992890                  3.0
# 26     Post last step              9   11.511505                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 254

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C008',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C008            254        466.281171                       27.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        9.407407   17.269673             1.000000
# std        17.079586   27.962451             1.921538
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.013398             0.000000
# 50%         3.000000   10.106140             0.000000
# 75%         9.500000   22.663024             1.000000
# max        88.000000  138.464439             8.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  208.696129
# 1         Add butter      2   41.156044
# 2         Add Sugar       1   41.653915
# 3          Add water      1   13.552243
# 4       Add cinnamon      1   25.368682
# 5         Pour syrup      1   14.826203
# 6          Stir bowl      1   43.968140
# 7   Add bottom crust      1   11.598053
# 8      Add crust top      1   19.957367
# 9    Put pie in oven      1   33.992890

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                 0       0             0
# Add butter             0                 1       7             2
# Add apples to pan     87                 1       0             0
# Add cinnamon           2                 1       0             0
# Stir bowl              4                 1       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                5        0
# Add water                            0      0                1        0
# Add butter                           0      0                0        0
# Add apples to pan                    0     30                0       11
# Add cinnamon                         1      0                0        1
# Stir bowl                            0      0                0        1
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Add bottom crust                     0      0                0        1
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   2                    0         0
# Put pie in oven         2                   0                    0         2
# Add bottom crust        0                   0                    1         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add water                        0             0         0             1
# Add butter                       4             0         0             1
# Add apples to pan               18             6         0             0
# Add cinnamon                     0             0         0             0
# Stir bowl                        2             3         0             4
# Add crust top                    0             2         0             0
# Put pie in oven                  0             0         0             0
# Add bottom crust                 0             1         0             0
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   9
# Add water             0                   2
# Add butter            0                  15
# Add apples to pan     0                 153
# Add cinnamon          0                   5
# Stir bowl             0                  16
# Add crust top         0                   7
# Put pie in oven       2                   7
# Add bottom crust      0                   3
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        114
# Right Hand Released     77
# Chopped                 25
# Left Hand Grab          22
# Left Hand Released      16
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          5.0
# Left Hand Released      0.0
# Right Hand Grab        22.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          5.0
# Left Hand Released      0.0
# Right Hand Grab        22.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           114                       22.0
# 4  Right Hand Released            77                        0.0
# 0              Chopped            25                        0.0
# 1       Left Hand Grab            22                        5.0
# 2   Left Hand Released            16                        0.0
