# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C032 D/'
file_name = 'C032_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type      Interacted Object
# 0     79.732475      Right Hand Grab                    NaN
# 1     82.488091      Right Hand Grab   ApplePieCookbook_C_0
# 2    106.928040      Right Hand Grab  SaucePot_C_2147482386
# 3    110.397346  Right Hand Released  SaucePot_C_2147482386
# 4    110.997711      Right Hand Grab  SaucePot_C_2147482386

# %%
df1.shape
# Out:
# (305, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    285
# 1     20
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       79.732475  Right Hand Grab               NaN                    1
# 6      115.707649  Right Hand Grab               NaN                    1
# 18     150.861511  Right Hand Grab               NaN                    1
# 21     154.178238  Right Hand Grab               NaN                    1
# 42     181.114075  Right Hand Grab               NaN                    1
# 93     265.807648  Right Hand Grab               NaN                    1
# 162    389.609680  Right Hand Grab               NaN                    1
# 163    390.232208  Right Hand Grab               NaN                    1
# 193    420.313904  Right Hand Grab               NaN                    1
# 209    442.653961  Right Hand Grab               NaN                    1
# 224    459.107880  Right Hand Grab               NaN                    1
# 225    461.108154  Right Hand Grab               NaN                    1
# 230    481.422241  Right Hand Grab               NaN                    1
# 234    493.531952  Right Hand Grab               NaN                    1
# 237    499.944275  Right Hand Grab               NaN                    1
# 281    596.528992  Right Hand Grab               NaN                    1
# 286    621.980530  Right Hand Grab               NaN                    1
# 291    631.287781  Right Hand Grab               NaN                    1
# 292    632.149475  Right Hand Grab               NaN                    1
# 297    647.740051  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type      Interacted Object  \
# 0     79.732475      Right Hand Grab                    NaN
# 1     82.488091      Right Hand Grab   ApplePieCookbook_C_0
# 2    106.928040      Right Hand Grab  SaucePot_C_2147482386
# 3    110.397346  Right Hand Released  SaucePot_C_2147482386
# 4    110.997711      Right Hand Grab  SaucePot_C_2147482386
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C032 D/'
file_name = 'C032_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    144.425430         Add Sugar
# 1    188.621429          Add water
# 2    221.532562         Add butter
# 3    237.627640         Add butter
# 4    329.997253  Add apples to pan
# 5    332.363708  Add apples to pan
# 6    333.201874  Add apples to pan
# 7    334.961700  Add apples to pan
# 8    351.705963  Add apples to pan
# 9    352.573029  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (322, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       79.732475      Right Hand Grab                           NaN
# 1       82.488091      Right Hand Grab          ApplePieCookbook_C_0
# 2      106.928040      Right Hand Grab         SaucePot_C_2147482386
# 3      110.397346  Right Hand Released         SaucePot_C_2147482386
# 4      110.997711      Right Hand Grab         SaucePot_C_2147482386
# 5      112.462479  Right Hand Released         SaucePot_C_2147482386
# 6      115.707649      Right Hand Grab                           NaN
# 7      118.441963      Right Hand Grab          ApplePieCookbook_C_0
# 8      127.653900      Right Hand Grab            StaticMeshActor_31
# 9      128.293427  Right Hand Released            StaticMeshActor_31
# 10     129.357544      Right Hand Grab  NewMeasuringCup_C_2147482387
# 11     130.759995  Right Hand Released  NewMeasuringCup_C_2147482387
# 12     132.180649      Right Hand Grab         SugarJar_C_2147482382
# 13     133.400894  Right Hand Released         SugarJar_C_2147482382
# 14     135.949936      Right Hand Grab  NewMeasuringCup_C_2147482387
# 305    144.425430                  NaN                           NaN
# 15     144.602936  Right Hand Released  NewMeasuringCup_C_2147482387
# 16     146.588806      Right Hand Grab  NewMeasuringCup_C_2147482387
# 17     149.016769  Right Hand Released  NewMeasuringCup_C_2147482387
# 18     150.861511      Right Hand Grab                           NaN
# 19     152.537231      Right Hand Grab  NewMeasuringCup_C_2147482387
# 20     153.311798  Right Hand Released  NewMeasuringCup_C_2147482387
# 21     154.178238      Right Hand Grab                           NaN
# 22     155.210739      Right Hand Grab     WaterPitcher_C_2147482381
# 23     159.204239  Right Hand Released     WaterPitcher_C_2147482381
# 24     160.378067      Right Hand Grab     WaterPitcher_C_2147482381
# 25     160.611084  Right Hand Released     WaterPitcher_C_2147482381
# 26     161.043655      Right Hand Grab     WaterPitcher_C_2147482381
# 27     162.140137  Right Hand Released     WaterPitcher_C_2147482381
# 28     163.441895      Right Hand Grab     WaterPitcher_C_2147482381
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 305                  NaN     Add Sugar
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   1.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        160
# Right Hand Released    124
# Chopped                 21
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 305

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482366                42
# SaucePot_C_2147482386               30
# Knife_C_1                           22
# WaterPitcher_C_2147482381           22
# StirSpoonPie_C_2147482380           20
# CinnyShakerGrabable_C_2147482385    16
# NewMeasuringCup_C_2147482387        14
# ApplePieCookbook_C_0                 7
# Butter_C_2147482368                  6
# oven_C_1                             6
# PiePan_C_2147482378                  6
# Apple_Slice3_C_2147482327            4
# Apple_Slice2_C_2147482333            4
# Butter_C_2147482383                  4
# ButterHolder_C_2147482384            4
# StaticMeshActor_31                   4
# Apple_Slice2_C_2147482344            3
# Apple_C_2147482358                   3
# Apple_Slice4_C_2147482335            3
# Apple_C_2147482341                   3
# Apple_C_2147482350                   3
# Apple_C_2147482363                   3
# Butter_C_2147482367                  3
# PillsberryDoughGirl_C_2147482316     3
# Apple_Slice4_C_2147482326            2
# Apple_Slice3_C_2147482336            2
# Apple_Slice_C_2147482334             2
# Apple_Slice3_C_2147482343            2
# Apple_Slice_C_2147482325             2
# Apple_Half_C_2147482338              2
# Apple_Slice2_C_2147482324            2
# Apple_Half2_C_2147482346             2
# Apple_Slice_C_2147482345             2
# Apple_C_2147482403                   2
# SugarJar_C_2147482382                2
# StaticMeshActor_84                   2
# Apple_Slice4_C_2147482353            2
# Apple_Slice3_C_2147482354            2
# Apple_Slice2_C_2147482351            2
# Apple_Slice_C_2147482352             2
# Butter_C_2147482369                  2
# Apple_Slice4_C_2147482342            2
# Apple_C_2147482407                   2
# Apple_C_2147482362                   2
# Apple_C_2147482406                   2
# PillsberryDoughBoy_C_2147482317      1
# Apple_Half_C_2147482329              1
# Apple_Half2_C_2147482355             1
# Apple_Half_C_2147482356              1
# Apple_Half2_C_2147482328             1
# Apple_Half_C_2147482347              1
# Apple_Half2_C_2147482337             1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              15   64.692955                  2.0
# 1           Add water             31   44.018493                  3.0
# 2          Add butter             25   30.835953                  0.0
# 3          Add butter             10   13.239243                  0.0
# 4   Add apples to pan             50   86.562515                  1.0
# 5   Add apples to pan              3    1.799926                  0.0
# 6   Add apples to pan              1    0.234162                  0.0
# 7   Add apples to pan              2    1.128082                  0.0
# 8   Add apples to pan             13   11.807220                  0.0
# 9   Add apples to pan              1    0.000000                  0.0
# 10  Add apples to pan              1    0.232880                  0.0
# 11  Add apples to pan              2    1.066773                  0.0
# 12       Add cinnamon             70  102.569672                  4.0
# 13         Pour syrup              5   18.865997                  2.0
# 14          Stir bowl             24   51.108581                  3.0
# 15   Add bottom crust              6   21.310913                  0.0
# 16      Add crust top             22   36.290588                  0.0
# 17    Put pie in oven             13   38.624267                  4.0
# 18     Post last step             11   32.567383                  1.0

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C032',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C032            305        556.955603                       20.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 305

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       16.052632   29.313453             1.052632
# std        18.280146   30.159822             1.470967
# min         1.000000    0.000000             0.000000
# 25%         2.500000    1.464004             0.000000
# 50%        11.000000   21.310913             0.000000
# 75%        23.000000   41.321380             2.000000
# max        70.000000  102.569672             4.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8  102.831558
# 1         Add butter      2   44.075196
# 2         Add Sugar       1   64.692955
# 3          Add water      1   44.018493
# 4       Add cinnamon      1  102.569672
# 5         Pour syrup      1   18.865997
# 6          Stir bowl      1   51.108581
# 7   Add bottom crust      1   21.310913
# 8      Add crust top      1   36.290588
# 9    Put pie in oven      1   38.624267

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add butter             0                 0      12             2
# Add apples to pan     36                 0       2             2
# Pour syrup             0                 0       0             0
# Stir bowl              0                 1       0             0
# Add water              0                 0       0             0
# Add cinnamon          32                 1       1             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                3        0
# Add butter                           0      0                0        0
# Add apples to pan                    0     16                0        8
# Pour syrup                           2      0                0        0
# Stir bowl                            0      0                0        0
# Add water                            0      0                9        0
# Add cinnamon                        14      6                2       10
# Add crust top                        0      0                0       18
# Put pie in oven                      0      0                0        0
# Add bottom crust                     0      0                0        4
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         4
# Add butter              0                   0                    0        16
# Add apples to pan       0                   0                    0         8
# Pour syrup              0                   0                    0         1
# Stir bowl               0                   0                    0         1
# Add water               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Add crust top           0                   0                    3         0
# Put pie in oven         4                   0                    0         0
# Add bottom crust        0                   1                    0         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        2             0         2             0
# Add butter                       4             0         0             1
# Add apples to pan                0             0         0             0
# Pour syrup                       0             0         0             0
# Stir bowl                        0            19         0             0
# Add water                        0             0         0            19
# Add cinnamon                     0             0         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add bottom crust                 0             1         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                  13
# Add butter            0                  35
# Add apples to pan     0                  72
# Pour syrup            0                   3
# Stir bowl             0                  21
# Add water             0                  28
# Add cinnamon          0                  66
# Add crust top         0                  22
# Put pie in oven       4                   9
# Add bottom crust      0                   6

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        160
# Right Hand Released    124
# Chopped                 21
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Right Hand Grab        20.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab           160                       20.0
# 2  Right Hand Released           124                        0.0
# 0              Chopped            21                        0.0
