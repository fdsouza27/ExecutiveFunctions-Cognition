# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C012 D/'
file_name = 'C012_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type      Interacted Object
# 0      6.583894      Right Hand Grab   ApplePieCookbook_C_0
# 1      6.607076       Left Hand Grab                    NaN
# 2     13.935595      Right Hand Grab   ApplePieCookbook_C_0
# 3     18.129238      Right Hand Grab  SugarJar_C_2147482372
# 4     19.743647  Right Hand Released  SugarJar_C_2147482372

# %%
df1.shape
# Out:
# (247, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    239
# 1      8
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1        6.607076   Left Hand Grab               NaN                    1
# 7       23.431129   Left Hand Grab               NaN                    1
# 8       27.999983   Left Hand Grab               NaN                    1
# 17      68.185562  Right Hand Grab               NaN                    1
# 183    345.299530  Right Hand Grab               NaN                    1
# 222    510.254303  Right Hand Grab               NaN                    1
# 229    528.934204   Left Hand Grab               NaN                    1
# 242    580.977356   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type      Interacted Object  \
# 0      6.583894      Right Hand Grab   ApplePieCookbook_C_0
# 1      6.607076       Left Hand Grab                    NaN
# 2     13.935595      Right Hand Grab   ApplePieCookbook_C_0
# 3     18.129238      Right Hand Grab  SugarJar_C_2147482372
# 4     19.743647  Right Hand Released  SugarJar_C_2147482372
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C012 D/'
file_name = 'C012_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     36.344566         Add Sugar
# 1     57.485668          Add water
# 2     99.350685         Add butter
# 3    102.943169         Add butter
# 4    143.238251  Add apples to pan
# 5    146.941010  Add apples to pan
# 6    152.635696  Add apples to pan
# 7    155.672470  Add apples to pan
# 8    174.406143  Add apples to pan
# 9    185.202194  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (273, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0        6.583894      Right Hand Grab          ApplePieCookbook_C_0
# 1        6.607076       Left Hand Grab                           NaN
# 2       13.935595      Right Hand Grab          ApplePieCookbook_C_0
# 3       18.129238      Right Hand Grab         SugarJar_C_2147482372
# 4       19.743647  Right Hand Released         SugarJar_C_2147482372
# 5       21.492500      Right Hand Grab            StaticMeshActor_31
# 6       22.361538  Right Hand Released            StaticMeshActor_31
# 7       23.431129       Left Hand Grab                           NaN
# 8       27.999983       Left Hand Grab                           NaN
# 9       30.506466       Left Hand Grab  NewMeasuringCup_C_2147482377
# 247     36.344566                  NaN                           NaN
# 10      36.699577   Left Hand Released  NewMeasuringCup_C_2147482377
# 11      38.547382       Left Hand Grab  NewMeasuringCup_C_2147482377
# 12      40.561794   Left Hand Released  NewMeasuringCup_C_2147482377
# 13      44.479950       Left Hand Grab  NewMeasuringCup_C_2147482377
# 14      45.875084   Left Hand Released  NewMeasuringCup_C_2147482377
# 15      52.262424      Right Hand Grab     WaterPitcher_C_2147482371
# 248     57.485668                  NaN                           NaN
# 16      67.319534  Right Hand Released     WaterPitcher_C_2147482371
# 17      68.185562      Right Hand Grab                           NaN
# 18      69.053551      Right Hand Grab     WaterPitcher_C_2147482371
# 19      74.496552  Right Hand Released     WaterPitcher_C_2147482371
# 20      86.677139      Right Hand Grab            StaticMeshActor_31
# 21      87.573524  Right Hand Released            StaticMeshActor_31
# 22      89.042625      Right Hand Grab            StaticMeshActor_31
# 23      89.780647  Right Hand Released            StaticMeshActor_31
# 24      91.243820       Left Hand Grab     ButterHolder_C_2147482374
# 25      93.766609   Left Hand Released     ButterHolder_C_2147482374
# 26      95.705589       Left Hand Grab           Butter_C_2147482373
# 249     99.350685                  NaN                           NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    0.0            NaN
# 247                  NaN     Add Sugar
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 248                  NaN      Add water
# 16                   0.0            NaN
# 17                   1.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 249                  NaN     Add butter

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        97
# Right Hand Released    81
# Left Hand Grab         31
# Left Hand Released     21
# Chopped                17
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 247

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                           36
# PieBowl_C_2147482363                30
# StirSpoonPie_C_2147482370           14
# StaticMeshActor_31                  14
# Apple_C_2147482362                  11
# ApplePieCookbook_C_0                 9
# CinnyShakerGrabable_C_2147482375     6
# StaticMeshActor_84                   6
# SugarJar_C_2147482372                6
# NewMeasuringCup_C_2147482377         6
# Apple_Slice2_C_2147482358            6
# Apple_Slice3_C_2147482334            4
# StaticMeshActor_23                   4
# oven_C_1                             4
# Apple_Slice2_C_2147482335            4
# Apple_Slice2_C_2147482342            4
# Apple_Slice3_C_2147482347            4
# Apple_Slice_C_2147482349             4
# PiePan_C_2147482368                  4
# WaterPitcher_C_2147482371            4
# Apple_Half2_C_2147482337             3
# Apple_C_2147482395                   3
# Apple_C_2147482341                   3
# Apple_C_2147482352                   3
# Apple_C_2147482394                   3
# Apple_Slice_C_2147482336             2
# Apple_Slice2_C_2147482326            2
# Apple_Slice3_C_2147482329            2
# Apple_Slice4_C_2147482328            2
# SaucePot_C_2147482376                2
# ButterHolder_C_2147482374            2
# Apple_Slice4_C_2147482333            2
# Apple_Slice2_C_2147482348            2
# PillsberryDoughGirl_C_2147482314     2
# Apple_Half_C_2147482361              2
# Apple_Half2_C_2147482344             2
# Apple_Slice_C_2147482343             2
# Apple_Slice4_C_2147482356            2
# Apple_Slice3_C_2147482357            2
# Apple_Slice_C_2147482359             2
# Apple_Slice4_C_2147482346            2
# Apple_Slice_C_2147482327             2
# Butter_C_2147482373                  1
# PillsberryDoughBoy_C_2147482315      1
# Apple_Half_C_2147482351              1
# Butter_C_2147482365                  1
# Apple_Half_C_2147482331              1
# Apple_Half2_C_2147482330             1
# Apple_Half_C_2147482338              1
# Apple_Half2_C_2147482360             1
# Apple_Half2_C_2147482350             1
# Apple_Half_C_2147482345              1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              10   29.760672                  3.0
# 1           Add water              6   20.786091                  0.0
# 2          Add butter             11   32.031151                  1.0
# 3          Add butter              1    1.925927                  0.0
# 4   Add apples to pan             16   36.658379                  0.0
# 5   Add apples to pan              5    3.273209                  0.0
# 6   Add apples to pan              5    5.495193                  0.0
# 7   Add apples to pan              4    1.737076                  0.0
# 8   Add apples to pan             16   16.400802                  0.0
# 9   Add apples to pan             14   10.230713                  0.0
# 10  Add apples to pan              9    5.963867                  0.0
# 11  Add apples to pan              4    3.339859                  0.0
# 12  Add apples to pan              8    9.600708                  0.0
# 13  Add apples to pan              4    6.267136                  0.0
# 14  Add apples to pan             16   14.800796                  0.0
# 15  Add apples to pan              9   10.297439                  0.0
# 16  Add apples to pan              4    4.205994                  0.0
# 17  Add apples to pan              2    1.230682                  0.0
# 18  Add apples to pan             13   17.370041                  0.0
# 19  Add apples to pan              2    1.102539                  0.0
# 20       Add cinnamon             14   29.792206                  0.0
# 21         Pour syrup              4   14.334350                  0.0
# 22          Stir bowl             38  157.314270                  1.0
# 23   Add bottom crust              7   20.044953                  0.0
# 24      Add crust top             11   25.748383                  2.0
# 25    Put pie in oven              8   31.648498                  0.0
# 26     Post last step              6   21.575561                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 247

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C012',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C012            247        532.936495                        8.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        9.148148   19.738389             0.296296
# std         7.352151   29.604916             0.724028
# min         1.000000    1.102539             0.000000
# 25%         4.000000    4.850593             0.000000
# 50%         8.000000   14.334350             0.000000
# 75%        12.000000   23.661972             0.000000
# max        38.000000  157.314270             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  147.974433
# 1         Add butter      2   33.957078
# 2         Add Sugar       1   29.760672
# 3          Add water      1   20.786091
# 4       Add cinnamon      1   29.792206
# 5         Pour syrup      1   14.334350
# 6          Stir bowl      1  157.314270
# 7   Add bottom crust      1   20.044953
# 8      Add crust top      1   25.748383
# 9    Put pie in oven      1   31.648498

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add cinnamon           4                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 3       0             0
# Put pie in oven        0                 1       0             0
# Add apples to pan     83                 0       0             0
# Add butter             0                 0       2             2
# Add bottom crust       0                 0       0             0
# Add water              0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                1        0
# Add cinnamon                         3      0                0        0
# Stir bowl                            0      0                0       18
# Add crust top                        0      0                0        4
# Put pie in oven                      0      0                0        0
# Add apples to pan                    0     36                0        6
# Add butter                           0      0                0        0
# Add bottom crust                     0      0                0        2
# Add water                            0      0                5        0
# Pour syrup                           3      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   1                    0         0
# Put pie in oven         2                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add butter              0                   0                    0         0
# Add bottom crust        0                   0                    2         0
# Add water               0                   0                    0         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        2             0         2             0
# Add cinnamon                     6             0         0             0
# Stir bowl                        8             9         0             0
# Add crust top                    1             0         0             0
# Put pie in oven                  1             0         2             0
# Add apples to pan                0             4         2             0
# Add butter                       4             0         0             3
# Add bottom crust                 2             1         0             0
# Add water                        0             0         0             1
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   7
# Add cinnamon          0                  14
# Stir bowl             0                  37
# Add crust top         0                   9
# Put pie in oven       2                   8
# Add apples to pan     0                 131
# Add butter            0                  11
# Add bottom crust      0                   7
# Add water             0                   6
# Pour syrup            0                   4

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        97
# Right Hand Released    81
# Left Hand Grab         31
# Left Hand Released     21
# Chopped                17
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         5.0
# Left Hand Released     0.0
# Right Hand Grab        3.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            97                        3.0
# 4  Right Hand Released            81                        0.0
# 1       Left Hand Grab            31                        5.0
# 2   Left Hand Released            21                        0.0
# 0              Chopped            17                        0.0
