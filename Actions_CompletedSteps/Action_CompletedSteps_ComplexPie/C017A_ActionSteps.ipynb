# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C017 A/'
file_name = 'C017_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type             Interacted Object
# 0     26.889717  Right Hand Grab          ApplePieCookbook_C_0
# 1     41.441101  Right Hand Grab                           NaN
# 2     44.472000  Right Hand Grab          ApplePieCookbook_C_0
# 3     64.582657   Left Hand Grab  NewMeasuringCup_C_2147482389
# 4     67.406700  Right Hand Grab         SugarJar_C_2147482384

# %%
df1.shape
# Out:
# (170, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    159
# 1     11
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       41.441101  Right Hand Grab               NaN                    1
# 9       83.137070   Left Hand Grab               NaN                    1
# 70     182.769165   Left Hand Grab               NaN                    1
# 93     292.637085   Left Hand Grab               NaN                    1
# 112    316.572174   Left Hand Grab               NaN                    1
# 138    340.868774  Right Hand Grab               NaN                    1
# 148    367.039673  Right Hand Grab               NaN                    1
# 153    384.419373  Right Hand Grab               NaN                    1
# 158    400.860565  Right Hand Grab               NaN                    1
# 159    402.258514  Right Hand Grab               NaN                    1
# 162    425.106415  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type             Interacted Object  \
# 0     26.889717  Right Hand Grab          ApplePieCookbook_C_0
# 1     41.441101  Right Hand Grab                           NaN
# 2     44.472000  Right Hand Grab          ApplePieCookbook_C_0
# 3     64.582657   Left Hand Grab  NewMeasuringCup_C_2147482389
# 4     67.406700  Right Hand Grab         SugarJar_C_2147482384
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C017 A/'
file_name = 'C017_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     93.362961         Add Sugar
# 1    120.868073         Add butter
# 2    123.599838         Add butter
# 3    135.413910          Add water
# 4    170.235733  Add apples to pan
# 5    170.535950  Add apples to pan
# 6    175.504074  Add apples to pan
# 7    176.906845  Add apples to pan
# 8    177.839462  Add apples to pan
# 9    177.873138  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (187, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       26.889717      Right Hand Grab          ApplePieCookbook_C_0
# 1       41.441101      Right Hand Grab                           NaN
# 2       44.472000      Right Hand Grab          ApplePieCookbook_C_0
# 3       64.582657       Left Hand Grab  NewMeasuringCup_C_2147482389
# 4       67.406700      Right Hand Grab         SugarJar_C_2147482384
# 5       68.583374  Right Hand Released         SugarJar_C_2147482384
# 6       79.229881   Left Hand Released  NewMeasuringCup_C_2147482389
# 7       79.963455      Right Hand Grab  NewMeasuringCup_C_2147482389
# 8       81.957085  Right Hand Released  NewMeasuringCup_C_2147482389
# 9       83.137070       Left Hand Grab                           NaN
# 10      84.449486       Left Hand Grab  NewMeasuringCup_C_2147482389
# 170     93.362961                  NaN                           NaN
# 11      95.589836   Left Hand Released  NewMeasuringCup_C_2147482389
# 12     103.963181      Right Hand Grab         SugarJar_C_2147482384
# 13     106.277359  Right Hand Released         SugarJar_C_2147482384
# 14     108.186630      Right Hand Grab            StaticMeshActor_31
# 15     108.220467       Left Hand Grab            StaticMeshActor_31
# 16     109.116829   Left Hand Released            StaticMeshActor_31
# 17     109.417038  Right Hand Released            StaticMeshActor_31
# 18     110.113434      Right Hand Grab     ButterHolder_C_2147482386
# 19     113.026939  Right Hand Released     ButterHolder_C_2147482386
# 20     114.615044      Right Hand Grab           Butter_C_2147482385
# 21     116.222893  Right Hand Released           Butter_C_2147482385
# 22     118.833595      Right Hand Grab           Butter_C_2147482385
# 23     120.336769  Right Hand Released           Butter_C_2147482385
# 171    120.868073                  NaN                           NaN
# 24     122.003746      Right Hand Grab           Butter_C_2147482377
# 25     123.333031  Right Hand Released           Butter_C_2147482377
# 172    123.599838                  NaN                           NaN
# 26     132.579529      Right Hand Grab     WaterPitcher_C_2147482383
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    1.0            NaN
# 10                   0.0            NaN
# 170                  NaN     Add Sugar
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 171                  NaN     Add butter
# 24                   0.0            NaN
# 25                   0.0            NaN
# 172                  NaN     Add butter
# 26                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        67
# Right Hand Released    44
# Left Hand Grab         24
# Left Hand Released     18
# Chopped                17
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 170

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482375                14
# Knife_C_1                           12
# ApplePieCookbook_C_0                11
# NewMeasuringCup_C_2147482389         8
# StaticMeshActor_31                   6
# StirSpoonPie_C_2147482382            6
# Apple_Half2_C_2147482363             5
# PiePan_C_2147482380                  4
# Butter_C_2147482385                  4
# oven_C_1                             4
# Apple_Slice2_C_2147482361            4
# StaticMeshActor_23                   4
# Apple_Slice2_C_2147482346            4
# SugarJar_C_2147482384                4
# Apple_Slice2_C_2147482337            4
# Apple_Slice_C_2147482366             4
# Apple_C_2147482350                   3
# Apple_C_2147482371                   3
# Apple_Slice_C_2147482362             3
# Apple_C_2147482372                   3
# Apple_C_2147482409                   3
# Apple_Half_C_2147482342              2
# Apple_Half2_C_2147482348             2
# Apple_Slice_C_2147482347             2
# Apple_Slice4_C_2147482344            2
# Apple_Slice4_C_2147482339            2
# Apple_Slice3_C_2147482345            2
# Apple_Slice3_C_2147482340            2
# Apple_Slice_C_2147482338             2
# Apple_Slice3_C_2147482360            2
# Apple_Half_C_2147482364              2
# CinnyShakerGrabable_C_2147482387     2
# Apple_Slice4_C_2147482359            2
# Apple_Slice4_C_2147482367            2
# Apple_Slice3_C_2147482368            2
# Apple_Slice2_C_2147482365            2
# ButterHolder_C_2147482386            2
# SaucePot_C_2147482388                2
# Butter_C_2147482377                  2
# Apple_Half2_C_2147482369             2
# WaterPitcher_C_2147482383            2
# PillsberryDoughGirl_C_2147482335     1
# Apple_Half_C_2147482349              1
# PillsberryDoughBoy_C_2147482336      1
# Apple_Half_C_2147482370              1
# Apple_Half2_C_2147482341             1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    9
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              11   66.473244                  2.0
# 1          Add butter             13   25.278237                  0.0
# 2          Add butter              2    1.596092                  0.0
# 3           Add water              1    2.834381                  0.0
# 4   Add apples to pan             27   30.890335                  0.0
# 5   Add apples to pan              0    0.000000                  0.0
# 6   Add apples to pan              8    4.497406                  0.0
# 7   Add apples to pan              2    0.701752                  0.0
# 8   Add apples to pan              2    0.232162                  0.0
# 9   Add apples to pan              0    0.000000                  0.0
# 10  Add apples to pan              8    9.975204                  1.0
# 11  Add apples to pan              1    0.000000                  0.0
# 12  Add apples to pan              1    0.000000                  0.0
# 13       Add cinnamon              2    7.946121                  0.0
# 14         Pour syrup              2   15.363815                  0.0
# 15          Stir bowl             62  120.176254                  3.0
# 16   Add bottom crust              6   15.586670                  0.0
# 17      Add crust top              5   15.084595                  1.0
# 18    Put pie in oven              8   28.872772                  3.0
# 19     Post last step              9   23.842163                  1.0

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C017',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C017            170        369.351203                       11.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 170

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      20.000000   20.000000            20.000000
# mean        8.500000   18.467560             0.550000
# std        14.095539   28.960801             0.998683
# min         0.000000    0.000000             0.000000
# 25%         1.750000    0.584354             0.000000
# 50%         3.500000    8.960662             0.000000
# 75%         8.250000   24.201182             1.000000
# max        62.000000  120.176254             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      9   46.296859
# 1         Add butter      2   26.874329
# 2         Add Sugar       1   66.473244
# 3          Add water      1    2.834381
# 4       Add cinnamon      1    7.946121
# 5         Pour syrup      1   15.363815
# 6          Stir bowl      1  120.176254
# 7   Add bottom crust      1   15.586670
# 8      Add crust top      1   15.084595
# 9    Put pie in oven      1   28.872772

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add butter             0                 0       6             2
# Add apples to pan     37                 0       0             0
# Add cinnamon           0                 1       0             0
# Stir bowl             32                 5       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 1       0             0
# Add water              0                 0       0             0
# Add bottom crust       0                 0       0             0
# Pour syrup             0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                5        0
# Add butter                           0      0                1        0
# Add apples to pan                    0      4                2        2
# Add cinnamon                         1      0                0        0
# Stir bowl                            0      6                0        8
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Add water                            0      0                0        0
# Add bottom crust                     0      0                0        2
# Pour syrup                           1      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   0                    1         0
# Put pie in oven         2                   0                    0         0
# Add water               0                   0                    0         0
# Add bottom crust        0                   1                    0         0
# Pour syrup              0                   0                    0         1
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add butter                       4             0         2             0
# Add apples to pan                2             0         0             1
# Add cinnamon                     0             0         0             0
# Stir bowl                        4             3         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add water                        0             0         0             1
# Add bottom crust                 0             3         0             0
# Pour syrup                       0             0         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   9
# Add butter            0                  15
# Add apples to pan     0                  48
# Add cinnamon          0                   2
# Stir bowl             0                  59
# Add crust top         0                   4
# Put pie in oven       2                   5
# Add water             0                   1
# Add bottom crust      0                   6
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        67
# Right Hand Released    44
# Left Hand Grab         24
# Left Hand Released     18
# Chopped                17
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         4.0
# Left Hand Released     0.0
# Right Hand Grab        7.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            67                        7.0
# 4  Right Hand Released            44                        0.0
# 1       Left Hand Grab            24                        4.0
# 2   Left Hand Released            18                        0.0
# 0              Chopped            17                        0.0
