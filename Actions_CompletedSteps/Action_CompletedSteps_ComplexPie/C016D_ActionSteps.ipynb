# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C016 D/'
file_name = 'C016_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object
# 0     14.572898      Right Hand Grab          ApplePieCookbook_C_0
# 1    104.477310      Right Hand Grab          ApplePieCookbook_C_0
# 2    149.524216       Left Hand Grab  NewMeasuringCup_C_2147482377
# 3    153.007812      Right Hand Grab         SugarJar_C_2147482372
# 4    154.847458  Right Hand Released         SugarJar_C_2147482372

# %%
df1.shape
# Out:
# (208, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    195
# 1     13
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 10     188.953262   Left Hand Grab               NaN                    1
# 15     219.550781   Left Hand Grab               NaN                    1
# 18     230.112625   Left Hand Grab               NaN                    1
# 37     310.788513   Left Hand Grab               NaN                    1
# 71     362.992279   Left Hand Grab               NaN                    1
# 106    386.820129   Left Hand Grab               NaN                    1
# 149    437.504669  Right Hand Grab               NaN                    1
# 157    475.849762  Right Hand Grab               NaN                    1
# 164    506.937988   Left Hand Grab               NaN                    1
# 190    566.182190   Left Hand Grab               NaN                    1
# 194    575.465759   Left Hand Grab               NaN                    1
# 198    584.753418   Left Hand Grab               NaN                    1
# 206    628.851990  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object  \
# 0     14.572898      Right Hand Grab          ApplePieCookbook_C_0
# 1    104.477310      Right Hand Grab          ApplePieCookbook_C_0
# 2    149.524216       Left Hand Grab  NewMeasuringCup_C_2147482377
# 3    153.007812      Right Hand Grab         SugarJar_C_2147482372
# 4    154.847458  Right Hand Released         SugarJar_C_2147482372
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C016 D/'
file_name = 'C016_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    173.699799         Add Sugar
# 1    206.550247          Add water
# 2    261.761963         Add butter
# 3    264.958893         Add butter
# 4    365.603394  Add apples to pan
# 5    367.831421  Add apples to pan
# 6    367.831421  Add apples to pan
# 7    370.631439  Add apples to pan
# 8    370.894226  Add apples to pan
# 9    372.782928  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (234, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       14.572898      Right Hand Grab          ApplePieCookbook_C_0
# 1      104.477310      Right Hand Grab          ApplePieCookbook_C_0
# 2      149.524216       Left Hand Grab  NewMeasuringCup_C_2147482377
# 3      153.007812      Right Hand Grab         SugarJar_C_2147482372
# 4      154.847458  Right Hand Released         SugarJar_C_2147482372
# 5      163.294220   Left Hand Released  NewMeasuringCup_C_2147482377
# 6      165.167206       Left Hand Grab  NewMeasuringCup_C_2147482377
# 208    173.699799                  NaN                           NaN
# 7      184.330093      Right Hand Grab     WaterPitcher_C_2147482371
# 8      187.353928  Right Hand Released     WaterPitcher_C_2147482371
# 9      188.597244   Left Hand Released  NewMeasuringCup_C_2147482377
# 10     188.953262       Left Hand Grab                           NaN
# 11     189.684387      Right Hand Grab     WaterPitcher_C_2147482371
# 12     190.395142       Left Hand Grab  NewMeasuringCup_C_2147482377
# 209    206.550247                  NaN                           NaN
# 13     212.670258  Right Hand Released     WaterPitcher_C_2147482371
# 14     216.096832   Left Hand Released  NewMeasuringCup_C_2147482377
# 15     219.550781       Left Hand Grab                           NaN
# 16     220.450470       Left Hand Grab  NewMeasuringCup_C_2147482377
# 17     222.250244   Left Hand Released  NewMeasuringCup_C_2147482377
# 18     230.112625       Left Hand Grab                           NaN
# 19     235.996948       Left Hand Grab            StaticMeshActor_31
# 20     237.540909   Left Hand Released            StaticMeshActor_31
# 21     238.136948       Left Hand Grab  NewMeasuringCup_C_2147482377
# 22     240.972641   Left Hand Released  NewMeasuringCup_C_2147482377
# 23     243.073257       Left Hand Grab     ButterHolder_C_2147482374
# 24     247.933975   Left Hand Released     ButterHolder_C_2147482374
# 25     248.601669       Left Hand Grab         SaucePot_C_2147482376
# 26     250.296783   Left Hand Released         SaucePot_C_2147482376
# 27     251.097885       Left Hand Grab         SaucePot_C_2147482376
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 208                  NaN     Add Sugar
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   1.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 209                  NaN      Add water
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   1.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        55
# Left Hand Grab         53
# Right Hand Released    41
# Left Hand Released     38
# Chopped                21
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 208

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowl_C_2147482356                20
# StirSpoonPie_C_2147482370           12
# Knife_C_1                           12
# NewMeasuringCup_C_2147482377        10
# StaticMeshActor_31                  10
# PillsberryDoughGirl_C_2147482308     8
# SaucePot_C_2147482376                8
# StaticMeshActor_84                   8
# ApplePieCookbook_C_0                 6
# WaterPitcher_C_2147482371            6
# Apple_Slice4_C_2147482327            6
# PiePan_C_2147482368                  4
# CinnyShakerGrabable_C_2147482375     4
# StaticMeshActor_23                   4
# oven_C_1                             4
# Apple_Slice3_C_2147482324            3
# Apple_Slice3_C_2147482338            3
# Apple_Slice2_C_2147482335            3
# Apple_C_2147482341                   3
# Apple_C_2147482334                   3
# Apple_Slice2_C_2147482314            2
# Apple_Slice4_C_2147482342            2
# Apple_Slice4_C_2147482323            2
# Apple_C_2147482331                   2
# Apple_Half2_C_2147482318             2
# Apple_Half_C_2147482319              2
# Apple_Slice_C_2147482315             2
# Apple_Slice4_C_2147482316            2
# Butter_C_2147482373                  2
# Apple_Slice4_C_2147482337            2
# PillsberryDoughBoy_C_2147482309      2
# ButterHolder_C_2147482374            2
# Apple_Slice3_C_2147482317            2
# SugarJar_C_2147482372                2
# Apple_C_2147482393                   2
# Apple_Slice3_C_2147482343            2
# Apple_C_2147482351                   2
# Apple_C_2147482348                   2
# Apple_Slice2_C_2147482344            2
# Apple_Slice3_C_2147482328            2
# Apple_Slice_C_2147482326             2
# Apple_Slice_C_2147482345             2
# Apple_Half_C_2147482333              2
# Apple_Slice2_C_2147482325            2
# Apple_Half2_C_2147482329             2
# Apple_Half2_C_2147482332             2
# Butter_C_2147482360                  1
# Apple_Half_C_2147482347              1
# Apple_Half_C_2147482330              1
# Apple_Half_C_2147482340              1
# Apple_Half2_C_2147482339             1
# Apple_Half2_C_2147482346             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               7  159.126901                  0.0
# 1           Add water              6   22.220154                  1.0
# 2          Add butter             20   49.091705                  2.0
# 3          Add butter              1    2.197724                  0.0
# 4   Add apples to pan             42   59.024720                  2.0
# 5   Add apples to pan              4    1.199280                  0.0
# 6   Add apples to pan              0    0.000000                  0.0
# 7   Add apples to pan              4    1.054718                  0.0
# 8   Add apples to pan              0    0.000000                  0.0
# 9   Add apples to pan              3    1.354156                  0.0
# 10  Add apples to pan             15   10.961761                  0.0
# 11  Add apples to pan              2    1.169311                  0.0
# 12  Add apples to pan              2    1.404754                  0.0
# 13  Add apples to pan              9    9.395203                  1.0
# 14  Add apples to pan              2    1.597931                  0.0
# 15  Add apples to pan              2    2.399414                  0.0
# 16  Add apples to pan              4    2.964508                  0.0
# 17  Add apples to pan             15   10.025543                  0.0
# 18  Add apples to pan              1    1.596008                  0.0
# 19  Add apples to pan              4    3.490509                  0.0
# 20       Add cinnamon             11   28.903259                  1.0
# 21         Pour syrup              2   14.304321                  0.0
# 22          Stir bowl             11   43.062622                  2.0
# 23   Add bottom crust              9   18.814697                  0.0
# 24      Add crust top             21   35.779053                  2.0
# 25    Put pie in oven              6   25.281983                  1.0
# 26     Post last step              5   11.387268                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 208

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C016',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C016            208        517.807503                       13.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        7.703704   19.178056             0.481481
# std         8.982097   32.480283             0.752962
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.500381             0.000000
# 50%         4.000000    9.395203             0.000000
# 75%        10.000000   23.751068             1.000000
# max        42.000000  159.126901             2.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  107.637816
# 1         Add butter      2   51.289429
# 2         Add Sugar       1  159.126901
# 3          Add water      1   22.220154
# 4       Add cinnamon      1   28.903259
# 5         Pour syrup      1   14.304321
# 6          Stir bowl      1   43.062622
# 7   Add bottom crust      1   18.814697
# 8      Add crust top      1   35.779053
# 9    Put pie in oven      1   25.281983

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add water              0                 0       0             0
# Add butter             0                 0       3             2
# Add cinnamon           0                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          2                 1       0             0
# Put pie in oven        0                 1       0             0
# Add apples to pan     68                 0       0             0
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                3        0
# Add water                            0      0                2        0
# Add butter                           0      0                5        0
# Add cinnamon                         1      2                0        2
# Stir bowl                            0      0                0        1
# Add crust top                        0      0                0        2
# Put pie in oven                      0      0                0        0
# Add apples to pan                    2     10                0       12
# Pour syrup                           1      0                0        0
# Add bottom crust                     0      0                0        3
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         4
# Add cinnamon            0                   0                    0         2
# Stir bowl               0                   0                    0         1
# Add crust top           0                   0                    8         0
# Put pie in oven         2                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   2                    0         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add water                        0             0         0             3
# Add butter                       4             0         0             1
# Add cinnamon                     0             0         0             2
# Stir bowl                        2             4         0             0
# Add crust top                    4             2         0             0
# Put pie in oven                  0             0         0             0
# Add apples to pan               10             4         0             0
# Pour syrup                       0             0         0             0
# Add bottom crust                 2             2         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   7
# Add water             0                   5
# Add butter            0                  19
# Add cinnamon          0                  10
# Stir bowl             0                   9
# Add crust top         0                  19
# Put pie in oven       2                   5
# Add apples to pan     0                 106
# Pour syrup            0                   2
# Add bottom crust      0                   9

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        55
# Left Hand Grab         53
# Right Hand Released    41
# Left Hand Released     38
# Chopped                21
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         10.0
# Left Hand Released      0.0
# Right Hand Grab         3.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            55                        3.0
# 1       Left Hand Grab            53                       10.0
# 4  Right Hand Released            41                        0.0
# 2   Left Hand Released            38                        0.0
# 0              Chopped            21                        0.0
