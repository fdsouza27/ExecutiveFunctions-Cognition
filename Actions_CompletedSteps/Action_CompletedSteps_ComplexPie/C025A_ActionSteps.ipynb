# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C025 A/'
file_name = 'C025_ComplexPie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object
# 0     43.511257      Right Hand Grab          ApplePieCookbook_C_0
# 1     52.839195      Right Hand Grab          ApplePieCookbook_C_0
# 2     55.903423      Right Hand Grab         SugarJar_C_2147482384
# 3     58.977764  Right Hand Released         SugarJar_C_2147482384
# 4     60.070549      Right Hand Grab  NewMeasuringCup_C_2147482389

# %%
df1.shape
# Out:
# (159, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    142
# 1     17
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 23     107.322594  Right Hand Grab               NaN                    1
# 119    314.645416   Left Hand Grab               NaN                    1
# 120    314.845490  Right Hand Grab               NaN                    1
# 121    316.094330  Right Hand Grab               NaN                    1
# 124    318.610107  Right Hand Grab               NaN                    1
# 125    325.078491  Right Hand Grab               NaN                    1
# 129    327.609802  Right Hand Grab               NaN                    1
# 131    330.185516  Right Hand Grab               NaN                    1
# 132    330.252472   Left Hand Grab               NaN                    1
# 135    333.362610  Right Hand Grab               NaN                    1
# 138    338.850494   Left Hand Grab               NaN                    1
# 139    338.962891  Right Hand Grab               NaN                    1
# 140    345.115692   Left Hand Grab               NaN                    1
# 141    345.115692  Right Hand Grab               NaN                    1
# 142    349.004242   Left Hand Grab               NaN                    1
# 143    349.337128  Right Hand Grab               NaN                    1
# 144    358.003906  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type             Interacted Object  \
# 0     43.511257      Right Hand Grab          ApplePieCookbook_C_0
# 1     52.839195      Right Hand Grab          ApplePieCookbook_C_0
# 2     55.903423      Right Hand Grab         SugarJar_C_2147482384
# 3     58.977764  Right Hand Released         SugarJar_C_2147482384
# 4     60.070549      Right Hand Grab  NewMeasuringCup_C_2147482389
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C025 A/'
file_name = 'C025_ComplexPie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     62.648346         Add Sugar
# 1     74.641235          Add water
# 2     99.186058         Add butter
# 3    102.114929         Add butter
# 4    131.518066  Add apples to pan
# 5    133.354828  Add apples to pan
# 6    135.322525  Add apples to pan
# 7    137.486298  Add apples to pan
# 8    157.986069  Add apples to pan
# 9    165.247589  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (177, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0       43.511257      Right Hand Grab          ApplePieCookbook_C_0
# 1       52.839195      Right Hand Grab          ApplePieCookbook_C_0
# 2       55.903423      Right Hand Grab         SugarJar_C_2147482384
# 3       58.977764  Right Hand Released         SugarJar_C_2147482384
# 4       60.070549      Right Hand Grab  NewMeasuringCup_C_2147482389
# 159     62.648346                  NaN                           NaN
# 5       64.543839  Right Hand Released  NewMeasuringCup_C_2147482389
# 6       72.165924      Right Hand Grab     WaterPitcher_C_2147482383
# 160     74.641235                  NaN                           NaN
# 7       77.800293  Right Hand Released     WaterPitcher_C_2147482383
# 8       81.300011      Right Hand Grab            StaticMeshActor_31
# 9       82.829514  Right Hand Released            StaticMeshActor_31
# 10      83.497520      Right Hand Grab  NewMeasuringCup_C_2147482389
# 11      84.562004  Right Hand Released  NewMeasuringCup_C_2147482389
# 12      85.191284      Right Hand Grab     ButterHolder_C_2147482386
# 13      86.455605  Right Hand Released     ButterHolder_C_2147482386
# 14      87.282944      Right Hand Grab     ButterHolder_C_2147482386
# 15      87.986931  Right Hand Released     ButterHolder_C_2147482386
# 16      89.785210      Right Hand Grab           Butter_C_2147482385
# 17      91.525169  Right Hand Released           Butter_C_2147482385
# 18      94.464180      Right Hand Grab  NewMeasuringCup_C_2147482389
# 19      95.794067  Right Hand Released  NewMeasuringCup_C_2147482389
# 20      96.623207      Right Hand Grab           Butter_C_2147482377
# 21      98.815109  Right Hand Released           Butter_C_2147482377
# 161     99.186058                  NaN                           NaN
# 22     100.215263      Right Hand Grab           Butter_C_2147482376
# 162    102.114929                  NaN                           NaN
# 23     107.322594      Right Hand Grab                           NaN
# 24     108.452690      Right Hand Grab            StaticMeshActor_31
# 25     109.522697  Right Hand Released            StaticMeshActor_31
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 159                  NaN     Add Sugar
# 5                    0.0            NaN
# 6                    0.0            NaN
# 160                  NaN      Add water
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 161                  NaN     Add butter
# 22                   0.0            NaN
# 162                  NaN     Add butter
# 23                   1.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Right Hand Released    43
# Chopped                22
# Left Hand Grab         15
# Left Hand Released      8
# Name: count, dtype: int64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 159

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# SaucePot_C_2147482388               10
# ApplePieCookbook_C_0                 8
# PiePan_C_2147482380                  8
# Knife_C_1                            8
# Apple_Slice3_C_2147482345            7
# NewMeasuringCup_C_2147482389         6
# PieBowl_C_2147482374                 6
# oven_C_1                             6
# Apple_C_2147482409                   5
# Apple_Slice_C_2147482363             4
# Apple_Slice4_C_2147482344            4
# ButterHolder_C_2147482386            4
# StaticMeshActor_31                   4
# Apple_C_2147482406                   3
# Apple_Slice_C_2147482343             3
# Apple_C_2147482373                   3
# Apple_C_2147482366                   3
# Apple_Slice3_C_2147482352            2
# Apple_Slice_C_2147482354             2
# Apple_Slice2_C_2147482342            2
# Apple_Slice4_C_2147482351            2
# Apple_Half2_C_2147482346             2
# CinnyShakerGrabable_C_2147482387     2
# StirSpoonPie_C_2147482382            2
# Apple_Slice2_C_2147482353            2
# Apple_Slice4_C_2147482360            2
# Butter_C_2147482377                  2
# Apple_Slice3_C_2147482361            2
# SugarJar_C_2147482384                2
# Apple_Slice2_C_2147482362            2
# WaterPitcher_C_2147482383            2
# Apple_Half2_C_2147482364             2
# Apple_Slice4_C_2147482367            2
# Apple_Slice_C_2147482370             2
# Apple_Slice3_C_2147482368            2
# Butter_C_2147482385                  2
# Apple_Slice2_C_2147482369            2
# Apple_Half_C_2147482358              1
# PillsberryDoughBoy_C_2147482339      1
# PillsberryDoughGirl_C_2147482338     1
# Apple_Half_C_2147482347              1
# Butter_C_2147482376                  1
# Apple_Half_C_2147482372              1
# Apple_Half2_C_2147482371             1
# Apple_Half2_C_2147482357             1
# Apple_Half_C_2147482365              1
# Exit_C_0                             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               5   19.137089                  0.0
# 1           Add water              2   10.097396                  0.0
# 2          Add butter             15   21.385765                  0.0
# 3          Add butter              1    1.899666                  0.0
# 4   Add apples to pan             14   24.195472                  1.0
# 5   Add apples to pan              2    1.166641                  0.0
# 6   Add apples to pan              2    1.199936                  0.0
# 7   Add apples to pan              2    1.298630                  0.0
# 8   Add apples to pan              9   18.102448                  0.0
# 9   Add apples to pan              7    7.228241                  0.0
# 10  Add apples to pan              2    1.299133                  0.0
# 11  Add apples to pan              2    1.398345                  0.0
# 12       Add cinnamon             41   59.556076                  0.0
# 13         Pour syrup              2    5.498856                  0.0
# 14          Stir bowl              3   14.966599                  0.0
# 15   Add bottom crust              2    9.959869                  0.0
# 16      Add crust top              6   26.900726                  0.0
# 17    Put pie in oven             35  111.279602                 16.0
# 18     Post last step              7   22.553863                  0.0

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C025',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C025            159        359.124353                       17.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 159

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        8.368421   18.901282             0.894737
# std        11.250731   26.489589             3.665071
# min         1.000000    1.166641             0.000000
# 25%         2.000000    1.649006             0.000000
# 50%         3.000000   10.097396             0.000000
# 75%         8.000000   21.969814             0.000000
# max        41.000000  111.279602            16.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   55.888846
# 1         Add butter      2   23.285431
# 2         Add Sugar       1   19.137089
# 3          Add water      1   10.097396
# 4       Add cinnamon      1   59.556076
# 5         Pour syrup      1    5.498856
# 6          Stir bowl      1   14.966599
# 7   Add bottom crust      1    9.959869
# 8      Add crust top      1   26.900726
# 9    Put pie in oven      1  111.279602

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)

interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolder  \
# Add Sugar              0                 2       0             0
# Add cinnamon          35                 1       0             0
# Stir bowl              0                 1       0             0
# Add crust top          0                 1       0             0
# Put pie in oven        0                 3       0             0
# Add water              0                 0       0             0
# Add butter             0                 0       5             4
# Add apples to pan     31                 0       0             0
# Pour syrup             0                 0       0             0
# Add bottom crust       0                 0       0             0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCup  PieBowl  \
# Add Sugar                            0      0                1        0
# Add cinnamon                         1      4                0        0
# Stir bowl                            0      0                0        0
# Add crust top                        0      0                0        4
# Put pie in oven                      0      0                0        0
# Add water                            0      0                1        0
# Add butter                           0      0                4        0
# Add apples to pan                    0      4                0        2
# Pour syrup                           1      0                0        0
# Add bottom crust                     0      0                0        0
#
#                    PiePan  PillsberryDoughBoy  PillsberryDoughGirl  SaucePot  \
# Add Sugar               0                   0                    0         0
# Add cinnamon            0                   0                    0         0
# Stir bowl               0                   0                    0         1
# Add crust top           0                   1                    0         0
# Put pie in oven         4                   0                    0         8
# Add water               0                   0                    0         0
# Add butter              0                   0                    0         0
# Add apples to pan       0                   0                    0         0
# Pour syrup              0                   0                    0         1
# Add bottom crust        0                   0                    1         0
#
#                    StaticMeshActor  StirSpoonPie  SugarJar  WaterPitcher  \
# Add Sugar                        0             0         2             0
# Add cinnamon                     0             0         0             0
# Stir bowl                        0             1         0             0
# Add crust top                    0             0         0             0
# Put pie in oven                  0             0         0             0
# Add water                        0             0         0             1
# Add butter                       2             0         0             1
# Add apples to pan                2             0         0             0
# Pour syrup                       0             0         0             0
# Add bottom crust                 0             1         0             0
#
#                    oven  Interacted Objects
# Add Sugar             0                   5
# Add cinnamon          0                  41
# Stir bowl             0                   3
# Add crust top         0                   6
# Put pie in oven       4                  19
# Add water             0                   2
# Add butter            0                  16
# Add apples to pan     0                  39
# Pour syrup            0                   2
# Add bottom crust      0                   2

# %%
feature_df = df_sorted.copy()

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Right Hand Released    43
# Chopped                22
# Left Hand Grab         15
# Left Hand Released      8
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          5.0
# Left Hand Released      0.0
# Right Hand Grab        12.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            71                       12.0
# 4  Right Hand Released            43                        0.0
# 0              Chopped            22                        0.0
# 1       Left Hand Grab            15                        5.0
# 2   Left Hand Released             8                        0.0
