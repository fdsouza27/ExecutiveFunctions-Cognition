# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C018 B/'
file_name = 'C018_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0      3.773839  Right Hand Grab  ApplePieCookbook_C_0
# 1     10.367924  Right Hand Grab                   NaN
# 2     96.376259  Right Hand Grab                   NaN
# 3     98.130699  Right Hand Grab                   NaN
# 4    100.508194  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (225, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    188
# 1     37
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       10.367924  Right Hand Grab               NaN                    1
# 2       96.376259  Right Hand Grab               NaN                    1
# 3       98.130699  Right Hand Grab               NaN                    1
# 4      100.508194  Right Hand Grab               NaN                    1
# 5      103.108337  Right Hand Grab               NaN                    1
# 6      104.919952  Right Hand Grab               NaN                    1
# 7      108.166458  Right Hand Grab               NaN                    1
# 8      110.906364  Right Hand Grab               NaN                    1
# 9      120.710808   Left Hand Grab               NaN                    1
# 10     121.177368  Right Hand Grab               NaN                    1
# 11     121.877281  Right Hand Grab               NaN                    1
# 12     122.009995   Left Hand Grab               NaN                    1
# 13     123.327263   Left Hand Grab               NaN                    1
# 33     192.344925   Left Hand Grab               NaN                    1
# 34     193.469894   Left Hand Grab               NaN                    1
# 47     216.354385   Left Hand Grab               NaN                    1
# 52     219.009415   Left Hand Grab               NaN                    1
# 62     257.533722  Right Hand Grab               NaN                    1
# 67     264.230164  Right Hand Grab               NaN                    1
# 68     265.460510  Right Hand Grab               NaN                    1
# 69     266.749420  Right Hand Grab               NaN                    1
# 160    362.944672  Right Hand Grab               NaN                    1
# 168    387.851990  Right Hand Grab               NaN                    1
# 169    388.964417  Right Hand Grab               NaN                    1
# 170    389.588104  Right Hand Grab               NaN                    1
# 171    390.254059  Right Hand Grab               NaN                    1
# 174    403.014648   Left Hand Grab               NaN                    1
# 199    445.300262  Right Hand Grab               NaN                    1
# 200    446.357727  Right Hand Grab               NaN                    1
# 210    480.990540   Left Hand Grab               NaN                    1
# 216    497.131195   Left Hand Grab               NaN                    1
# 217    497.952179   Left Hand Grab               NaN                    1
# 218    498.819183   Left Hand Grab               NaN                    1
# 220    504.007111  Right Hand Grab               NaN                    1
# 221    504.838043  Right Hand Grab               NaN                    1
# 222    505.482117  Right Hand Grab               NaN                    1
# 223    506.224335  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0      3.773839  Right Hand Grab  ApplePieCookbook_C_0                    0
# 1     10.367924  Right Hand Grab                   NaN                    1
# 2     96.376259  Right Hand Grab                   NaN                    1
# 3     98.130699  Right Hand Grab                   NaN                    1
# 4    100.508194  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C018 B/'
file_name = 'C018_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    211.573227         Add Sugar
# 1    228.008209          Add water
# 2    247.480576         Add butter
# 3    252.246704         Add butter
# 4    332.170319  Add apples to pan
# 5    334.191803  Add apples to pan
# 6    335.943115  Add apples to pan
# 7    337.788544  Add apples to pan
# 8    341.863403  Add apples to pan
# 9    343.711426  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (250, 5)

# %%
df.head(30)
# Out:
#     Session Time         Action Type                    Interacted Object  \
# 0       3.773839     Right Hand Grab                 ApplePieCookbook_C_0
# 1      10.367924     Right Hand Grab                                  NaN
# 2      96.376259     Right Hand Grab                                  NaN
# 3      98.130699     Right Hand Grab                                  NaN
# 4     100.508194     Right Hand Grab                                  NaN
# 5     103.108337     Right Hand Grab                                  NaN
# 6     104.919952     Right Hand Grab                                  NaN
# 7     108.166458     Right Hand Grab                                  NaN
# 8     110.906364     Right Hand Grab                                  NaN
# 9     120.710808      Left Hand Grab                                  NaN
# 10    121.177368     Right Hand Grab                                  NaN
# 11    121.877281     Right Hand Grab                                  NaN
# 12    122.009995      Left Hand Grab                                  NaN
# 13    123.327263      Left Hand Grab                                  NaN
# 14    123.604797     Right Hand Grab                 ApplePieCookbook_C_0
# 15    164.383392      Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 16    166.416550  Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 17    167.082886      Left Hand Grab          SugarJarSimple_C_2147482373
# 18    169.172287  Left Hand Released          SugarJarSimple_C_2147482373
# 19    170.520355      Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 20    175.349777  Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 21    176.283340      Left Hand Grab                 ApplePieCookbook_C_0
# 22    177.285004      Left Hand Grab                 ApplePieCookbook_C_0
# 23    178.462280      Left Hand Grab                 ApplePieCookbook_C_0
# 24    179.816055      Left Hand Grab                 ApplePieCookbook_C_0
# 25    182.512711      Left Hand Grab                 ApplePieCookbook_C_0
# 26    184.022568      Left Hand Grab                 ApplePieCookbook_C_0
# 27    185.800781      Left Hand Grab                 ApplePieCookbook_C_0
# 28    186.624786      Left Hand Grab                 ApplePieCookbook_C_0
# 29    187.592621      Left Hand Grab                 ApplePieCookbook_C_0
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   1.0            NaN
# 6                   1.0            NaN
# 7                   1.0            NaN
# 8                   1.0            NaN
# 9                   1.0            NaN
# 10                  1.0            NaN
# 11                  1.0            NaN
# 12                  1.0            NaN
# 13                  1.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
#df.to_csv('act_step_C018B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Left Hand Grab         69
# Right Hand Released    36
# Left Hand Released     25
# Chopped                24
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     45.000000
# std      23.313086
# min      24.000000
# 25%      25.000000
# 50%      36.000000
# 75%      69.000000
# max      71.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 225

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# ApplePieCookbook_C_0                      34
# PieBowlSimple_C_2147482366                34
# PiePanSimple_C_2147482369                 10
# NewMeasuringCupSimple2_C_2147482378        6
# Apple_Slice2_C_2147482351                  6
# oven_C_1                                   6
# PillsberryDoughGirlSimple_C_2147482335     5
# Apple_Slice2_C_2147482339                  4
# Apple_Slice4_C_2147482341                  4
# StirSpoonPieSImple_C_2147482371            4
# Apple_Slice_C_2147482344                   3
# Apple_Slice_C_2147482352                   3
# Apple_Slice2_C_2147482357                  3
# Apple_Slice_C_2147482358                   3
# Apple_Slice3_C_2147482342                  3
# PillsberryDoughBoySimple_C_2147482336      3
# Apple_C_2147482363                         3
# Apple_C_2147482387                         3
# Apple_C_2147482364                         3
# Apple_C_2147482365                         3
# Apple_Slice2_C_2147482343                  2
# CinnyShakerGrabable_C_2147482376           2
# Apple_Slice4_C_2147482337                  2
# Apple_Slice3_C_2147482338                  2
# Apple_Slice_C_2147482340                   2
# Apple_Slice4_C_2147482349                  2
# Apple_Slice3_C_2147482356                  2
# SugarJarSimple_C_2147482373                2
# SaucePotSimple2_C_2147482377               2
# Butter_C_2147482368                        2
# Apple_Slice4_C_2147482355                  2
# Apple_Slice3_C_2147482350                  2
# Apple_C_2147482388                         2
# WaterPitcherSimple_C_2147482372            2
# Apple_Half2_C_2147482347                   2
# ButterHolderSimple_C_2147482375            2
# Apple_Half_C_2147482354                    2
# Apple_Half_C_2147482360                    2
# Knife_C_4                                  2
# Butter_C_2147482374                        2
# Apple_Half_C_2147482346                    1
# Apple_Half2_C_2147482345                   1
# Apple_Half2_C_2147482353                   1
# Apple_Half2_C_2147482359                   1
# Apple_Half_C_2147482348                    1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              46  207.799388                 15.0
# 1           Add water              9   14.399826                  2.0
# 2          Add butter              5   10.004044                  0.0
# 3          Add butter              2    3.366638                  0.0
# 4   Add apples to pan             62   74.636597                  4.0
# 5   Add apples to pan              2    1.255341                  0.0
# 6   Add apples to pan              1    1.006256                  0.0
# 7   Add apples to pan              3    1.801178                  0.0
# 8   Add apples to pan              6    2.980468                  0.0
# 9   Add apples to pan              2    1.041199                  0.0
# 10  Add apples to pan              6    3.411987                  0.0
# 11  Add apples to pan              0    0.000000                  0.0
# 12  Add apples to pan              4    2.043823                  0.0
# 13  Add apples to pan              0    0.000000                  0.0
# 14  Add apples to pan              4    2.334778                  0.0
# 15  Add apples to pan              0    0.000000                  0.0
# 16  Add apples to pan              4    2.097657                  0.0
# 17  Add apples to pan              0    0.000000                  0.0
# 18  Add apples to pan              4    2.105499                  0.0
# 19  Add apples to pan              0    0.000000                  0.0
# 20       Add cinnamon              3    7.429077                  1.0
# 21         Pour syrup              4   11.052551                  0.0
# 22          Stir bowl             12   29.645142                  5.0
# 23   Add bottom crust             20   24.234039                  0.0
# 24      Add crust top              6   11.315278                  2.0
# 25    Put pie in oven              7   24.077973                  1.0
# 26     Post last step             13   22.736511                  7.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 225

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C018',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C018            225         460.77525                       37.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        8.333333   17.065750             1.370370
# std        14.104009   41.194012             3.248054
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.148270             0.000000
# 50%         4.000000    2.980468             0.000000
# 75%         6.500000   12.857552             1.000000
# max        62.000000  207.799388            15.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16   94.714783
# 1         Add butter      2   13.370682
# 2         Add Sugar       1  207.799388
# 3          Add water      1   14.399826
# 4       Add cinnamon      1    7.429077
# 5         Pour syrup      1   11.052551
# 6          Stir bowl      1   29.645142
# 7   Add bottom crust      1   24.234039
# 8      Add crust top      1   11.315278
# 9    Put pie in oven      1   24.077973

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                24       0                   0
# Add water              0                 5       0                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add butter             0                 0       4                   2
# Add apples to pan     70                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       5
# Add water                            0      0                       1
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       0
# Add apples to pan                    0      2                       0
# Pour syrup                           1      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      2             0                         0
# Add crust top                  2             0                         1
# Put pie in oven                0             2                         0
# Add butter                     0             0                         0
# Add apples to pan             22             0                         0
# Pour syrup                     2             0                         0
# Add bottom crust               6             6                         2
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add crust top                              0                0
# Put pie in oven                            0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Pour syrup                                 0                1
# Add bottom crust                           5                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add water                           0               0                   1
# Add cinnamon                        0               0                   0
# Stir bowl                           3               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Pour syrup                          0               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  31
# Add water             0                   7
# Add cinnamon          0                   2
# Stir bowl             0                   7
# Add crust top         0                   4
# Put pie in oven       3                   6
# Add butter            0                   7
# Add apples to pan     0                  94
# Pour syrup            0                   4
# Add bottom crust      0                  20

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time      Action Type     Interacted Object  Missed Interactions  \
# 0        3.773839  Right Hand Grab  ApplePieCookbook_C_0                  0.0
# 1       10.367924  Right Hand Grab                   NaN                  1.0
# 2       96.376259  Right Hand Grab                   NaN                  1.0
# 3       98.130699  Right Hand Grab                   NaN                  1.0
# 4      100.508194  Right Hand Grab                   NaN                  1.0
# ..            ...              ...                   ...                  ...
# 245    504.007111  Right Hand Grab                   NaN                  1.0
# 246    504.838043  Right Hand Grab                   NaN                  1.0
# 247    505.482117  Right Hand Grab                   NaN                  1.0
# 248    506.224335  Right Hand Grab                   NaN                  1.0
# 249    507.399902  Right Hand Grab  ApplePieCookbook_C_0                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 245            NaN
# 246            NaN
# 247            NaN
# 248            NaN
# 249            NaN
#
# [250 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Left Hand Grab         69
# Right Hand Released    36
# Left Hand Released     25
# Chopped                24
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         12.0
# Left Hand Released      0.0
# Right Hand Grab        25.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            71                       25.0
# 1       Left Hand Grab            69                       12.0
# 4  Right Hand Released            36                        0.0
# 2   Left Hand Released            25                        0.0
# 0              Chopped            24                        0.0
