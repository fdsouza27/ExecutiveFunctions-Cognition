# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C023 C/'
file_name = 'C023_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object
# 0      8.167534      Right Hand Grab         ApplePieCookbook_C_0
# 1     14.232637      Right Hand Grab         ApplePieCookbook_C_0
# 2     22.364754      Right Hand Grab  SugarJarSimple_C_2147482373
# 3     23.397171  Right Hand Released  SugarJarSimple_C_2147482373
# 4     24.389807       Left Hand Grab                          NaN

# %%
df1.shape
# Out:
# (179, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    162
# 1     17
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 4       24.389807   Left Hand Grab               NaN                    1
# 7       44.161777  Right Hand Grab               NaN                    1
# 12      56.348656  Right Hand Grab               NaN                    1
# 55     141.342285  Right Hand Grab               NaN                    1
# 118    228.962723  Right Hand Grab               NaN                    1
# 119    229.650497  Right Hand Grab               NaN                    1
# 148    297.194672  Right Hand Grab               NaN                    1
# 152    337.174530  Right Hand Grab               NaN                    1
# 153    338.196442  Right Hand Grab               NaN                    1
# 154    341.552216  Right Hand Grab               NaN                    1
# 155    342.842133  Right Hand Grab               NaN                    1
# 156    343.963593  Right Hand Grab               NaN                    1
# 157    344.741669  Right Hand Grab               NaN                    1
# 162    360.938263  Right Hand Grab               NaN                    1
# 163    361.994537   Left Hand Grab               NaN                    1
# 164    362.893738   Left Hand Grab               NaN                    1
# 177    384.508636  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object  \
# 0      8.167534      Right Hand Grab         ApplePieCookbook_C_0
# 1     14.232637      Right Hand Grab         ApplePieCookbook_C_0
# 2     22.364754      Right Hand Grab  SugarJarSimple_C_2147482373
# 3     23.397171  Right Hand Released  SugarJarSimple_C_2147482373
# 4     24.389807       Left Hand Grab                          NaN
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C023 C/'
file_name = 'C023_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     67.014099         Add Sugar
# 1     86.165962          Add water
# 2    105.238159         Add butter
# 3    108.528458         Add butter
# 4    149.551941  Add apples to pan
# 5    170.168610  Add apples to pan
# 6    173.389084  Add apples to pan
# 7    177.358093  Add apples to pan
# 8    178.945145  Add apples to pan
# 9    180.457123  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (205, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0        8.167534      Right Hand Grab                 ApplePieCookbook_C_0
# 1       14.232637      Right Hand Grab                 ApplePieCookbook_C_0
# 2       22.364754      Right Hand Grab          SugarJarSimple_C_2147482373
# 3       23.397171  Right Hand Released          SugarJarSimple_C_2147482373
# 4       24.389807       Left Hand Grab                                  NaN
# 5       25.939974      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 6       43.649376  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 7       44.161777      Right Hand Grab                                  NaN
# 8       45.326744      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 9       48.425503  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 10      50.837059      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 11      52.315220  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 12      56.348656      Right Hand Grab                                  NaN
# 13      57.903793      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 14      62.336636       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 15      63.645893  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 179     67.014099                  NaN                                  NaN
# 16      69.611198   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 17      70.612839      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 18      71.535492  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 19      79.519653      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 180     86.165962                  NaN                                  NaN
# 20      90.496239  Right Hand Released      WaterPitcherSimple_C_2147482372
# 21      96.872589      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 22      98.239677  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 23      98.983879      Right Hand Grab      ButterHolderSimple_C_2147482375
# 24     100.118256  Right Hand Released      ButterHolderSimple_C_2147482375
# 25     101.094521      Right Hand Grab                  Butter_C_2147482374
# 26     105.215828  Right Hand Released                  Butter_C_2147482374
# 181    105.238159                  NaN                                  NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   1.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 179                  NaN     Add Sugar
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 180                  NaN      Add water
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 181                  NaN     Add butter

# %%
#df.to_csv('act_step_C023C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    48
# Left Hand Grab         19
# Chopped                18
# Left Hand Released     14
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     35.800000
# std      28.181554
# min      14.000000
# 25%      18.000000
# 50%      19.000000
# 75%      48.000000
# max      80.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 179

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowlSimple_C_2147482366                24
# PiePanSimple_C_2147482369                 16
# NewMeasuringCupSimple2_C_2147482378       14
# oven_C_1                                  10
# ApplePieCookbook_C_0                       7
# Knife_C_4                                  6
# CinnyShakerGrabable_C_2147482376           6
# StirSpoonPieSImple_C_2147482371            6
# Apple_Slice4_C_2147482352                  5
# WaterPitcherSimple_C_2147482372            4
# Apple_C_2147482364                         3
# Apple_C_2147482365                         3
# Apple_C_2147482391                         3
# Apple_C_2147482363                         3
# Apple_Slice4_C_2147482346                  2
# Apple_Slice2_C_2147482340                  2
# Apple_Slice2_C_2147482356                  2
# Apple_Slice2_C_2147482350                  2
# Apple_Slice_C_2147482357                   2
# Apple_Slice3_C_2147482359                  2
# Apple_Slice_C_2147482351                   2
# Apple_Slice3_C_2147482353                  2
# Apple_Slice4_C_2147482358                  2
# Apple_Slice_C_2147482341                   2
# SaucePotSimple2_C_2147482377               2
# Apple_Slice3_C_2147482347                  2
# ButterHolderSimple_C_2147482375            2
# Apple_Slice_C_2147482345                   2
# Apple_Half2_C_2147482342                   2
# Apple_Half2_C_2147482360                   2
# Apple_Half2_C_2147482354                   2
# Butter_C_2147482374                        2
# Apple_Slice2_C_2147482344                  2
# Apple_Slice3_C_2147482339                  2
# SugarJarSimple_C_2147482373                2
# Apple_Slice4_C_2147482338                  2
# Apple_Half_C_2147482343                    1
# Apple_Half_C_2147482349                    1
# Apple_Half_C_2147482355                    1
# Apple_Half_C_2147482361                    1
# PillsberryDoughBoySimple_C_2147482337      1
# PillsberryDoughGirlSimple_C_2147482336     1
# Butter_C_2147482368                        1
# Apple_Half2_C_2147482348                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              16   58.846565                  3.0
# 1           Add water              4   16.554764                  0.0
# 2          Add butter              7   14.741920                  0.0
# 3          Add butter              1    2.111855                  0.0
# 4   Add apples to pan             35   33.428398                  1.0
# 5   Add apples to pan              9   15.872589                  0.0
# 6   Add apples to pan              3    2.665207                  0.0
# 7   Add apples to pan              5    3.946426                  0.0
# 8   Add apples to pan              2    0.787888                  0.0
# 9   Add apples to pan              2    1.245087                  0.0
# 10  Add apples to pan              2    0.865814                  0.0
# 11  Add apples to pan              2    1.023193                  0.0
# 12  Add apples to pan              2    1.410782                  0.0
# 13  Add apples to pan              2    1.234772                  0.0
# 14  Add apples to pan              2    0.879135                  0.0
# 15  Add apples to pan              2    1.077499                  0.0
# 16  Add apples to pan              2    1.011688                  0.0
# 17  Add apples to pan              2    1.056976                  0.0
# 18  Add apples to pan              2    1.045273                  0.0
# 19  Add apples to pan              2    1.264526                  0.0
# 20       Add cinnamon              5    8.074570                  0.0
# 21         Pour syrup              8   16.185608                  0.0
# 22          Stir bowl             14   22.485183                  2.0
# 23   Add bottom crust              5    5.440948                  0.0
# 24      Add crust top              4   10.797669                  0.0
# 25    Put pie in oven             25   93.303528                 10.0
# 26     Post last step             14   15.553040                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 179

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C023',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C023            179        332.910903                       17.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        6.629630   12.330033             0.629630
# std         8.015121   20.742634             2.002847
# min         1.000000    0.787888             0.000000
# 25%         2.000000    1.067238             0.000000
# 50%         3.000000    2.665207             0.000000
# 75%         7.500000   15.712815             0.000000
# max        35.000000   93.303528            10.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16   68.815253
# 1         Add butter      2   16.853775
# 2         Add Sugar       1   58.846565
# 3          Add water      1   16.554764
# 4       Add cinnamon      1    8.074570
# 5         Pour syrup      1   16.185608
# 6          Stir bowl      1   22.485183
# 7   Add bottom crust      1    5.440948
# 8      Add crust top      1   10.797669
# 9    Put pie in oven      1   93.303528

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add water              0                 0       0                   0
# Add butter             0                 0       3                   2
# Add apples to pan     58                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add cinnamon           0                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       9
# Add water                            0      0                       3
# Add butter                           0      0                       2
# Add apples to pan                    0      6                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add cinnamon                         1      0                       0
# Pour syrup                           5      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add butter                     0             0                         0
# Add apples to pan             10             0                         0
# Stir bowl                      3             0                         0
# Add crust top                  2             0                         0
# Put pie in oven                0             6                         0
# Add cinnamon                   4             0                         0
# Pour syrup                     2             0                         0
# Add bottom crust               3             0                         1
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Stir bowl                                  0                1
# Add crust top                              1                0
# Put pie in oven                            0                0
# Add cinnamon                               0                0
# Pour syrup                                 0                1
# Add bottom crust                           0                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add water                           0               0                   1
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Stir bowl                           5               0                   2
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add cinnamon                        0               0                   0
# Pour syrup                          0               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  13
# Add water             0                   4
# Add butter            0                   8
# Add apples to pan     0                  75
# Stir bowl             0                  12
# Add crust top         0                   4
# Put pie in oven       8                  15
# Add cinnamon          0                   5
# Pour syrup            0                   8
# Add bottom crust      0                   5

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0        8.167534      Right Hand Grab         ApplePieCookbook_C_0
# 1       14.232637      Right Hand Grab         ApplePieCookbook_C_0
# 2       22.364754      Right Hand Grab  SugarJarSimple_C_2147482373
# 3       23.397171  Right Hand Released  SugarJarSimple_C_2147482373
# 4       24.389807       Left Hand Grab                          NaN
# ..            ...                  ...                          ...
# 200    378.500610  Right Hand Released    PiePanSimple_C_2147482369
# 201    379.009613   Left Hand Released    PiePanSimple_C_2147482369
# 202    381.575958      Right Hand Grab                     oven_C_1
# 203    384.508636      Right Hand Grab                          NaN
# 204    385.234192      Right Hand Grab         ApplePieCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 200                  0.0            NaN
# 201                  0.0            NaN
# 202                  0.0            NaN
# 203                  1.0            NaN
# 204                  0.0            NaN
#
# [205 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    48
# Left Hand Grab         19
# Chopped                18
# Left Hand Released     14
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          3.0
# Left Hand Released      0.0
# Right Hand Grab        14.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            80                       14.0
# 4  Right Hand Released            48                        0.0
# 1       Left Hand Grab            19                        3.0
# 0              Chopped            18                        0.0
# 2   Left Hand Released            14                        0.0
