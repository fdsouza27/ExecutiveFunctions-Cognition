# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C015 C/'
file_name = 'C015_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0      6.043740  Right Hand Grab  ApplePieCookbook_C_0
# 1      8.886678  Right Hand Grab                   NaN
# 2      9.805173  Right Hand Grab                   NaN
# 3     10.331388  Right Hand Grab                   NaN
# 4     14.112337  Right Hand Grab  ApplePieCookbook_C_0

# %%
df1.shape
# Out:
# (148, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    141
# 1      7
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1        8.886678  Right Hand Grab               NaN                    1
# 2        9.805173  Right Hand Grab               NaN                    1
# 3       10.331388  Right Hand Grab               NaN                    1
# 116    145.435959  Right Hand Grab               NaN                    1
# 141    207.585815  Right Hand Grab               NaN                    1
# 145    217.097534  Right Hand Grab               NaN                    1
# 147    220.466858  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0      6.043740  Right Hand Grab  ApplePieCookbook_C_0                    0
# 1      8.886678  Right Hand Grab                   NaN                    1
# 2      9.805173  Right Hand Grab                   NaN                    1
# 3     10.331388  Right Hand Grab                   NaN                    1
# 4     14.112337  Right Hand Grab  ApplePieCookbook_C_0                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C015 C/'
file_name = 'C015_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     22.487411         Add Sugar
# 1     31.987659         Add butter
# 2     33.833786         Add butter
# 3     46.634224          Add water
# 4     69.455162  Add apples to pan
# 5     71.632500  Add apples to pan
# 6     73.323334  Add apples to pan
# 7     74.998772  Add apples to pan
# 8     85.606415  Add apples to pan
# 9     86.827484  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (172, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0        6.043740      Right Hand Grab                 ApplePieCookbook_C_0
# 1        8.886678      Right Hand Grab                                  NaN
# 2        9.805173      Right Hand Grab                                  NaN
# 3       10.331388      Right Hand Grab                                  NaN
# 4       14.112337      Right Hand Grab                 ApplePieCookbook_C_0
# 5       16.620079       Left Hand Grab          SugarJarSimple_C_2147482373
# 6       18.417677   Left Hand Released          SugarJarSimple_C_2147482373
# 7       19.428328      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 148     22.487411                  NaN                                  NaN
# 8       24.507296  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 9       26.229437       Left Hand Grab          SugarJarSimple_C_2147482373
# 10      28.264757   Left Hand Released          SugarJarSimple_C_2147482373
# 11      29.421633       Left Hand Grab      ButterHolderSimple_C_2147482375
# 12      30.539629      Right Hand Grab                  Butter_C_2147482374
# 13      31.783827  Right Hand Released                  Butter_C_2147482374
# 149     31.987659                  NaN                                  NaN
# 14      32.635319      Right Hand Grab                  Butter_C_2147482368
# 150     33.833786                  NaN                                  NaN
# 15      35.159145   Left Hand Released      ButterHolderSimple_C_2147482375
# 16      37.891006      Right Hand Grab                   Apple_C_2147482388
# 17      39.650658  Right Hand Released                   Apple_C_2147482388
# 18      40.853535      Right Hand Grab                   Apple_C_2147482388
# 19      41.989384  Right Hand Released                   Apple_C_2147482388
# 20      44.287735      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 151     46.634224                  NaN                                  NaN
# 21      49.912178  Right Hand Released      WaterPitcherSimple_C_2147482372
# 22      52.068588      Right Hand Grab                   Apple_C_2147482384
# 23      53.619446  Right Hand Released                   Apple_C_2147482384
# 24      54.130703      Right Hand Grab           PieBowlSimple_C_2147482364
# 25      55.361160  Right Hand Released           PieBowlSimple_C_2147482364
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 148                  NaN     Add Sugar
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 149                  NaN     Add butter
# 14                   0.0            NaN
# 150                  NaN     Add butter
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 151                  NaN      Add water
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN

# %%
#df.to_csv('act_step_C015C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        61
# Right Hand Released    42
# Chopped                21
# Left Hand Grab         13
# Left Hand Released     11
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     29.600000
# std      21.419617
# min      11.000000
# 25%      13.000000
# 50%      21.000000
# 75%      42.000000
# max      61.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 148

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowlSimple_C_2147482364                16
# Knife_C_4                                 14
# ApplePieCookbook_C_0                       7
# StirSpoonPieSImple_C_2147482371            6
# PiePanSimple_C_2147482369                  4
# Apple_Slice2_C_2147482343                  4
# SugarJarSimple_C_2147482373                4
# Apple_Slice3_C_2147482353                  4
# Apple_Slice2_C_2147482357                  4
# oven_C_1                                   4
# Apple_C_2147482388                         4
# WaterPitcherSimple_C_2147482372            4
# Apple_C_2147482384                         3
# Apple_Slice3_C_2147482339                  3
# Apple_C_2147482349                         3
# Apple_C_2147482356                         3
# Apple_Slice4_C_2147482352                  3
# Apple_Slice3_C_2147482346                  3
# Apple_C_2147482365                         3
# Apple_Half_C_2147482355                    2
# Apple_Slice_C_2147482344                   2
# NewMeasuringCupSimple2_C_2147482378        2
# ButterHolderSimple_C_2147482375            2
# SaucePotSimple2_C_2147482377               2
# CinnyShakerGrabable_C_2147482376           2
# Apple_Slice4_C_2147482338                  2
# Apple_Slice_C_2147482337                   2
# Apple_Slice2_C_2147482336                  2
# Apple_Half_C_2147482341                    2
# Apple_Slice4_C_2147482359                  2
# Apple_Slice4_C_2147482345                  2
# Butter_C_2147482374                        2
# Apple_Half_C_2147482362                    2
# Apple_Half_C_2147482348                    2
# Apple_Slice3_C_2147482360                  2
# Apple_Slice_C_2147482351                   2
# Apple_Slice_C_2147482358                   2
# Apple_Slice2_C_2147482350                  2
# Apple_Half2_C_2147482354                   1
# Apple_Half2_C_2147482340                   1
# Apple_Half2_C_2147482361                   1
# Apple_Half2_C_2147482347                   1
# Butter_C_2147482368                        1
# PillsberryDoughGirlSimple_C_2147482334     1
# PillsberryDoughBoySimple_C_2147482335      1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               8   16.443671                  3.0
# 1          Add butter              6    7.480363                  0.0
# 2          Add butter              1    1.198467                  0.0
# 3           Add water              6   11.475079                  0.0
# 4   Add apples to pan             19   19.542984                  0.0
# 5   Add apples to pan              2    1.134270                  0.0
# 6   Add apples to pan              1    0.841965                  0.0
# 7   Add apples to pan              3    1.607231                  0.0
# 8   Add apples to pan             14    9.946869                  0.0
# 9   Add apples to pan              2    0.732216                  0.0
# 10  Add apples to pan              7    3.767097                  0.0
# 11  Add apples to pan              2    0.917962                  0.0
# 12  Add apples to pan             13    8.528160                  0.0
# 13  Add apples to pan              2    0.720207                  0.0
# 14  Add apples to pan              4    1.418037                  0.0
# 15  Add apples to pan              0    0.000000                  0.0
# 16  Add apples to pan             15    9.793129                  0.0
# 17  Add apples to pan              0    0.000000                  0.0
# 18  Add apples to pan              4    2.157310                  0.0
# 19  Add apples to pan              2    0.833206                  0.0
# 20       Add cinnamon              2    5.207191                  0.0
# 21         Pour syrup              2    9.055191                  0.0
# 22          Stir bowl             14   22.575318                  1.0
# 23   Add bottom crust              2    6.327790                  0.0
# 24      Add crust top              4   10.177094                  0.0
# 25    Put pie in oven              7   19.269379                  1.0
# 26     Post last step              6    7.966354                  2.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 148

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C015',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C015            148         179.11654                        7.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        5.481481    6.633946             0.259259
# std         5.176652    6.638716             0.712125
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.026116             0.000000
# 50%         4.000000    5.207191             0.000000
# 75%         7.000000    9.869999             0.000000
# max        19.000000   22.575318             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16   61.940643
# 1         Add butter      2    8.678830
# 2         Add Sugar       1   16.443671
# 3          Add water      1   11.475079
# 4       Add cinnamon      1    5.207191
# 5         Pour syrup      1    9.055191
# 6          Stir bowl      1   22.575318
# 7   Add bottom crust      1    6.327790
# 8      Add crust top      1   10.177094
# 9    Put pie in oven      1   19.269379

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 2       0                   0
# Add butter             0                 0       3                   1
# Add water              4                 0       0                   1
# Add apples to pan     65                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       1
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       1
# Add water                            0      0                       0
# Add apples to pan                    0     14                       0
# Pour syrup                           1      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      4             0                         0
# Add crust top                  2             0                         1
# Put pie in oven                0             2                         0
# Add butter                     0             0                         0
# Add water                      0             0                         0
# Add apples to pan             10             0                         0
# Pour syrup                     0             0                         0
# Add bottom crust               0             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add crust top                              0                0
# Put pie in oven                            0                0
# Add butter                                 0                0
# Add water                                  0                0
# Add apples to pan                          0                0
# Pour syrup                                 0                1
# Add bottom crust                           1                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add cinnamon                        0               0                   0
# Stir bowl                           5               0                   2
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               2                   0
# Add water                           0               0                   1
# Add apples to pan                   0               0                   1
# Pour syrup                          0               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                   5
# Add cinnamon          0                   2
# Stir bowl             0                  13
# Add crust top         0                   4
# Put pie in oven       2                   6
# Add butter            0                   7
# Add water             0                   6
# Add apples to pan     0                  90
# Pour syrup            0                   2
# Add bottom crust      0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type          Interacted Object  \
# 0        6.043740      Right Hand Grab       ApplePieCookbook_C_0
# 1        8.886678      Right Hand Grab                        NaN
# 2        9.805173      Right Hand Grab                        NaN
# 3       10.331388      Right Hand Grab                        NaN
# 4       14.112337      Right Hand Grab       ApplePieCookbook_C_0
# ..            ...                  ...                        ...
# 167    213.445114      Right Hand Grab  PiePanSimple_C_2147482369
# 168    215.453598  Right Hand Released  PiePanSimple_C_2147482369
# 169    217.097534      Right Hand Grab                        NaN
# 170    218.069092      Right Hand Grab                   oven_C_1
# 171    220.466858      Right Hand Grab                        NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 167                  0.0            NaN
# 168                  0.0            NaN
# 169                  1.0            NaN
# 170                  0.0            NaN
# 171                  1.0            NaN
#
# [172 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        61
# Right Hand Released    42
# Chopped                21
# Left Hand Grab         13
# Left Hand Released     11
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         0.0
# Left Hand Released     0.0
# Right Hand Grab        7.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            61                        7.0
# 4  Right Hand Released            42                        0.0
# 0              Chopped            21                        0.0
# 1       Left Hand Grab            13                        0.0
# 2   Left Hand Released            11                        0.0
