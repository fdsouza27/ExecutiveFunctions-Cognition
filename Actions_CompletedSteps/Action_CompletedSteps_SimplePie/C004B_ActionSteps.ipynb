# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C004 B/'
file_name = 'C004_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0     15.357754  Right Hand Grab                   NaN
# 1     16.680088  Right Hand Grab  ApplePieCookbook_C_0
# 2     34.231636   Left Hand Grab                   NaN
# 3     53.940189  Right Hand Grab  ApplePieCookbook_C_0
# 4     59.927822   Left Hand Grab  ApplePieCookbook_C_0

# %%
df1.shape
# Out:
# (106, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    96
# 1    10
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       15.357754  Right Hand Grab               NaN                    1
# 2       34.231636   Left Hand Grab               NaN                    1
# 18     106.026039   Left Hand Grab               NaN                    1
# 19     106.137428   Left Hand Grab               NaN                    1
# 20     106.236946   Left Hand Grab               NaN                    1
# 21     106.348770   Left Hand Grab               NaN                    1
# 22     106.450050   Left Hand Grab               NaN                    1
# 35     145.311874   Left Hand Grab               NaN                    1
# 36     146.431992   Left Hand Grab               NaN                    1
# 104    329.883362  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0     15.357754  Right Hand Grab                   NaN                    1
# 1     16.680088  Right Hand Grab  ApplePieCookbook_C_0                    0
# 2     34.231636   Left Hand Grab                   NaN                    1
# 3     53.940189  Right Hand Grab  ApplePieCookbook_C_0                    0
# 4     59.927822   Left Hand Grab  ApplePieCookbook_C_0                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C004 B/'
file_name = 'C004_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    119.505554         Add Sugar
# 1    126.348793          Add water
# 2    143.944885         Add butter
# 3    149.283630         Add butter
# 4    166.063812  Add apples to pan
# 5    167.419022  Add apples to pan
# 6    168.738129  Add apples to pan
# 7    170.260956  Add apples to pan
# 8    183.130341  Add apples to pan
# 9    184.703323  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (122, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0       15.357754      Right Hand Grab                                  NaN
# 1       16.680088      Right Hand Grab                 ApplePieCookbook_C_0
# 2       34.231636       Left Hand Grab                                  NaN
# 3       53.940189      Right Hand Grab                 ApplePieCookbook_C_0
# 4       59.927822       Left Hand Grab                 ApplePieCookbook_C_0
# 5       61.594765       Left Hand Grab         SaucePotSimple2_C_2147482389
# 6       66.549675   Left Hand Released         SaucePotSimple2_C_2147482389
# 7       68.704643       Left Hand Grab         SaucePotSimple2_C_2147482389
# 8       69.770958   Left Hand Released         SaucePotSimple2_C_2147482389
# 9       71.114304       Left Hand Grab         SaucePotSimple2_C_2147482389
# 10      72.414291   Left Hand Released         SaucePotSimple2_C_2147482389
# 11      78.403389      Right Hand Grab                 ApplePieCookbook_C_0
# 12      91.873474       Left Hand Grab          SugarJarSimple_C_2147482385
# 13      93.437370   Left Hand Released          SugarJarSimple_C_2147482385
# 14      95.304810       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 15     105.893250   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 16     105.916611       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 17     105.937065   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 18     106.026039       Left Hand Grab                                  NaN
# 19     106.137428       Left Hand Grab                                  NaN
# 20     106.236946       Left Hand Grab                                  NaN
# 21     106.348770       Left Hand Grab                                  NaN
# 22     106.450050       Left Hand Grab                                  NaN
# 23     107.675026       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 24     108.785446   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 25     109.984108       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 26     115.178596      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 27     115.367523   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 106    119.505554                  NaN                                  NaN
# 28     121.604927  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   1.0            NaN
# 20                   1.0            NaN
# 21                   1.0            NaN
# 22                   1.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 106                  NaN     Add Sugar
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C004B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         38
# Left Hand Released     25
# Right Hand Grab        23
# Right Hand Released    12
# Chopped                 8
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     21.200000
# std      11.819475
# min       8.000000
# 25%      12.000000
# 50%      23.000000
# 75%      25.000000
# max      38.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 106

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# NewMeasuringCupSimple2_C_2147482390       10
# ApplePieCookbook_C_0                       9
# SaucePotSimple2_C_2147482389               8
# PieBowlSimple_C_2147482378                 8
# PiePanSimple_C_2147482381                  6
# WaterPitcherSimple_C_2147482384            4
# Knife_C_4                                  4
# oven_C_1                                   3
# Apple_C_2147482400                         3
# Apple_C_2147482396                         3
# Apple_Slice4_C_2147482364                  3
# Apple_Slice2_C_2147482366                  3
# PillsberryDoughGirlSimple_C_2147482362     2
# StirSpoonPieSImple_C_2147482383            2
# CinnyShakerGrabable_C_2147482388           2
# Apple_Slice3_C_2147482365                  2
# Apple_Slice_C_2147482367                   2
# Apple_Slice3_C_2147482372                  2
# Apple_Slice_C_2147482374                   2
# Apple_Slice4_C_2147482371                  2
# Apple_Slice2_C_2147482373                  2
# Butter_C_2147482380                        2
# Butter_C_2147482386                        2
# ButterHolderSimple_C_2147482387            2
# SugarJarSimple_C_2147482385                2
# Apple_Half_C_2147482369                    1
# Apple_Half2_C_2147482368                   1
# Apple_Half2_C_2147482375                   1
# Apple_Half_C_2147482376                    1
# PillsberryDoughBoySimple_C_2147482363      1
# Exit_C_1                                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              28  104.147800                  7.0
# 1           Add water              2    4.743866                  0.0
# 2          Add butter              5   12.932815                  0.0
# 3          Add butter              4    3.971756                  2.0
# 4   Add apples to pan             12   14.999756                  0.0
# 5   Add apples to pan              2    0.776734                  0.0
# 6   Add apples to pan              2    0.753678                  0.0
# 7   Add apples to pan              2    0.956192                  0.0
# 8   Add apples to pan             12   10.991776                  0.0
# 9   Add apples to pan              2    0.825485                  0.0
# 10  Add apples to pan              2    0.931808                  0.0
# 11  Add apples to pan              2    0.890182                  0.0
# 12       Add cinnamon              2    7.664902                  0.0
# 13         Pour syrup              2    7.531357                  0.0
# 14          Stir bowl              6   20.552735                  0.0
# 15   Add bottom crust              3    5.545456                  0.0
# 16      Add crust top              5   14.874344                  0.0
# 17    Put pie in oven              7   27.038422                  0.0
# 18     Post last step              6   26.958007                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 106

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C004',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C004            106        267.087071                       10.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        5.578947   14.057214             0.526316
# std         6.292110   23.447028             1.645479
# min         2.000000    0.753678             0.000000
# 25%         2.000000    0.944000             0.000000
# 50%         3.000000    7.531357             0.000000
# 75%         6.000000   14.937050             0.000000
# max        28.000000  104.147800             7.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   31.125611
# 1         Add butter      2   16.904571
# 2         Add Sugar       1  104.147800
# 3          Add water      1    4.743866
# 4       Add cinnamon      1    7.664902
# 5         Pour syrup      1    7.531357
# 6          Stir bowl      1   20.552735
# 7   Add bottom crust      1    5.545456
# 8      Add crust top      1   14.874344
# 9    Put pie in oven      1   27.038422

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 4       0                   0
# Add water              0                 0       0                   0
# Pour syrup             0                 0       0                   0
# Stir bowl              0                 1       0                   0
# Add cinnamon           0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add butter             0                 0       4                   2
# Add apples to pan     28                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       9
# Add water                            0      0                       1
# Pour syrup                           1      0                       0
# Stir bowl                            0      0                       0
# Add cinnamon                         1      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       0
# Add apples to pan                    0      4                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Pour syrup                     0             0                         0
# Stir bowl                      1             0                         0
# Add cinnamon                   0             0                         0
# Add crust top                  2             0                         0
# Put pie in oven                0             4                         0
# Add butter                     0             0                         0
# Add apples to pan              4             0                         0
# Add bottom crust               1             0                         1
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                6
# Add water                                  0                0
# Pour syrup                                 0                1
# Stir bowl                                  0                1
# Add cinnamon                               0                0
# Add crust top                              2                0
# Put pie in oven                            0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Add bottom crust                           0                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add water                           0               0                   1
# Pour syrup                          0               0                   0
# Stir bowl                           1               0                   2
# Add cinnamon                        0               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  21
# Add water             0                   2
# Pour syrup            0                   2
# Stir bowl             0                   6
# Add cinnamon          0                   2
# Add crust top         0                   5
# Put pie in oven       2                   7
# Add butter            0                   7
# Add apples to pan     0                  36
# Add bottom crust      0                   3

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time         Action Type          Interacted Object  \
# 0       15.357754     Right Hand Grab                        NaN
# 1       16.680088     Right Hand Grab       ApplePieCookbook_C_0
# 2       34.231636      Left Hand Grab                        NaN
# 3       53.940189     Right Hand Grab       ApplePieCookbook_C_0
# 4       59.927822      Left Hand Grab       ApplePieCookbook_C_0
# ..            ...                 ...                        ...
# 117    305.240692      Left Hand Grab  PiePanSimple_C_2147482381
# 118    308.877930  Left Hand Released  PiePanSimple_C_2147482381
# 119    320.877106     Right Hand Grab       ApplePieCookbook_C_0
# 120    329.883362     Right Hand Grab                        NaN
# 121    330.451080     Right Hand Grab                   Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 117                  0.0            NaN
# 118                  0.0            NaN
# 119                  0.0            NaN
# 120                  1.0            NaN
# 121                  0.0            NaN
#
# [122 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         38
# Left Hand Released     25
# Right Hand Grab        23
# Right Hand Released    12
# Chopped                 8
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         8.0
# Left Hand Released     0.0
# Right Hand Grab        2.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1       Left Hand Grab            38                        8.0
# 2   Left Hand Released            25                        0.0
# 3      Right Hand Grab            23                        2.0
# 4  Right Hand Released            12                        0.0
# 0              Chopped             8                        0.0
