# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C011 C/'
file_name = 'C011_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type                    Interacted Object
# 0      6.903294      Right Hand Grab                                  NaN
# 1      7.191969      Right Hand Grab                 ApplePieCookbook_C_0
# 2     19.366428      Right Hand Grab          SugarJarSimple_C_2147482373
# 3     20.107567  Right Hand Released          SugarJarSimple_C_2147482373
# 4     20.803507      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378

# %%
df1.shape
# Out:
# (57, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    53
# 1     4
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#     Session Time      Action Type Interacted Object  Missed Interactions
# 0       6.903294  Right Hand Grab               NaN                    1
# 19     43.943790   Left Hand Grab               NaN                    1
# 20     44.921989   Left Hand Grab               NaN                    1
# 56     92.399406  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type                    Interacted Object  \
# 0      6.903294      Right Hand Grab                                  NaN
# 1      7.191969      Right Hand Grab                 ApplePieCookbook_C_0
# 2     19.366428      Right Hand Grab          SugarJarSimple_C_2147482373
# 3     20.107567  Right Hand Released          SugarJarSimple_C_2147482373
# 4     20.803507      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C011 C/'
file_name = 'C011_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     24.278833     Add Sugar
# 1     34.130165     Add butter
# 2     37.562660     Add butter

# %%
df2.shape
# Out:
# (3, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (60, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                    Interacted Object  \
# 0       6.903294      Right Hand Grab                                  NaN
# 1       7.191969      Right Hand Grab                 ApplePieCookbook_C_0
# 2      19.366428      Right Hand Grab          SugarJarSimple_C_2147482373
# 3      20.107567  Right Hand Released          SugarJarSimple_C_2147482373
# 4      20.803507      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 57     24.278833                  NaN                                  NaN
# 5      26.035055  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 6      27.801617      Right Hand Grab          SugarJarSimple_C_2147482373
# 7      29.122837  Right Hand Released          SugarJarSimple_C_2147482373
# 8      29.875202      Right Hand Grab          SugarJarSimple_C_2147482373
# 9      30.925806  Right Hand Released          SugarJarSimple_C_2147482373
# 10     31.623087      Right Hand Grab      ButterHolderSimple_C_2147482375
# 11     32.199692  Right Hand Released      ButterHolderSimple_C_2147482375
# 12     32.841789      Right Hand Grab                  Butter_C_2147482374
# 13     33.807568  Right Hand Released                  Butter_C_2147482374
# 14     33.952133      Right Hand Grab                 ApplePieCookbook_C_0
# 58     34.130165                  NaN                                  NaN
# 15     35.000019      Right Hand Grab                  Butter_C_2147482368
# 59     37.562660                  NaN                                  NaN
# 16     38.530029      Right Hand Grab      ButterHolderSimple_C_2147482375
# 17     39.415852  Right Hand Released      ButterHolderSimple_C_2147482375
# 18     42.232399      Right Hand Grab                 ApplePieCookbook_C_0
# 19     43.943790       Left Hand Grab                                  NaN
# 20     44.921989       Left Hand Grab                                  NaN
# 21     45.565170       Left Hand Grab                 ApplePieCookbook_C_0
# 22     46.998516      Right Hand Grab                   Apple_C_2147482384
# 23     47.908730  Right Hand Released                   Apple_C_2147482384
# 24     48.687084      Right Hand Grab                   Apple_C_2147482366
# 25     49.586403  Right Hand Released                   Apple_C_2147482366
# 26     50.575588      Right Hand Grab                   Apple_C_2147482365
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 57                  NaN     Add Sugar
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 58                  NaN     Add butter
# 15                  0.0            NaN
# 59                  NaN     Add butter
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  1.0            NaN
# 20                  1.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN

# %%
#df.to_csv('act_step_C011C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        22
# Chopped                17
# Right Hand Released    15
# Left Hand Grab          3
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     4.000000
# mean     14.250000
# std       8.057088
# min       3.000000
# 25%      12.000000
# 50%      16.000000
# 75%      18.250000
# max      22.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 57

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# SugarJarSimple_C_2147482373            6
# ApplePieCookbook_C_0                   5
# Knife_C_4                              4
# ButterHolderSimple_C_2147482375        4
# Apple_Half_C_2147482362                3
# Apple_C_2147482384                     3
# Apple_C_2147482366                     3
# Apple_C_2147482365                     3
# Apple_C_2147482388                     3
# Apple_Slice3_C_2147482358              2
# CinnyShakerGrabable_C_2147482376       2
# Butter_C_2147482374                    2
# NewMeasuringCupSimple2_C_2147482378    2
# Apple_Half2_C_2147482361               1
# Butter_C_2147482368                    1
# Apple_Slice4_C_2147482357              1
# Apple_Half2_C_2147482351               1
# Apple_Half2_C_2147482353               1
# Apple_Half2_C_2147482359               1
# Apple_Slice4_C_2147482347              1
# Apple_Half_C_2147482352                1
# Apple_Half_C_2147482354                1
# Apple_Slice2_C_2147482343              1
# Apple_Half_C_2147482360                1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add butter    2
# Add Sugar     1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#    Completed Step  Actions Count  Time Spent  Missed Interactions
# 0      Add Sugar               5   17.375539                  1.0
# 1      Add butter             10    8.095110                  0.0
# 2      Add butter              1    2.562641                  0.0
# 3  Post last step             41   53.869377                  3.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 57

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C011',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C011             57         81.902667                        4.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count        4.00000    4.000000             4.000000
# mean        14.25000   20.475667             1.000000
# std         18.20943   23.086109             1.414214
# min          1.00000    2.562641             0.000000
# 25%          4.00000    6.711993             0.000000
# 50%          7.50000   12.735324             0.500000
# 75%         17.75000   26.498998             1.500000
# max         41.00000   53.869377             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add butter      2   10.657751
# 1     Add Sugar       1   17.375539

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#             ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar                  1       0                   0
# Add butter                 1       3                   2
#
#             NewMeasuringCupSimple2  SugarJarSimple  Interacted Objects
# Add Sugar                        1               2                   4
# Add butter                       1               4                  11

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#     Session Time          Action Type                    Interacted Object  \
# 0       6.903294      Right Hand Grab                                  NaN
# 1       7.191969      Right Hand Grab                 ApplePieCookbook_C_0
# 2      19.366428      Right Hand Grab          SugarJarSimple_C_2147482373
# 3      20.107567  Right Hand Released          SugarJarSimple_C_2147482373
# 4      20.803507      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 5      24.278833                  NaN                                  NaN
# 6      26.035055  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 7      27.801617      Right Hand Grab          SugarJarSimple_C_2147482373
# 8      29.122837  Right Hand Released          SugarJarSimple_C_2147482373
# 9      29.875202      Right Hand Grab          SugarJarSimple_C_2147482373
# 10     30.925806  Right Hand Released          SugarJarSimple_C_2147482373
# 11     31.623087      Right Hand Grab      ButterHolderSimple_C_2147482375
# 12     32.199692  Right Hand Released      ButterHolderSimple_C_2147482375
# 13     32.841789      Right Hand Grab                  Butter_C_2147482374
# 14     33.807568  Right Hand Released                  Butter_C_2147482374
# 15     33.952133      Right Hand Grab                 ApplePieCookbook_C_0
# 16     34.130165                  NaN                                  NaN
# 17     35.000019      Right Hand Grab                  Butter_C_2147482368
# 18     37.562660                  NaN                                  NaN
# 19     38.530029      Right Hand Grab      ButterHolderSimple_C_2147482375
# 20     39.415852  Right Hand Released      ButterHolderSimple_C_2147482375
# 21     42.232399      Right Hand Grab                 ApplePieCookbook_C_0
# 22     43.943790       Left Hand Grab                                  NaN
# 23     44.921989       Left Hand Grab                                  NaN
# 24     45.565170       Left Hand Grab                 ApplePieCookbook_C_0
# 25     46.998516      Right Hand Grab                   Apple_C_2147482384
# 26     47.908730  Right Hand Released                   Apple_C_2147482384
# 27     48.687084      Right Hand Grab                   Apple_C_2147482366
# 28     49.586403  Right Hand Released                   Apple_C_2147482366
# 29     50.575588      Right Hand Grab                   Apple_C_2147482365
# 30     51.607986  Right Hand Released                   Apple_C_2147482365
# 31     52.330280      Right Hand Grab                   Apple_C_2147482388
# 32     53.374531  Right Hand Released                   Apple_C_2147482388
# 33     54.184212      Right Hand Grab                            Knife_C_4
# 34     55.107086              Chopped                   Apple_C_2147482366
# 35     55.672562              Chopped                   Apple_C_2147482384
# 36     56.218689              Chopped             Apple_Half2_C_2147482361
# 37     56.741222              Chopped              Apple_Half_C_2147482360
# 38     57.297203              Chopped                   Apple_C_2147482365
# 39     57.852085              Chopped                   Apple_C_2147482388
# 40     58.396408              Chopped            Apple_Slice4_C_2147482357
# 41     59.262363              Chopped             Apple_Half2_C_2147482351
# 42     59.818649              Chopped             Apple_Half2_C_2147482353
# 43     60.640579              Chopped             Apple_Half2_C_2147482359
# 44     61.183746              Chopped            Apple_Slice4_C_2147482347
# 45     61.995808              Chopped            Apple_Slice3_C_2147482358
# 46     62.550556              Chopped            Apple_Slice3_C_2147482358
# 47     63.284061              Chopped              Apple_Half_C_2147482352
# 48     64.284050  Right Hand Released                            Knife_C_4
# 49     65.005882      Right Hand Grab              Apple_Half_C_2147482362
# 50     66.841759  Right Hand Released              Apple_Half_C_2147482362
# 51     69.412483      Right Hand Grab                            Knife_C_4
# 52     70.148941              Chopped              Apple_Half_C_2147482362
# 53     71.250763              Chopped              Apple_Half_C_2147482354
# 54     72.767433              Chopped            Apple_Slice2_C_2147482343
# 55     73.401230  Right Hand Released                            Knife_C_4
# 56     74.602669      Right Hand Grab                 ApplePieCookbook_C_0
# 57     76.803429      Right Hand Grab     CinnyShakerGrabable_C_2147482376
# 58     83.177238  Right Hand Released     CinnyShakerGrabable_C_2147482376
# 59     92.399406      Right Hand Grab                                  NaN
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   NaN     Add Sugar
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  NaN     Add butter
# 17                  0.0            NaN
# 18                  NaN     Add butter
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  1.0            NaN
# 23                  1.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN
# 30                  0.0            NaN
# 31                  0.0            NaN
# 32                  0.0            NaN
# 33                  0.0            NaN
# 34                  0.0            NaN
# 35                  0.0            NaN
# 36                  0.0            NaN
# 37                  0.0            NaN
# 38                  0.0            NaN
# 39                  0.0            NaN
# 40                  0.0            NaN
# 41                  0.0            NaN
# 42                  0.0            NaN
# 43                  0.0            NaN
# 44                  0.0            NaN
# 45                  0.0            NaN
# 46                  0.0            NaN
# 47                  0.0            NaN
# 48                  0.0            NaN
# 49                  0.0            NaN
# 50                  0.0            NaN
# 51                  0.0            NaN
# 52                  0.0            NaN
# 53                  0.0            NaN
# 54                  0.0            NaN
# 55                  0.0            NaN
# 56                  0.0            NaN
# 57                  0.0            NaN
# 58                  0.0            NaN
# 59                  1.0            NaN

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        22
# Chopped                17
# Right Hand Released    15
# Left Hand Grab          3
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         2.0
# Right Hand Grab        2.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 2      Right Hand Grab            22                        2.0
# 0              Chopped            17                        0.0
# 3  Right Hand Released            15                        0.0
# 1       Left Hand Grab             3                        2.0
