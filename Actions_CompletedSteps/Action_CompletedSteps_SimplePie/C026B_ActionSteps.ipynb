# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C026 B/'
file_name = 'C026_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object
# 0      8.741570      Right Hand Grab         ApplePieCookbook_C_0
# 1     48.179050      Right Hand Grab         ApplePieCookbook_C_0
# 2     68.395615      Right Hand Grab  SugarJarSimple_C_2147482385
# 3     68.631279  Right Hand Released  SugarJarSimple_C_2147482385
# 4     70.146233      Right Hand Grab  SugarJarSimple_C_2147482385

# %%
df1.shape
# Out:
# (269, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    251
# 1     18
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 6       73.121628  Right Hand Grab               NaN                    1
# 10      81.225479  Right Hand Grab               NaN                    1
# 22     115.898430  Right Hand Grab               NaN                    1
# 31     127.586571  Right Hand Grab               NaN                    1
# 54     156.025711  Right Hand Grab               NaN                    1
# 55     156.136719  Right Hand Grab               NaN                    1
# 56     156.249359  Right Hand Grab               NaN                    1
# 57     156.358948  Right Hand Grab               NaN                    1
# 58     156.470230  Right Hand Grab               NaN                    1
# 59     156.579849  Right Hand Grab               NaN                    1
# 60     156.688675  Right Hand Grab               NaN                    1
# 95     240.498901  Right Hand Grab               NaN                    1
# 100    263.270233  Right Hand Grab               NaN                    1
# 103    268.148987  Right Hand Grab               NaN                    1
# 197    416.161896  Right Hand Grab               NaN                    1
# 202    425.542206  Right Hand Grab               NaN                    1
# 203    427.741852  Right Hand Grab               NaN                    1
# 266    648.317200  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object  \
# 0      8.741570      Right Hand Grab         ApplePieCookbook_C_0
# 1     48.179050      Right Hand Grab         ApplePieCookbook_C_0
# 2     68.395615      Right Hand Grab  SugarJarSimple_C_2147482385
# 3     68.631279  Right Hand Released  SugarJarSimple_C_2147482385
# 4     70.146233      Right Hand Grab  SugarJarSimple_C_2147482385
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C026 B/'
file_name = 'C026_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    222.236115         Add Sugar
# 1    238.089035          Add water
# 2    267.115021         Add butter
# 3    271.380188         Add butter
# 4    357.232422  Add apples to pan
# 5    359.874023  Add apples to pan
# 6    361.996155  Add apples to pan
# 7    364.017120  Add apples to pan
# 8    365.884613  Add apples to pan
# 9    368.362061  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (287, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                    Interacted Object  \
# 0       8.741570      Right Hand Grab                 ApplePieCookbook_C_0
# 1      48.179050      Right Hand Grab                 ApplePieCookbook_C_0
# 2      68.395615      Right Hand Grab          SugarJarSimple_C_2147482385
# 3      68.631279  Right Hand Released          SugarJarSimple_C_2147482385
# 4      70.146233      Right Hand Grab          SugarJarSimple_C_2147482385
# 5      71.239304  Right Hand Released          SugarJarSimple_C_2147482385
# 6      73.121628      Right Hand Grab                                  NaN
# 7      78.969078       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 8      80.215508   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 9      80.681572       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 10     81.225479      Right Hand Grab                                  NaN
# 11     83.784683   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 12     85.099373      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 13     90.435493  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 14     93.173111      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 15     94.102806  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 16    104.212204      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 17    107.001884  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 18    108.189613      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 19    109.757401  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 20    111.193031      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 21    112.731796  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 22    115.898430      Right Hand Grab                                  NaN
# 23    117.944038      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 24    118.898781  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 25    119.543350      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 26    121.442398  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 27    122.086288      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 28    124.674561  Right Hand Released  NewMeasuringCupSimple2_C_2147482390
# 29    125.440781      Right Hand Grab  NewMeasuringCupSimple2_C_2147482390
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   1.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  1.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  1.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
#df.to_csv('act_step_C026B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        141
# Right Hand Released    108
# Chopped                 16
# Left Hand Grab           2
# Left Hand Released       2
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      53.800000
# std       65.834641
# min        2.000000
# 25%        2.000000
# 50%       16.000000
# 75%      108.000000
# max      141.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 269

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# NewMeasuringCupSimple2_C_2147482390       76
# CinnyShakerGrabable_C_2147482388          20
# PieBowlSimple_C_2147482378                20
# Knife_C_4                                 18
# PiePanSimple_C_2147482381                 10
# StirSpoonPieSImple_C_2147482383            8
# ApplePieCookbook_C_0                       7
# SugarJarSimple_C_2147482385                4
# Apple_Slice_C_2147482345                   4
# SaucePotSimple2_C_2147482389               4
# oven_C_1                                   4
# Apple_Slice_C_2147482364                   3
# Apple_Half2_C_2147482353                   3
# Apple_Slice_C_2147482358                   3
# Apple_C_2147482377                         3
# Apple_C_2147482376                         3
# Apple_C_2147482399                         3
# Apple_C_2147482397                         3
# Apple_C_2147482398                         3
# Apple_Half2_C_2147482346                   2
# Apple_Slice2_C_2147482344                  2
# Apple_Slice4_C_2147482361                  2
# Apple_Slice3_C_2147482356                  2
# Apple_Slice4_C_2147482355                  2
# Apple_Slice3_C_2147482362                  2
# Apple_Slice4_C_2147482349                  2
# Apple_Slice3_C_2147482350                  2
# Apple_Slice2_C_2147482357                  2
# Apple_Slice2_C_2147482351                  2
# Apple_Slice_C_2147482370                   2
# Apple_Slice3_C_2147482368                  2
# Apple_Slice2_C_2147482363                  2
# Apple_Slice_C_2147482352                   2
# WaterPitcherSimple_C_2147482384            2
# ButterHolderSimple_C_2147482387            2
# Butter_C_2147482386                        2
# Butter_C_2147482380                        2
# Apple_Slice2_C_2147482369                  2
# Apple_C_2147482400                         2
# Apple_Half_C_2147482372                    1
# PillsberryDoughBoySimple_C_2147482343      1
# PillsberryDoughGirlSimple_C_2147482342     1
# Apple_Half_C_2147482366                    1
# Apple_Half2_C_2147482371                   1
# Apple_Half_C_2147482347                    1
# Apple_Half2_C_2147482365                   1
# Apple_Half_C_2147482360                    1
# Apple_Half2_C_2147482359                   1
# Apple_Half_C_2147482354                    1
# Apple_Slice4_C_2147482367                  1
# Exit_C_1                                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              92  213.494545                 11.0
# 1           Add water              2   13.809128                  0.0
# 2          Add butter              9   28.382279                  2.0
# 3          Add butter              3    3.231201                  1.0
# 4   Add apples to pan             42   81.030548                  0.0
# 5   Add apples to pan              3    2.564056                  0.0
# 6   Add apples to pan              2    1.089234                  0.0
# 7   Add apples to pan              2    1.100097                  0.0
# 8   Add apples to pan              2    1.146149                  0.0
# 9   Add apples to pan              2    1.845398                  0.0
# 10  Add apples to pan              2    1.311524                  0.0
# 11  Add apples to pan              2    1.344909                  0.0
# 12       Add cinnamon             47   81.213745                  3.0
# 13         Pour syrup             10   21.455872                  0.0
# 14          Stir bowl             16   65.064270                  0.0
# 15   Add bottom crust              7   10.929627                  0.0
# 16      Add crust top              6   22.956543                  0.0
# 17    Put pie in oven             13   37.341736                  0.0
# 18     Post last step              7   26.251098                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 269

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C026',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C026            269        615.561959                       18.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       14.157895   32.397998             0.947368
# std        22.869833   51.232678             2.570639
# min         2.000000    1.089234             0.000000
# 25%         2.000000    1.595153             0.000000
# 50%         6.000000   13.809128             0.000000
# 75%        11.500000   32.862007             0.500000
# max        92.000000  213.494545            11.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   91.431915
# 1         Add butter      2   31.613480
# 2         Add Sugar       1  213.494545
# 3          Add water      1   13.809128
# 4       Add cinnamon      1   81.213745
# 5         Pour syrup      1   21.455872
# 6          Stir bowl      1   65.064270
# 7   Add bottom crust      1   10.929627
# 8      Add crust top      1   22.956543
# 9    Put pie in oven      1   37.341736

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add water              0                 0       0                   0
# Add cinnamon          30                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add butter             0                 0       4                   2
# Add apples to pan     39                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                      75
# Add water                            0      0                       1
# Add cinnamon                         1     12                       0
# Stir bowl                           10      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      2                       0
# Add butter                           0      2                       0
# Add apples to pan                    0      2                       0
# Pour syrup                           9      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      0             0                         0
# Add crust top                  4             0                         1
# Put pie in oven                0             6                         0
# Add butter                     0             0                         0
# Add apples to pan             16             0                         0
# Pour syrup                     0             0                         0
# Add bottom crust               0             2                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                3
# Add crust top                              0                0
# Put pie in oven                            0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Pour syrup                                 0                1
# Add bottom crust                           1                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               4                   0
# Add water                           0               0                   1
# Add cinnamon                        0               0                   0
# Stir bowl                           2               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     2               0                   0
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Pour syrup                          0               0                   0
# Add bottom crust                    4               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  81
# Add water             0                   2
# Add cinnamon          0                  44
# Stir bowl             0                  16
# Add crust top         0                   6
# Put pie in oven       2                  13
# Add butter            0                   9
# Add apples to pan     0                  57
# Pour syrup            0                  10
# Add bottom crust      0                   7

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0        8.741570      Right Hand Grab         ApplePieCookbook_C_0
# 1       48.179050      Right Hand Grab         ApplePieCookbook_C_0
# 2       68.395615      Right Hand Grab  SugarJarSimple_C_2147482385
# 3       68.631279  Right Hand Released  SugarJarSimple_C_2147482385
# 4       70.146233      Right Hand Grab  SugarJarSimple_C_2147482385
# ..            ...                  ...                          ...
# 282    644.009155  Right Hand Released    PiePanSimple_C_2147482381
# 283    645.395386      Right Hand Grab                     oven_C_1
# 284    648.317200      Right Hand Grab                          NaN
# 285    649.315125      Right Hand Grab         ApplePieCookbook_C_0
# 286    663.872375      Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 282                  0.0            NaN
# 283                  0.0            NaN
# 284                  1.0            NaN
# 285                  0.0            NaN
# 286                  0.0            NaN
#
# [287 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        141
# Right Hand Released    108
# Chopped                 16
# Left Hand Grab           2
# Left Hand Released       2
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          0.0
# Left Hand Released      0.0
# Right Hand Grab        18.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           141                       18.0
# 4  Right Hand Released           108                        0.0
# 0              Chopped            16                        0.0
# 1       Left Hand Grab             2                        0.0
# 2   Left Hand Released             2                        0.0
