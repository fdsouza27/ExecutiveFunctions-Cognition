# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C010 B/'
file_name = 'C010_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0     77.188957  Right Hand Grab  ApplePieCookbook_C_0
# 1     92.347488  Right Hand Grab                   NaN
# 2     93.742058  Right Hand Grab                   NaN
# 3     95.295464   Left Hand Grab                   NaN
# 4     95.406570  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (189, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    160
# 1     29
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       92.347488  Right Hand Grab               NaN                    1
# 2       93.742058  Right Hand Grab               NaN                    1
# 3       95.295464   Left Hand Grab               NaN                    1
# 4       95.406570  Right Hand Grab               NaN                    1
# 5       96.751823  Right Hand Grab               NaN                    1
# 6       96.807632   Left Hand Grab               NaN                    1
# 7      114.580406  Right Hand Grab               NaN                    1
# 8      115.780121  Right Hand Grab               NaN                    1
# 9      115.790367   Left Hand Grab               NaN                    1
# 10     117.055527  Right Hand Grab               NaN                    1
# 11     117.099541   Left Hand Grab               NaN                    1
# 16     162.305908  Right Hand Grab               NaN                    1
# 17     163.539261  Right Hand Grab               NaN                    1
# 18     164.640244  Right Hand Grab               NaN                    1
# 19     167.761230  Right Hand Grab               NaN                    1
# 20     169.310089  Right Hand Grab               NaN                    1
# 24     210.165497   Left Hand Grab               NaN                    1
# 30     234.126389  Right Hand Grab               NaN                    1
# 35     259.308472  Right Hand Grab               NaN                    1
# 52     284.472992  Right Hand Grab               NaN                    1
# 126    367.580322  Right Hand Grab               NaN                    1
# 127    368.346802  Right Hand Grab               NaN                    1
# 128    369.898651   Left Hand Grab               NaN                    1
# 146    432.033264   Left Hand Grab               NaN                    1
# 170    476.527863  Right Hand Grab               NaN                    1
# 171    477.294891  Right Hand Grab               NaN                    1
# 174    500.152344  Right Hand Grab               NaN                    1
# 182    510.363647   Left Hand Grab               NaN                    1
# 183    510.363647  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0     77.188957  Right Hand Grab  ApplePieCookbook_C_0                    0
# 1     92.347488  Right Hand Grab                   NaN                    1
# 2     93.742058  Right Hand Grab                   NaN                    1
# 3     95.295464   Left Hand Grab                   NaN                    1
# 4     95.406570  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C002 B/'
file_name = 'C002_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    179.718933         Add Sugar
# 1    227.432983          Add water
# 2    243.818832         Add butter
# 3    248.096603         Add butter
# 4    313.651947  Add apples to pan
# 5    315.084442  Add apples to pan
# 6    318.672028  Add apples to pan
# 7    320.016266  Add apples to pan
# 8    329.737640  Add apples to pan
# 9    330.826447  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (207, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0       77.188957      Right Hand Grab                 ApplePieCookbook_C_0
# 1       92.347488      Right Hand Grab                                  NaN
# 2       93.742058      Right Hand Grab                                  NaN
# 3       95.295464       Left Hand Grab                                  NaN
# 4       95.406570      Right Hand Grab                                  NaN
# 5       96.751823      Right Hand Grab                                  NaN
# 6       96.807632       Left Hand Grab                                  NaN
# 7      114.580406      Right Hand Grab                                  NaN
# 8      115.780121      Right Hand Grab                                  NaN
# 9      115.790367       Left Hand Grab                                  NaN
# 10     117.055527      Right Hand Grab                                  NaN
# 11     117.099541       Left Hand Grab                                  NaN
# 12     120.789864      Right Hand Grab          SugarJarSimple_C_2147482373
# 13     123.216240  Right Hand Released          SugarJarSimple_C_2147482373
# 14     128.368607      Right Hand Grab      ButterHolderSimple_C_2147482375
# 15     129.544525  Right Hand Released      ButterHolderSimple_C_2147482375
# 16     162.305908      Right Hand Grab                                  NaN
# 17     163.539261      Right Hand Grab                                  NaN
# 18     164.640244      Right Hand Grab                                  NaN
# 19     167.761230      Right Hand Grab                                  NaN
# 20     169.310089      Right Hand Grab                                  NaN
# 21     174.511841      Right Hand Grab                 ApplePieCookbook_C_0
# 189    179.718933                  NaN                                  NaN
# 22     200.272598       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 23     208.399506   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 24     210.165497       Left Hand Grab                                  NaN
# 25     211.386612       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 26     214.664902   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 27     220.071823       Left Hand Grab                  Butter_C_2147482374
# 28     222.004120   Left Hand Released                  Butter_C_2147482374
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    1.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    1.0            NaN
# 10                   1.0            NaN
# 11                   1.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   1.0            NaN
# 17                   1.0            NaN
# 18                   1.0            NaN
# 19                   1.0            NaN
# 20                   1.0            NaN
# 21                   0.0            NaN
# 189                  NaN     Add Sugar
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   1.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C010B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        74
# Right Hand Released    43
# Left Hand Grab         35
# Left Hand Released     23
# Chopped                14
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     37.800000
# std      23.080295
# min      14.000000
# 25%      23.000000
# 50%      35.000000
# 75%      43.000000
# max      74.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 189

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowlSimple_C_2147482366                30
# StirSpoonPieSImple_C_2147482371           12
# Knife_C_4                                  8
# ApplePieCookbook_C_0                       7
# Apple_C_2147482364                         7
# PillsberryDoughGirlSimple_C_2147482336     6
# PiePanSimple_C_2147482369                  6
# Apple_C_2147482384                         5
# Apple_C_2147482365                         5
# Apple_Slice_C_2147482355                   4
# SaucePotSimple2_C_2147482377               4
# Apple_Slice_C_2147482341                   4
# CinnyShakerGrabable_C_2147482376           4
# NewMeasuringCupSimple2_C_2147482378        4
# Apple_C_2147482387                         3
# Apple_Slice4_C_2147482358                  3
# ButterHolderSimple_C_2147482375            2
# Apple_Slice_C_2147482347                   2
# oven_C_1                                   2
# Apple_Slice3_C_2147482339                  2
# Apple_Slice4_C_2147482338                  2
# Apple_Slice2_C_2147482340                  2
# PillsberryDoughBoySimple_C_2147482337      2
# Apple_Slice2_C_2147482346                  2
# Apple_Slice4_C_2147482344                  2
# Apple_Slice3_C_2147482345                  2
# Apple_Half_C_2147482349                    2
# Apple_Slice4_C_2147482352                  2
# Apple_Slice3_C_2147482353                  2
# WaterPitcherSimple_C_2147482372            2
# Butter_C_2147482374                        2
# Apple_Slice2_C_2147482354                  2
# Apple_Slice2_C_2147482350                  2
# SugarJarSimple_C_2147482373                2
# Apple_Slice3_C_2147482359                  2
# Apple_Slice_C_2147482351                   2
# Apple_Half_C_2147482361                    1
# Apple_Half2_C_2147482342                   1
# Apple_Half2_C_2147482356                   1
# Apple_Half_C_2147482357                    1
# Apple_Half2_C_2147482360                   1
# Butter_C_2147482368                        1
# Apple_Half2_C_2147482348                   1
# Apple_Half_C_2147482343                    1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              22  102.529976                 16.0
# 1           Add water              8   27.160385                  1.0
# 2          Add butter              2    9.692443                  1.0
# 3          Add butter              0    0.000000                  0.0
# 4   Add apples to pan             54   64.585831                  2.0
# 5   Add apples to pan              1    0.670288                  0.0
# 6   Add apples to pan              4    3.127869                  0.0
# 7   Add apples to pan              2    0.958374                  0.0
# 8   Add apples to pan             16    8.675750                  0.0
# 9   Add apples to pan              2    0.886384                  0.0
# 10  Add apples to pan              2    2.132325                  0.0
# 11  Add apples to pan              0    0.000000                  0.0
# 12       Add cinnamon              5   10.960815                  0.0
# 13         Pour syrup              7   15.604706                  0.0
# 14          Stir bowl              6   22.089508                  3.0
# 15   Add bottom crust              2    7.775025                  0.0
# 16      Add crust top             22   42.111115                  1.0
# 17    Put pie in oven             15   31.408905                  0.0
# 18     Post last step             19   41.012176                  5.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 189

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C010',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C010            189        391.381875                       29.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        9.947368   20.599046             1.526316
# std        13.031900   26.769512             3.747124
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.545350             0.000000
# 50%         5.000000    9.692443             0.000000
# 75%        15.500000   29.284645             1.000000
# max        54.000000  102.529976            16.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   81.036821
# 1         Add butter      2    9.692443
# 2         Add Sugar       1  102.529976
# 3          Add water      1   27.160385
# 4       Add cinnamon      1   10.960815
# 5         Pour syrup      1   15.604706
# 6          Stir bowl      1   22.089508
# 7   Add bottom crust      1    7.775025
# 8      Add crust top      1   42.111115
# 9    Put pie in oven      1   31.408905

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   2
# Pour syrup             0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add water              0                 0       3                   0
# Add butter             0                 0       0                   0
# Add apples to pan     66                 0       0                   0
# Add cinnamon           0                 0       0                   0
# Stir bowl              0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       0
# Pour syrup                           1      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add water                            0      0                       4
# Add butter                           0      0                       0
# Add apples to pan                    0      8                       0
# Add cinnamon                         0      0                       0
# Stir bowl                            3      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0                         0
# Pour syrup                     5                         0
# Add crust top                  6                         0
# Put pie in oven                8                         2
# Add water                      0                         0
# Add butter                     0                         0
# Add apples to pan              4                         0
# Add cinnamon                   5                         0
# Stir bowl                      0                         0
# Add bottom crust               0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Pour syrup                                 0                0
# Add crust top                              4                0
# Put pie in oven                            2                0
# Add water                                  0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                0
# Add bottom crust                           0                2
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Pour syrup                          0               0                   0
# Add crust top                      10               0                   0
# Put pie in oven                     2               0                   0
# Add water                           0               0                   0
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   1
# Add cinnamon                        0               0                   0
# Stir bowl                           0               0                   0
# Add bottom crust                    0               0                   0
#
#                    Interacted Objects
# Add Sugar                           6
# Pour syrup                          7
# Add crust top                      21
# Put pie in oven                    15
# Add water                           7
# Add butter                          1
# Add apples to pan                  79
# Add cinnamon                        5
# Stir bowl                           3
# Add bottom crust                    2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type          Interacted Object  \
# 0       77.188957      Right Hand Grab       ApplePieCookbook_C_0
# 1       92.347488      Right Hand Grab                        NaN
# 2       93.742058      Right Hand Grab                        NaN
# 3       95.295464       Left Hand Grab                        NaN
# 4       95.406570      Right Hand Grab                        NaN
# ..            ...                  ...                        ...
# 202    511.451538      Right Hand Grab  PiePanSimple_C_2147482369
# 203    511.462799       Left Hand Grab  PiePanSimple_C_2147482369
# 204    515.305786   Left Hand Released  PiePanSimple_C_2147482369
# 205    515.384155  Right Hand Released  PiePanSimple_C_2147482369
# 206    517.540039      Right Hand Grab                   oven_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 202                  0.0            NaN
# 203                  0.0            NaN
# 204                  0.0            NaN
# 205                  0.0            NaN
# 206                  0.0            NaN
#
# [207 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        74
# Right Hand Released    43
# Left Hand Grab         35
# Left Hand Released     23
# Chopped                14
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          8.0
# Left Hand Released      0.0
# Right Hand Grab        21.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            74                       21.0
# 4  Right Hand Released            43                        0.0
# 1       Left Hand Grab            35                        8.0
# 2   Left Hand Released            23                        0.0
# 0              Chopped            14                        0.0
