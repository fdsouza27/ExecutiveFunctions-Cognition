# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C014 B/'
file_name = 'C014_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type            Interacted Object
# 0      3.337766  Right Hand Grab         ApplePieCookbook_C_0
# 1      9.278296   Left Hand Grab                          NaN
# 2     14.512472   Left Hand Grab                          NaN
# 3     33.833042  Right Hand Grab         ApplePieCookbook_C_0
# 4     55.893211   Left Hand Grab  SugarJarSimple_C_2147482373

# %%
df1.shape
# Out:
# (252, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    240
# 1     12
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1        9.278296   Left Hand Grab               NaN                    1
# 2       14.512472   Left Hand Grab               NaN                    1
# 6       58.227493   Left Hand Grab               NaN                    1
# 14      94.320198   Left Hand Grab               NaN                    1
# 18     105.751518  Right Hand Grab               NaN                    1
# 103    215.909332   Left Hand Grab               NaN                    1
# 160    256.236938  Right Hand Grab               NaN                    1
# 161    257.058228  Right Hand Grab               NaN                    1
# 186    326.503510  Right Hand Grab               NaN                    1
# 190    336.643066  Right Hand Grab               NaN                    1
# 198    350.806976   Left Hand Grab               NaN                    1
# 235    394.354675  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type            Interacted Object  \
# 0      3.337766  Right Hand Grab         ApplePieCookbook_C_0
# 1      9.278296   Left Hand Grab                          NaN
# 2     14.512472   Left Hand Grab                          NaN
# 3     33.833042  Right Hand Grab         ApplePieCookbook_C_0
# 4     55.893211   Left Hand Grab  SugarJarSimple_C_2147482373
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C014 B/'
file_name = 'C014_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     68.259148         Add Sugar
# 1     98.965324          Add water
# 2    132.469482         Add butter
# 3    136.546295         Add butter
# 4    182.860931  Add apples to pan
# 5    184.693985  Add apples to pan
# 6    186.348770  Add apples to pan
# 7    187.938217  Add apples to pan
# 8    210.578888  Add apples to pan
# 9    212.076218  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (275, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0        3.337766      Right Hand Grab                 ApplePieCookbook_C_0
# 1        9.278296       Left Hand Grab                                  NaN
# 2       14.512472       Left Hand Grab                                  NaN
# 3       33.833042      Right Hand Grab                 ApplePieCookbook_C_0
# 4       55.893211       Left Hand Grab          SugarJarSimple_C_2147482373
# 5       57.288612   Left Hand Released          SugarJarSimple_C_2147482373
# 6       58.227493       Left Hand Grab                                  NaN
# 7       62.357006       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 8       68.215073   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 252     68.259148                  NaN                                  NaN
# 9       73.335709       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 10      74.335335   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 11      75.058693       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 12      77.045998   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 13      82.955269      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 14      94.320198       Left Hand Grab                                  NaN
# 15      95.831940       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 16      96.477966   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 253     98.965324                  NaN                                  NaN
# 17      99.409973  Right Hand Released      WaterPitcherSimple_C_2147482372
# 18     105.751518      Right Hand Grab                                  NaN
# 19     107.330345      Right Hand Grab            PiePanSimple_C_2147482369
# 20     107.930618  Right Hand Released            PiePanSimple_C_2147482369
# 21     108.585884      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 22     110.863136  Right Hand Released      WaterPitcherSimple_C_2147482372
# 23     112.305962      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 24     113.048355  Right Hand Released      WaterPitcherSimple_C_2147482372
# 25     125.570198      Right Hand Grab      ButterHolderSimple_C_2147482375
# 26     126.737228  Right Hand Released      ButterHolderSimple_C_2147482375
# 27     127.558678      Right Hand Grab      ButterHolderSimple_C_2147482375
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 252                  NaN     Add Sugar
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   1.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 253                  NaN      Add water
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
#df.to_csv('act_step_C014B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        88
# Right Hand Released    73
# Left Hand Grab         41
# Left Hand Released     30
# Chopped                20
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     50.400000
# std      28.953411
# min      20.000000
# 25%      30.000000
# 50%      41.000000
# 75%      73.000000
# max      88.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 252

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PiePanSimple_C_2147482369                 58
# Knife_C_4                                 24
# NewMeasuringCupSimple2_C_2147482378       16
# StirSpoonPieSImple_C_2147482371           16
# PieBowlSimple_C_2147482366                12
# CinnyShakerGrabable_C_2147482376           8
# ButterHolderSimple_C_2147482375            8
# ApplePieCookbook_C_0                       7
# Apple_C_2147482358                         7
# WaterPitcherSimple_C_2147482372            6
# SugarJarSimple_C_2147482373                6
# Apple_Slice_C_2147482348                   4
# Apple_Slice2_C_2147482347                  4
# Apple_Slice4_C_2147482361                  4
# Apple_C_2147482393                         3
# Apple_C_2147482351                         3
# Apple_C_2147482389                         3
# oven_C_1                                   3
# Apple_C_2147482390                         3
# Apple_Slice2_C_2147482359                  2
# SaucePotSimple2_C_2147482377               2
# Apple_Slice3_C_2147482334                  2
# Apple_Slice_C_2147482339                   2
# Apple_Slice2_C_2147482338                  2
# Apple_Slice4_C_2147482340                  2
# Apple_Slice3_C_2147482341                  2
# Apple_Half_C_2147482343                    2
# Apple_Slice4_C_2147482345                  2
# Apple_Slice3_C_2147482362                  2
# Apple_Slice3_C_2147482346                  2
# Apple_Slice_C_2147482360                   2
# Apple_Slice4_C_2147482352                  2
# Apple_Half2_C_2147482356                   2
# Apple_Slice2_C_2147482354                  2
# Apple_Slice3_C_2147482353                  2
# Apple_Half_C_2147482350                    2
# Apple_Half2_C_2147482342                   1
# Apple_Half_C_2147482364                    1
# Butter_C_2147482368                        1
# Apple_Slice_C_2147482355                   1
# Butter_C_2147482374                        1
# Apple_Half2_C_2147482335                   1
# Apple_Half_C_2147482357                    1
# Apple_Half2_C_2147482363                   1
# PillsberryDoughGirlSimple_C_2147482331     1
# PillsberryDoughBoySimple_C_2147482332      1
# Apple_Half2_C_2147482349                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               9   64.921382                  3.0
# 1           Add water              8   25.629615                  1.0
# 2          Add butter             15   33.059509                  1.0
# 3          Add butter              1    0.974243                  0.0
# 4   Add apples to pan             40   42.193451                  0.0
# 5   Add apples to pan              2    1.721832                  0.0
# 6   Add apples to pan              2    1.577621                  0.0
# 7   Add apples to pan              2    1.523071                  0.0
# 8   Add apples to pan             19   22.562653                  0.0
# 9   Add apples to pan              2    1.453247                  0.0
# 10  Add apples to pan              2    1.201355                  0.0
# 11  Add apples to pan             22   16.054520                  1.0
# 12  Add apples to pan              2    0.610443                  0.0
# 13  Add apples to pan              2    0.640671                  0.0
# 14  Add apples to pan              4    1.955795                  0.0
# 15  Add apples to pan             10    7.948899                  0.0
# 16  Add apples to pan              1    0.532303                  0.0
# 17  Add apples to pan              3    0.914551                  0.0
# 18  Add apples to pan              2    1.644135                  0.0
# 19  Add apples to pan             12    6.229446                  0.0
# 20       Add cinnamon              8   14.052369                  2.0
# 21         Pour syrup              2   10.375915                  0.0
# 22          Stir bowl              3   10.064972                  0.0
# 23   Add bottom crust             13   27.423675                  0.0
# 24      Add crust top              4    8.416168                  1.0
# 25    Put pie in oven             10   24.960450                  2.0
# 26     Post last step             52   45.117126                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 252

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C014',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C014            252        373.759417                       12.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        9.333333   13.842941             0.444444
# std        12.140207   16.811596             0.800641
# min         1.000000    0.532303             0.000000
# 25%         2.000000    1.488159             0.000000
# 50%         4.000000    7.948899             0.000000
# 75%        11.000000   23.761552             1.000000
# max        52.000000   64.921382             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  108.763993
# 1         Add butter      2   34.033752
# 2         Add Sugar       1   64.921382
# 3          Add water      1   25.629615
# 4       Add cinnamon      1   14.052369
# 5         Pour syrup      1   10.375915
# 6          Stir bowl      1   10.064972
# 7   Add bottom crust      1   27.423675
# 8      Add crust top      1    8.416168
# 9    Put pie in oven      1   24.960450

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add bottom crust       0                 1       0                   0
# Put pie in oven        0                 2       0                   0
# Add apples to pan     70                 0       0                   0
# Add water              0                 0       0                   0
# Add butter             0                 0       2                   6
# Add crust top          0                 0       0                   0
# Pour syrup             0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       2
# Add cinnamon                         5      0                       0
# Stir bowl                            0      0                       0
# Add bottom crust                     0      0                       2
# Put pie in oven                      0      0                       0
# Add apples to pan                    2     24                       6
# Add water                            0      0                       6
# Add butter                           0      0                       0
# Add crust top                        0      0                       0
# Pour syrup                           1      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      0             0                         0
# Add bottom crust               2             4                         0
# Put pie in oven                0             4                         0
# Add apples to pan              8             0                         0
# Add water                      0             0                         0
# Add butter                     0             2                         0
# Add crust top                  2             0                         1
# Pour syrup                     0             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add bottom crust                           1                0
# Put pie in oven                            0                0
# Add apples to pan                          0                0
# Add water                                  0                0
# Add butter                                 0                0
# Add crust top                              0                0
# Pour syrup                                 0                1
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add cinnamon                        0               0                   0
# Stir bowl                           1               0                   0
# Add bottom crust                    3               0                   0
# Put pie in oven                     0               0                   0
# Add apples to pan                  12               4                   0
# Add water                           0               0                   1
# Add butter                          0               0                   5
# Add crust top                       0               0                   0
# Pour syrup                          0               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                   6
# Add cinnamon          0                   6
# Stir bowl             0                   3
# Add bottom crust      0                  13
# Put pie in oven       2                   8
# Add apples to pan     0                 126
# Add water             0                   7
# Add butter            0                  15
# Add crust top         0                   3
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                Interacted Object  \
# 0        3.337766      Right Hand Grab             ApplePieCookbook_C_0
# 1        9.278296       Left Hand Grab                              NaN
# 2       14.512472       Left Hand Grab                              NaN
# 3       33.833042      Right Hand Grab             ApplePieCookbook_C_0
# 4       55.893211       Left Hand Grab      SugarJarSimple_C_2147482373
# ..            ...                  ...                              ...
# 270    405.081787  Right Hand Released        PiePanSimple_C_2147482369
# 271    407.650360      Right Hand Grab  ButterHolderSimple_C_2147482375
# 272    408.833008  Right Hand Released  ButterHolderSimple_C_2147482375
# 273    409.899445      Right Hand Grab        PiePanSimple_C_2147482369
# 274    410.199310  Right Hand Released        PiePanSimple_C_2147482369
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 270                  0.0            NaN
# 271                  0.0            NaN
# 272                  0.0            NaN
# 273                  0.0            NaN
# 274                  0.0            NaN
#
# [275 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        88
# Right Hand Released    73
# Left Hand Grab         41
# Left Hand Released     30
# Chopped                20
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         6.0
# Left Hand Released     0.0
# Right Hand Grab        6.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            88                        6.0
# 4  Right Hand Released            73                        0.0
# 1       Left Hand Grab            41                        6.0
# 2   Left Hand Released            30                        0.0
# 0              Chopped            20                        0.0
