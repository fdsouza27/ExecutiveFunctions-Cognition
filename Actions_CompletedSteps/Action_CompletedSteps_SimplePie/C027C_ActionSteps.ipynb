# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C027 C/'
file_name = 'C027_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object
# 0      6.326388     Right Hand Grab         ApplePieCookbook_C_0
# 1     12.215217     Right Hand Grab                          NaN
# 2     13.849139     Right Hand Grab         ApplePieCookbook_C_0
# 3     22.400694      Left Hand Grab  SugarJarSimple_C_2147482373
# 4     23.621077  Left Hand Released  SugarJarSimple_C_2147482373

# %%
df1.shape
# Out:
# (194, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    177
# 1     17
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       12.215217  Right Hand Grab               NaN                    1
# 7       38.755142   Left Hand Grab               NaN                    1
# 10      41.810440   Left Hand Grab               NaN                    1
# 33     108.064743   Left Hand Grab               NaN                    1
# 37     116.585274  Right Hand Grab               NaN                    1
# 85     160.765945  Right Hand Grab               NaN                    1
# 138    204.532242  Right Hand Grab               NaN                    1
# 155    248.228928  Right Hand Grab               NaN                    1
# 157    259.182526   Left Hand Grab               NaN                    1
# 159    271.608673   Left Hand Grab               NaN                    1
# 160    274.765533  Right Hand Grab               NaN                    1
# 161    276.089294   Left Hand Grab               NaN                    1
# 183    348.576294  Right Hand Grab               NaN                    1
# 186    365.982910  Right Hand Grab               NaN                    1
# 189    372.568634  Right Hand Grab               NaN                    1
# 190    374.369507  Right Hand Grab               NaN                    1
# 192    377.623993  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object  \
# 0      6.326388     Right Hand Grab         ApplePieCookbook_C_0
# 1     12.215217     Right Hand Grab                          NaN
# 2     13.849139     Right Hand Grab         ApplePieCookbook_C_0
# 3     22.400694      Left Hand Grab  SugarJarSimple_C_2147482373
# 4     23.621077  Left Hand Released  SugarJarSimple_C_2147482373
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C027 C/'
file_name = 'C027_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     61.238972         Add Sugar
# 1     72.065010          Add water
# 2     95.056396         Add butter
# 3     98.760849         Add butter
# 4    137.592789  Add apples to pan
# 5    139.496872  Add apples to pan
# 6    145.935730  Add apples to pan
# 7    154.824036  Add apples to pan
# 8    166.787308  Add apples to pan
# 9    168.543228  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (220, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0        6.326388      Right Hand Grab                 ApplePieCookbook_C_0
# 1       12.215217      Right Hand Grab                                  NaN
# 2       13.849139      Right Hand Grab                 ApplePieCookbook_C_0
# 3       22.400694       Left Hand Grab          SugarJarSimple_C_2147482373
# 4       23.621077   Left Hand Released          SugarJarSimple_C_2147482373
# 5       25.890135       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 6       37.455193   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 7       38.755142       Left Hand Grab                                  NaN
# 8       40.332428       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 9       40.798344   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 10      41.810440       Left Hand Grab                                  NaN
# 11      44.077602       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 12      49.152824   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 13      51.319595       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 14      54.251793   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 15      56.214630       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 194     61.238972                  NaN                                  NaN
# 16      62.578087   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 17      66.205658       Left Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 18      67.316971   Left Hand Released  NewMeasuringCupSimple2_C_2147482378
# 19      68.990700      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 195     72.065010                  NaN                                  NaN
# 20      78.603851  Right Hand Released      WaterPitcherSimple_C_2147482372
# 21      79.675781      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 22      80.879349  Right Hand Released      WaterPitcherSimple_C_2147482372
# 23      83.911446      Right Hand Grab                   Apple_C_2147482386
# 24      85.257790  Right Hand Released                   Apple_C_2147482386
# 25      89.477798       Left Hand Grab      ButterHolderSimple_C_2147482375
# 26      90.355530   Left Hand Released      ButterHolderSimple_C_2147482375
# 27      92.811874       Left Hand Grab                  Butter_C_2147482374
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   1.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 194                  NaN     Add Sugar
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 195                  NaN      Add water
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN

# %%
#df.to_csv('act_step_C027C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        84
# Right Hand Released    61
# Left Hand Grab         21
# Chopped                15
# Left Hand Released     13
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.00000
# mean     38.80000
# std      31.95622
# min      13.00000
# 25%      15.00000
# 50%      21.00000
# 75%      61.00000
# max      84.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 194

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                 24
# Apple_C_2147482365                        17
# StirSpoonPieSImple_C_2147482371           14
# NewMeasuringCupSimple2_C_2147482378       12
# PieBowlSimple_C_2147482366                10
# ApplePieCookbook_C_0                       7
# oven_C_1                                   4
# Apple_Slice2_C_2147482339                  4
# Apple_Half_C_2147482356                    4
# Apple_Slice2_C_2147482359                  4
# PiePanSimple_C_2147482369                  4
# ButterHolderSimple_C_2147482375            4
# Apple_C_2147482386                         4
# WaterPitcherSimple_C_2147482372            4
# Apple_Half_C_2147482349                    3
# Apple_C_2147482364                         3
# Apple_C_2147482361                         3
# Apple_Half_C_2147482342                    3
# Apple_C_2147482388                         3
# Apple_Half2_C_2147482362                   3
# Apple_Slice2_C_2147482346                  2
# Apple_Slice_C_2147482340                   2
# Apple_Slice3_C_2147482338                  2
# Apple_Slice4_C_2147482337                  2
# Apple_Slice4_C_2147482344                  2
# CinnyShakerGrabable_C_2147482376           2
# SaucePotSimple2_C_2147482377               2
# Apple_Slice3_C_2147482345                  2
# Apple_Slice_C_2147482347                   2
# Apple_Slice_C_2147482354                   2
# Apple_Slice2_C_2147482353                  2
# SugarJarSimple_C_2147482373                2
# Apple_Slice3_C_2147482352                  2
# Apple_Slice3_C_2147482358                  2
# Apple_Slice4_C_2147482357                  2
# Apple_Slice_C_2147482360                   2
# Butter_C_2147482374                        2
# Apple_Slice4_C_2147482351                  2
# Butter_C_2147482368                        1
# Apple_Half2_C_2147482348                   1
# Apple_Half2_C_2147482341                   1
# Apple_Half2_C_2147482355                   1
# PillsberryDoughGirlSimple_C_2147482335     1
# PillsberryDoughBoySimple_C_2147482336      1
# Apple_Half_C_2147482363                    1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              16   54.912584                  3.0
# 1           Add water              4    9.486923                  0.0
# 2          Add butter              9   16.452545                  0.0
# 3          Add butter              1    2.482674                  0.0
# 4   Add apples to pan             27   33.882843                  2.0
# 5   Add apples to pan              3    1.448303                  0.0
# 6   Add apples to pan              8    5.765839                  0.0
# 7   Add apples to pan             11    7.757965                  0.0
# 8   Add apples to pan             14   11.153748                  1.0
# 9   Add apples to pan              3    1.654999                  0.0
# 10  Add apples to pan              2    0.988586                  0.0
# 11  Add apples to pan              2    0.744766                  0.0
# 12  Add apples to pan             15   11.292877                  0.0
# 13  Add apples to pan              2    1.170151                  0.0
# 14  Add apples to pan              2    1.165055                  0.0
# 15  Add apples to pan              2    0.723068                  0.0
# 16  Add apples to pan             20   17.102432                  1.0
# 17  Add apples to pan              2    1.357513                  0.0
# 18  Add apples to pan              1    3.311615                  0.0
# 19  Add apples to pan              3    1.664810                  0.0
# 20       Add cinnamon              4   14.162125                  0.0
# 21         Pour syrup              2    8.718796                  0.0
# 22          Stir bowl             18   60.328080                  5.0
# 23   Add bottom crust              4    7.636292                  0.0
# 24      Add crust top              3    6.231751                  0.0
# 25    Put pie in oven              7   31.438873                  1.0
# 26     Post last step              9   15.976868                  4.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 194

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C027',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C027            194        329.012081                       17.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        7.185185   12.185633             0.629630
# std         6.922855   15.739465             1.334401
# min         1.000000    0.723068             0.000000
# 25%         2.000000    1.551651             0.000000
# 50%         4.000000    7.636292             0.000000
# 75%        10.000000   15.069497             0.500000
# max        27.000000   60.328080             5.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16  101.184570
# 1         Add butter      2   18.935219
# 2         Add Sugar       1   54.912584
# 3          Add water      1    9.486923
# 4       Add cinnamon      1   14.162125
# 5         Pour syrup      1    8.718796
# 6          Stir bowl      1   60.328080
# 7   Add bottom crust      1    7.636292
# 8      Add crust top      1    6.231751
# 9    Put pie in oven      1   31.438873

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add water              0                 0       0                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   2
# Put pie in oven        0                 2       0                   0
# Add butter             2                 0       3                   2
# Add apples to pan     81                 0       0                   0
# Add bottom crust       0                 0       0                   0
# Add crust top          0                 0       0                   0
# Pour syrup             0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       9
# Add water                            0      0                       3
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       0
# Add apples to pan                    0     24                       0
# Add bottom crust                     0      0                       0
# Add crust top                        0      0                       0
# Pour syrup                           1      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add cinnamon                   2             0                         0
# Stir bowl                      0             0                         0
# Put pie in oven                0             2                         0
# Add butter                     0             0                         0
# Add apples to pan              4             0                         0
# Add bottom crust               2             0                         0
# Add crust top                  2             0                         1
# Pour syrup                     0             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Put pie in oven                            0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Add bottom crust                           1                0
# Add crust top                              0                0
# Pour syrup                                 0                1
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add water                           0               0                   1
# Add cinnamon                        0               0                   0
# Stir bowl                           9               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               0                   3
# Add apples to pan                   4               0                   0
# Add bottom crust                    1               0                   0
# Add crust top                       0               0                   0
# Pour syrup                          0               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  13
# Add water             0                   4
# Add cinnamon          0                   4
# Stir bowl             0                  13
# Put pie in oven       2                   6
# Add butter            0                  10
# Add apples to pan     0                 113
# Add bottom crust      0                   4
# Add crust top         0                   3
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time         Action Type            Interacted Object  \
# 0        6.326388     Right Hand Grab         ApplePieCookbook_C_0
# 1       12.215217     Right Hand Grab                          NaN
# 2       13.849139     Right Hand Grab         ApplePieCookbook_C_0
# 3       22.400694      Left Hand Grab  SugarJarSimple_C_2147482373
# 4       23.621077  Left Hand Released  SugarJarSimple_C_2147482373
# ..            ...                 ...                          ...
# 215    372.568634     Right Hand Grab                          NaN
# 216    374.369507     Right Hand Grab                          NaN
# 217    375.757202     Right Hand Grab                     oven_C_1
# 218    377.623993     Right Hand Grab                          NaN
# 219    378.904175     Right Hand Grab         ApplePieCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 215                  1.0            NaN
# 216                  1.0            NaN
# 217                  0.0            NaN
# 218                  1.0            NaN
# 219                  0.0            NaN
#
# [220 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        84
# Right Hand Released    61
# Left Hand Grab         21
# Chopped                15
# Left Hand Released     13
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          6.0
# Left Hand Released      0.0
# Right Hand Grab        11.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            84                       11.0
# 4  Right Hand Released            61                        0.0
# 1       Left Hand Grab            21                        6.0
# 0              Chopped            15                        0.0
# 2   Left Hand Released            13                        0.0
