# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C005 C/'
file_name = 'C005_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type            Interacted Object
# 0     49.072052   Left Hand Grab                          NaN
# 1     50.232567   Left Hand Grab         ApplePieCookbook_C_0
# 2     57.472851   Left Hand Grab                          NaN
# 3     58.481625   Left Hand Grab         ApplePieCookbook_C_0
# 4     67.155403  Right Hand Grab  SugarJarSimple_C_2147482385

# %%
df1.shape
# Out:
# (224, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    200
# 1     24
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       49.072052   Left Hand Grab               NaN                    1
# 2       57.472851   Left Hand Grab               NaN                    1
# 7       93.142235   Left Hand Grab               NaN                    1
# 35     141.911682   Left Hand Grab               NaN                    1
# 36     142.987183   Left Hand Grab               NaN                    1
# 37     143.856277  Right Hand Grab               NaN                    1
# 77     195.200790  Right Hand Grab               NaN                    1
# 78     196.122910  Right Hand Grab               NaN                    1
# 80     197.055176  Right Hand Grab               NaN                    1
# 121    268.482605   Left Hand Grab               NaN                    1
# 140    274.873688   Left Hand Grab               NaN                    1
# 165    362.662323  Right Hand Grab               NaN                    1
# 166    363.439392  Right Hand Grab               NaN                    1
# 184    429.237366   Left Hand Grab               NaN                    1
# 186    444.981079   Left Hand Grab               NaN                    1
# 187    446.447693   Left Hand Grab               NaN                    1
# 190    453.258179   Left Hand Grab               NaN                    1
# 191    453.829895   Left Hand Grab               NaN                    1
# 192    454.418732   Left Hand Grab               NaN                    1
# 193    455.319031   Left Hand Grab               NaN                    1
# 206    474.731079   Left Hand Grab               NaN                    1
# 208    477.069733  Right Hand Grab               NaN                    1
# 210    478.027832  Right Hand Grab               NaN                    1
# 212    489.502319  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type            Interacted Object  \
# 0     49.072052   Left Hand Grab                          NaN
# 1     50.232567   Left Hand Grab         ApplePieCookbook_C_0
# 2     57.472851   Left Hand Grab                          NaN
# 3     58.481625   Left Hand Grab         ApplePieCookbook_C_0
# 4     67.155403  Right Hand Grab  SugarJarSimple_C_2147482385
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C005 C/'
file_name = 'C005_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    107.506393         Add Sugar
# 1    116.226830          Add water
# 2    132.433853         Add butter
# 3    134.768982         Add butter
# 4    210.832001  Add apples to pan
# 5    215.341568  Add apples to pan
# 6    217.120193  Add apples to pan
# 7    219.175369  Add apples to pan
# 8    221.217514  Add apples to pan
# 9    223.073196  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (242, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0       49.072052       Left Hand Grab                                  NaN
# 1       50.232567       Left Hand Grab                 ApplePieCookbook_C_0
# 2       57.472851       Left Hand Grab                                  NaN
# 3       58.481625       Left Hand Grab                 ApplePieCookbook_C_0
# 4       67.155403      Right Hand Grab          SugarJarSimple_C_2147482385
# 5       68.926575       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 6       92.675529   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 7       93.142235       Left Hand Grab                                  NaN
# 8       95.080734       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 9       96.102585   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 10      96.672554       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 11      97.552185   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 12      98.463173       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 13      99.418327   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 14     100.774025       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 15     103.373055   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 16     103.494553       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 17     104.716835   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 18     104.995811       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 224    107.506393                  NaN                                  NaN
# 19     110.148811   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 20     110.693283  Right Hand Released          SugarJarSimple_C_2147482385
# 21     114.287483       Left Hand Grab      WaterPitcherSimple_C_2147482384
# 225    116.226830                  NaN                                  NaN
# 22     123.702454   Left Hand Released      WaterPitcherSimple_C_2147482384
# 23     128.286499      Right Hand Grab      ButterHolderSimple_C_2147482387
# 24     129.352646  Right Hand Released      ButterHolderSimple_C_2147482387
# 25     130.226791      Right Hand Grab                  Butter_C_2147482386
# 26     132.122757  Right Hand Released                  Butter_C_2147482386
# 226    132.433853                  NaN                                  NaN
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 224                  NaN     Add Sugar
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 225                  NaN      Add water
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 226                  NaN     Add butter

# %%
#df.to_csv('act_step_C005C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         97
# Left Hand Released     61
# Right Hand Grab        30
# Chopped                22
# Right Hand Released    14
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     44.800000
# std      34.186255
# min      14.000000
# 25%      22.000000
# 50%      30.000000
# 75%      61.000000
# max      97.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 224

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# StirSpoonPieSImple_C_2147482383           40
# PieBowlSimple_C_2147482378                22
# ApplePieCookbook_C_0                      16
# PiePanSimple_C_2147482381                 16
# NewMeasuringCupSimple2_C_2147482390       14
# Apple_Slice_C_2147482361                  11
# ButterHolderSimple_C_2147482387           10
# oven_C_1                                   7
# Knife_C_4                                  6
# Apple_C_2147482377                         4
# Apple_Slice3_C_2147482363                  3
# Apple_Slice_C_2147482369                   3
# Apple_Slice2_C_2147482360                  3
# Apple_Half2_C_2147482364                   3
# Apple_C_2147482375                         3
# Apple_C_2147482376                         3
# Apple_C_2147482396                         3
# WaterPitcherSimple_C_2147482384            2
# Apple_Slice2_C_2147482368                  2
# CinnyShakerGrabable_C_2147482388           2
# SaucePotSimple2_C_2147482389               2
# Apple_Slice4_C_2147482356                  2
# Apple_Slice3_C_2147482357                  2
# Butter_C_2147482380                        2
# Apple_Slice2_C_2147482358                  2
# Apple_Slice_C_2147482359                   2
# Apple_Slice4_C_2147482362                  2
# Apple_Half2_C_2147482370                   2
# Butter_C_2147482386                        2
# SugarJarSimple_C_2147482385                2
# Apple_Half_C_2147482365                    1
# Apple_Half_C_2147482367                    1
# PillsberryDoughBoySimple_C_2147482355      1
# PillsberryDoughGirlSimple_C_2147482354     1
# Apple_Half2_C_2147482366                   1
# Apple_Half_C_2147482371                    1
# Exit_C_1                                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Pour syrup           1
# Add cinnamon         1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              19   58.434341                  3.0
# 1           Add water              3    6.078019                  0.0
# 2          Add butter              5    8.731399                  0.0
# 3          Add butter              2    1.588272                  0.0
# 4   Add apples to pan             63   75.341584                  6.0
# 5   Add apples to pan              3    3.843750                  0.0
# 6   Add apples to pan              3    1.746215                  0.0
# 7   Add apples to pan              2    1.478302                  0.0
# 8   Add apples to pan              2    1.122070                  0.0
# 9   Add apples to pan              2    1.077957                  0.0
# 10  Add apples to pan              8    6.053925                  0.0
# 11  Add apples to pan              2    1.099945                  0.0
# 12         Pour syrup              3    9.275421                  0.0
# 13       Add cinnamon             52  124.043671                  4.0
# 14          Stir bowl              4   23.751648                  0.0
# 15   Add bottom crust              2    5.488465                  0.0
# 16      Add crust top              3    6.880005                  0.0
# 17    Put pie in oven             33   66.836518                 10.0
# 18     Post last step             13   17.332367                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 224

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C005',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C005            224        420.203874                       24.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       11.789474   22.115993             1.263158
# std        17.989438   34.038938             2.704772
# min         2.000000    1.077957             0.000000
# 25%         2.000000    1.667243             0.000000
# 50%         3.000000    6.078019             0.000000
# 75%        10.500000   20.542007             0.500000
# max        63.000000  124.043671            10.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   91.763748
# 1         Add butter      2   10.319671
# 2         Add Sugar       1   58.434341
# 3          Add water      1    6.078019
# 4         Pour syrup      1    9.275421
# 5       Add cinnamon      1  124.043671
# 6          Stir bowl      1   23.751648
# 7   Add bottom crust      1    5.488465
# 8      Add crust top      1    6.880005
# 9    Put pie in oven      1   66.836518

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add water              0                 0       0                   0
# Add apples to pan     52                 5       0                   8
# Add cinnamon           2                 2       0                   0
# Put pie in oven        0                 7       0                   0
# Add butter             0                 0       4                   2
# Pour syrup             0                 0       0                   0
# Add crust top          0                 0       0                   0
# Stir bowl              0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                      13
# Add water                            0      0                       1
# Add apples to pan                    0      4                       0
# Add cinnamon                         1      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       0
# Pour syrup                           0      0                       0
# Add crust top                        0      0                       0
# Stir bowl                            1      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add apples to pan             10             0                         0
# Add cinnamon                   8             0                         0
# Put pie in oven                0            10                         0
# Add butter                     0             0                         0
# Pour syrup                     2             0                         0
# Add crust top                  2             0                         0
# Stir bowl                      0             0                         0
# Add bottom crust               0             0                         1
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                0
# Add apples to pan                          0                0
# Add cinnamon                               0                1
# Put pie in oven                            0                0
# Add butter                                 0                0
# Pour syrup                                 0                1
# Add crust top                              1                0
# Stir bowl                                  0                0
# Add bottom crust                           0                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               1                   0
# Add water                           0               1                   1
# Add apples to pan                   0               0                   0
# Add cinnamon                       34               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               0                   1
# Pour syrup                          0               0                   0
# Add crust top                       0               0                   0
# Stir bowl                           3               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  16
# Add water             0                   3
# Add apples to pan     0                  79
# Add cinnamon          0                  48
# Put pie in oven       6                  23
# Add butter            0                   7
# Pour syrup            0                   3
# Add crust top         0                   3
# Stir bowl             0                   4
# Add bottom crust      0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time         Action Type            Interacted Object  \
# 0       49.072052      Left Hand Grab                          NaN
# 1       50.232567      Left Hand Grab         ApplePieCookbook_C_0
# 2       57.472851      Left Hand Grab                          NaN
# 3       58.481625      Left Hand Grab         ApplePieCookbook_C_0
# 4       67.155403     Right Hand Grab  SugarJarSimple_C_2147482385
# ..            ...                 ...                          ...
# 237    498.254272      Left Hand Grab    PiePanSimple_C_2147482381
# 238    499.420135  Left Hand Released    PiePanSimple_C_2147482381
# 239    499.986328      Left Hand Grab                    Knife_C_4
# 240    504.209686  Left Hand Released                    Knife_C_4
# 241    505.544067      Left Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 237                  0.0            NaN
# 238                  0.0            NaN
# 239                  0.0            NaN
# 240                  0.0            NaN
# 241                  0.0            NaN
#
# [242 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         97
# Left Hand Released     61
# Right Hand Grab        30
# Chopped                22
# Right Hand Released    14
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         15.0
# Left Hand Released      0.0
# Right Hand Grab         9.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1       Left Hand Grab            97                       15.0
# 2   Left Hand Released            61                        0.0
# 3      Right Hand Grab            30                        9.0
# 0              Chopped            22                        0.0
# 4  Right Hand Released            14                        0.0
