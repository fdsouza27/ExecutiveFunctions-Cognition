# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C002 B/'
file_name = 'C002_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type                    Interacted Object
# 0      6.339067     Right Hand Grab                 ApplePieCookbook_C_0
# 1     24.180655     Right Hand Grab          SugarJarSimple_C_2147482385
# 2     25.688787      Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 3     35.035526  Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 4     35.878883      Left Hand Grab                                  NaN

# %%
df1.shape
# Out:
# (231, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    201
# 1     30
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 4       35.878883   Left Hand Grab               NaN                    1
# 9       49.821171   Left Hand Grab               NaN                    1
# 23      61.774578   Left Hand Grab               NaN                    1
# 40     101.666168  Right Hand Grab               NaN                    1
# 41     104.070572  Right Hand Grab               NaN                    1
# 42     105.499901  Right Hand Grab               NaN                    1
# 43     107.778397  Right Hand Grab               NaN                    1
# 44     109.000031  Right Hand Grab               NaN                    1
# 54     144.258957  Right Hand Grab               NaN                    1
# 57     147.658218  Right Hand Grab               NaN                    1
# 60     155.325272  Right Hand Grab               NaN                    1
# 61     156.792557  Right Hand Grab               NaN                    1
# 62     158.268036  Right Hand Grab               NaN                    1
# 63     160.401123  Right Hand Grab               NaN                    1
# 66     166.134781   Left Hand Grab               NaN                    1
# 82     203.971573   Left Hand Grab               NaN                    1
# 83     204.593460   Left Hand Grab               NaN                    1
# 170    338.502075  Right Hand Grab               NaN                    1
# 171    340.158966  Right Hand Grab               NaN                    1
# 172    340.735260  Right Hand Grab               NaN                    1
# 180    370.086395  Right Hand Grab               NaN                    1
# 192    401.525421  Right Hand Grab               NaN                    1
# 193    402.325562  Right Hand Grab               NaN                    1
# 194    404.736115  Right Hand Grab               NaN                    1
# 215    443.451263  Right Hand Grab               NaN                    1
# 221    458.769257  Right Hand Grab               NaN                    1
# 222    459.936462  Right Hand Grab               NaN                    1
# 223    460.747589  Right Hand Grab               NaN                    1
# 224    461.802551  Right Hand Grab               NaN                    1
# 225    462.569214  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type                    Interacted Object  \
# 0      6.339067     Right Hand Grab                 ApplePieCookbook_C_0
# 1     24.180655     Right Hand Grab          SugarJarSimple_C_2147482385
# 2     25.688787      Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 3     35.035526  Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 4     35.878883      Left Hand Grab                                  NaN
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C002 B/'
file_name = 'C002_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    179.718933         Add Sugar
# 1    227.432983          Add water
# 2    243.818832         Add butter
# 3    248.096603         Add butter
# 4    313.651947  Add apples to pan
# 5    315.084442  Add apples to pan
# 6    318.672028  Add apples to pan
# 7    320.016266  Add apples to pan
# 8    329.737640  Add apples to pan
# 9    330.826447  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (249, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                    Interacted Object  \
# 0       6.339067      Right Hand Grab                 ApplePieCookbook_C_0
# 1      24.180655      Right Hand Grab          SugarJarSimple_C_2147482385
# 2      25.688787       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 3      35.035526   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 4      35.878883       Left Hand Grab                                  NaN
# 5      37.957458       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 6      39.090801   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 7      40.667622       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 8      41.777798   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 9      49.821171       Left Hand Grab                                  NaN
# 10     51.266541       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 11     51.599739   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 12     52.387516       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 13     52.743511   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 14     53.220055       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 15     53.541439   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 16     54.176365       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 17     54.587440   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 18     55.075165       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 19     56.721214   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 20     56.833065  Right Hand Released          SugarJarSimple_C_2147482385
# 21     58.953251      Right Hand Grab          SugarJarSimple_C_2147482385
# 22     60.141605  Right Hand Released          SugarJarSimple_C_2147482385
# 23     61.774578       Left Hand Grab                                  NaN
# 24     63.742779       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 25     64.341599   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 26     64.530640       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 27     64.653236   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 28     65.218674       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 29     67.307640   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   1.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   1.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  1.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
#df.to_csv('act_step_C002B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        97
# Right Hand Released    57
# Left Hand Grab         40
# Left Hand Released     27
# Chopped                10
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     46.200000
# std      33.221981
# min      10.000000
# 25%      27.000000
# 50%      40.000000
# 75%      57.000000
# max      97.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 231

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# NewMeasuringCupSimple2_C_2147482390       38
# PieBowlSimple_C_2147482376                28
# Knife_C_4                                 20
# ApplePieCookbook_C_0                      15
# Butter_C_2147482386                        8
# WaterPitcherSimple_C_2147482384            8
# ButterHolderSimple_C_2147482387            6
# StirSpoonPieSImple_C_2147482383            6
# Apple_Slice4_C_2147482361                  6
# Apple_C_2147482401                         5
# PillsberryDoughBoySimple_C_2147482360      5
# Apple_Slice_C_2147482364                   5
# SugarJarSimple_C_2147482385                4
# oven_C_1                                   4
# CinnyShakerGrabable_C_2147482388           4
# Apple_Slice_C_2147482371                   4
# Apple_Slice3_C_2147482369                  4
# SaucePotSimple2_C_2147482389               4
# PiePanSimple_C_2147482381                  4
# Apple_C_2147482375                         3
# Apple_Slice2_C_2147482370                  3
# Apple_Slice4_C_2147482368                  2
# Apple_Slice2_C_2147482363                  2
# Apple_Slice3_C_2147482362                  2
# Apple_C_2147482402                         2
# Apple_C_2147482403                         2
# PillsberryDoughGirlSimple_C_2147482359     2
# Apple_Half2_C_2147482372                   1
# Apple_Half_C_2147482366                    1
# Apple_Half2_C_2147482365                   1
# Apple_Half_C_2147482373                    1
# Butter_C_2147482380                        1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              70  173.379866                 15.0
# 1           Add water             22   47.492569                  2.0
# 2          Add butter              7   10.143325                  0.0
# 3          Add butter              1    1.055877                  0.0
# 4   Add apples to pan             38   57.580658                  0.0
# 5   Add apples to pan              2    0.766479                  0.0
# 6   Add apples to pan              4    2.921235                  0.0
# 7   Add apples to pan              1    0.721466                  0.0
# 8   Add apples to pan             13    9.709259                  0.0
# 9   Add apples to pan              2    0.845490                  0.0
# 10  Add apples to pan              4    1.777588                  0.0
# 11  Add apples to pan              4    0.899780                  0.0
# 12       Add cinnamon              7   12.307739                  3.0
# 13         Pour syrup              4   13.787475                  0.0
# 14          Stir bowl              7   19.482819                  1.0
# 15   Add bottom crust              6    7.308991                  0.0
# 16      Add crust top             23   39.561127                  3.0
# 17    Put pie in oven             12   32.746247                  6.0
# 18     Post last step              4    8.796326                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 231

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C002',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C002            231        441.284316                       30.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean       12.157895   23.225490             1.578947
# std        16.889389   40.197124             3.625769
# min         1.000000    0.721466             0.000000
# 25%         4.000000    1.416733             0.000000
# 50%         6.000000    9.709259             0.000000
# 75%        12.500000   26.114533             1.500000
# max        70.000000  173.379866            15.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   75.221955
# 1         Add butter      2   11.199202
# 2         Add Sugar       1  173.379866
# 3          Add water      1   47.492569
# 4       Add cinnamon      1   12.307739
# 5         Pour syrup      1   13.787475
# 6          Stir bowl      1   19.482819
# 7   Add bottom crust      1    7.308991
# 8      Add crust top      1   39.561127
# 9    Put pie in oven      1   32.746247

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              2                 2       4                   6
# Add water              0                 8       2                   0
# Add crust top          0                 1       0                   0
# Add butter             0                 0       3                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   0
# Put pie in oven        0                 2       0                   0
# Add apples to pan     42                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      2                      35
# Add water                            0      0                       1
# Add crust top                        2      2                       2
# Add butter                           0      4                       0
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Put pie in oven                      0      0                       0
# Add apples to pan                    0     12                       0
# Pour syrup                           1      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add water                      0             0                         0
# Add crust top                  8             0                         5
# Add butter                     0             0                         0
# Add cinnamon                   2             0                         0
# Stir bowl                      1             0                         0
# Put pie in oven                0             2                         0
# Add apples to pan             14             0                         0
# Pour syrup                     2             0                         0
# Add bottom crust               1             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add water                                  0                2
# Add crust top                              0                0
# Add butter                                 0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Put pie in oven                            0                0
# Add apples to pan                          0                0
# Pour syrup                                 0                1
# Add bottom crust                           2                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               4                   0
# Add water                           0               0                   7
# Add crust top                       0               0                   0
# Add butter                          0               0                   1
# Add cinnamon                        0               0                   0
# Stir bowl                           3               0                   0
# Put pie in oven                     0               0                   0
# Add apples to pan                   0               0                   0
# Pour syrup                          0               0                   0
# Add bottom crust                    3               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                  55
# Add water             0                  20
# Add crust top         0                  20
# Add butter            0                   8
# Add cinnamon          0                   4
# Stir bowl             0                   6
# Put pie in oven       2                   6
# Add apples to pan     0                  68
# Pour syrup            0                   4
# Add bottom crust      0                   6

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0        6.339067      Right Hand Grab                 ApplePieCookbook_C_0
# 1       24.180655      Right Hand Grab          SugarJarSimple_C_2147482385
# 2       25.688787       Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 3       35.035526   Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 4       35.878883       Left Hand Grab                                  NaN
# ..            ...                  ...                                  ...
# 244    476.197510                  NaN                                  NaN
# 245    483.487976      Right Hand Grab                             oven_C_1
# 246    484.954041      Right Hand Grab            PiePanSimple_C_2147482381
# 247    490.452484  Right Hand Released            PiePanSimple_C_2147482381
# 248    492.284302      Right Hand Grab                             oven_C_1
#
#      Missed Interactions   Completed Step
# 0                    0.0              NaN
# 1                    0.0              NaN
# 2                    0.0              NaN
# 3                    0.0              NaN
# 4                    1.0              NaN
# ..                   ...              ...
# 244                  NaN  Put pie in oven
# 245                  0.0              NaN
# 246                  0.0              NaN
# 247                  0.0              NaN
# 248                  0.0              NaN
#
# [249 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        97
# Right Hand Released    57
# Left Hand Grab         40
# Left Hand Released     27
# Chopped                10
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          6.0
# Left Hand Released      0.0
# Right Hand Grab        24.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            97                       24.0
# 4  Right Hand Released            57                        0.0
# 1       Left Hand Grab            40                        6.0
# 2   Left Hand Released            27                        0.0
# 0              Chopped            10                        0.0
