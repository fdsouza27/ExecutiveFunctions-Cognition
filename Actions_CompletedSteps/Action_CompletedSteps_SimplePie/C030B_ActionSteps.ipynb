# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C030 B/'
file_name = 'C030_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object
# 0      7.862499  Right Hand Grab               NaN
# 1      9.128106  Right Hand Grab               NaN
# 2     10.501829  Right Hand Grab               NaN
# 3     14.183489  Right Hand Grab               NaN
# 4     14.461099  Right Hand Grab               NaN

# %%
df1.shape
# Out:
# (159, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    126
# 1     33
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0        7.862499  Right Hand Grab               NaN                    1
# 1        9.128106  Right Hand Grab               NaN                    1
# 2       10.501829  Right Hand Grab               NaN                    1
# 3       14.183489  Right Hand Grab               NaN                    1
# 4       14.461099  Right Hand Grab               NaN                    1
# 5       14.672199  Right Hand Grab               NaN                    1
# 6       15.072233  Right Hand Grab               NaN                    1
# 7       15.627643  Right Hand Grab               NaN                    1
# 8       15.849701  Right Hand Grab               NaN                    1
# 9       19.171751  Right Hand Grab               NaN                    1
# 10      19.449463  Right Hand Grab               NaN                    1
# 11      20.504257  Right Hand Grab               NaN                    1
# 12      20.737478  Right Hand Grab               NaN                    1
# 13      20.926697  Right Hand Grab               NaN                    1
# 14      21.115557  Right Hand Grab               NaN                    1
# 15      22.371099  Right Hand Grab               NaN                    1
# 16      34.968655   Left Hand Grab               NaN                    1
# 17      35.257393   Left Hand Grab               NaN                    1
# 18      39.666965   Left Hand Grab               NaN                    1
# 19      40.088638   Left Hand Grab               NaN                    1
# 20      40.389324   Left Hand Grab               NaN                    1
# 21      40.621967   Left Hand Grab               NaN                    1
# 22      47.243633  Right Hand Grab               NaN                    1
# 23      47.866302   Left Hand Grab               NaN                    1
# 25      74.360161  Right Hand Grab               NaN                    1
# 27      78.746864   Left Hand Grab               NaN                    1
# 49     157.955627  Right Hand Grab               NaN                    1
# 62     189.374832   Left Hand Grab               NaN                    1
# 73     218.856720  Right Hand Grab               NaN                    1
# 113    248.827148  Right Hand Grab               NaN                    1
# 140    303.876312  Right Hand Grab               NaN                    1
# 147    334.956787  Right Hand Grab               NaN                    1
# 153    344.647034  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object  Missed Interactions
# 0      7.862499  Right Hand Grab               NaN                    1
# 1      9.128106  Right Hand Grab               NaN                    1
# 2     10.501829  Right Hand Grab               NaN                    1
# 3     14.183489  Right Hand Grab               NaN                    1
# 4     14.461099  Right Hand Grab               NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C030 B/'
file_name = 'C030_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0    124.252731         Add Sugar
# 1    131.994675          Add water
# 2    150.947662         Add butter
# 3    171.721054         Add butter
# 4    234.587509  Add apples to pan
# 5    235.913513  Add apples to pan
# 6    237.542877  Add apples to pan
# 7    240.442245  Add apples to pan
# 8    254.761230  Add apples to pan
# 9    255.651138  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (177, 5)

# %%
df.head(30)
# Out:
#     Session Time      Action Type     Interacted Object  Missed Interactions  \
# 0       7.862499  Right Hand Grab                   NaN                  1.0
# 1       9.128106  Right Hand Grab                   NaN                  1.0
# 2      10.501829  Right Hand Grab                   NaN                  1.0
# 3      14.183489  Right Hand Grab                   NaN                  1.0
# 4      14.461099  Right Hand Grab                   NaN                  1.0
# 5      14.672199  Right Hand Grab                   NaN                  1.0
# 6      15.072233  Right Hand Grab                   NaN                  1.0
# 7      15.627643  Right Hand Grab                   NaN                  1.0
# 8      15.849701  Right Hand Grab                   NaN                  1.0
# 9      19.171751  Right Hand Grab                   NaN                  1.0
# 10     19.449463  Right Hand Grab                   NaN                  1.0
# 11     20.504257  Right Hand Grab                   NaN                  1.0
# 12     20.737478  Right Hand Grab                   NaN                  1.0
# 13     20.926697  Right Hand Grab                   NaN                  1.0
# 14     21.115557  Right Hand Grab                   NaN                  1.0
# 15     22.371099  Right Hand Grab                   NaN                  1.0
# 16     34.968655   Left Hand Grab                   NaN                  1.0
# 17     35.257393   Left Hand Grab                   NaN                  1.0
# 18     39.666965   Left Hand Grab                   NaN                  1.0
# 19     40.088638   Left Hand Grab                   NaN                  1.0
# 20     40.389324   Left Hand Grab                   NaN                  1.0
# 21     40.621967   Left Hand Grab                   NaN                  1.0
# 22     47.243633  Right Hand Grab                   NaN                  1.0
# 23     47.866302   Left Hand Grab                   NaN                  1.0
# 24     60.263855  Right Hand Grab  ApplePieCookbook_C_0                  0.0
# 25     74.360161  Right Hand Grab                   NaN                  1.0
# 26     76.849350  Right Hand Grab  ApplePieCookbook_C_0                  0.0
# 27     78.746864   Left Hand Grab                   NaN                  1.0
# 28     79.959709   Left Hand Grab  ApplePieCookbook_C_0                  0.0
# 29     88.889076  Right Hand Grab  ApplePieCookbook_C_0                  0.0
#
#    Completed Step
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN

# %%
df.to_csv('act_step_C030B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        62
# Left Hand Grab         37
# Right Hand Released    28
# Left Hand Released     22
# Chopped                10
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     31.800000
# std      19.524344
# min      10.000000
# 25%      22.000000
# 50%      28.000000
# 75%      37.000000
# max      62.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 159

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowlSimple_C_2147482378                16
# SaucePotSimple2_C_2147482389              14
# Knife_C_4                                 14
# ApplePieCookbook_C_0                       9
# PiePanSimple_C_2147482381                  6
# Apple_C_2147482396                         5
# Apple_Slice2_C_2147482373                  4
# Apple_Slice3_C_2147482367                  4
# Butter_C_2147482380                        4
# oven_C_1                                   4
# Apple_Slice_C_2147482374                   4
# Apple_Half_C_2147482369                    4
# Apple_Slice4_C_2147482366                  4
# Apple_C_2147482400                         3
# Apple_Half2_C_2147482375                   3
# Butter_C_2147482386                        3
# StirSpoonPieSImple_C_2147482383            2
# CinnyShakerGrabable_C_2147482388           2
# Apple_Slice2_C_2147482364                  2
# Apple_Slice_C_2147482365                   2
# ButterHolderSimple_C_2147482387            2
# Apple_Slice3_C_2147482372                  2
# SugarJarSimple_C_2147482385                2
# Apple_Half_C_2147482376                    2
# NewMeasuringCupSimple2_C_2147482390        2
# WaterPitcherSimple_C_2147482384            2
# Apple_Slice4_C_2147482371                  2
# Apple_Half2_C_2147482368                   1
# PillsberryDoughBoySimple_C_2147482363      1
# PillsberryDoughGirlSimple_C_2147482362     1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              35  116.390232                 26.0
# 1           Add water              2    7.664391                  0.0
# 2          Add butter             12   14.058532                  0.0
# 3          Add butter              2   13.765427                  1.0
# 4   Add apples to pan             42   62.532394                  2.0
# 5   Add apples to pan              2    0.659500                  0.0
# 6   Add apples to pan              2    0.577957                  0.0
# 7   Add apples to pan              5    2.588150                  0.0
# 8   Add apples to pan             21   13.130264                  1.0
# 9   Add apples to pan              2    0.700973                  0.0
# 10  Add apples to pan              2    0.644867                  0.0
# 11  Add apples to pan              2    0.745087                  0.0
# 12       Add cinnamon              2    5.466919                  0.0
# 13         Pour syrup              2    6.761780                  0.0
# 14          Stir bowl              4   10.923676                  0.0
# 15   Add bottom crust              3   12.008118                  0.0
# 16      Add crust top              5   19.848755                  1.0
# 17    Put pie in oven              9   25.771210                  2.0
# 18     Post last step              5    7.298828                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 159

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C030',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C030            159         321.53706                       33.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        8.368421   16.923003             1.736842
# std        11.691452   27.981493             5.914597
# min         2.000000    0.577957             0.000000
# 25%         2.000000    1.666619             0.000000
# 50%         3.000000    7.664391             0.000000
# 75%         7.000000   13.911980             1.000000
# max        42.000000  116.390232            26.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   81.579192
# 1         Add butter      2   27.823959
# 2         Add Sugar       1  116.390232
# 3          Add water      1    7.664391
# 4       Add cinnamon      1    5.466919
# 5         Pour syrup      1    6.761780
# 6          Stir bowl      1   10.923676
# 7   Add bottom crust      1   12.008118
# 8      Add crust top      1   19.848755
# 9    Put pie in oven      1   25.771210

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 4       0                   0
# Add cinnamon           0                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add butter             0                 0       4                   2
# Add apples to pan     42                 0       3                   0
# Pour syrup             0                 0       0                   0
# Add water              0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       1
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add butter                           0      0                       0
# Add apples to pan                    0     14                       0
# Pour syrup                           1      0                       0
# Add water                            0      0                       1
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      1             0                         0
# Add crust top                  2             0                         0
# Put pie in oven                0             4                         0
# Add butter                     0             0                         0
# Add apples to pan             12             0                         0
# Pour syrup                     0             0                         0
# Add water                      0             0                         0
# Add bottom crust               1             0                         1
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                2
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add crust top                              1                0
# Put pie in oven                            0                0
# Add butter                                 0                6
# Add apples to pan                          0                4
# Pour syrup                                 0                1
# Add water                                  0                0
# Add bottom crust                           0                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add cinnamon                        0               0                   0
# Stir bowl                           1               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Pour syrup                          0               0                   0
# Add water                           0               0                   1
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                   9
# Add cinnamon          0                   2
# Stir bowl             0                   4
# Add crust top         0                   4
# Put pie in oven       2                   7
# Add butter            0                  13
# Add apples to pan     0                  75
# Pour syrup            0                   2
# Add water             0                   2
# Add bottom crust      0                   3

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type          Interacted Object  \
# 0        7.862499      Right Hand Grab                        NaN
# 1        9.128106      Right Hand Grab                        NaN
# 2       10.501829      Right Hand Grab                        NaN
# 3       14.183489      Right Hand Grab                        NaN
# 4       14.461099      Right Hand Grab                        NaN
# ..            ...                  ...                        ...
# 172    358.930237      Right Hand Grab       ApplePieCookbook_C_0
# 173    361.704224       Left Hand Grab                   oven_C_1
# 174    363.051941      Right Hand Grab  PiePanSimple_C_2147482381
# 175    365.197632  Right Hand Released  PiePanSimple_C_2147482381
# 176    366.229065       Left Hand Grab                   oven_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 172                  0.0            NaN
# 173                  0.0            NaN
# 174                  0.0            NaN
# 175                  0.0            NaN
# 176                  0.0            NaN
#
# [177 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        62
# Left Hand Grab         37
# Right Hand Released    28
# Left Hand Released     22
# Chopped                10
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          9.0
# Left Hand Released      0.0
# Right Hand Grab        24.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            62                       24.0
# 1       Left Hand Grab            37                        9.0
# 4  Right Hand Released            28                        0.0
# 2   Left Hand Released            22                        0.0
# 0              Chopped            10                        0.0
