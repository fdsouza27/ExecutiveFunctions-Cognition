# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C031 C/'
file_name = 'C031_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0     28.205835  Right Hand Grab  ApplePieCookbook_C_0
# 1     42.328316  Right Hand Grab                   NaN
# 2     43.160664  Right Hand Grab                   NaN
# 3     44.172668  Right Hand Grab                   NaN
# 4     45.526615  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (149, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    121
# 1     28
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       42.328316  Right Hand Grab               NaN                    1
# 2       43.160664  Right Hand Grab               NaN                    1
# 3       44.172668  Right Hand Grab               NaN                    1
# 4       45.526615  Right Hand Grab               NaN                    1
# 5       47.338001  Right Hand Grab               NaN                    1
# 6       47.938084  Right Hand Grab               NaN                    1
# 7       48.499035  Right Hand Grab               NaN                    1
# 19     110.925461  Right Hand Grab               NaN                    1
# 22     118.470726  Right Hand Grab               NaN                    1
# 25     123.633499  Right Hand Grab               NaN                    1
# 61     152.495148  Right Hand Grab               NaN                    1
# 96     182.869720  Right Hand Grab               NaN                    1
# 98     186.467865  Right Hand Grab               NaN                    1
# 104    209.419449  Right Hand Grab               NaN                    1
# 105    210.096390  Right Hand Grab               NaN                    1
# 111    237.337448  Right Hand Grab               NaN                    1
# 112    237.925980  Right Hand Grab               NaN                    1
# 116    252.556778  Right Hand Grab               NaN                    1
# 121    265.265289  Right Hand Grab               NaN                    1
# 124    269.772888  Right Hand Grab               NaN                    1
# 125    270.717865  Right Hand Grab               NaN                    1
# 128    274.074921  Right Hand Grab               NaN                    1
# 130    287.331635  Right Hand Grab               NaN                    1
# 131    287.975739  Right Hand Grab               NaN                    1
# 133    290.598145  Right Hand Grab               NaN                    1
# 134    291.432098  Right Hand Grab               NaN                    1
# 137    296.696716  Right Hand Grab               NaN                    1
# 139    300.925812  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0     28.205835  Right Hand Grab  ApplePieCookbook_C_0                    0
# 1     42.328316  Right Hand Grab                   NaN                    1
# 2     43.160664  Right Hand Grab                   NaN                    1
# 3     44.172668  Right Hand Grab                   NaN                    1
# 4     45.526615  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C031 C/'
file_name = 'C031_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     84.153320         Add Sugar
# 1     93.761276          Add water
# 2    110.248627         Add butter
# 3    113.179688         Add butter
# 4    131.177048  Add apples to pan
# 5    134.863678  Add apples to pan
# 6    136.208618  Add apples to pan
# 7    137.495651  Add apples to pan
# 8    146.174484  Add apples to pan
# 9    148.198303  Add apples to pan

# %%
df2.shape
# Out:
# (26, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (175, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 0       28.205835      Right Hand Grab                 ApplePieCookbook_C_0
# 1       42.328316      Right Hand Grab                                  NaN
# 2       43.160664      Right Hand Grab                                  NaN
# 3       44.172668      Right Hand Grab                                  NaN
# 4       45.526615      Right Hand Grab                                  NaN
# 5       47.338001      Right Hand Grab                                  NaN
# 6       47.938084      Right Hand Grab                                  NaN
# 7       48.499035      Right Hand Grab                                  NaN
# 8       49.293068      Right Hand Grab                 ApplePieCookbook_C_0
# 9       59.721249      Right Hand Grab          SugarJarSimple_C_2147482373
# 10      61.336517  Right Hand Released          SugarJarSimple_C_2147482373
# 11      70.145256      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 149     84.153320                  NaN                                  NaN
# 12      87.029732  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 13      91.825752      Right Hand Grab      WaterPitcherSimple_C_2147482372
# 150     93.761276                  NaN                                  NaN
# 14      96.570702  Right Hand Released      WaterPitcherSimple_C_2147482372
# 15     104.279457      Right Hand Grab      ButterHolderSimple_C_2147482375
# 16     106.035110  Right Hand Released      ButterHolderSimple_C_2147482375
# 17     108.975975      Right Hand Grab                  Butter_C_2147482374
# 18     110.014183  Right Hand Released                  Butter_C_2147482374
# 151    110.248627                  NaN                                  NaN
# 19     110.925461      Right Hand Grab                                  NaN
# 20     111.836441      Right Hand Grab                  Butter_C_2147482368
# 21     112.702789  Right Hand Released                  Butter_C_2147482368
# 152    113.179688                  NaN                                  NaN
# 22     118.470726      Right Hand Grab                                  NaN
# 23     120.780182      Right Hand Grab                   Apple_C_2147482388
# 24     122.578712  Right Hand Released                   Apple_C_2147482388
# 25     123.633499      Right Hand Grab                                  NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    1.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 149                  NaN     Add Sugar
# 12                   0.0            NaN
# 13                   0.0            NaN
# 150                  NaN      Add water
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 151                  NaN     Add butter
# 19                   1.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 152                  NaN     Add butter
# 22                   1.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   1.0            NaN

# %%
df.to_csv('act_step_C031C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        86
# Right Hand Released    45
# Chopped                18
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     3.000000
# mean     49.666667
# std      34.239354
# min      18.000000
# 25%      31.500000
# 50%      45.000000
# 75%      65.500000
# max      86.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 149

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                 12
# ApplePieCookbook_C_0                       9
# PiePanSimple_C_2147482369                  6
# WaterPitcherSimple_C_2147482372            4
# Apple_Slice_C_2147482360                   4
# oven_C_1                                   4
# CinnyShakerGrabable_C_2147482376           4
# Apple_Slice2_C_2147482359                  4
# Apple_C_2147482351                         3
# Apple_Slice_C_2147482348                   3
# Apple_Slice3_C_2147482355                  3
# Apple_C_2147482365                         3
# Apple_C_2147482358                         3
# Apple_C_2147482388                         3
# Apple_Slice4_C_2147482361                  2
# Apple_Slice3_C_2147482362                  2
# Butter_C_2147482374                        2
# PillsberryDoughBoySimple_C_2147482337      2
# PieBowlSimple_C_2147482366                 2
# PillsberryDoughGirlSimple_C_2147482336     2
# StirSpoonPieSImple_C_2147482371            2
# SaucePotSimple2_C_2147482377               2
# Butter_C_2147482368                        2
# Apple_Slice_C_2147482339                   2
# Apple_Slice3_C_2147482341                  2
# Apple_Slice2_C_2147482338                  2
# Apple_Slice4_C_2147482340                  2
# Apple_Half2_C_2147482342                   2
# Apple_Slice3_C_2147482346                  2
# Apple_Slice4_C_2147482345                  2
# Apple_Slice2_C_2147482347                  2
# NewMeasuringCupSimple2_C_2147482378        2
# ButterHolderSimple_C_2147482375            2
# SugarJarSimple_C_2147482373                2
# Apple_Slice4_C_2147482354                  2
# Apple_Slice_C_2147482353                   2
# Apple_Slice2_C_2147482352                  2
# Apple_Half2_C_2147482363                   2
# Apple_Half_C_2147482357                    2
# Apple_Half2_C_2147482349                   2
# Apple_Half_C_2147482343                    1
# Apple_Half_C_2147482350                    1
# Apple_Half2_C_2147482356                   1
# Apple_Half_C_2147482364                    1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    16
# Add butter            2
# Add Sugar             1
# Add water             1
# Add cinnamon          1
# Pour syrup            1
# Stir bowl             1
# Add bottom crust      1
# Add crust top         1
# Put pie in oven       1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar              12   55.947485                  7.0
# 1           Add water              2    6.731544                  0.0
# 2          Add butter              5   13.677925                  0.0
# 3          Add butter              3    2.254227                  1.0
# 4   Add apples to pan             12   12.706322                  2.0
# 5   Add apples to pan              6    3.188171                  0.0
# 6   Add apples to pan              2    0.789200                  0.0
# 7   Add apples to pan              2    0.799972                  0.0
# 8   Add apples to pan             11    7.022125                  0.0
# 9   Add apples to pan              2    1.435608                  0.0
# 10  Add apples to pan              2    0.782791                  0.0
# 11  Add apples to pan              2    0.677521                  0.0
# 12  Add apples to pan             12    7.575790                  1.0
# 13  Add apples to pan              2    0.777741                  0.0
# 14  Add apples to pan              1    0.750106                  0.0
# 15  Add apples to pan              3    1.332321                  0.0
# 16  Add apples to pan              9    6.177231                  0.0
# 17  Add apples to pan              3    1.599991                  0.0
# 18  Add apples to pan              1    0.689743                  0.0
# 19  Add apples to pan              3    1.398835                  0.0
# 20       Add cinnamon              6   12.323960                  2.0
# 21         Pour syrup              2    7.766418                  0.0
# 22          Stir bowl              5   19.119965                  2.0
# 23   Add bottom crust              3    5.088790                  0.0
# 24      Add crust top              8   17.916901                  3.0
# 25    Put pie in oven             11   28.424622                  4.0
# 26     Post last step             19   25.040557                  6.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 149

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C031',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C031            149        241.995862                       28.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      27.000000   27.000000            27.000000
# mean        5.518519    8.962810             1.037037
# std         4.635734   12.227201             1.911131
# min         1.000000    0.677521             0.000000
# 25%         2.000000    1.066146             0.000000
# 50%         3.000000    5.088790             0.000000
# 75%         8.500000   12.515141             1.500000
# max        19.000000   55.947485             7.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan     16   47.703468
# 1         Add butter      2   15.932152
# 2         Add Sugar       1   55.947485
# 3          Add water      1    6.731544
# 4       Add cinnamon      1   12.323960
# 5         Pour syrup      1    7.766418
# 6          Stir bowl      1   19.119965
# 7   Add bottom crust      1    5.088790
# 8      Add crust top      1   17.916901
# 9    Put pie in oven      1   28.424622

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add cinnamon           0                 3       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add water              0                 0       0                   0
# Add butter             0                 0       4                   2
# Add apples to pan     62                 0       0                   0
# Pour syrup             0                 0       0                   0
# Add bottom crust       0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       1
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add water                            0      0                       1
# Add butter                           0      0                       0
# Add apples to pan                    0      8                       0
# Pour syrup                           1      0                       0
# Add bottom crust                     0      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add cinnamon                   0             0                         0
# Stir bowl                      0             0                         0
# Add crust top                  2             0                         2
# Put pie in oven                0             4                         0
# Add water                      0             0                         0
# Add butter                     0             0                         0
# Add apples to pan              0             0                         0
# Pour syrup                     0             0                         0
# Add bottom crust               0             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add crust top                              0                0
# Put pie in oven                            0                0
# Add water                                  0                0
# Add butter                                 0                0
# Add apples to pan                          0                0
# Pour syrup                                 0                1
# Add bottom crust                           2                0
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add cinnamon                        0               0                   0
# Stir bowl                           1               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add water                           0               0                   1
# Add butter                          0               0                   1
# Add apples to pan                   0               0                   0
# Pour syrup                          0               0                   0
# Add bottom crust                    1               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                   5
# Add cinnamon          0                   4
# Stir bowl             0                   3
# Add crust top         0                   5
# Put pie in oven       2                   7
# Add water             0                   2
# Add butter            0                   7
# Add apples to pan     0                  70
# Pour syrup            0                   2
# Add bottom crust      0                   3

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                 Interacted Object  \
# 0       28.205835      Right Hand Grab              ApplePieCookbook_C_0
# 1       42.328316      Right Hand Grab                               NaN
# 2       43.160664      Right Hand Grab                               NaN
# 3       44.172668      Right Hand Grab                               NaN
# 4       45.526615      Right Hand Grab                               NaN
# ..            ...                  ...                               ...
# 170    309.593597  Right Hand Released   WaterPitcherSimple_C_2147482372
# 171    310.292480      Right Hand Grab  CinnyShakerGrabable_C_2147482376
# 172    310.659180  Right Hand Released  CinnyShakerGrabable_C_2147482376
# 173    311.850525      Right Hand Grab                         Knife_C_4
# 174    312.372192  Right Hand Released                         Knife_C_4
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 170                  0.0            NaN
# 171                  0.0            NaN
# 172                  0.0            NaN
# 173                  0.0            NaN
# 174                  0.0            NaN
#
# [175 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        86
# Right Hand Released    45
# Chopped                18
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Right Hand Grab        28.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab            86                       28.0
# 2  Right Hand Released            45                        0.0
# 0              Chopped            18                        0.0
