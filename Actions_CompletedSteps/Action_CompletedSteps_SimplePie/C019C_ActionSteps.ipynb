# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C019 C/'
file_name = 'C019_SimplePie_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object
# 0     33.567154      Left Hand Grab         ApplePieCookbook_C_0
# 1     40.820400      Left Hand Grab         ApplePieCookbook_C_0
# 2     47.115963      Left Hand Grab  SugarJarSimple_C_2147482385
# 3     48.315170  Left Hand Released  SugarJarSimple_C_2147482385
# 4     49.060112      Left Hand Grab                          NaN

# %%
df1.shape
# Out:
# (149, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    135
# 1     14
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 4       49.060112   Left Hand Grab               NaN                    1
# 11      62.868935   Left Hand Grab               NaN                    1
# 67     123.036339  Right Hand Grab               NaN                    1
# 68     124.693184  Right Hand Grab               NaN                    1
# 81     168.030731   Left Hand Grab               NaN                    1
# 82     175.275742   Left Hand Grab               NaN                    1
# 93     201.891220  Right Hand Grab               NaN                    1
# 99     220.321732  Right Hand Grab               NaN                    1
# 103    229.476105  Right Hand Grab               NaN                    1
# 139    294.729248  Right Hand Grab               NaN                    1
# 142    299.577881  Right Hand Grab               NaN                    1
# 143    300.355286  Right Hand Grab               NaN                    1
# 145    303.881500  Right Hand Grab               NaN                    1
# 146    304.762634  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object  \
# 0     33.567154      Left Hand Grab         ApplePieCookbook_C_0
# 1     40.820400      Left Hand Grab         ApplePieCookbook_C_0
# 2     47.115963      Left Hand Grab  SugarJarSimple_C_2147482385
# 3     48.315170  Left Hand Released  SugarJarSimple_C_2147482385
# 4     49.060112      Left Hand Grab                          NaN
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C019 C/'
file_name = 'C019_SimplePie_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time     Completed Step
# 0     56.351753         Add Sugar
# 1     65.218475         Add butter
# 2     68.292343         Add butter
# 3     72.970192          Add water
# 4     96.178322  Add apples to pan
# 5     98.683174  Add apples to pan
# 6    102.667267  Add apples to pan
# 7    103.688934  Add apples to pan
# 8    115.507721  Add apples to pan
# 9    116.342125  Add apples to pan

# %%
df2.shape
# Out:
# (18, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (167, 5)

# %%
df.head(30)
# Out:
#      Session Time         Action Type                    Interacted Object  \
# 0       33.567154      Left Hand Grab                 ApplePieCookbook_C_0
# 1       40.820400      Left Hand Grab                 ApplePieCookbook_C_0
# 2       47.115963      Left Hand Grab          SugarJarSimple_C_2147482385
# 3       48.315170  Left Hand Released          SugarJarSimple_C_2147482385
# 4       49.060112      Left Hand Grab                                  NaN
# 5       50.040443      Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 6       51.774036  Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 7       52.474823      Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 149     56.351753                 NaN                                  NaN
# 8       58.539795  Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 9       59.384830      Left Hand Grab      ButterHolderSimple_C_2147482387
# 10      61.182392  Left Hand Released      ButterHolderSimple_C_2147482387
# 11      62.868935      Left Hand Grab                                  NaN
# 12      63.815956      Left Hand Grab                  Butter_C_2147482386
# 13      65.072670  Left Hand Released                  Butter_C_2147482386
# 150     65.218475                 NaN                                  NaN
# 14      66.106064      Left Hand Grab  NewMeasuringCupSimple2_C_2147482390
# 15      66.651527  Left Hand Released  NewMeasuringCupSimple2_C_2147482390
# 16      67.007645      Left Hand Grab                  Butter_C_2147482380
# 17      68.072372  Left Hand Released                  Butter_C_2147482380
# 151     68.292343                 NaN                                  NaN
# 18      70.425064      Left Hand Grab      WaterPitcherSimple_C_2147482384
# 152     72.970192                 NaN                                  NaN
# 19      75.081856  Left Hand Released      WaterPitcherSimple_C_2147482384
# 20      77.356323      Left Hand Grab           PieBowlSimple_C_2147482378
# 21      78.623375  Left Hand Released           PieBowlSimple_C_2147482378
# 22      80.222641      Left Hand Grab                   Apple_C_2147482396
# 23      81.580467  Left Hand Released                   Apple_C_2147482396
# 24      82.570290      Left Hand Grab                   Apple_C_2147482377
# 25      84.080681  Left Hand Released                   Apple_C_2147482377
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 149                  NaN     Add Sugar
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   1.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 150                  NaN     Add butter
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 151                  NaN     Add butter
# 18                   0.0            NaN
# 152                  NaN      Add water
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN

# %%
#df.to_csv('act_step_C019C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        41
# Left Hand Grab         39
# Left Hand Released     33
# Right Hand Released    21
# Chopped                15
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     29.800000
# std      11.366618
# min      15.000000
# 25%      21.000000
# 50%      33.000000
# 75%      39.000000
# max      41.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 149

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# PieBowlSimple_C_2147482378                26
# ApplePieCookbook_C_0                       7
# PiePanSimple_C_2147482381                  6
# Knife_C_4                                  6
# NewMeasuringCupSimple2_C_2147482390        6
# StirSpoonPieSImple_C_2147482383            4
# Apple_Slice3_C_2147482355                  4
# oven_C_1                                   4
# Apple_C_2147482396                         3
# Apple_C_2147482377                         3
# Apple_C_2147482376                         3
# Apple_C_2147482375                         3
# Apple_Slice2_C_2147482360                  3
# Apple_Slice2_C_2147482352                  2
# Apple_Slice4_C_2147482356                  2
# Apple_Slice_C_2147482353                   2
# Apple_Slice4_C_2147482350                  2
# Apple_Slice4_C_2147482354                  2
# Apple_Slice_C_2147482361                   2
# Apple_Slice2_C_2147482358                  2
# PillsberryDoughGirlSimple_C_2147482348     2
# Apple_Slice3_C_2147482357                  2
# Apple_Slice3_C_2147482351                  2
# Apple_Slice_C_2147482359                   2
# Apple_Half_C_2147482367                    2
# PillsberryDoughBoySimple_C_2147482349      2
# SugarJarSimple_C_2147482385                2
# SaucePotSimple2_C_2147482389               2
# Apple_Slice4_C_2147482368                  2
# Apple_Slice3_C_2147482369                  2
# Apple_Slice_C_2147482371                   2
# Apple_Slice2_C_2147482370                  2
# Apple_Half_C_2147482373                    2
# WaterPitcherSimple_C_2147482384            2
# Butter_C_2147482380                        2
# Butter_C_2147482386                        2
# ButterHolderSimple_C_2147482387            2
# CinnyShakerGrabable_C_2147482388           2
# Apple_Half2_C_2147482364                   1
# Apple_Half2_C_2147482366                   1
# Apple_Half_C_2147482365                    1
# Apple_Half2_C_2147482362                   1
# Apple_Half_C_2147482363                    1
# Apple_Half2_C_2147482372                   1
# Exit_C_1                                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add apples to pan    8
# Add butter           2
# Add Sugar            1
# Add water            1
# Add cinnamon         1
# Pour syrup           1
# Stir bowl            1
# Add bottom crust     1
# Add crust top        1
# Put pie in oven      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#        Completed Step  Actions Count  Time Spent  Missed Interactions
# 0          Add Sugar               8   22.784599                  1.0
# 1          Add butter              6    6.678680                  1.0
# 2          Add butter              4    2.186279                  0.0
# 3           Add water              1    2.545128                  0.0
# 4   Add apples to pan             18   21.096466                  0.0
# 5   Add apples to pan              2    1.905083                  0.0
# 6   Add apples to pan              5    3.141724                  0.0
# 7   Add apples to pan              2    0.644569                  0.0
# 8   Add apples to pan             15   11.419357                  0.0
# 9   Add apples to pan              2    0.523590                  0.0
# 10  Add apples to pan              2    0.588356                  0.0
# 11  Add apples to pan              2    0.589836                  0.0
# 12       Add cinnamon             29   82.730018                  5.0
# 13         Pour syrup              2    7.076584                  0.0
# 14          Stir bowl              7   15.331482                  2.0
# 15   Add bottom crust              5    5.387726                  0.0
# 16      Add crust top             21   26.262710                  0.0
# 17    Put pie in oven              7   21.647736                  0.0
# 18     Post last step             11   18.751861                  5.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 149

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C019',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C019            149        251.291784                       14.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      19.000000   19.000000            19.000000
# mean        7.842105   13.225883             0.736842
# std         7.719119   19.017818             1.593114
# min         1.000000    0.523590             0.000000
# 25%         2.000000    2.045681             0.000000
# 50%         5.000000    6.678680             0.000000
# 75%         9.500000   19.924164             0.500000
# max        29.000000   82.730018             5.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#       Completed Step  Count  Time Spent
# 0  Add apples to pan      8   39.908981
# 1         Add butter      2    8.864959
# 2         Add Sugar       1   22.784599
# 3          Add water      1    2.545128
# 4       Add cinnamon      1   82.730018
# 5         Pour syrup      1    7.076584
# 6          Stir bowl      1   15.331482
# 7   Add bottom crust      1    5.387726
# 8      Add crust top      1   26.262710
# 9    Put pie in oven      1   21.647736

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#                    Apple  ApplePieCookbook  Butter  ButterHolderSimple  \
# Add Sugar              0                 2       0                   0
# Add butter             0                 0       4                   2
# Add cinnamon          18                 1       0                   0
# Stir bowl              0                 1       0                   0
# Add crust top          0                 1       0                   0
# Put pie in oven        0                 1       0                   0
# Add water              0                 0       0                   0
# Add apples to pan     39                 0       0                   0
# Add bottom crust       0                 0       0                   0
# Pour syrup             0                 0       0                   0
#
#                    CinnyShakerGrabable  Knife  NewMeasuringCupSimple2  \
# Add Sugar                            0      0                       3
# Add butter                           0      0                       3
# Add cinnamon                         1      0                       0
# Stir bowl                            0      0                       0
# Add crust top                        0      0                       0
# Put pie in oven                      0      0                       0
# Add water                            0      0                       0
# Add apples to pan                    0      6                       0
# Add bottom crust                     0      0                       0
# Pour syrup                           1      0                       0
#
#                    PieBowlSimple  PiePanSimple  PillsberryDoughBoySimple  \
# Add Sugar                      0             0                         0
# Add butter                     0             0                         0
# Add cinnamon                   4             0                         0
# Stir bowl                      0             0                         0
# Add crust top                 18             0                         2
# Put pie in oven                0             4                         0
# Add water                      0             0                         0
# Add apples to pan              2             0                         0
# Add bottom crust               2             0                         0
# Pour syrup                     0             0                         0
#
#                    PillsberryDoughGirlSimple  SaucePotSimple2  \
# Add Sugar                                  0                0
# Add butter                                 0                0
# Add cinnamon                               0                0
# Stir bowl                                  0                1
# Add crust top                              0                0
# Put pie in oven                            0                0
# Add water                                  0                0
# Add apples to pan                          0                0
# Add bottom crust                           2                0
# Pour syrup                                 0                1
#
#                    StirSpoonPieSImple  SugarJarSimple  WaterPitcherSimple  \
# Add Sugar                           0               2                   0
# Add butter                          0               0                   0
# Add cinnamon                        0               0                   0
# Stir bowl                           3               0                   0
# Add crust top                       0               0                   0
# Put pie in oven                     0               0                   0
# Add water                           0               0                   1
# Add apples to pan                   0               0                   1
# Add bottom crust                    1               0                   0
# Pour syrup                          0               0                   0
#
#                    oven  Interacted Objects
# Add Sugar             0                   7
# Add butter            0                   9
# Add cinnamon          0                  24
# Stir bowl             0                   5
# Add crust top         0                  21
# Put pie in oven       2                   7
# Add water             0                   1
# Add apples to pan     0                  48
# Add bottom crust      0                   5
# Pour syrup            0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time         Action Type            Interacted Object  \
# 0       33.567154      Left Hand Grab         ApplePieCookbook_C_0
# 1       40.820400      Left Hand Grab         ApplePieCookbook_C_0
# 2       47.115963      Left Hand Grab  SugarJarSimple_C_2147482385
# 3       48.315170  Left Hand Released  SugarJarSimple_C_2147482385
# 4       49.060112      Left Hand Grab                          NaN
# ..            ...                 ...                          ...
# 162    301.155243     Right Hand Grab                     oven_C_1
# 163    303.881500     Right Hand Grab                          NaN
# 164    304.762634     Right Hand Grab                          NaN
# 165    305.817749     Right Hand Grab         ApplePieCookbook_C_0
# 166    311.199066     Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 162                  0.0            NaN
# 163                  1.0            NaN
# 164                  1.0            NaN
# 165                  0.0            NaN
# 166                  0.0            NaN
#
# [167 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        41
# Left Hand Grab         39
# Left Hand Released     33
# Right Hand Released    21
# Chopped                15
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          4.0
# Left Hand Released      0.0
# Right Hand Grab        10.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            41                       10.0
# 1       Left Hand Grab            39                        4.0
# 2   Left Hand Released            33                        0.0
# 4  Right Hand Released            21                        0.0
# 0              Chopped            15                        0.0
