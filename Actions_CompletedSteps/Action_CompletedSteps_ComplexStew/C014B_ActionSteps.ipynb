# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C014 B/'
file_name = 'C014_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     41.803726      Right Hand Grab      BeefStewCookbook_C_0
# 1     54.849632      Right Hand Grab  BrothParent_C_2147482365
# 2     70.852600  Right Hand Released  BrothParent_C_2147482365
# 3     71.097168      Right Hand Grab      BeefStewCookbook_C_0
# 4     72.119766      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (149, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    136
# 1     13
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 72     195.319016  Right Hand Grab               NaN                    1
# 131    317.048218  Right Hand Grab               NaN                    1
# 132    318.568268  Right Hand Grab               NaN                    1
# 133    319.456543  Right Hand Grab               NaN                    1
# 134    331.296173  Right Hand Grab               NaN                    1
# 137    341.576813  Right Hand Grab               NaN                    1
# 138    343.577087  Right Hand Grab               NaN                    1
# 139    347.639771  Right Hand Grab               NaN                    1
# 142    349.221619  Right Hand Grab               NaN                    1
# 143    368.715820  Right Hand Grab               NaN                    1
# 144    382.972534  Right Hand Grab               NaN                    1
# 146    385.312500   Left Hand Grab               NaN                    1
# 147    386.824097   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     41.803726      Right Hand Grab      BeefStewCookbook_C_0
# 1     54.849632      Right Hand Grab  BrothParent_C_2147482365
# 2     70.852600  Right Hand Released  BrothParent_C_2147482365
# 3     71.097168      Right Hand Grab      BeefStewCookbook_C_0
# 4     72.119766      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C014 B/'
file_name = 'C014_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     76.828033     Pour Broth
# 1    102.384590    Add Tomtato
# 2    104.708679    Add Tomtato
# 3    107.464043    Add Tomtato
# 4    112.569252    Add Tomtato
# 5    138.398956     Add Potato
# 6    141.275650     Add Potato
# 7    142.931519     Add Potato
# 8    144.931046     Add Potato
# 9    168.926819      Add Onion

# %%
df2.shape
# Out:
# (24, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (173, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type  \
# 0       41.803726      Right Hand Grab
# 1       54.849632      Right Hand Grab
# 2       70.852600  Right Hand Released
# 3       71.097168      Right Hand Grab
# 4       72.119766      Right Hand Grab
# 5       73.291832      Right Hand Grab
# 6       74.804840      Right Hand Grab
# 149     76.828033                  NaN
# 7       79.049759  Right Hand Released
# 8       80.160927      Right Hand Grab
# 9       81.006905  Right Hand Released
# 10      81.874924      Right Hand Grab
# 11      82.383560  Right Hand Released
# 12      89.452919      Right Hand Grab
# 13      90.275024       Left Hand Grab
# 14      91.765343  Right Hand Released
# 15      91.786423   Left Hand Released
# 16      93.113686      Right Hand Grab
# 17      94.065460              Chopped
# 18      94.705597              Chopped
# 19      96.124443              Chopped
# 20      99.097961  Right Hand Released
# 21     101.008270      Right Hand Grab
# 22     101.125229       Left Hand Grab
# 150    102.384590                  NaN
# 23     102.445801   Left Hand Released
# 24     103.178078      Right Hand Grab
# 25     104.574913  Right Hand Released
# 151    104.708679                  NaN
# 26     105.485306      Right Hand Grab
#
#                             Interacted Object  Missed Interactions  \
# 0                        BeefStewCookbook_C_0                  0.0
# 1                    BrothParent_C_2147482365                  0.0
# 2                    BrothParent_C_2147482365                  0.0
# 3                        BeefStewCookbook_C_0                  0.0
# 4                        BeefStewCookbook_C_0                  0.0
# 5                        BeefStewCookbook_C_0                  0.0
# 6                    BrothParent_C_2147482365                  0.0
# 149                                       NaN                  NaN
# 7                    BrothParent_C_2147482365                  0.0
# 8                    BrothParent_C_2147482365                  0.0
# 9                    BrothParent_C_2147482365                  0.0
# 10                   BrothParent_C_2147482365                  0.0
# 11                   BrothParent_C_2147482365                  0.0
# 12              Tomato_Choppable_C_2147482382                  0.0
# 13              Tomato_Choppable_C_2147482384                  0.0
# 14              Tomato_Choppable_C_2147482382                  0.0
# 15              Tomato_Choppable_C_2147482384                  0.0
# 16                                  Knife_C_1                  0.0
# 17              Tomato_Choppable_C_2147482384                  0.0
# 18              Tomato_Choppable_C_2147482382                  0.0
# 19      Tomato_TopHalf_Choppable_C_2147482353                  0.0
# 20                                  Knife_C_1                  0.0
# 21   Tomato_BottomHalf_Choppable_C_2147482352                  0.0
# 22   Tomato_BottomHalf_Choppable_C_2147482354                  0.0
# 150                                       NaN                  NaN
# 23   Tomato_BottomHalf_Choppable_C_2147482354                  0.0
# 24      Tomato_TopHalf_Choppable_C_2147482353                  0.0
# 25      Tomato_TopHalf_Choppable_C_2147482353                  0.0
# 151                                       NaN                  NaN
# 26   Tomato_BottomHalf_Choppable_C_2147482354                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 149     Pour Broth
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 150    Add Tomtato
# 23             NaN
# 24             NaN
# 25             NaN
# 151    Add Tomtato
# 26             NaN

# %%
df.to_csv('act_step_C014B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        72
# Right Hand Released    35
# Chopped                20
# Left Hand Grab         13
# Left Hand Released      9
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     29.800000
# std      25.587106
# min       9.000000
# 25%      13.000000
# 50%      20.000000
# 75%      35.000000
# max      72.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 149

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      18
# BeefStewCookbook_C_0                           16
# BrothParent_C_2147482365                       12
# SaltShakerGrabable_C_2147482364                 6
# Carrot_Choppable_C_2147482392                   5
# Tomato_BottomHalf_Choppable_C_2147482354        5
# StirSpoon_C_2147482367                          4
# CarrotBottomQuarter1_Choppable_C_2147482325     4
# PepperShakerGrabable_C_2147482363               4
# Potato_Choppable_C_2147482397                   3
# Potato_Choppable_C_2147482351                   3
# Tomato_TopHalf_Choppable_C_2147482355           3
# Potato_BottomHalf_Choppable_C_2147482344        3
# Onion_Choppable_C_2147482379                    3
# Onion_Choppable_C_2147482343                    3
# Tomato_TopHalf_Choppable_C_2147482353           3
# Tomato_Choppable_C_2147482384                   3
# Tomato_Choppable_C_2147482382                   3
# Carrot_Choppable_C_2147482333                   3
# CarrotBottomQuarter1_Choppable_C_2147482321     2
# CarrotTopQuarter1_Choppable_C_2147482323        2
# CarrotBottomQuarter2_Choppable_C_2147482324     2
# Onion_Half2_C_2147482338                        2
# Onion_Half_C_2147482339                         2
# Onion_Half2_C_2147482336                        2
# Potato_TopHalf_Choppable_C_2147482347           2
# Potato_BottomHalf_Choppable_C_2147482346        2
# StaticMeshActor_83                              2
# Onion_Half_C_2147482337                         2
# CarrotTop_Choppable_C_2147482329                1
# Onion_Peeled_C_2147482340                       1
# Onion_Peeled_C_2147482341                       1
# Potato_TopHalf_Choppable_C_2147482345           1
# CarrotBotton_Choppable_C_2147482330             1
# CarrotTopQuarter2_Choppable_C_2147482322        1
# CarrotTopQuarter1_Choppable_C_2147482327        1
# CarrotTopQuarter2_Choppable_C_2147482326        1
# CarrotBottomQuarter2_Choppable_C_2147482320     1
# CarrotTop_Choppable_C_2147482331                1
# Tomato_BottomHalf_Choppable_C_2147482352        1
# CarrotBotton_Choppable_C_2147482328             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Tomtato    4
# Add Potato     4
# Add Onion      4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              7   35.024307                  0.0
# 1      Add Tomtato             16   23.334831                  0.0
# 2      Add Tomtato              3    2.262878                  0.0
# 3      Add Tomtato              3    1.978737                  0.0
# 4      Add Tomtato              4    4.217636                  0.0
# 5       Add Potato             14   17.997139                  0.0
# 6       Add Potato              2    1.663696                  0.0
# 7       Add Potato              1    1.127030                  0.0
# 8       Add Potato              1    0.989106                  0.0
# 9        Add Onion             14   18.358307                  0.0
# 10       Add Onion              2    1.324783                  0.0
# 11       Add Onion              2    1.531952                  0.0
# 12       Add Onion              2    1.117188                  0.0
# 13      Add Carrot             35   41.770477                  1.0
# 14      Add Carrot              1    0.906998                  0.0
# 15      Add Carrot              1    0.812576                  0.0
# 16      Add Carrot              2    1.114411                  0.0
# 17      Add Carrot              1    0.795257                  0.0
# 18      Add Carrot              1    0.752533                  0.0
# 19      Add Carrot              1    0.827408                  0.0
# 20      Add Carrot              2    0.973114                  0.0
# 21      Add pepper              8   23.190292                  0.0
# 22        Add Salt              3    6.284394                  0.0
# 23       Stir Stew              3   24.529907                  0.0
# 24  Post last step             20   88.504577                 12.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 149

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C014',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C014            149        301.389534                       13.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      25.000000   25.000000                25.00
# mean        5.960000   12.055581                 0.52
# std         8.116239   19.998222                 2.40
# min         1.000000    0.752533                 0.00
# 25%         1.000000    0.989106                 0.00
# 50%         2.000000    1.663696                 0.00
# 75%         7.000000   18.358307                 0.00
# max        35.000000   88.504577                12.00

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   47.952774
# 1    Add Tomtato      4   31.794082
# 2     Add Potato      4   21.776971
# 3      Add Onion      4   22.332230
# 4     Pour Broth      1   35.024307
# 5     Add pepper      1   23.190292
# 6       Add Salt      1    6.284394
# 7      Stir Stew      1   24.529907

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  4            3       0                     0
# Add Tomtato                 1            5       0                     0
# Add Potato                  2            0       0                     0
# Add Carrot                  3            2       8                     6
# Add pepper                  1            0       0                     0
# Add Salt                    1            0       0                     0
# Stir Stew                   1            0       0                     0
# Add Onion                   0            2       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      3             2          2                  3
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Onion                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Onion  PepperShakerGrabable  Potato  \
# Pour Broth                   0      0      0                     0       0
# Add Tomtato                  0      2      0                     0       0
# Add Potato                   0      2      0                     0      14
# Add Carrot                   2     10      0                     0       0
# Add pepper                   0      2      0                     3       0
# Add Salt                     0      0      0                     1       0
# Stir Stew                    0      0      0                     0       0
# Add Onion                    0      2     16                     0       0
#
#              SaltShakerGrabable  StirSpoon  Tomato  Interacted Objects
# Pour Broth                    0          0       0                   7
# Add Tomtato                   0          0      18                  26
# Add Potato                    0          0       0                  18
# Add Carrot                    0          2       0                  43
# Add pepper                    2          0       0                   8
# Add Salt                      1          0       0                   3
# Stir Stew                     1          1       0                   3
# Add Onion                     0          0       0                  20

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0       41.803726      Right Hand Grab      BeefStewCookbook_C_0
# 1       54.849632      Right Hand Grab  BrothParent_C_2147482365
# 2       70.852600  Right Hand Released  BrothParent_C_2147482365
# 3       71.097168      Right Hand Grab      BeefStewCookbook_C_0
# 4       72.119766      Right Hand Grab      BeefStewCookbook_C_0
# ..            ...                  ...                       ...
# 168    382.972534      Right Hand Grab                       NaN
# 169    384.575317      Right Hand Grab      BeefStewCookbook_C_0
# 170    385.312500       Left Hand Grab                       NaN
# 171    386.824097       Left Hand Grab                       NaN
# 172    386.913177      Right Hand Grab      BeefStewCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 168                  1.0            NaN
# 169                  0.0            NaN
# 170                  1.0            NaN
# 171                  1.0            NaN
# 172                  0.0            NaN
#
# [173 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        72
# Right Hand Released    35
# Chopped                20
# Left Hand Grab         13
# Left Hand Released      9
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          2.0
# Left Hand Released      0.0
# Right Hand Grab        11.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            72                       11.0
# 4  Right Hand Released            35                        0.0
# 0              Chopped            20                        0.0
# 1       Left Hand Grab            13                        2.0
# 2   Left Hand Released             9                        0.0
