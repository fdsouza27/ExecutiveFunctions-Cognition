# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C027 C/'
file_name = 'C027_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      7.880408      Right Hand Grab      BeefStewCookbook_C_0
# 1     12.146532      Right Hand Grab  BrothParent_C_2147482365
# 2     26.409163  Right Hand Released  BrothParent_C_2147482365
# 3     27.253353      Right Hand Grab  BrothParent_C_2147482365
# 4     27.435158  Right Hand Released  BrothParent_C_2147482365

# %%
df1.shape
# Out:
# (167, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    163
# 1      4
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 46      90.841904  Right Hand Grab               NaN                    1
# 47      92.201881  Right Hand Grab               NaN                    1
# 147    281.933685  Right Hand Grab               NaN                    1
# 158    351.146667  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      7.880408      Right Hand Grab      BeefStewCookbook_C_0
# 1     12.146532      Right Hand Grab  BrothParent_C_2147482365
# 2     26.409163  Right Hand Released  BrothParent_C_2147482365
# 3     27.253353      Right Hand Grab  BrothParent_C_2147482365
# 4     27.435158  Right Hand Released  BrothParent_C_2147482365
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C027 C/'
file_name = 'C027_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     23.695011     Pour Broth
# 1     65.804543     Add Carrot
# 2     68.622734     Add Carrot
# 3     70.982430     Add Carrot
# 4     74.046188     Add Carrot
# 5     78.981033     Add Carrot
# 6     81.776367     Add Carrot
# 7     84.351044     Add Carrot
# 8     87.320740     Add Carrot
# 9    119.410957       Add Beef

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (199, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type  \
# 0        7.880408      Right Hand Grab
# 1       12.146532      Right Hand Grab
# 167     23.695011                  NaN
# 2       26.409163  Right Hand Released
# 3       27.253353      Right Hand Grab
# 4       27.435158  Right Hand Released
# 5       30.872189      Right Hand Grab
# 6       32.432404  Right Hand Released
# 7       37.611240      Right Hand Grab
# 8       39.630718  Right Hand Released
# 9       41.585258      Right Hand Grab
# 10      43.074432  Right Hand Released
# 11      44.140411      Right Hand Grab
# 12      45.253712  Right Hand Released
# 13      46.656517      Right Hand Grab
# 14      48.456070              Chopped
# 15      49.429504              Chopped
# 16      50.432449              Chopped
# 17      51.613560              Chopped
# 18      52.386772              Chopped
# 19      53.253765              Chopped
# 20      55.139107              Chopped
# 21      55.965248              Chopped
# 22      56.591343              Chopped
# 23      57.458393              Chopped
# 24      58.347157              Chopped
# 25      59.371307              Chopped
# 26      60.082310              Chopped
# 27      61.351364  Right Hand Released
# 28      62.753933      Right Hand Grab
#
#                                Interacted Object  Missed Interactions  \
# 0                           BeefStewCookbook_C_0                  0.0
# 1                       BrothParent_C_2147482365                  0.0
# 167                                          NaN                  NaN
# 2                       BrothParent_C_2147482365                  0.0
# 3                       BrothParent_C_2147482365                  0.0
# 4                       BrothParent_C_2147482365                  0.0
# 5                  Carrot_Choppable_C_2147482392                  0.0
# 6                  Carrot_Choppable_C_2147482392                  0.0
# 7                  Carrot_Choppable_C_2147482359                  0.0
# 8                  Carrot_Choppable_C_2147482359                  0.0
# 9              PepperShakerGrabable_C_2147482363                  0.0
# 10             PepperShakerGrabable_C_2147482363                  0.0
# 11             PepperShakerGrabable_C_2147482363                  0.0
# 12             PepperShakerGrabable_C_2147482363                  0.0
# 13                                     Knife_C_1                  0.0
# 14                 Carrot_Choppable_C_2147482392                  0.0
# 15           CarrotBotton_Choppable_C_2147482356                  0.0
# 16           CarrotBotton_Choppable_C_2147482356                  0.0
# 17              CarrotTop_Choppable_C_2147482357                  0.0
# 18      CarrotTopQuarter2_Choppable_C_2147482352                  0.0
# 19   CarrotBottomQuarter1_Choppable_C_2147482355                  0.0
# 20      CarrotTopQuarter1_Choppable_C_2147482353                  0.0
# 21   CarrotBottomQuarter1_Choppable_C_2147482355                  0.0
# 22                 Carrot_Choppable_C_2147482359                  0.0
# 23   CarrotBottomQuarter1_Choppable_C_2147482355                  0.0
# 24              CarrotTop_Choppable_C_2147482351                  0.0
# 25   CarrotBottomQuarter1_Choppable_C_2147482355                  0.0
# 26           CarrotBotton_Choppable_C_2147482350                  0.0
# 27                                     Knife_C_1                  0.0
# 28   CarrotBottomQuarter2_Choppable_C_2147482354                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 167     Pour Broth
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN

# %%
df.to_csv('act_step_C027C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Right Hand Released    53
# Chopped                33
# Left Hand Grab          5
# Left Hand Released      5
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.00000
# mean     33.40000
# std      29.20274
# min       5.00000
# 25%       5.00000
# 50%      33.00000
# 75%      53.00000
# max      71.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 167

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      20
# BeefStewCookbook_C_0                            9
# PepperShakerGrabable_C_2147482363               6
# CarrotBottomQuarter1_Choppable_C_2147482355     6
# Meat_Choppable_C_2147482343                     5
# CarrotBottomQuarter2_Choppable_C_2147482354     4
# StirSpoon_C_2147482367                          4
# Onion_Half2_C_2147482318                        4
# BrothParent_C_2147482365                        4
# Meat_QuarterLeft2_C_2147482339                  4
# Meat_QuarterLeft1_C_2147482340                  4
# NewLadle_C_2147482297                           4
# CarrotTopQuarter2_Choppable_C_2147482352        3
# Potato_Choppable_C_2147482393                   3
# Onion_Choppable_C_2147482327                    3
# Potato_TopHalf_Choppable_C_2147482303           3
# Potato_BottomHalf_Choppable_C_2147482304        3
# Potato_Choppable_C_2147482396                   3
# Carrot_Choppable_C_2147482359                   3
# Onion_Choppable_C_2147482376                    3
# Carrot_Choppable_C_2147482392                   3
# Meat_Choppable_C_2147482387                     3
# Tomato_Choppable_C_2147482381                   3
# Tomato_Choppable_C_2147482382                   3
# Tomato_TopHalf_Choppable_C_2147482313           3
# Onion_Half2_C_2147482320                        2
# Meat_QuarterLeft1_C_2147482329                  2
# Onion_Half_C_2147482321                         2
# Tomato_BottomHalf_Choppable_C_2147482310        2
# Meat_QuarterRight1_C_2147482331                 2
# CarrotBotton_Choppable_C_2147482356             2
# Meat_QuarterRight2_C_2147482330                 2
# Meat_QuarterLeft2_C_2147482328                  2
# Tomato_BottomHalf_Choppable_C_2147482312        2
# Potato_TopHalf_Choppable_C_2147482305           2
# Meat_QuarterRight2_C_2147482337                 2
# Meat_QuarterRight1_C_2147482338                 2
# SaltShakerGrabable_C_2147482364                 2
# CarrotTopQuarter1_Choppable_C_2147482353        2
# CarrotTopQuarter1_Choppable_C_2147482347        2
# CarrotBottomQuarter2_Choppable_C_2147482344     2
# StaticMeshActor_31                              2
# CarrotTopQuarter2_Choppable_C_2147482346        2
# Tomato_TopHalf_Choppable_C_2147482311           2
# Potato_BottomHalf_Choppable_C_2147482302        1
# CarrotBotton_Choppable_C_2147482350             1
# Onion_Half_C_2147482319                         1
# Onion_Peeled_C_2147482322                       1
# CarrotTop_Choppable_C_2147482351                1
# Meat_HalfLeft_Choppable_C_2147482333            1
# Meat_HalfRight_Choppable_C_2147482332           1
# CarrotTop_Choppable_C_2147482357                1
# Meat_HalfRight_Choppable_C_2147482341           1
# Meat_HalfLeft_Choppable_C_2147482342            1
# CarrotBottomQuarter1_Choppable_C_2147482345     1
# Onion_Peeled_C_2147482325                       1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       8
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add Salt       1
# Add pepper     1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              2   15.814603                  0.0
# 1       Add Carrot             30   39.395380                  0.0
# 2       Add Carrot              2    1.806595                  0.0
# 3       Add Carrot              1    1.581376                  0.0
# 4       Add Carrot              2    2.066230                  0.0
# 5       Add Carrot              4    4.108650                  0.0
# 6       Add Carrot              2    1.953674                  0.0
# 7       Add Carrot              1    2.043953                  0.0
# 8       Add Carrot              2    1.799813                  0.0
# 9         Add Beef             19   28.569053                  2.0
# 10        Add Beef              2    1.618736                  0.0
# 11        Add Beef              2    1.425812                  0.0
# 12        Add Beef              3    2.292153                  0.0
# 13        Add Beef             11   12.151398                  0.0
# 14        Add Beef              2    1.718033                  0.0
# 15        Add Beef              2    1.666763                  0.0
# 16        Add Beef              2    1.605881                  0.0
# 17       Add Onion             15   26.311768                  0.0
# 18       Add Onion              4    3.381363                  0.0
# 19       Add Onion              1    2.512176                  0.0
# 20       Add Onion              2    1.431046                  0.0
# 21     Add Tomtato             12   21.368439                  0.0
# 22     Add Tomtato              2    1.530228                  0.0
# 23     Add Tomtato              2    1.713273                  0.0
# 24     Add Tomtato              2    1.585068                  0.0
# 25      Add Potato             12   23.342193                  0.0
# 26      Add Potato              2    1.495513                  0.0
# 27      Add Potato              2    1.531952                  0.0
# 28      Add Potato              2    1.534454                  0.0
# 29        Add Salt              4   17.953980                  1.0
# 30      Add pepper              2    4.282928                  0.0
# 31       Stir Stew              4   30.032868                  0.0
# 32  Post last step             10   27.065002                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 167

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C027',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C027            167        288.690354                        4.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        5.060606    8.748193             0.121212
# std         6.368572   11.180709             0.415149
# min         1.000000    1.425812             0.000000
# 25%         2.000000    1.605881             0.000000
# 50%         2.000000    2.043953             0.000000
# 75%         4.000000   15.814603             0.000000
# max        30.000000   39.395380             2.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   54.755671
# 1       Add Beef      8   51.047829
# 2      Add Onion      4   33.636353
# 3    Add Tomtato      4   26.197008
# 4     Add Potato      4   27.904112
# 5     Pour Broth      1   15.814603
# 6       Add Salt      1   17.953980
# 7     Add pepper      1    4.282928
# 8      Stir Stew      1   30.032868

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            0       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Salt                    2            0       0                     0
# Add Carrot                  0            3       6                     7
# Add pepper                  0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Add Carrot                      6             3          2                  4
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0      8    32      0                     0
# Add Onion                    0      4     0     17                     0
# Add Tomtato                  0      2     0      0                     0
# Add Potato                   0      2     0      0                     0
# Add Salt                     0      0     0      0                     0
# Add Carrot                   5      4     0      0                     4
# Add pepper                   0      0     0      0                     1
# Stir Stew                    0      0     0      0                     1
#
#              Potato  SaltShakerGrabable  StirSpoon  Tomato  Interacted Objects
# Pour Broth        0                   0          0       0                   2
# Add Beef          0                   0          0       0                  41
# Add Onion         0                   0          0       0                  22
# Add Tomtato       0                   0          0      15                  18
# Add Potato       15                   0          0       0                  18
# Add Salt          0                   1          0       0                   3
# Add Carrot        0                   0          0       0                  44
# Add pepper        0                   1          0       0                   2
# Stir Stew         0                   0          3       0                   4

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0        7.880408      Right Hand Grab      BeefStewCookbook_C_0
# 1       12.146532      Right Hand Grab  BrothParent_C_2147482365
# 2       23.695011                  NaN                       NaN
# 3       26.409163  Right Hand Released  BrothParent_C_2147482365
# 4       27.253353      Right Hand Grab  BrothParent_C_2147482365
# ..            ...                  ...                       ...
# 194    362.003174       Left Hand Grab     NewLadle_C_2147482297
# 195    366.471252   Left Hand Released     NewLadle_C_2147482297
# 196    367.785767       Left Hand Grab     NewLadle_C_2147482297
# 197    369.219421   Left Hand Released     NewLadle_C_2147482297
# 198    372.677612      Right Hand Grab      BeefStewCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    NaN     Pour Broth
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 194                  0.0            NaN
# 195                  0.0            NaN
# 196                  0.0            NaN
# 197                  0.0            NaN
# 198                  0.0            NaN
#
# [199 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        71
# Right Hand Released    53
# Chopped                33
# Left Hand Grab          5
# Left Hand Released      5
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         0.0
# Left Hand Released     0.0
# Right Hand Grab        4.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            71                        4.0
# 4  Right Hand Released            53                        0.0
# 0              Chopped            33                        0.0
# 1       Left Hand Grab             5                        0.0
# 2   Left Hand Released             5                        0.0
