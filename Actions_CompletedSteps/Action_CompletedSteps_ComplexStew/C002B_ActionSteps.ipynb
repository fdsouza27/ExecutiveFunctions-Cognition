# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C002 B/'
file_name = 'C002_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     20.283197      Right Hand Grab      BeefStewCookbook_C_0
# 1     43.945660      Right Hand Grab                       NaN
# 2     45.079723      Right Hand Grab  BrothParent_C_2147482377
# 3     59.248859  Right Hand Released  BrothParent_C_2147482377
# 4     62.165054      Right Hand Grab                       NaN

# %%
df1.shape
# Out:
# (236, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    229
# 1      7
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       43.945660  Right Hand Grab               NaN                    1
# 4       62.165054  Right Hand Grab               NaN                    1
# 5       62.944500  Right Hand Grab               NaN                    1
# 6       63.744728  Right Hand Grab               NaN                    1
# 60     159.991577  Right Hand Grab               NaN                    1
# 150    315.480347  Right Hand Grab               NaN                    1
# 151    316.283447  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     20.283197      Right Hand Grab      BeefStewCookbook_C_0
# 1     43.945660      Right Hand Grab                       NaN
# 2     45.079723      Right Hand Grab  BrothParent_C_2147482377
# 3     59.248859  Right Hand Released  BrothParent_C_2147482377
# 4     62.165054      Right Hand Grab                       NaN
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C002 B/'
file_name = 'C002_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     56.983345     Pour Broth
# 1    147.669235       Add Beef
# 2    150.072662       Add Beef
# 3    152.179459       Add Beef
# 4    155.139999       Add Beef
# 5    190.299713      Add Onion
# 6    198.379425      Add Onion
# 7    200.736740      Add Onion
# 8    209.235367      Add Onion
# 9    242.716125    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (264, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       20.283197      Right Hand Grab                   BeefStewCookbook_C_0
# 1       43.945660      Right Hand Grab                                    NaN
# 2       45.079723      Right Hand Grab               BrothParent_C_2147482377
# 236     56.983345                  NaN                                    NaN
# 3       59.248859  Right Hand Released               BrothParent_C_2147482377
# 4       62.165054      Right Hand Grab                                    NaN
# 5       62.944500      Right Hand Grab                                    NaN
# 6       63.744728      Right Hand Grab                                    NaN
# 7       64.879120      Right Hand Grab                   BeefStewCookbook_C_0
# 8       70.181274      Right Hand Grab            Meat_Choppable_C_2147482399
# 9       71.672165  Right Hand Released            Meat_Choppable_C_2147482399
# 10      77.851120      Right Hand Grab            Meat_Choppable_C_2147482398
# 11      78.691833  Right Hand Released            Meat_Choppable_C_2147482398
# 12      80.649055      Right Hand Grab                              Knife_C_1
# 13      82.672859              Chopped            Meat_Choppable_C_2147482398
# 14      83.592873              Chopped  Meat_HalfRight_Choppable_C_2147482366
# 15      85.529846              Chopped   Meat_HalfLeft_Choppable_C_2147482367
# 16      86.637161              Chopped  Meat_HalfRight_Choppable_C_2147482366
# 17      87.605179  Right Hand Released                              Knife_C_1
# 18      87.941803      Right Hand Grab                              Knife_C_1
# 19      88.475105              Chopped        Meat_QuarterRight2_C_2147482362
# 20      88.879021  Right Hand Released                              Knife_C_1
# 21      92.478111      Right Hand Grab                              Knife_C_1
# 22      93.540497              Chopped        Meat_QuarterRight2_C_2147482362
# 23      95.246193              Chopped        Meat_QuarterRight2_C_2147482362
# 24      96.602654              Chopped        Meat_QuarterRight1_C_2147482363
# 25      97.563362  Right Hand Released                              Knife_C_1
# 26      97.850975      Right Hand Grab                              Knife_C_1
# 27      98.876534              Chopped        Meat_QuarterRight1_C_2147482363
# 28      99.674072  Right Hand Released                              Knife_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 236                  NaN     Pour Broth
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        112
# Right Hand Released     89
# Chopped                 35
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      3.000000
# mean      78.666667
# std       39.526363
# min       35.000000
# 25%       62.000000
# 50%       89.000000
# 75%      100.500000
# max      112.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 236

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                   34
# StaticMeshActor_107                         14
# Meat_QuarterRight2_C_2147482362             13
# BeefStewCookbook_C_0                        12
# StaticMeshActor_31                           8
#                                             ..
# Onion_Peeled_C_2147482352                    1
# CarrotTopQuarter1_Choppable_C_2147482321     1
# CarrotBotton_Choppable_C_2147482322          1
# CarrotTop_Choppable_C_2147482323             1
# Tomato_BottomHalf_Choppable_C_2147482338     1
# Name: count, Length: 61, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       4
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              3   36.700148                  1.0
# 1         Add Beef             51   88.420376                  3.0
# 2         Add Beef              2    1.802932                  0.0
# 3         Add Beef              2    1.540543                  0.0
# 4         Add Beef              2    1.623687                  0.0
# 5        Add Onion             19   30.308136                  1.0
# 6        Add Onion              2    2.217117                  0.0
# 7        Add Onion              2    1.496323                  0.0
# 8        Add Onion              8    7.541199                  0.0
# 9      Add Tomtato             14   30.627365                  0.0
# 10     Add Tomtato              3    8.119766                  0.0
# 11     Add Tomtato              2    1.351501                  0.0
# 12     Add Tomtato              1    1.174682                  0.0
# 13      Add Potato             31   42.019592                  0.0
# 14      Add Potato              6    6.321167                  0.0
# 15      Add Potato              1    1.011993                  0.0
# 16      Add Potato              1    1.484711                  0.0
# 17      Add Carrot             26   36.952606                  2.0
# 18      Add Carrot              2    1.688354                  0.0
# 19      Add Carrot              2    1.464600                  0.0
# 20      Add Carrot              1    1.026306                  0.0
# 21      Add Carrot             12    9.590118                  0.0
# 22      Add Carrot              2    1.174072                  0.0
# 23      Add Carrot              2    1.534699                  0.0
# 24      Add Carrot              2    1.093048                  0.0
# 25      Add pepper              4    8.527893                  0.0
# 26        Add Salt              8    8.509644                  0.0
# 27       Stir Stew              6   13.345063                  0.0
# 28  Post last step             19   31.049560                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 236

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C002',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C002            236        379.717201                        7.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        8.137931   13.093697             0.241379
# std        11.435297   19.599364             0.689470
# min         1.000000    1.011993             0.000000
# 25%         2.000000    1.484711             0.000000
# 50%         2.000000    2.217117             0.000000
# 75%         8.000000   13.345063             0.000000
# max        51.000000   88.420376             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   54.523803
# 1       Add Beef      4   93.387538
# 2      Add Onion      4   41.562775
# 3    Add Tomtato      4   41.273314
# 4     Add Potato      4   50.837463
# 5     Pour Broth      1   36.700148
# 6     Add pepper      1    8.527893
# 7       Add Salt      1    8.509644
# 8      Stir Stew      1   13.345063

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 5            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0      10                     6
# Add pepper                  1            0       0                     0
# Stir Stew                   0            4       0                     0
# Add Salt                    0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             2          3                  3
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Salt                        0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0     14    38      0                     0
# Add Onion                    0      6     1     18                     0
# Add Tomtato                  0      2     0      0                     0
# Add Potato                   0      4     8      0                     0
# Add Carrot                   4      4     2      0                     0
# Add pepper                   0      0     0      0                     1
# Stir Stew                    0      0     0      0                     0
# Add Salt                     0      0     0      0                     3
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                4          0       0
# Add Tomtato       0                   0                0          0      13
# Add Potato       18                   0                8          0       0
# Add Carrot        0                   0                8          0       0
# Add pepper        0                   0                2          0       0
# Stir Stew         0                   1                0          1       0
# Add Salt          0                   1                4          0       0
#
#              Interacted Objects
# Pour Broth                    2
# Add Beef                     54
# Add Onion                    30
# Add Tomtato                  20
# Add Potato                   39
# Add Carrot                   47
# Add pepper                    4
# Stir Stew                     6
# Add Salt                      8

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0       20.283197      Right Hand Grab      BeefStewCookbook_C_0
# 1       43.945660      Right Hand Grab                       NaN
# 2       45.079723      Right Hand Grab  BrothParent_C_2147482377
# 3       56.983345                  NaN                       NaN
# 4       59.248859  Right Hand Released  BrothParent_C_2147482377
# ..            ...                  ...                       ...
# 259    437.129608  Right Hand Released                 Knife_C_1
# 260    437.767548      Right Hand Grab     NewLadle_C_2147482308
# 261    441.640686  Right Hand Released     NewLadle_C_2147482308
# 262    442.369049      Right Hand Grab     StewBowl_C_2147482306
# 263    443.654022  Right Hand Released     StewBowl_C_2147482306
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    NaN     Pour Broth
# 4                    0.0            NaN
# ..                   ...            ...
# 259                  0.0            NaN
# 260                  0.0            NaN
# 261                  0.0            NaN
# 262                  0.0            NaN
# 263                  0.0            NaN
#
# [264 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        112
# Right Hand Released     89
# Chopped                 35
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Right Hand Grab        7.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab           112                        7.0
# 2  Right Hand Released            89                        0.0
# 0              Chopped            35                        0.0
