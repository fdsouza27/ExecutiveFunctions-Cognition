# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C004 B/'
file_name = 'C004_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object
# 0     35.486504     Right Hand Grab         BeefStewCookbook_C_0
# 1     51.236073     Right Hand Grab         BeefStewCookbook_C_0
# 2     57.801266      Left Hand Grab  Meat_Choppable_C_2147482399
# 3     59.661488  Left Hand Released  Meat_Choppable_C_2147482399
# 4     60.397537      Left Hand Grab  Meat_Choppable_C_2147482399

# %%
df1.shape
# Out:
# (230, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    219
# 1     11
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 82     200.665237   Left Hand Grab               NaN                    1
# 84     202.164581  Right Hand Grab               NaN                    1
# 98     229.005051  Right Hand Grab               NaN                    1
# 109    244.768005  Right Hand Grab               NaN                    1
# 150    311.910706   Left Hand Grab               NaN                    1
# 169    337.371796   Left Hand Grab               NaN                    1
# 170    339.839081   Left Hand Grab               NaN                    1
# 177    350.782013   Left Hand Grab               NaN                    1
# 182    358.245239   Left Hand Grab               NaN                    1
# 183    361.330017   Left Hand Grab               NaN                    1
# 224    509.210480  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object  \
# 0     35.486504     Right Hand Grab         BeefStewCookbook_C_0
# 1     51.236073     Right Hand Grab         BeefStewCookbook_C_0
# 2     57.801266      Left Hand Grab  Meat_Choppable_C_2147482399
# 3     59.661488  Left Hand Released  Meat_Choppable_C_2147482399
# 4     60.397537      Left Hand Grab  Meat_Choppable_C_2147482399
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C004 B/'
file_name = 'C004_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    108.794991       Add Beef
# 1    108.794991       Add Beef
# 2    108.794991       Add Beef
# 3    108.794991       Add Beef
# 4    117.595551     Pour Broth
# 5    213.395721      Add Onion
# 6    215.548462      Add Onion
# 7    217.829697      Add Onion
# 8    221.917603      Add Onion
# 9    240.859818    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (258, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      35.486504      Right Hand Grab                   BeefStewCookbook_C_0
# 1      51.236073      Right Hand Grab                   BeefStewCookbook_C_0
# 2      57.801266       Left Hand Grab            Meat_Choppable_C_2147482399
# 3      59.661488   Left Hand Released            Meat_Choppable_C_2147482399
# 4      60.397537       Left Hand Grab            Meat_Choppable_C_2147482399
# 5      61.312576   Left Hand Released            Meat_Choppable_C_2147482399
# 6      63.936382      Right Hand Grab                              Knife_C_1
# 7      65.674370  Right Hand Released                              Knife_C_1
# 8      66.385841      Right Hand Grab                              Knife_C_1
# 9      68.075111              Chopped            Meat_Choppable_C_2147482399
# 10     69.159904              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 11     69.866776              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 12     71.708641              Chopped         Meat_QuarterLeft2_C_2147482367
# 13     72.444572              Chopped         Meat_QuarterLeft2_C_2147482367
# 14     73.335068              Chopped         Meat_QuarterLeft2_C_2147482367
# 15     74.223701  Right Hand Released                              Knife_C_1
# 16     75.312828      Right Hand Grab                              Knife_C_1
# 17     77.002960  Right Hand Released                              Knife_C_1
# 18     78.110481       Left Hand Grab        Meat_QuarterRight1_C_2147482366
# 19     79.019119   Left Hand Released        Meat_QuarterRight1_C_2147482366
# 20     79.618721       Left Hand Grab        Meat_QuarterRight1_C_2147482366
# 21     80.682716   Left Hand Released        Meat_QuarterRight1_C_2147482366
# 22     81.549461       Left Hand Grab         Meat_QuarterLeft2_C_2147482367
# 23     82.502739   Left Hand Released         Meat_QuarterLeft2_C_2147482367
# 24     84.506592       Left Hand Grab        Meat_QuarterRight1_C_2147482366
# 25     85.497086   Left Hand Released        Meat_QuarterRight1_C_2147482366
# 26     86.612144       Left Hand Grab         Meat_QuarterLeft2_C_2147482367
# 27     91.310287   Left Hand Released         Meat_QuarterLeft2_C_2147482367
# 28     92.440392       Left Hand Grab        Meat_QuarterRight2_C_2147482365
# 29     93.593964   Left Hand Released        Meat_QuarterRight2_C_2147482365
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         65
# Left Hand Released     56
# Right Hand Grab        41
# Chopped                41
# Right Hand Released    27
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     46.000000
# std      14.764823
# min      27.000000
# 25%      41.000000
# 50%      41.000000
# 75%      56.000000
# max      65.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 230

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                               32
# BeefStewCookbook_C_0                    11
# NewLadle_C_2147482297                    8
# Meat_QuarterLeft2_C_2147482367           7
# Meat_QuarterRight1_C_2147482366          6
#                                         ..
# Meat_HalfLeft_Choppable_C_2147482352     1
# Onion_Peeled_C_2147482343                1
# CarrotTop_Choppable_C_2147482312         1
# CarrotBotton_Choppable_C_2147482319      1
# Exit_C_0                                 1
# Name: count, Length: 71, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       4
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0         Add Beef             34   73.308487                  0.0
# 1         Add Beef              0    0.000000                  0.0
# 2         Add Beef              0    0.000000                  0.0
# 3         Add Beef              0    0.000000                  0.0
# 4       Pour Broth              0    0.000000                  0.0
# 5        Add Onion             57   92.662445                  2.0
# 6        Add Onion              2    1.246613                  0.0
# 7        Add Onion              2    1.329148                  0.0
# 8        Add Onion              2    1.965958                  0.0
# 9      Add Tomtato             10   15.865220                  1.0
# 10     Add Tomtato              2    1.461701                  0.0
# 11     Add Tomtato              8    8.809464                  1.0
# 12     Add Tomtato              2    1.168213                  0.0
# 13      Add Potato             17   31.545166                  0.0
# 14      Add Potato              2    1.251435                  0.0
# 15      Add Potato              9    9.796387                  0.0
# 16      Add Potato              2    0.986663                  0.0
# 17      Add Carrot             13   17.579193                  1.0
# 18      Add Carrot              2    1.150879                  0.0
# 19      Add Carrot             11   16.700897                  2.0
# 20      Add Carrot              2    1.522339                  0.0
# 21      Add Carrot              3    2.823944                  1.0
# 22      Add Carrot              2    1.464111                  0.0
# 23      Add Carrot             11   14.590271                  2.0
# 24      Add Carrot              2    1.154815                  0.0
# 25      Add pepper              8   15.448150                  0.0
# 26        Add Salt              4    5.395752                  0.0
# 27       Stir Stew              2   13.134308                  0.0
# 28  Post last step             21  115.916688                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 230

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C004',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C004            230        448.278247                       11.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.931034   15.457871             0.379310
# std        12.106465   28.758543             0.676852
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.168213             0.000000
# 50%         2.000000    1.965958             0.000000
# 75%        10.000000   15.448150             1.000000
# max        57.000000  115.916688             2.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   56.986449
# 1       Add Beef      4   73.308487
# 2      Add Onion      4   97.204164
# 3    Add Tomtato      4   27.304598
# 4     Add Potato      4   43.579651
# 5     Pour Broth      1    0.000000
# 6     Add pepper      1   15.448150
# 7       Add Salt      1    5.395752
# 8      Stir Stew      1   13.134308

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Add Beef                    3            1       0                     0
# Add Onion                   2            1       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       9                     2
# Add pepper                  1            0       0                     2
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      2             4          4                  6
# Add pepper                      2             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Add Beef                     0      6    24      0                     0
# Add Onion                    0     10    29     19                     0
# Add Tomtato                  0      4     0      0                     0
# Add Potato                   0      6     0      0                     0
# Add Carrot                   6      6     0      0                     0
# Add pepper                   0      0     0      0                     1
# Add Salt                     0      0     0      0                     1
# Stir Stew                    0      0     0      0                     0
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                0          0       0
# Add Tomtato       0                   0                0          0      15
# Add Potato       19                   0                4          0       0
# Add Carrot        0                   0                0          0       0
# Add pepper        0                   0                2          0       0
# Add Salt          0                   1                2          0       0
# Stir Stew         0                   1                0          1       0
#
#              Interacted Objects
# Add Beef                     34
# Add Onion                    61
# Add Tomtato                  20
# Add Potato                   30
# Add Carrot                   40
# Add pepper                    8
# Add Salt                      4
# Stir Stew                     2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time         Action Type            Interacted Object  \
# 0       35.486504     Right Hand Grab         BeefStewCookbook_C_0
# 1       51.236073     Right Hand Grab         BeefStewCookbook_C_0
# 2       57.801266      Left Hand Grab  Meat_Choppable_C_2147482399
# 3       59.661488  Left Hand Released  Meat_Choppable_C_2147482399
# 4       60.397537      Left Hand Grab  Meat_Choppable_C_2147482399
# ..            ...                 ...                          ...
# 253    514.204468      Left Hand Grab        NewLadle_C_2147482297
# 254    527.299622  Left Hand Released        NewLadle_C_2147482297
# 255    528.261536      Left Hand Grab        StewBowl_C_2147482295
# 256    529.332214  Left Hand Released        StewBowl_C_2147482295
# 257    533.558167     Right Hand Grab                     Exit_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 253                  0.0            NaN
# 254                  0.0            NaN
# 255                  0.0            NaN
# 256                  0.0            NaN
# 257                  0.0            NaN
#
# [258 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Left Hand Grab         65
# Left Hand Released     56
# Right Hand Grab        41
# Chopped                41
# Right Hand Released    27
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         7.0
# Left Hand Released     0.0
# Right Hand Grab        4.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1       Left Hand Grab            65                        7.0
# 2   Left Hand Released            56                        0.0
# 0              Chopped            41                        0.0
# 3      Right Hand Grab            41                        4.0
# 4  Right Hand Released            27                        0.0
