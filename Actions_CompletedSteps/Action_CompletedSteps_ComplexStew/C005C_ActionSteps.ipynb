# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C005 C/'
file_name = 'C005_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object
# 0    323.221222  Right Hand Grab               NaN
# 1    384.156738   Left Hand Grab               NaN
# 2    384.533936   Left Hand Grab               NaN
# 3    384.871399   Left Hand Grab               NaN
# 4    388.627441   Left Hand Grab               NaN

# %%
df1.shape
# Out:
# (244, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    218
# 1     26
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0      323.221222  Right Hand Grab               NaN                    1
# 1      384.156738   Left Hand Grab               NaN                    1
# 2      384.533936   Left Hand Grab               NaN                    1
# 3      384.871399   Left Hand Grab               NaN                    1
# 4      388.627441   Left Hand Grab               NaN                    1
# 5      388.807892  Right Hand Grab               NaN                    1
# 6      389.778992  Right Hand Grab               NaN                    1
# 7      389.878296   Left Hand Grab               NaN                    1
# 8      396.327301  Right Hand Grab               NaN                    1
# 12     443.800201  Right Hand Grab               NaN                    1
# 15     465.037659  Right Hand Grab               NaN                    1
# 20     471.839539  Right Hand Grab               NaN                    1
# 85     595.976685  Right Hand Grab               NaN                    1
# 94     623.779480   Left Hand Grab               NaN                    1
# 95     625.088989   Left Hand Grab               NaN                    1
# 143    682.220886  Right Hand Grab               NaN                    1
# 161    765.901001  Right Hand Grab               NaN                    1
# 163    768.433899  Right Hand Grab               NaN                    1
# 164    769.126953  Right Hand Grab               NaN                    1
# 165    769.908875  Right Hand Grab               NaN                    1
# 166    770.441833  Right Hand Grab               NaN                    1
# 185    846.799072  Right Hand Grab               NaN                    1
# 221    896.750732  Right Hand Grab               NaN                    1
# 237    971.824097   Left Hand Grab               NaN                    1
# 240    973.649048   Left Hand Grab               NaN                    1
# 242    975.056213   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object  Missed Interactions
# 0    323.221222  Right Hand Grab               NaN                    1
# 1    384.156738   Left Hand Grab               NaN                    1
# 2    384.533936   Left Hand Grab               NaN                    1
# 3    384.871399   Left Hand Grab               NaN                    1
# 4    388.627441   Left Hand Grab               NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C005 C/'
file_name = 'C005_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    477.481750     Pour Broth
# 1    542.443298       Add Beef
# 2    542.780945       Add Beef
# 3    546.927185       Add Beef
# 4    549.968445       Add Beef
# 5    584.132141      Add Onion
# 6    586.681152      Add Onion
# 7    589.005188      Add Onion
# 8    590.892700      Add Onion
# 9    635.487366    Add Tomtato

# %%
df2.shape
# Out:
# (24, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (268, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0      323.221222      Right Hand Grab                          NaN
# 1      384.156738       Left Hand Grab                          NaN
# 2      384.533936       Left Hand Grab                          NaN
# 3      384.871399       Left Hand Grab                          NaN
# 4      388.627441       Left Hand Grab                          NaN
# 5      388.807892      Right Hand Grab                          NaN
# 6      389.778992      Right Hand Grab                          NaN
# 7      389.878296       Left Hand Grab                          NaN
# 8      396.327301      Right Hand Grab                          NaN
# 9      397.160187       Left Hand Grab           StaticMeshActor_31
# 10     397.339020   Left Hand Released           StaticMeshActor_31
# 11     421.739624      Right Hand Grab         BeefStewCookbook_C_0
# 12     443.800201      Right Hand Grab                          NaN
# 13     444.710632      Right Hand Grab     BrothParent_C_2147482363
# 14     462.552216  Right Hand Released     BrothParent_C_2147482363
# 15     465.037659      Right Hand Grab                          NaN
# 16     466.174072      Right Hand Grab     BrothParent_C_2147482363
# 17     468.394012  Right Hand Released     BrothParent_C_2147482363
# 18     469.129242      Right Hand Grab     BrothParent_C_2147482363
# 19     470.176544  Right Hand Released     BrothParent_C_2147482363
# 20     471.839539      Right Hand Grab                          NaN
# 21     475.347565      Right Hand Grab     BrothParent_C_2147482363
# 244    477.481750                  NaN                          NaN
# 22     481.126831  Right Hand Released     BrothParent_C_2147482363
# 23     483.327087      Right Hand Grab         BeefStewCookbook_C_0
# 24     493.552429      Right Hand Grab     BrothParent_C_2147482363
# 25     494.645264  Right Hand Released     BrothParent_C_2147482363
# 26     501.296906       Left Hand Grab  Meat_Choppable_C_2147482385
# 27     503.263550   Left Hand Released  Meat_Choppable_C_2147482385
# 28     504.807343      Right Hand Grab                    Knife_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    1.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   1.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   1.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   1.0            NaN
# 21                   0.0            NaN
# 244                  NaN     Pour Broth
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        106
# Right Hand Released     62
# Chopped                 33
# Left Hand Grab          27
# Left Hand Released      16
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      48.800000
# std       36.217399
# min       16.000000
# 25%       27.000000
# 50%       33.000000
# 75%       62.000000
# max      106.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 244

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      26
# BeefStewCookbook_C_0                           25
# StaticMeshActor_84                             16
# StirSpoon_C_2147482365                         14
# StaticMeshActor_31                             10
# BrothParent_C_2147482363                       10
# PepperShakerGrabable_C_2147482361               6
# SaltShakerGrabable_C_2147482362                 6
# Meat_Choppable_C_2147482385                     5
# Meat_QuarterLeft2_C_2147482298                  4
# Meat_QuarterRight2_C_2147482345                 4
# Onion_Half2_C_2147482338                        4
# Onion_Half_C_2147482339                         4
# Tomato_TopHalf_Choppable_C_2147482328           4
# Meat_HalfRight_Choppable_C_2147482300           3
# Meat_Choppable_C_2147482353                     3
# Tomato_Choppable_C_2147482382                   3
# Carrot_Choppable_C_2147482386                   3
# Tomato_Choppable_C_2147482332                   3
# Carrot_Choppable_C_2147482390                   3
# Meat_QuarterLeft2_C_2147482347                  3
# Onion_Choppable_C_2147482342                    3
# Onion_Choppable_C_2147482377                    3
# Onion_Half2_C_2147482335                        2
# Onion_Half_C_2147482336                         2
# Meat_QuarterLeft1_C_2147482299                  2
# Meat_QuarterRight1_C_2147482297                 2
# Meat_QuarterRight2_C_2147482296                 2
# Meat_HalfLeft_Choppable_C_2147482301            2
# StaticMeshActor_83                              2
# oven_C_1                                        2
# Meat_QuarterRight1_C_2147482346                 2
# Meat_QuarterLeft1_C_2147482348                  2
# CarrotTopQuarter1_Choppable_C_2147482314        2
# CarrotBottomQuarter1_Choppable_C_2147482310     2
# CarrotTopQuarter2_Choppable_C_2147482313        2
# CarrotBottomQuarter2_Choppable_C_2147482309     2
# CarrotTopQuarter1_Choppable_C_2147482316        2
# CarrotBottomQuarter1_Choppable_C_2147482318     2
# CarrotBottomQuarter2_Choppable_C_2147482317     2
# CarrotTopQuarter2_Choppable_C_2147482315        2
# Onion_Peeled_C_2147482340                       2
# Tomato_TopHalf_Choppable_C_2147482330           2
# Tomato_BottomHalf_Choppable_C_2147482327        2
# Tomato_BottomHalf_Choppable_C_2147482329        2
# Onion_Peeled_C_2147482337                       2
# CarrotBotton_Choppable_C_2147482321             1
# CarrotTop_Choppable_C_2147482322                1
# CarrotTop_Choppable_C_2147482324                1
# CarrotBotton_Choppable_C_2147482323             1
# Meat_HalfRight_Choppable_C_2147482349           1
# Meat_HalfLeft_Choppable_C_2147482350            1
# Exit_C_0                                        1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       4
# Add Onion      4
# Add Tomtato    4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             22  154.260528                 12.0
# 1         Add Beef             29   61.316467                  0.0
# 2         Add Beef              1    0.181702                  0.0
# 3         Add Beef              4    2.454895                  0.0
# 4         Add Beef              2    1.708435                  0.0
# 5        Add Onion             21   32.716553                  0.0
# 6        Add Onion              2    1.684387                  0.0
# 7        Add Onion              2    1.638977                  0.0
# 8        Add Onion              2    1.311706                  0.0
# 9      Add Tomtato             23   39.510681                  3.0
# 10     Add Tomtato              0    0.000000                  0.0
# 11     Add Tomtato              4    1.550171                  0.0
# 12     Add Tomtato              0    0.000000                  0.0
# 13      Add Carrot             19   28.717347                  0.0
# 14      Add Carrot              0    0.000000                  0.0
# 15      Add Carrot              4    1.776612                  0.0
# 16      Add Carrot              0    0.000000                  0.0
# 17      Add Carrot              4    1.870300                  0.0
# 18      Add Carrot              0    0.000000                  0.0
# 19      Add Carrot              4    2.025147                  0.0
# 20      Add Carrot              0    0.000000                  0.0
# 21      Add pepper              8   17.740601                  1.0
# 22        Add Salt              0    0.000000                  0.0
# 23       Stir Stew              5   24.501709                  0.0
# 24  Post last step             88  255.347901                 10.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 244

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C005',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C005            244        630.314119                       26.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      25.000000   25.000000            25.000000
# mean        9.760000   25.212565             1.040000
# std        18.489366   58.190539             3.075169
# min         0.000000    0.000000             0.000000
# 25%         0.000000    0.000000             0.000000
# 50%         4.000000    1.708435             0.000000
# 75%         8.000000   24.501709             0.000000
# max        88.000000  255.347901            12.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   34.389406
# 1       Add Beef      4   65.661499
# 2      Add Onion      4   37.351623
# 3    Add Tomtato      4   41.060852
# 4     Pour Broth      1  154.260528
# 5     Add pepper      1   17.740601
# 6       Add Salt      1    0.000000
# 7      Stir Stew      1   24.501709

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            7       0                     0
# Add Beef                    1            3       0                     0
# Stir Stew                   0            0       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 2            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Carrot                      4             2          2                  4
# Add pepper                      0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0      8    18      0                     0
# Stir Stew                    0      0     0      0                     1
# Add Onion                    0      2     0     22                     0
# Add Tomtato                  0      2     0      0                     0
# Add Carrot                   4      4     0      0                     0
# Add pepper                   0      0     0      0                     1
#
#              SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth                    0                2          0       0
# Add Beef                      0                6          0       0
# Stir Stew                     1                2          1       0
# Add Onion                     0                2          0       0
# Add Tomtato                   0                4          0      16
# Add Carrot                    0                0          0       0
# Add pepper                    1                4          0       0
#
#              Interacted Objects
# Pour Broth                   10
# Add Beef                     36
# Stir Stew                     5
# Add Onion                    27
# Add Tomtato                  24
# Add Carrot                   31
# Add pepper                    7

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time      Action Type     Interacted Object  Missed Interactions  \
# 0      323.221222  Right Hand Grab                   NaN                  1.0
# 1      384.156738   Left Hand Grab                   NaN                  1.0
# 2      384.533936   Left Hand Grab                   NaN                  1.0
# 3      384.871399   Left Hand Grab                   NaN                  1.0
# 4      388.627441   Left Hand Grab                   NaN                  1.0
# ..            ...              ...                   ...                  ...
# 263    973.605225  Right Hand Grab  BeefStewCookbook_C_0                  0.0
# 264    973.649048   Left Hand Grab                   NaN                  1.0
# 265    975.033875  Right Hand Grab  BeefStewCookbook_C_0                  0.0
# 266    975.056213   Left Hand Grab                   NaN                  1.0
# 267    990.257996  Right Hand Grab              Exit_C_0                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 263            NaN
# 264            NaN
# 265            NaN
# 266            NaN
# 267            NaN
#
# [268 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        106
# Right Hand Released     62
# Chopped                 33
# Left Hand Grab          27
# Left Hand Released      16
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         10.0
# Left Hand Released      0.0
# Right Hand Grab        16.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           106                       16.0
# 4  Right Hand Released            62                        0.0
# 0              Chopped            33                        0.0
# 1       Left Hand Grab            27                       10.0
# 2   Left Hand Released            16                        0.0
