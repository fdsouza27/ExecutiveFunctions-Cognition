# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C015 C/'
file_name = 'C015_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      7.147973      Right Hand Grab      BeefStewCookbook_C_0
# 1     37.269070      Right Hand Grab                       NaN
# 2     38.538105      Right Hand Grab  BrothParent_C_2147482365
# 3     53.443485  Right Hand Released  BrothParent_C_2147482365
# 4     55.417454      Right Hand Grab                       NaN

# %%
df1.shape
# Out:
# (328, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    310
# 1     18
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       37.269070  Right Hand Grab               NaN                    1
# 4       55.417454  Right Hand Grab               NaN                    1
# 7       59.508736  Right Hand Grab               NaN                    1
# 10      63.680935  Right Hand Grab               NaN                    1
# 74     146.431808  Right Hand Grab               NaN                    1
# 93     179.789291  Right Hand Grab               NaN                    1
# 163    273.309967  Right Hand Grab               NaN                    1
# 188    313.642426  Right Hand Grab               NaN                    1
# 189    314.689850  Right Hand Grab               NaN                    1
# 212    346.338654   Left Hand Grab               NaN                    1
# 241    376.061127  Right Hand Grab               NaN                    1
# 260    399.161011   Left Hand Grab               NaN                    1
# 261    399.338440  Right Hand Grab               NaN                    1
# 262    402.147247  Right Hand Grab               NaN                    1
# 267    411.084137  Right Hand Grab               NaN                    1
# 311    499.893738   Left Hand Grab               NaN                    1
# 312    501.336914   Left Hand Grab               NaN                    1
# 313    502.421204  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      7.147973      Right Hand Grab      BeefStewCookbook_C_0
# 1     37.269070      Right Hand Grab                       NaN
# 2     38.538105      Right Hand Grab  BrothParent_C_2147482365
# 3     53.443485  Right Hand Released  BrothParent_C_2147482365
# 4     55.417454      Right Hand Grab                       NaN
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C015 C/'
file_name = 'C015_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     53.089268     Pour Broth
# 1    133.504562       Add Beef
# 2    137.167099       Add Beef
# 3    149.818817       Add Beef
# 4    153.170990       Add Beef
# 5    166.159149       Add Beef
# 6    168.160660       Add Beef
# 7    170.258041       Add Beef
# 8    171.994110       Add Beef
# 9    212.189606      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (360, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        7.147973      Right Hand Grab                   BeefStewCookbook_C_0
# 1       37.269070      Right Hand Grab                                    NaN
# 2       38.538105      Right Hand Grab               BrothParent_C_2147482365
# 328     53.089268                  NaN                                    NaN
# 3       53.443485  Right Hand Released               BrothParent_C_2147482365
# 4       55.417454      Right Hand Grab                                    NaN
# 5       56.528477      Right Hand Grab               BrothParent_C_2147482365
# 6       58.374146  Right Hand Released               BrothParent_C_2147482365
# 7       59.508736      Right Hand Grab                                    NaN
# 8       60.355968      Right Hand Grab               BrothParent_C_2147482365
# 9       61.244267  Right Hand Released               BrothParent_C_2147482365
# 10      63.680935      Right Hand Grab                                    NaN
# 11      65.017937      Right Hand Grab                   BeefStewCookbook_C_0
# 12      76.693001      Right Hand Grab            Meat_Choppable_C_2147482387
# 13      78.386566  Right Hand Released            Meat_Choppable_C_2147482387
# 14      79.415741      Right Hand Grab            Meat_Choppable_C_2147482387
# 15      80.656250  Right Hand Released            Meat_Choppable_C_2147482387
# 16      83.921616      Right Hand Grab                              Knife_C_1
# 17      86.967911              Chopped            Meat_Choppable_C_2147482387
# 18      88.030899              Chopped   Meat_HalfLeft_Choppable_C_2147482358
# 19      88.265099  Right Hand Released                              Knife_C_1
# 20      91.030609      Right Hand Grab                              Knife_C_1
# 21      91.530182  Right Hand Released                              Knife_C_1
# 22      92.664658      Right Hand Grab                              Knife_C_1
# 23      93.531219              Chopped         Meat_QuarterLeft1_C_2147482354
# 24      94.896523              Chopped  Meat_HalfRight_Choppable_C_2147482357
# 25      95.795380              Chopped        Meat_QuarterRight2_C_2147482351
# 26      96.428337              Chopped         Meat_QuarterLeft1_C_2147482354
# 27      96.595245  Right Hand Released                              Knife_C_1
# 28      98.061470      Right Hand Grab                              Knife_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 328                  NaN     Pour Broth
# 3                    0.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   1.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C015C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        135
# Right Hand Released     94
# Chopped                 55
# Left Hand Grab          24
# Left Hand Released      20
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.00000
# mean      65.60000
# std       48.84977
# min       20.00000
# 25%       24.00000
# 50%       55.00000
# 75%       94.00000
# max      135.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 328

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                46
# BeefStewCookbook_C_0                     22
# Meat_QuarterLeft1_C_2147482354           13
# Meat_QuarterRight2_C_2147482351          11
# StaticMeshActor_84                       10
#                                          ..
# CarrotTop_Choppable_C_2147482290          1
# Meat_HalfLeft_Choppable_C_2147482358      1
# Meat_QuarterLeft1_C_2147482345            1
# Meat_HalfLeft_Choppable_C_2147482349      1
# Meat_HalfRight_Choppable_C_2147482348     1
# Name: count, Length: 77, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef       8
# Add Carrot     8
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              3   45.941295                  1.0
# 1         Add Beef             61   80.061077                  3.0
# 2         Add Beef              2    1.307114                  0.0
# 3         Add Beef             10   11.581558                  1.0
# 4         Add Beef              2    1.551575                  0.0
# 5         Add Beef             10   10.898117                  0.0
# 6         Add Beef              1    1.099915                  0.0
# 7         Add Beef              2    1.230880                  0.0
# 8         Add Beef              1    1.067596                  0.0
# 9        Add Onion             21   34.314667                  1.0
# 10       Add Onion              2    2.098221                  0.0
# 11       Add Onion              9    9.913086                  0.0
# 12       Add Onion              2    2.187149                  0.0
# 13     Add Tomtato             20   23.529220                  0.0
# 14     Add Tomtato              1    0.200073                  0.0
# 15     Add Tomtato              2    1.503723                  0.0
# 16     Add Tomtato             12    8.576141                  0.0
# 17      Add Potato             49   73.989380                  3.0
# 18      Add Potato              2    0.948150                  0.0
# 19      Add Potato              5    2.474792                  1.0
# 20      Add Potato              0    0.000000                  0.0
# 21      Add Carrot             39   42.627686                  1.0
# 22      Add Carrot              0    0.000000                  0.0
# 23      Add Carrot              9   10.981903                  3.0
# 24      Add Carrot              5    6.345917                  1.0
# 25      Add Carrot             15   13.840973                  0.0
# 26      Add Carrot              0    0.000000                  0.0
# 27      Add Carrot              4    1.969482                  0.0
# 28      Add Carrot              0    0.000000                  0.0
# 29      Add pepper              4    8.080658                  0.0
# 30        Add Salt              2    4.241577                  0.0
# 31       Stir Stew             15   27.794861                  0.0
# 32  Post last step             18   46.781067                  3.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 328

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C015',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C015            328        477.137853                       18.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        9.939394   14.458723             0.545455
# std        14.393878   21.283863             1.002837
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.230880             0.000000
# 50%         4.000000    4.241577             0.000000
# 75%        12.000000   13.840973             1.000000
# max        61.000000   80.061077             3.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8  108.797832
# 1     Add Carrot      8   75.765961
# 2      Add Onion      4   48.513123
# 3    Add Tomtato      4   33.809157
# 4     Add Potato      4   77.412322
# 5     Pour Broth      1   45.941295
# 6     Add pepper      1    8.080658
# 7       Add Salt      1    4.241577
# 8      Stir Stew      1   27.794861

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    3            5       0                     0
# Add Onion                   3            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  9            0       6                     0
# Add Carrot                  3            0      12                     4
# Add pepper                  1            0       0                     0
# Stir Stew                   1            0       0                     0
# Add Salt                    0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             4          5                  0
# Add Carrot                      5             8         11                  4
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Salt                        0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0     24    53      0                     0
# Add Onion                    0      8     0     22                     0
# Add Tomtato                  0      4     2      0                     0
# Add Potato                   0      4     2      0                     0
# Add Carrot                   8      6     0      0                     0
# Add pepper                   0      0     0      0                     1
# Stir Stew                    0      0     0      0                     2
# Add Salt                     0      0     0      0                     1
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                0          0       0
# Add Tomtato       0                   0                6          0      22
# Add Potato       20                   0                2          0       0
# Add Carrot        0                   0                4          2       0
# Add pepper        0                   0                2          0       0
# Stir Stew         0                   7                2          3       0
# Add Salt          0                   1                0          0       0
#
#              Interacted Objects
# Pour Broth                    2
# Add Beef                     85
# Add Onion                    33
# Add Tomtato                  35
# Add Potato                   52
# Add Carrot                   67
# Add pepper                    4
# Stir Stew                    15
# Add Salt                      2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0        7.147973      Right Hand Grab      BeefStewCookbook_C_0
# 1       37.269070      Right Hand Grab                       NaN
# 2       38.538105      Right Hand Grab  BrothParent_C_2147482365
# 3       53.089268                  NaN                       NaN
# 4       53.443485  Right Hand Released  BrothParent_C_2147482365
# ..            ...                  ...                       ...
# 355    526.145508  Right Hand Released     StewBowl_C_2147482280
# 356    526.611450       Left Hand Grab     StewBowl_C_2147482280
# 357    526.656006      Right Hand Grab     StewBowl_C_2147482280
# 358    528.616455   Left Hand Released     StewBowl_C_2147482280
# 359    528.661743  Right Hand Released     StewBowl_C_2147482280
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    NaN     Pour Broth
# 4                    0.0            NaN
# ..                   ...            ...
# 355                  0.0            NaN
# 356                  0.0            NaN
# 357                  0.0            NaN
# 358                  0.0            NaN
# 359                  0.0            NaN
#
# [360 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        135
# Right Hand Released     94
# Chopped                 55
# Left Hand Grab          24
# Left Hand Released      20
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          4.0
# Left Hand Released      0.0
# Right Hand Grab        14.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           135                       14.0
# 4  Right Hand Released            94                        0.0
# 0              Chopped            55                        0.0
# 1       Left Hand Grab            24                        4.0
# 2   Left Hand Released            20                        0.0
