# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C023 C/'
file_name = 'C023_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     88.432007      Right Hand Grab                       NaN
# 1     89.556389      Right Hand Grab      BeefStewCookbook_C_0
# 2    111.086990      Right Hand Grab                       NaN
# 3    153.440659      Right Hand Grab  BrothParent_C_2147482363
# 4    168.270340  Right Hand Released  BrothParent_C_2147482363

# %%
df1.shape
# Out:
# (296, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    289
# 1      7
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       88.432007  Right Hand Grab               NaN                    1
# 2      111.086990  Right Hand Grab               NaN                    1
# 5      181.254135  Right Hand Grab               NaN                    1
# 144    417.982391  Right Hand Grab               NaN                    1
# 251    589.701172   Left Hand Grab               NaN                    1
# 290    669.753967   Left Hand Grab               NaN                    1
# 292    672.019226   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     88.432007      Right Hand Grab                       NaN
# 1     89.556389      Right Hand Grab      BeefStewCookbook_C_0
# 2    111.086990      Right Hand Grab                       NaN
# 3    153.440659      Right Hand Grab  BrothParent_C_2147482363
# 4    168.270340  Right Hand Released  BrothParent_C_2147482363
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C023 C/'
file_name = 'C023_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    167.514099     Pour Broth
# 1    247.861923       Add Beef
# 2    250.865311       Add Beef
# 3    255.098495       Add Beef
# 4    260.898132       Add Beef
# 5    294.017975       Add Beef
# 6    300.691284       Add Beef
# 7    316.086700       Add Beef
# 8    346.877594       Add Beef
# 9    388.598450      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (328, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       88.432007      Right Hand Grab                                    NaN
# 1       89.556389      Right Hand Grab                   BeefStewCookbook_C_0
# 2      111.086990      Right Hand Grab                                    NaN
# 3      153.440659      Right Hand Grab               BrothParent_C_2147482363
# 296    167.514099                  NaN                                    NaN
# 4      168.270340  Right Hand Released               BrothParent_C_2147482363
# 5      181.254135      Right Hand Grab                                    NaN
# 6      184.678024      Right Hand Grab                   BeefStewCookbook_C_0
# 7      193.836990      Right Hand Grab            Meat_Choppable_C_2147482385
# 8      195.429672  Right Hand Released            Meat_Choppable_C_2147482385
# 9      198.572968      Right Hand Grab                              Knife_C_1
# 10     200.528229              Chopped            Meat_Choppable_C_2147482385
# 11     201.221207              Chopped  Meat_HalfRight_Choppable_C_2147482353
# 12     202.323914  Right Hand Released                              Knife_C_1
# 13     215.532333      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482353
# 14     218.407578  Right Hand Released  Meat_HalfRight_Choppable_C_2147482353
# 15     221.440979      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482354
# 16     223.018127  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482354
# 17     224.489532      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482353
# 18     230.270035  Right Hand Released  Meat_HalfRight_Choppable_C_2147482353
# 19     231.551849      Right Hand Grab                              Knife_C_1
# 20     232.592789              Chopped  Meat_HalfRight_Choppable_C_2147482353
# 21     233.103271  Right Hand Released                              Knife_C_1
# 22     234.917465      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482354
# 23     236.277008  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482354
# 24     237.491135      Right Hand Grab                              Knife_C_1
# 25     238.246994              Chopped   Meat_HalfLeft_Choppable_C_2147482354
# 26     239.087463  Right Hand Released                              Knife_C_1
# 27     240.854080      Right Hand Grab         Meat_QuarterLeft2_C_2147482347
# 28     241.657104  Right Hand Released         Meat_QuarterLeft2_C_2147482347
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 296                  NaN     Pour Broth
# 4                    0.0            NaN
# 5                    1.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C023C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        128
# Right Hand Released    114
# Chopped                 37
# Left Hand Grab          10
# Left Hand Released       7
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      59.200000
# std       57.824735
# min        7.000000
# 25%       10.000000
# 50%       37.000000
# 75%      114.000000
# max      128.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 296

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                               74
# BeefStewCookbook_C_0                    10
# StaticMeshActor_84                      10
# Meat_QuarterLeft1_C_2147482341           7
# StaticMeshActor_31                       6
#                                         ..
# CarrotTop_Choppable_C_2147482279         1
# Meat_HalfLeft_Choppable_C_2147482332     1
# CarrotTop_Choppable_C_2147482290         1
# CarrotBotton_Choppable_C_2147482289      1
# Meat_HalfLeft_Choppable_C_2147482343     1
# Name: count, Length: 70, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef       8
# Add Carrot     8
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              4   79.082092                  2.0
# 1         Add Beef             29   79.591583                  1.0
# 2         Add Beef              2    1.469818                  0.0
# 3         Add Beef              2    2.032669                  0.0
# 4         Add Beef              4    4.232910                  0.0
# 5         Add Beef             23   27.701050                  0.0
# 6         Add Beef              4    5.266754                  0.0
# 7         Add Beef              9   11.396240                  0.0
# 8         Add Beef             32   28.614258                  0.0
# 9        Add Onion             17   35.582947                  0.0
# 10       Add Onion              4    4.671936                  0.0
# 11       Add Onion             12   13.633728                  0.0
# 12       Add Onion              5    5.084290                  1.0
# 13     Add Tomtato             11   14.331573                  0.0
# 14     Add Tomtato              2    1.296234                  0.0
# 15     Add Tomtato             11   13.348419                  0.0
# 16     Add Tomtato              2    2.729156                  0.0
# 17      Add Potato             18   19.779145                  0.0
# 18      Add Potato              2    1.337188                  0.0
# 19      Add Potato              7    8.150177                  0.0
# 20      Add Potato              2    1.067444                  0.0
# 21      Add Carrot             31   47.830627                  0.0
# 22      Add Carrot             18   24.995727                  0.0
# 23      Add Carrot              9   11.565796                  1.0
# 24      Add Carrot              2    1.613769                  0.0
# 25      Add Carrot              2    1.959167                  0.0
# 26      Add Carrot             12   11.478455                  0.0
# 27      Add Carrot              4    4.946900                  0.0
# 28      Add Carrot              2    1.670715                  0.0
# 29      Add pepper              2   10.343689                  0.0
# 30        Add Salt              2    3.933899                  0.0
# 31       Stir Stew              2   12.508728                  0.0
# 32  Post last step              8   19.213135                  2.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 296

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C023',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C023            296        512.460218                        7.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        8.969697   15.529098             0.212121
# std         9.005154   19.852216             0.545297
# min         2.000000    1.067444             0.000000
# 25%         2.000000    2.729156             0.000000
# 50%         4.000000   10.343689             0.000000
# 75%        12.000000   19.213135             0.000000
# max        32.000000   79.591583             2.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8  160.305282
# 1     Add Carrot      8  106.061156
# 2      Add Onion      4   58.972901
# 3    Add Tomtato      4   31.705382
# 4     Add Potato      4   30.333954
# 5     Pour Broth      1   79.082092
# 6     Add pepper      1   10.343689
# 7       Add Salt      1    3.933899
# 8      Stir Stew      1   12.508728

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       9                     4
# Add pepper                  1            0       0                     0
# Stir Stew                   0            0       0                     0
# Add Salt                    0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             5          5                  6
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Salt                        0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0     40    62      0                     0
# Add Onion                    0      8     4     24                     0
# Add Tomtato                  0      8     1      0                     0
# Add Potato                   0      6     0      0                     0
# Add Carrot                   6     12     7      0                     0
# Add pepper                   0      0     0      0                     1
# Stir Stew                    0      0     0      0                     0
# Add Salt                     0      0     0      0                     1
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                0          0       0
# Add Tomtato       0                   0                0          0      16
# Add Potato       18                   0                4          0       0
# Add Carrot        0                   0               18          2       0
# Add pepper        0                   0                0          0       0
# Stir Stew         0                   1                0          1       0
# Add Salt          0                   1                0          0       0
#
#              Interacted Objects
# Pour Broth                    2
# Add Beef                    104
# Add Onion                    37
# Add Tomtato                  26
# Add Potato                   29
# Add Carrot                   79
# Add pepper                    2
# Stir Stew                     2
# Add Salt                      2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0       88.432007      Right Hand Grab                       NaN
# 1       89.556389      Right Hand Grab      BeefStewCookbook_C_0
# 2      111.086990      Right Hand Grab                       NaN
# 3      153.440659      Right Hand Grab  BrothParent_C_2147482363
# 4      167.514099                  NaN                       NaN
# ..            ...                  ...                       ...
# 323    669.788086      Right Hand Grab      BeefStewCookbook_C_0
# 324    672.019226       Left Hand Grab                       NaN
# 325    672.130249      Right Hand Grab      BeefStewCookbook_C_0
# 326    677.743103      Right Hand Grab     NewLadle_C_2147482273
# 327    682.818604  Right Hand Released     NewLadle_C_2147482273
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    NaN     Pour Broth
# ..                   ...            ...
# 323                  0.0            NaN
# 324                  1.0            NaN
# 325                  0.0            NaN
# 326                  0.0            NaN
# 327                  0.0            NaN
#
# [328 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        128
# Right Hand Released    114
# Chopped                 37
# Left Hand Grab          10
# Left Hand Released       7
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         3.0
# Left Hand Released     0.0
# Right Hand Grab        4.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           128                        4.0
# 4  Right Hand Released           114                        0.0
# 0              Chopped            37                        0.0
# 1       Left Hand Grab            10                        3.0
# 2   Left Hand Released             7                        0.0
