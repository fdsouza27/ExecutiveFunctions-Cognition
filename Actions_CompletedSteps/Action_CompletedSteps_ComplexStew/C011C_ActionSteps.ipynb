# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C011 C/'
file_name = 'C011_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object
# 0     24.297844   Left Hand Grab               NaN
# 1     27.098755  Right Hand Grab               NaN
# 2     27.894211   Left Hand Grab               NaN
# 3     28.560734  Right Hand Grab               NaN
# 4     38.030224   Left Hand Grab               NaN

# %%
df1.shape
# Out:
# (317, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    249
# 1     68
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       24.297844   Left Hand Grab               NaN                    1
# 1       27.098755  Right Hand Grab               NaN                    1
# 2       27.894211   Left Hand Grab               NaN                    1
# 3       28.560734  Right Hand Grab               NaN                    1
# 4       38.030224   Left Hand Grab               NaN                    1
# ..            ...              ...               ...                  ...
# 312    487.185486  Right Hand Grab               NaN                    1
# 313    487.519836  Right Hand Grab               NaN                    1
# 314    488.634369  Right Hand Grab               NaN                    1
# 315    488.923523  Right Hand Grab               NaN                    1
# 316    489.167664  Right Hand Grab               NaN                    1
#
# [68 rows x 4 columns]

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object  Missed Interactions
# 0     24.297844   Left Hand Grab               NaN                    1
# 1     27.098755  Right Hand Grab               NaN                    1
# 2     27.894211   Left Hand Grab               NaN                    1
# 3     28.560734  Right Hand Grab               NaN                    1
# 4     38.030224   Left Hand Grab               NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C011 C/'
file_name = 'C011_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     93.155380     Pour Broth
# 1    143.087006       Add Beef
# 2    146.864059       Add Beef
# 3    162.740631       Add Beef
# 4    165.194534       Add Beef
# 5    189.968307       Add Beef
# 6    194.743774       Add Beef
# 7    197.282913       Add Beef
# 8    199.658432       Add Beef
# 9    239.044250      Add Onion

# %%
df2.shape
# Out:
# (19, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (336, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0       24.297844       Left Hand Grab                          NaN
# 1       27.098755      Right Hand Grab                          NaN
# 2       27.894211       Left Hand Grab                          NaN
# 3       28.560734      Right Hand Grab                          NaN
# 4       38.030224       Left Hand Grab                          NaN
# 5       40.141235       Left Hand Grab                          NaN
# 6       40.386284       Left Hand Grab         BeefStewCookbook_C_0
# 7       65.723976       Left Hand Grab                          NaN
# 8       66.675156       Left Hand Grab                          NaN
# 9       67.409103       Left Hand Grab     BrothParent_C_2147482365
# 10      67.586845   Left Hand Released     BrothParent_C_2147482365
# 11      67.698517       Left Hand Grab     BrothParent_C_2147482365
# 12      68.032585   Left Hand Released     BrothParent_C_2147482365
# 13      68.432266       Left Hand Grab     BrothParent_C_2147482365
# 14      71.161140   Left Hand Released     BrothParent_C_2147482365
# 15      75.891953      Right Hand Grab                          NaN
# 16      76.114502      Right Hand Grab                          NaN
# 17      77.737381      Right Hand Grab                          NaN
# 18      77.984505      Right Hand Grab                          NaN
# 19      79.385872      Right Hand Grab     BrothParent_C_2147482365
# 20      79.563774  Right Hand Released     BrothParent_C_2147482365
# 21      79.763878      Right Hand Grab     BrothParent_C_2147482365
# 317     93.155380                  NaN                          NaN
# 22      93.844810  Right Hand Released     BrothParent_C_2147482365
# 23      94.420914      Right Hand Grab                          NaN
# 24     102.073380      Right Hand Grab                          NaN
# 25     102.362274      Right Hand Grab         BeefStewCookbook_C_0
# 26     112.132095       Left Hand Grab                          NaN
# 27     112.504013       Left Hand Grab                          NaN
# 28     113.540169       Left Hand Grab  Meat_Choppable_C_2147482387
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   1.0            NaN
# 16                   1.0            NaN
# 17                   1.0            NaN
# 18                   1.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 317                  NaN     Pour Broth
# 22                   0.0            NaN
# 23                   1.0            NaN
# 24                   1.0            NaN
# 25                   0.0            NaN
# 26                   1.0            NaN
# 27                   1.0            NaN
# 28                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        133
# Right Hand Released     84
# Left Hand Grab          55
# Chopped                 25
# Left Hand Released      20
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.00000
# mean      63.40000
# std       46.62939
# min       20.00000
# 25%       25.00000
# 50%       55.00000
# 75%       84.00000
# max      133.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 317

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# StaticMeshActor_23                          28
# Knife_C_1                                   20
# StaticMeshActor_31                          18
# BeefStewCookbook_C_0                        13
# Meat_QuarterRight1_C_2147482354             11
# BrothParent_C_2147482365                    10
# Meat_Choppable_C_2147482350                  8
# Onion_Half_C_2147482329                      8
# Meat_Choppable_C_2147482385                  8
# Potato_Choppable_C_2147482317                7
# Meat_HalfLeft_Choppable_C_2147482356         7
# Onion_Peeled_C_2147482338                    6
# Tomato_Choppable_C_2147482384                5
# Potato_Choppable_C_2147482393                5
# Onion_Choppable_C_2147482379                 5
# Onion_Choppable_C_2147482341                 5
# Meat_QuarterLeft1_C_2147482352               5
# Onion_Half_C_2147482337                      4
# Tomato_BottomHalf_Choppable_C_2147482322     4
# StaticMeshActor_84                           4
# Meat_QuarterRight2_C_2147482353              4
# Potato_TopHalf_Choppable_C_2147482316        4
# Onion_Half2_C_2147482336                     4
# Meat_QuarterLeft2_C_2147482344               4
# Meat_QuarterLeft1_C_2147482345               4
# Meat_QuarterRight1_C_2147482343              4
# Meat_QuarterRight2_C_2147482342              4
# Potato_BottomHalf_Choppable_C_2147482315     4
# Onion_Choppable_C_2147482340                 3
# Onion_Peeled_C_2147482330                    3
# Tomato_Choppable_C_2147482325                3
# Meat_Choppable_C_2147482357                  3
# Meat_Choppable_C_2147482387                  3
# Meat_QuarterLeft2_C_2147482351               3
# Potato_Choppable_C_2147482394                2
# Potato_Choppable_C_2147482314                2
# Tomato_TopHalf_Choppable_C_2147482321        2
# Onion_Half2_C_2147482328                     2
# Onion_Half2_C_2147482334                     2
# Meat_HalfLeft_Choppable_C_2147482347         2
# Meat_HalfRight_Choppable_C_2147482355        2
# Tomato_BottomHalf_Choppable_C_2147482320     1
# Tomato_TopHalf_Choppable_C_2147482323        1
# Meat_HalfRight_Choppable_C_2147482346        1
# Onion_Peeled_C_2147482339                    1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef       8
# Add Onion      4
# Add Tomtato    4
# Add Potato     2
# Pour Broth     1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             22   68.857536                 12.0
# 1         Add Beef             31   49.242196                  5.0
# 2         Add Beef              5    2.906326                  1.0
# 3         Add Beef             15   14.809585                  2.0
# 4         Add Beef              4    1.434219                  0.0
# 5         Add Beef             29   23.657043                  1.0
# 6         Add Beef              6    3.961624                  2.0
# 7         Add Beef              4    1.899505                  0.0
# 8         Add Beef              4    1.642868                  0.0
# 9        Add Onion             31   36.331130                  6.0
# 10       Add Onion              4    1.427078                  0.0
# 11       Add Onion             10    9.090545                  1.0
# 12       Add Onion             12   10.107346                  0.0
# 13     Add Tomtato             22   27.497101                  1.0
# 14     Add Tomtato              1    1.311157                  0.0
# 15     Add Tomtato              1    1.129761                  0.0
# 16     Add Tomtato              2    1.171722                  0.0
# 17      Add Potato             64   84.847870                 20.0
# 18      Add Potato              4    1.934296                  0.0
# 19  Post last step             46   98.083374                 17.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 317

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C011',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C011            317        441.342282                       68.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      20.000000   20.000000            20.000000
# mean       15.850000   22.067114             3.400000
# std        17.067282   30.200194             5.959513
# min         1.000000    1.129761             0.000000
# 25%         4.000000    1.590706             0.000000
# 50%         8.000000    6.526084             1.000000
# 75%        23.750000   29.705608             2.750000
# max        64.000000   98.083374            20.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   99.553366
# 1      Add Onion      4   56.956099
# 2    Add Tomtato      4   31.109741
# 3     Add Potato      2   86.782166
# 4     Pour Broth      1   68.857536

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Knife  Meat  Onion  Potato  \
# Pour Broth                  1            9      0     0      0       0
# Add Beef                    1            1      8    57      0       0
# Add Onion                   3            0      8     0     35       0
# Add Tomtato                 1            0      2     0      4       0
# Add Potato                  7            0      2    14      2      15
#
#              StaticMeshActor  Tomato  Interacted Objects
# Pour Broth                 0       0                  10
# Add Beef                  20       0                  87
# Add Onion                  4       0                  50
# Add Tomtato                2      16                  25
# Add Potato                 8       0                  48

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions  \
# 0       24.297844   Left Hand Grab               NaN                  1.0
# 1       27.098755  Right Hand Grab               NaN                  1.0
# 2       27.894211   Left Hand Grab               NaN                  1.0
# 3       28.560734  Right Hand Grab               NaN                  1.0
# 4       38.030224   Left Hand Grab               NaN                  1.0
# ..            ...              ...               ...                  ...
# 331    487.185486  Right Hand Grab               NaN                  1.0
# 332    487.519836  Right Hand Grab               NaN                  1.0
# 333    488.634369  Right Hand Grab               NaN                  1.0
# 334    488.923523  Right Hand Grab               NaN                  1.0
# 335    489.167664  Right Hand Grab               NaN                  1.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 331            NaN
# 332            NaN
# 333            NaN
# 334            NaN
# 335            NaN
#
# [336 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        133
# Right Hand Released     84
# Left Hand Grab          55
# Chopped                 25
# Left Hand Released      20
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         30.0
# Left Hand Released      0.0
# Right Hand Grab        38.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           133                       38.0
# 4  Right Hand Released            84                        0.0
# 1       Left Hand Grab            55                       30.0
# 0              Chopped            25                        0.0
# 2   Left Hand Released            20                        0.0
