# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C026 B/'
file_name = 'C026_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object
# 0     57.794533      Right Hand Grab         BeefStewCookbook_C_0
# 1     86.779274      Right Hand Grab     BrothParent_C_2147482377
# 2    101.475761  Right Hand Released     BrothParent_C_2147482377
# 3    103.369019      Right Hand Grab         BeefStewCookbook_C_0
# 4    107.607048      Right Hand Grab  Meat_Choppable_C_2147482399

# %%
df1.shape
# Out:
# (202, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    201
# 1      1
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#     Session Time      Action Type Interacted Object  Missed Interactions
# 95    262.990143  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type            Interacted Object  \
# 0     57.794533      Right Hand Grab         BeefStewCookbook_C_0
# 1     86.779274      Right Hand Grab     BrothParent_C_2147482377
# 2    101.475761  Right Hand Released     BrothParent_C_2147482377
# 3    103.369019      Right Hand Grab         BeefStewCookbook_C_0
# 4    107.607048      Right Hand Grab  Meat_Choppable_C_2147482399
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C026 B/'
file_name = 'C026_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     98.790543     Pour Broth
# 1    155.597977       Add Beef
# 2    158.057159       Add Beef
# 3    160.830276       Add Beef
# 4    163.141144       Add Beef
# 5    220.571487      Add Onion
# 6    222.901321      Add Onion
# 7    239.805099      Add Onion
# 8    241.967590      Add Onion
# 9    258.311279    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (230, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       57.794533      Right Hand Grab                   BeefStewCookbook_C_0
# 1       86.779274      Right Hand Grab               BrothParent_C_2147482377
# 202     98.790543                  NaN                                    NaN
# 2      101.475761  Right Hand Released               BrothParent_C_2147482377
# 3      103.369019      Right Hand Grab                   BeefStewCookbook_C_0
# 4      107.607048      Right Hand Grab            Meat_Choppable_C_2147482399
# 5      108.825554  Right Hand Released            Meat_Choppable_C_2147482399
# 6      111.197540      Right Hand Grab      PepperShakerGrabable_C_2147482375
# 7      111.668381  Right Hand Released      PepperShakerGrabable_C_2147482375
# 8      112.493546      Right Hand Grab      PepperShakerGrabable_C_2147482375
# 9      113.652397  Right Hand Released      PepperShakerGrabable_C_2147482375
# 10     114.318596      Right Hand Grab      PepperShakerGrabable_C_2147482375
# 11     115.617622  Right Hand Released      PepperShakerGrabable_C_2147482375
# 12     117.195663      Right Hand Grab                              Knife_C_1
# 13     121.325661              Chopped            Meat_Choppable_C_2147482399
# 14     122.807190              Chopped   Meat_HalfLeft_Choppable_C_2147482368
# 15     123.939415              Chopped         Meat_QuarterLeft2_C_2147482365
# 16     124.735329              Chopped         Meat_QuarterLeft2_C_2147482365
# 17     125.849831              Chopped         Meat_QuarterLeft1_C_2147482366
# 18     127.686234              Chopped         Meat_QuarterLeft1_C_2147482366
# 19     128.526978              Chopped  Meat_HalfRight_Choppable_C_2147482367
# 20     129.859833              Chopped         Meat_QuarterLeft2_C_2147482365
# 21     136.860474              Chopped         Meat_QuarterLeft2_C_2147482365
# 22     141.666306              Chopped        Meat_QuarterRight1_C_2147482364
# 23     141.910019  Right Hand Released                              Knife_C_1
# 24     145.421143      Right Hand Grab        Meat_QuarterRight2_C_2147482363
# 25     146.954208  Right Hand Released        Meat_QuarterRight2_C_2147482363
# 26     148.010651      Right Hand Grab        Meat_QuarterRight2_C_2147482363
# 27     150.495331  Right Hand Released        Meat_QuarterRight2_C_2147482363
# 28     151.114471      Right Hand Grab         Meat_QuarterLeft1_C_2147482366
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 202                  NaN     Pour Broth
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C026B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        90
# Right Hand Released    79
# Chopped                33
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     3.000000
# mean     67.333333
# std      30.237945
# min      33.000000
# 25%      56.000000
# 50%      79.000000
# 75%      84.500000
# max      90.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 202

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      24
# StaticMeshActor_84                             12
# BeefStewCookbook_C_0                            9
# PepperShakerGrabable_C_2147482375               8
# Meat_QuarterLeft1_C_2147482366                  6
# BrothParent_C_2147482377                        6
# Meat_QuarterRight2_C_2147482363                 6
# Meat_QuarterLeft2_C_2147482365                  6
# Carrot_Choppable_C_2147482325                   5
# Potato_Choppable_C_2147482409                   5
# StaticMeshActor_31                              4
# StaticMeshActor_23                              4
# Meat_QuarterLeft1_C_2147482355                  4
# StirSpoon_C_2147482379                          4
# StewBowl_C_2147482305                           4
# Onion_Peeled_C_2147482346                       4
# Carrot_Choppable_C_2147482404                   3
# Onion_Choppable_C_2147482351                    3
# Potato_Choppable_C_2147482408                   3
# Tomato_Choppable_C_2147482396                   3
# Onion_Half2_C_2147482344                        3
# Tomato_Choppable_C_2147482341                   3
# Meat_QuarterRight1_C_2147482364                 3
# Meat_Choppable_C_2147482399                     3
# Onion_Choppable_C_2147482391                    3
# Meat_Choppable_C_2147482369                     3
# Meat_QuarterRight2_C_2147482356                 3
# CarrotBotton_Choppable_C_2147482316             2
# CarrotTopQuarter1_Choppable_C_2147482320        2
# CarrotBottomQuarter2_Choppable_C_2147482321     2
# CarrotBottomQuarter1_Choppable_C_2147482322     2
# CarrotTopQuarter2_Choppable_C_2147482319        2
# CarrotBottomQuarter2_Choppable_C_2147482314     2
# Potato_BottomHalf_Choppable_C_2147482326        2
# CarrotTopQuarter1_Choppable_C_2147482313        2
# CarrotBottomQuarter1_Choppable_C_2147482315     2
# CarrotTopQuarter2_Choppable_C_2147482312        2
# SaltShakerGrabable_C_2147482376                 2
# NewLadle_C_2147482307                           2
# Onion_Half_C_2147482349                         2
# Onion_Half2_C_2147482348                        2
# Potato_TopHalf_Choppable_C_2147482327           2
# Tomato_TopHalf_Choppable_C_2147482340           2
# Potato_TopHalf_Choppable_C_2147482334           2
# Potato_BottomHalf_Choppable_C_2147482333        2
# Onion_Half_C_2147482345                         2
# Meat_QuarterLeft2_C_2147482354                  2
# Tomato_BottomHalf_Choppable_C_2147482336        2
# Tomato_BottomHalf_Choppable_C_2147482339        2
# Tomato_TopHalf_Choppable_C_2147482337           2
# Meat_QuarterRight1_C_2147482357                 2
# Onion_Peeled_C_2147482350                       1
# Meat_HalfLeft_Choppable_C_2147482368            1
# CarrotTop_Choppable_C_2147482317                1
# CarrotBotton_Choppable_C_2147482323             1
# Meat_HalfRight_Choppable_C_2147482367           1
# Meat_HalfLeft_Choppable_C_2147482359            1
# Meat_HalfRight_Choppable_C_2147482358           1
# CarrotTop_Choppable_C_2147482324                1
# Exit_C_0                                        1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       4
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add Salt       1
# Add pepper     1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              2   40.996010                  0.0
# 1         Add Beef             30   54.122216                  0.0
# 2         Add Beef              2    1.388794                  0.0
# 3         Add Beef              2    1.636169                  0.0
# 4         Add Beef              2    1.374024                  0.0
# 5        Add Onion             27   55.931991                  0.0
# 6        Add Onion              2    1.456665                  0.0
# 7        Add Onion             16   15.479232                  0.0
# 8        Add Onion              2    1.273513                  0.0
# 9      Add Tomtato              8   13.823700                  0.0
# 10     Add Tomtato              2    2.605774                  0.0
# 11     Add Tomtato             10   10.880096                  1.0
# 12     Add Tomtato              2    1.355407                  0.0
# 13      Add Potato             18   32.229645                  0.0
# 14      Add Potato              2    1.441955                  0.0
# 15      Add Potato              7    9.467224                  0.0
# 16      Add Potato              2    1.903778                  0.0
# 17      Add Carrot             10   14.458405                  0.0
# 18      Add Carrot              2    1.355439                  0.0
# 19      Add Carrot              2    1.225586                  0.0
# 20      Add Carrot              2    1.045532                  0.0
# 21      Add Carrot             12   14.723480                  0.0
# 22      Add Carrot              2    1.362579                  0.0
# 23      Add Carrot              2    1.313171                  0.0
# 24      Add Carrot              2    1.474701                  0.0
# 25        Add Salt              6    9.430420                  0.0
# 26      Add pepper              6   15.192688                  0.0
# 27       Stir Stew              8   33.139862                  0.0
# 28  Post last step             12   50.250122                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 202

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C026',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C026            202        392.338178                        1.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        6.965517   13.528903             0.034483
# std         7.566292   17.435068             0.185695
# min         2.000000    1.045532             0.000000
# 25%         2.000000    1.374024             0.000000
# 50%         2.000000    2.605774             0.000000
# 75%        10.000000   15.192688             0.000000
# max        30.000000   55.931991             1.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   36.958893
# 1       Add Beef      4   58.521203
# 2      Add Onion      4   74.141401
# 3    Add Tomtato      4   28.664977
# 4     Add Potato      4   45.042602
# 5     Pour Broth      1   40.996010
# 6       Add Salt      1    9.430420
# 7     Add pepper      1   15.192688
# 8      Stir Stew      1   33.139862

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       8                     4
# Add Salt                    1            0       0                     0
# Stir Stew                   0            4       0                     0
# Add pepper                  0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             3          2                  4
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add pepper                      0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0      2    26      0                     6
# Add Onion                    0      8    16     20                     0
# Add Tomtato                  0      4     0      0                     0
# Add Potato                   0      6     0      0                     0
# Add Carrot                   4      4     0      0                     0
# Add Salt                     0      0     0      0                     0
# Stir Stew                    0      0     0      0                     1
# Add pepper                   0      0     0      0                     1
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                2          0       0
# Add Tomtato       0                   0                2          0      14
# Add Potato       16                   0                6          0       0
# Add Carrot        0                   0                0          0       0
# Add Salt          0                   1                4          0       0
# Stir Stew         0                   0                2          1       0
# Add pepper        0                   1                4          0       0
#
#              Interacted Objects
# Pour Broth                    2
# Add Beef                     36
# Add Onion                    47
# Add Tomtato                  21
# Add Potato                   29
# Add Carrot                   34
# Add Salt                      6
# Stir Stew                     8
# Add pepper                    6

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0       57.794533      Right Hand Grab      BeefStewCookbook_C_0
# 1       86.779274      Right Hand Grab  BrothParent_C_2147482377
# 2       98.790543                  NaN                       NaN
# 3      101.475761  Right Hand Released  BrothParent_C_2147482377
# 4      103.369019      Right Hand Grab      BeefStewCookbook_C_0
# ..            ...                  ...                       ...
# 225    475.358826  Right Hand Released     StewBowl_C_2147482305
# 226    476.091736      Right Hand Grab     StewBowl_C_2147482305
# 227    477.355194  Right Hand Released     StewBowl_C_2147482305
# 228    485.508759      Right Hand Grab      BeefStewCookbook_C_0
# 229    488.618042      Right Hand Grab                  Exit_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    NaN     Pour Broth
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 225                  0.0            NaN
# 226                  0.0            NaN
# 227                  0.0            NaN
# 228                  0.0            NaN
# 229                  0.0            NaN
#
# [230 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        90
# Right Hand Released    79
# Chopped                33
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Right Hand Grab        1.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab            90                        1.0
# 2  Right Hand Released            79                        0.0
# 0              Chopped            33                        0.0
