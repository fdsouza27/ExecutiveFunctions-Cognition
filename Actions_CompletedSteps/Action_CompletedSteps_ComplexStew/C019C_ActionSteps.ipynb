# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C019 C/'
file_name = 'C019_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     99.596092      Right Hand Grab      BeefStewCookbook_C_0
# 1    160.330292      Right Hand Grab                       NaN
# 2    161.176086      Right Hand Grab  BrothParent_C_2147482375
# 3    161.706924  Right Hand Released  BrothParent_C_2147482375
# 4    162.129105      Right Hand Grab  BrothParent_C_2147482375

# %%
df1.shape
# Out:
# (222, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    219
# 1      3
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1      160.330292  Right Hand Grab               NaN                    1
# 6      187.826111  Right Hand Grab               NaN                    1
# 217    504.430511  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     99.596092      Right Hand Grab      BeefStewCookbook_C_0
# 1    160.330292      Right Hand Grab                       NaN
# 2    161.176086      Right Hand Grab  BrothParent_C_2147482375
# 3    161.706924  Right Hand Released  BrothParent_C_2147482375
# 4    162.129105      Right Hand Grab  BrothParent_C_2147482375
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C019 C/'
file_name = 'C019_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    177.248871     Pour Broth
# 1    215.024597       Add Beef
# 2    218.367599       Add Beef
# 3    229.328171       Add Beef
# 4    231.902817       Add Beef
# 5    316.151703      Add Onion
# 6    318.618195      Add Onion
# 7    332.198883      Add Onion
# 8    334.871674      Add Onion
# 9    353.818848    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (249, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       99.596092      Right Hand Grab                   BeefStewCookbook_C_0
# 1      160.330292      Right Hand Grab                                    NaN
# 2      161.176086      Right Hand Grab               BrothParent_C_2147482375
# 3      161.706924  Right Hand Released               BrothParent_C_2147482375
# 4      162.129105      Right Hand Grab               BrothParent_C_2147482375
# 222    177.248871                  NaN                                    NaN
# 5      180.336914  Right Hand Released               BrothParent_C_2147482375
# 6      187.826111      Right Hand Grab                                    NaN
# 7      189.181976      Right Hand Grab                   BeefStewCookbook_C_0
# 8      194.692596      Right Hand Grab            Meat_Choppable_C_2147482397
# 9      195.867889  Right Hand Released            Meat_Choppable_C_2147482397
# 10     197.164658      Right Hand Grab                              Knife_C_1
# 11     201.148193              Chopped            Meat_Choppable_C_2147482397
# 12     202.460312  Right Hand Released                              Knife_C_1
# 13     203.018356      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482365
# 14     204.258514  Right Hand Released  Meat_HalfRight_Choppable_C_2147482365
# 15     204.722031      Right Hand Grab                              Knife_C_1
# 16     205.676254              Chopped  Meat_HalfRight_Choppable_C_2147482365
# 17     206.658478  Right Hand Released                              Knife_C_1
# 18     208.277145      Right Hand Grab        Meat_QuarterRight2_C_2147482363
# 19     210.076096  Right Hand Released        Meat_QuarterRight2_C_2147482363
# 20     210.565338      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482366
# 21     212.225006  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482366
# 22     212.909302      Right Hand Grab        Meat_QuarterRight2_C_2147482363
# 23     214.537277  Right Hand Released        Meat_QuarterRight2_C_2147482363
# 223    215.024597                  NaN                                    NaN
# 24     216.260498      Right Hand Grab        Meat_QuarterRight1_C_2147482364
# 25     218.101334  Right Hand Released        Meat_QuarterRight1_C_2147482364
# 224    218.367599                  NaN                                    NaN
# 26     223.569046      Right Hand Grab                              Knife_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 222                  NaN     Pour Broth
# 5                    0.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 223                  NaN       Add Beef
# 24                   0.0            NaN
# 25                   0.0            NaN
# 224                  NaN       Add Beef
# 26                   0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        101
# Right Hand Released     88
# Chopped                 33
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      3.000000
# mean      74.000000
# std       36.097091
# min       33.000000
# 25%       60.500000
# 50%       88.000000
# 75%       94.500000
# max      101.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 222

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                   40
# BeefStewCookbook_C_0                         9
# Meat_HalfRight_Choppable_C_2147482353        6
# StaticMeshActor_23                           4
# Onion_Peeled_C_2147482335                    4
#                                             ..
# Potato_BottomHalf_Choppable_C_2147482321     2
# CarrotTop_Choppable_C_2147482309             1
# CarrotBotton_Choppable_C_2147482312          1
# Meat_HalfLeft_Choppable_C_2147482354         1
# Exit_C_0                                     1
# Name: count, Length: 68, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Carrot     8
# Add Beef       4
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              5   77.652779                  1.0
# 1         Add Beef             19   34.687683                  1.0
# 2         Add Beef              2    2.107101                  0.0
# 3         Add Beef              6    5.759125                  0.0
# 4         Add Beef              2    2.103531                  0.0
# 5        Add Onion             62   80.526550                  0.0
# 6        Add Onion              2    1.733490                  0.0
# 7        Add Onion             16   12.482971                  0.0
# 8        Add Onion              1    1.202942                  0.0
# 9      Add Tomtato              8   10.895142                  0.0
# 10     Add Tomtato              2    1.940216                  0.0
# 11     Add Tomtato              7    6.075684                  0.0
# 12     Add Tomtato              2    1.385803                  0.0
# 13      Add Potato             13   16.162598                  0.0
# 14      Add Potato              4    2.910492                  0.0
# 15      Add Potato              2    1.842102                  0.0
# 16      Add Potato              7    6.074188                  0.0
# 17      Add Carrot             21   20.732911                  0.0
# 18      Add Carrot              2    1.596253                  0.0
# 19      Add Carrot              2    1.933380                  0.0
# 20      Add Carrot              2    1.734161                  0.0
# 21      Add Carrot              8    9.707946                  0.0
# 22      Add Carrot              2    1.569824                  0.0
# 23      Add Carrot              2    1.501434                  0.0
# 24      Add Carrot              2    1.598602                  0.0
# 25      Add pepper              4   29.068512                  0.0
# 26        Add Salt              2    6.461853                  0.0
# 27       Stir Stew              8   13.830994                  0.0
# 28  Post last step              7   37.037598                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 222

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C019',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C019            222        392.315865                        3.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.655172   13.528133             0.103448
# std        11.736013   20.766125             0.309934
# min         1.000000    1.202942             0.000000
# 25%         2.000000    1.734161             0.000000
# 50%         4.000000    5.759125             0.000000
# 75%         8.000000   13.830994             0.000000
# max        62.000000   80.526550             1.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   40.374511
# 1       Add Beef      4   44.657440
# 2      Add Onion      4   95.945953
# 3    Add Tomtato      4   20.296845
# 4     Add Potato      4   26.989380
# 5     Pour Broth      1   77.652779
# 6     Add pepper      1   29.068512
# 7       Add Salt      1    6.461853
# 8      Stir Stew      1   13.830994

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            3       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             5          5                  4
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0      6    20      0                     0
# Add Onion                    0     18    28     32                     0
# Add Tomtato                  0      4     0      0                     0
# Add Potato                   0      6     0      0                     0
# Add Carrot                   4      6     0      0                     0
# Add pepper                   0      0     0      0                     3
# Add Salt                     0      0     0      0                     1
# Stir Stew                    0      0     0      0                     0
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                0          0       0
# Add Onion         0                   0                2          0       0
# Add Tomtato       0                   0                0          0      14
# Add Potato       19                   0                0          0       0
# Add Carrot        2                   0                0          0       0
# Add pepper        0                   0                0          0       0
# Add Salt          0                   1                0          0       0
# Stir Stew         0                   1                4          3       0
#
#              Interacted Objects
# Pour Broth                    4
# Add Beef                     28
# Add Onion                    81
# Add Tomtato                  19
# Add Potato                   26
# Add Carrot                   41
# Add pepper                    4
# Add Salt                      2
# Stir Stew                     8

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0       99.596092      Right Hand Grab      BeefStewCookbook_C_0
# 1      160.330292      Right Hand Grab                       NaN
# 2      161.176086      Right Hand Grab  BrothParent_C_2147482375
# 3      161.706924  Right Hand Released  BrothParent_C_2147482375
# 4      162.129105      Right Hand Grab  BrothParent_C_2147482375
# ..            ...                  ...                       ...
# 244    504.430511      Right Hand Grab                       NaN
# 245    506.989655      Right Hand Grab     NewLadle_C_2147482297
# 246    518.301025  Right Hand Released     NewLadle_C_2147482297
# 247    519.636841      Right Hand Grab      BeefStewCookbook_C_0
# 248    536.047852      Right Hand Grab                  Exit_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 244                  1.0            NaN
# 245                  0.0            NaN
# 246                  0.0            NaN
# 247                  0.0            NaN
# 248                  0.0            NaN
#
# [249 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        101
# Right Hand Released     88
# Chopped                 33
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Right Hand Grab        3.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab           101                        3.0
# 2  Right Hand Released            88                        0.0
# 0              Chopped            33                        0.0
