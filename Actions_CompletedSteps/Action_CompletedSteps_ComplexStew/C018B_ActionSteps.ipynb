# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C018 B/'
file_name = 'C018_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      8.872890      Right Hand Grab      BeefStewCookbook_C_0
# 1     23.448008      Right Hand Grab  BrothParent_C_2147482365
# 2     38.253365  Right Hand Released  BrothParent_C_2147482365
# 3     40.127579      Right Hand Grab                       NaN
# 4     41.367043      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (175, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    169
# 1      6
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 3       40.127579  Right Hand Grab               NaN                    1
# 48     108.056976  Right Hand Grab               NaN                    1
# 50     113.397545  Right Hand Grab               NaN                    1
# 73     149.982925  Right Hand Grab               NaN                    1
# 122    230.004135   Left Hand Grab               NaN                    1
# 160    281.161865  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      8.872890      Right Hand Grab      BeefStewCookbook_C_0
# 1     23.448008      Right Hand Grab  BrothParent_C_2147482365
# 2     38.253365  Right Hand Released  BrothParent_C_2147482365
# 3     40.127579      Right Hand Grab                       NaN
# 4     41.367043      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C018 B/'
file_name = 'C018_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     35.788654     Pour Broth
# 1     81.490295       Add Beef
# 2     84.658241       Add Beef
# 3     87.187294       Add Beef
# 4     90.118500       Add Beef
# 5     92.995255       Add Beef
# 6     95.834854       Add Beef
# 7    104.025307       Add Beef
# 8    106.687080       Add Beef
# 9    132.191055      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (207, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        8.872890      Right Hand Grab                   BeefStewCookbook_C_0
# 1       23.448008      Right Hand Grab               BrothParent_C_2147482365
# 175     35.788654                  NaN                                    NaN
# 2       38.253365  Right Hand Released               BrothParent_C_2147482365
# 3       40.127579      Right Hand Grab                                    NaN
# 4       41.367043      Right Hand Grab                   BeefStewCookbook_C_0
# 5       46.493202       Left Hand Grab            Meat_Choppable_C_2147482387
# 6       48.022903   Left Hand Released            Meat_Choppable_C_2147482387
# 7       49.257130       Left Hand Grab            Meat_Choppable_C_2147482359
# 8       50.822220   Left Hand Released            Meat_Choppable_C_2147482359
# 9       52.744396      Right Hand Grab                              Knife_C_1
# 10      53.834225              Chopped            Meat_Choppable_C_2147482387
# 11      54.585697              Chopped            Meat_Choppable_C_2147482359
# 12      55.491261              Chopped   Meat_HalfLeft_Choppable_C_2147482357
# 13      56.157276              Chopped         Meat_QuarterLeft2_C_2147482352
# 14      59.868382              Chopped         Meat_QuarterLeft2_C_2147482352
# 15      60.797081              Chopped         Meat_QuarterLeft2_C_2147482352
# 16      62.293915              Chopped  Meat_HalfRight_Choppable_C_2147482354
# 17      63.330315              Chopped         Meat_QuarterLeft1_C_2147482353
# 18      64.031166              Chopped         Meat_QuarterLeft1_C_2147482353
# 19      65.765366  Right Hand Released                              Knife_C_1
# 20      66.566422      Right Hand Grab         Meat_QuarterLeft2_C_2147482352
# 21      68.266022  Right Hand Released         Meat_QuarterLeft2_C_2147482352
# 22      68.964218      Right Hand Grab        Meat_QuarterRight1_C_2147482349
# 23      71.031120  Right Hand Released        Meat_QuarterRight1_C_2147482349
# 24      72.331253      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482356
# 25      73.697197  Right Hand Released  Meat_HalfRight_Choppable_C_2147482356
# 26      74.730110      Right Hand Grab                              Knife_C_1
# 27      75.763313              Chopped  Meat_HalfRight_Choppable_C_2147482356
# 28      77.496239  Right Hand Released                              Knife_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 175                  NaN     Pour Broth
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C018B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        56
# Right Hand Released    40
# Chopped                32
# Left Hand Grab         25
# Left Hand Released     22
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     35.000000
# std      13.638182
# min      22.000000
# 25%      25.000000
# 50%      32.000000
# 75%      40.000000
# max      56.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 175

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      18
# BeefStewCookbook_C_0                           11
# Meat_QuarterLeft2_C_2147482352                  7
# NewLadle_C_2147482292                           6
# Potato_TopHalf_Choppable_C_2147482318           5
# Onion_Half2_C_2147482337                        4
# Meat_QuarterLeft1_C_2147482353                  4
# Meat_QuarterRight1_C_2147482349                 4
# Onion_Choppable_C_2147482375                    3
# Potato_Choppable_C_2147482397                   3
# Potato_Choppable_C_2147482396                   3
# Tomato_Choppable_C_2147482330                   3
# Carrot_Choppable_C_2147482392                   3
# Carrot_Choppable_C_2147482388                   3
# Tomato_Choppable_C_2147482331                   3
# Tomato_Choppable_C_2147482384                   3
# Meat_Choppable_C_2147482359                     3
# Onion_Choppable_C_2147482379                    3
# Meat_Choppable_C_2147482387                     3
# Meat_HalfRight_Choppable_C_2147482356           3
# Potato_TopHalf_Choppable_C_2147482316           2
# CarrotBotton_Choppable_C_2147482307             2
# Potato_BottomHalf_Choppable_C_2147482315        2
# Potato_BottomHalf_Choppable_C_2147482317        2
# StirSpoon_C_2147482367                          2
# SaltShakerGrabable_C_2147482364                 2
# PepperShakerGrabable_C_2147482363               2
# CarrotTopQuarter2_Choppable_C_2147482303        2
# CarrotTopQuarter1_Choppable_C_2147482300        2
# CarrotBottomQuarter1_Choppable_C_2147482298     2
# CarrotBottomQuarter2_Choppable_C_2147482297     2
# CarrotTopQuarter1_Choppable_C_2147482304        2
# CarrotBottomQuarter2_Choppable_C_2147482305     2
# CarrotBottomQuarter1_Choppable_C_2147482306     2
# CarrotTopQuarter2_Choppable_C_2147482299        2
# CarrotTop_Choppable_C_2147482302                2
# Meat_Choppable_C_2147482358                     2
# Tomato_BottomHalf_Choppable_C_2147482326        2
# Tomato_TopHalf_Choppable_C_2147482322           2
# Onion_Half_C_2147482335                         2
# Meat_QuarterRight2_C_2147482346                 2
# Meat_QuarterRight1_C_2147482347                 2
# Meat_QuarterRight2_C_2147482348                 2
# Meat_QuarterLeft1_C_2147482345                  2
# Meat_QuarterLeft2_C_2147482344                  2
# Tomato_BottomHalf_Choppable_C_2147482321        2
# Onion_Peeled_C_2147482336                       2
# StewBowl_C_2147482290                           2
# Onion_Half_C_2147482338                         2
# Onion_Half2_C_2147482334                        2
# Tomato_TopHalf_Choppable_C_2147482329           2
# Tomato_BottomHalf_Choppable_C_2147482328        2
# Tomato_TopHalf_Choppable_C_2147482327           2
# BrothParent_C_2147482365                        2
# Onion_Peeled_C_2147482339                       1
# CarrotTop_Choppable_C_2147482308                1
# Meat_HalfLeft_Choppable_C_2147482355            1
# Meat_HalfRight_Choppable_C_2147482354           1
# Meat_HalfLeft_Choppable_C_2147482357            1
# CarrotBotton_Choppable_C_2147482301             1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef       8
# Add Carrot     8
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add pepper     1
# Add Salt       1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              2   26.915764                  0.0
# 1         Add Beef             29   43.236930                  1.0
# 2         Add Beef              2    1.636268                  0.0
# 3         Add Beef              2    1.566010                  0.0
# 4         Add Beef              2    1.906540                  0.0
# 5         Add Beef              2    1.739983                  0.0
# 6         Add Beef              2    1.769401                  0.0
# 7         Add Beef              5    6.823700                  0.0
# 8         Add Beef              2    1.576515                  0.0
# 9        Add Onion             17   24.134079                  2.0
# 10       Add Onion              3    2.266067                  0.0
# 11       Add Onion              2    1.866913                  0.0
# 12       Add Onion              2    1.799103                  0.0
# 13     Add Tomtato             12   26.546432                  1.0
# 14     Add Tomtato              4    4.618286                  0.0
# 15     Add Tomtato              2    1.625580                  0.0
# 16     Add Tomtato              7    7.364807                  0.0
# 17      Add Potato             17   28.848252                  0.0
# 18      Add Potato              2    1.217514                  0.0
# 19      Add Potato              2    1.537369                  0.0
# 20      Add Potato              2    1.337189                  0.0
# 21      Add Carrot             15   20.858933                  1.0
# 22      Add Carrot              2    1.097153                  0.0
# 23      Add Carrot              2    1.132202                  0.0
# 24      Add Carrot              2    1.067169                  0.0
# 25      Add Carrot             10    6.863311                  0.0
# 26      Add Carrot              0    0.000000                  0.0
# 27      Add Carrot              4    2.368317                  0.0
# 28      Add Carrot              0    0.000000                  0.0
# 29      Add pepper              2    7.792816                  0.0
# 30        Add Salt              2    4.064178                  0.0
# 31       Stir Stew              3   12.276520                  1.0
# 32  Post last step             13   63.375763                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 175

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C018',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C018            175        311.229064                        6.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        5.303030    9.431184             0.181818
# std         6.434695   14.441232             0.464660
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.566010             0.000000
# 50%         2.000000    1.906540             0.000000
# 75%         5.000000    7.792816             0.000000
# max        29.000000   63.375763             2.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   60.255347
# 1     Add Carrot      8   33.387085
# 2      Add Onion      4   30.066162
# 3    Add Tomtato      4   40.155105
# 4     Add Potato      4   32.940324
# 5     Pour Broth      1   26.915764
# 6     Add pepper      1    7.792816
# 7       Add Salt      1    4.064178
# 8      Stir Stew      1   12.276520

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  3            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             3          3                  4
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0      6    37      0                     0
# Add Onion                    0      2     0     19                     0
# Add Tomtato                  0      4     0      0                     0
# Add Potato                   0      1     0      0                     0
# Add Carrot                   4      5     0      0                     0
# Add pepper                   0      0     0      0                     1
# Add Salt                     0      0     0      0                     1
# Stir Stew                    0      0     0      0                     0
#
#              Potato  SaltShakerGrabable  StirSpoon  Tomato  Interacted Objects
# Pour Broth        0                   0          0       0                   2
# Add Beef          0                   0          0       0                  45
# Add Onion         0                   0          0       0                  22
# Add Tomtato       0                   0          0      19                  24
# Add Potato       17                   0          0       2                  23
# Add Carrot        0                   0          0       0                  34
# Add pepper        0                   0          0       0                   2
# Add Salt          0                   1          0       0                   2
# Stir Stew         0                   1          1       0                   2

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type         Interacted Object  \
# 0        8.872890      Right Hand Grab      BeefStewCookbook_C_0
# 1       23.448008      Right Hand Grab  BrothParent_C_2147482365
# 2       35.788654                  NaN                       NaN
# 3       38.253365  Right Hand Released  BrothParent_C_2147482365
# 4       40.127579      Right Hand Grab                       NaN
# ..            ...                  ...                       ...
# 202    337.933899       Left Hand Grab     NewLadle_C_2147482292
# 203    348.104248   Left Hand Released     NewLadle_C_2147482292
# 204    350.956207      Right Hand Grab      BeefStewCookbook_C_0
# 205    357.336975       Left Hand Grab     StewBowl_C_2147482290
# 206    357.336975      Right Hand Grab     StewBowl_C_2147482290
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    NaN     Pour Broth
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 202                  0.0            NaN
# 203                  0.0            NaN
# 204                  0.0            NaN
# 205                  0.0            NaN
# 206                  0.0            NaN
#
# [207 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        56
# Right Hand Released    40
# Chopped                32
# Left Hand Grab         25
# Left Hand Released     22
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        5.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            56                        5.0
# 4  Right Hand Released            40                        0.0
# 0              Chopped            32                        0.0
# 1       Left Hand Grab            25                        1.0
# 2   Left Hand Released            22                        0.0
