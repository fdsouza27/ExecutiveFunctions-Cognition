# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C030 B/'
file_name = 'C030_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object
# 0     11.164168      Left Hand Grab         BeefStewCookbook_C_0
# 1     74.865181     Right Hand Grab         BeefStewCookbook_C_0
# 2    100.259918      Left Hand Grab  Meat_Choppable_C_2147482399
# 3    101.598877  Left Hand Released  Meat_Choppable_C_2147482399
# 4    102.781532     Right Hand Grab                    Knife_C_1

# %%
df1.shape
# Out:
# (152, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    151
# 1      1
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time     Action Type Interacted Object  Missed Interactions
# 142    273.596375  Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type            Interacted Object  \
# 0     11.164168      Left Hand Grab         BeefStewCookbook_C_0
# 1     74.865181     Right Hand Grab         BeefStewCookbook_C_0
# 2    100.259918      Left Hand Grab  Meat_Choppable_C_2147482399
# 3    101.598877  Left Hand Released  Meat_Choppable_C_2147482399
# 4    102.781532     Right Hand Grab                    Knife_C_1
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C030 B/'
file_name = 'C030_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     268.50296      Stir Stew

# %%
df2.shape
# Out:
# (1, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (153, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      11.164168       Left Hand Grab                   BeefStewCookbook_C_0
# 1      74.865181      Right Hand Grab                   BeefStewCookbook_C_0
# 2     100.259918       Left Hand Grab            Meat_Choppable_C_2147482399
# 3     101.598877   Left Hand Released            Meat_Choppable_C_2147482399
# 4     102.781532      Right Hand Grab                              Knife_C_1
# 5     104.692856              Chopped            Meat_Choppable_C_2147482399
# 6     105.492561              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 7     106.025467  Right Hand Released                              Knife_C_1
# 8     106.937065      Right Hand Grab                              Knife_C_1
# 9     107.803635              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 10    108.581032              Chopped        Meat_QuarterRight2_C_2147482367
# 11    110.424637              Chopped        Meat_QuarterRight1_C_2147482368
# 12    110.979591              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 13    112.047447  Right Hand Released                              Knife_C_1
# 14    112.957909      Right Hand Grab        Meat_QuarterRight1_C_2147482368
# 15    113.824005  Right Hand Released        Meat_QuarterRight1_C_2147482368
# 16    115.733978      Right Hand Grab        Meat_QuarterRight1_C_2147482368
# 17    116.735321  Right Hand Released        Meat_QuarterRight1_C_2147482368
# 18    117.997330      Right Hand Grab        Meat_QuarterRight2_C_2147482367
# 19    119.114052  Right Hand Released        Meat_QuarterRight2_C_2147482367
# 20    123.094788      Right Hand Grab                              Knife_C_1
# 21    123.625114              Chopped         Meat_QuarterLeft1_C_2147482366
# 22    124.223457  Right Hand Released                              Knife_C_1
# 23    124.934845      Right Hand Grab         Meat_QuarterLeft2_C_2147482365
# 24    125.468559       Left Hand Grab         Meat_QuarterLeft2_C_2147482365
# 25    126.001366   Left Hand Released         Meat_QuarterLeft2_C_2147482365
# 26    126.356758  Right Hand Released         Meat_QuarterLeft2_C_2147482365
# 27    127.466591      Right Hand Grab         Meat_QuarterLeft1_C_2147482366
# 28    128.444870  Right Hand Released         Meat_QuarterLeft1_C_2147482366
# 29    132.220230       Left Hand Grab            Meat_Choppable_C_2147482398
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        46
# Right Hand Released    38
# Chopped                29
# Left Hand Grab         22
# Left Hand Released     17
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     30.400000
# std      11.760102
# min      17.000000
# 25%      22.000000
# 50%      29.000000
# 75%      38.000000
# max      46.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 152

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                                      20
# BeefStewCookbook_C_0                           12
# StirSpoon_C_2147482379                          8
# CarrotBottomQuarter1_Choppable_C_2147482324     6
# Carrot_Choppable_C_2147482404                   5
# Meat_QuarterRight2_C_2147482367                 5
# Meat_QuarterRight1_C_2147482368                 5
# Meat_QuarterLeft2_C_2147482365                  4
# Onion_Half2_C_2147482349                        4
# Carrot_Choppable_C_2147482400                   3
# Tomato_Choppable_C_2147482394                   3
# CarrotBottomQuarter1_Choppable_C_2147482334     3
# Meat_Choppable_C_2147482399                     3
# Onion_Choppable_C_2147482355                    3
# Tomato_Choppable_C_2147482396                   3
# Meat_QuarterLeft1_C_2147482361                  3
# Meat_Choppable_C_2147482398                     3
# Meat_QuarterLeft1_C_2147482366                  3
# Onion_Choppable_C_2147482391                    3
# CarrotBottomQuarter2_Choppable_C_2147482333     2
# Tomato_TopHalf_Choppable_C_2147482342           2
# CarrotTopQuarter1_Choppable_C_2147482330        2
# CarrotTopQuarter2_Choppable_C_2147482329        2
# CarrotTopQuarter2_Choppable_C_2147482325        2
# CarrotTopQuarter1_Choppable_C_2147482326        2
# CarrotBottomQuarter2_Choppable_C_2147482323     2
# CarrotBotton_Choppable_C_2147482327             2
# PepperShakerGrabable_C_2147482375               2
# SaltShakerGrabable_C_2147482376                 2
# CarrotBotton_Choppable_C_2147482335             2
# Meat_HalfLeft_Choppable_C_2147482370            2
# Tomato_BottomHalf_Choppable_C_2147482339        2
# Onion_Peeled_C_2147482347                       2
# Meat_HalfRight_Choppable_C_2147482362           2
# Meat_QuarterRight2_C_2147482358                 2
# Meat_QuarterRight1_C_2147482359                 2
# Meat_QuarterLeft2_C_2147482360                  2
# Tomato_TopHalf_Choppable_C_2147482340           2
# Onion_Half_C_2147482350                         2
# Onion_Half_C_2147482346                         2
# Tomato_BottomHalf_Choppable_C_2147482341        2
# Onion_Half2_C_2147482345                        2
# CarrotTop_Choppable_C_2147482328                1
# Onion_Peeled_C_2147482351                       1
# Meat_Choppable_C_2147482371                     1
# CarrotTop_Choppable_C_2147482336                1
# Meat_HalfRight_Choppable_C_2147482369           1
# Meat_HalfLeft_Choppable_C_2147482363            1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Stir Stew    1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#    Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Stir Stew            140  257.338792                  0.0
# 1  Post last step             12   38.408478                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 152

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C030',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C030            152         295.74727                        1.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count       2.000000    2.000000             2.000000
# mean       76.000000  147.873635             0.500000
# std        90.509668  154.807110             0.707107
# min        12.000000   38.408478             0.000000
# 25%        44.000000   93.141056             0.250000
# 50%        76.000000  147.873635             0.500000
# 75%       108.000000  202.606213             0.750000
# max       140.000000  257.338792             1.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0      Stir Stew      1  257.338792

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#            BeefStewCookbook  Carrot  CarrotBottomQuarter1  \
# Stir Stew                 8       8                     9
#
#            CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Stir Stew                     4             4          2                  4
#
#            CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Stir Stew                  4     20    37     19                     2
#
#            SaltShakerGrabable  StirSpoon  Tomato  Interacted Objects
# Stir Stew                   2          3      14                 140

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                Interacted Object  \
# 0       11.164168       Left Hand Grab             BeefStewCookbook_C_0
# 1       74.865181      Right Hand Grab             BeefStewCookbook_C_0
# 2      100.259918       Left Hand Grab      Meat_Choppable_C_2147482399
# 3      101.598877   Left Hand Released      Meat_Choppable_C_2147482399
# 4      102.781532      Right Hand Grab                        Knife_C_1
# ..            ...                  ...                              ...
# 148    302.802979      Right Hand Grab  Meat_QuarterRight2_C_2147482367
# 149    303.316467  Right Hand Released  Meat_QuarterRight2_C_2147482367
# 150    304.182098      Right Hand Grab           StirSpoon_C_2147482379
# 151    306.140900  Right Hand Released           StirSpoon_C_2147482379
# 152    309.526886      Right Hand Grab             BeefStewCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 148                  0.0            NaN
# 149                  0.0            NaN
# 150                  0.0            NaN
# 151                  0.0            NaN
# 152                  0.0            NaN
#
# [153 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        46
# Right Hand Released    38
# Chopped                29
# Left Hand Grab         22
# Left Hand Released     17
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        0.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            46                        0.0
# 4  Right Hand Released            38                        0.0
# 0              Chopped            29                        0.0
# 1       Left Hand Grab            22                        1.0
# 2   Left Hand Released            17                        0.0
