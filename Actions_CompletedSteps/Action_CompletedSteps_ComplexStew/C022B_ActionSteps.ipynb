# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C022 B/'
file_name = 'C022_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0    112.795860  Right Hand Grab                   NaN
# 1    117.995171  Right Hand Grab  ApplePieCookbook_C_0
# 2    132.736984  Right Hand Grab                   NaN
# 3    135.047073  Right Hand Grab                   NaN
# 4    137.736206  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (276, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    266
# 1     10
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0      112.795860  Right Hand Grab               NaN                    1
# 2      132.736984  Right Hand Grab               NaN                    1
# 3      135.047073  Right Hand Grab               NaN                    1
# 4      137.736206  Right Hand Grab               NaN                    1
# 5      142.146896  Right Hand Grab               NaN                    1
# 63     278.099304  Right Hand Grab               NaN                    1
# 259    651.549316  Right Hand Grab               NaN                    1
# 262    699.049561  Right Hand Grab               NaN                    1
# 264    702.328247   Left Hand Grab               NaN                    1
# 273    735.348450  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0    112.795860  Right Hand Grab                   NaN                    1
# 1    117.995171  Right Hand Grab  ApplePieCookbook_C_0                    0
# 2    132.736984  Right Hand Grab                   NaN                    1
# 3    135.047073  Right Hand Grab                   NaN                    1
# 4    137.736206  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C022 B/'
file_name = 'C022_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     51.871471     Pour Broth
# 1     87.670967       Add Beef
# 2     90.958092       Add Beef
# 3     93.802597       Add Beef
# 4    100.327698       Add Beef
# 5    121.107491       Add Beef
# 6    123.521828       Add Beef
# 7    126.521210       Add Beef
# 8    128.512833       Add Beef
# 9    155.336731      Add Onion

# %%
df2.shape
# Out:
# (11, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (287, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                    Interacted Object  \
# 276     51.871471                  NaN                                  NaN
# 277     87.670967                  NaN                                  NaN
# 278     90.958092                  NaN                                  NaN
# 279     93.802597                  NaN                                  NaN
# 280    100.327698                  NaN                                  NaN
# 0      112.795860      Right Hand Grab                                  NaN
# 1      117.995171      Right Hand Grab                 ApplePieCookbook_C_0
# 281    121.107491                  NaN                                  NaN
# 282    123.521828                  NaN                                  NaN
# 283    126.521210                  NaN                                  NaN
# 284    128.512833                  NaN                                  NaN
# 2      132.736984      Right Hand Grab                                  NaN
# 3      135.047073      Right Hand Grab                                  NaN
# 4      137.736206      Right Hand Grab                                  NaN
# 5      142.146896      Right Hand Grab                                  NaN
# 6      146.835617      Right Hand Grab                 ApplePieCookbook_C_0
# 285    155.336731                  NaN                                  NaN
# 286    162.063416                  NaN                                  NaN
# 7      168.860367      Right Hand Grab          SugarJarSimple_C_2147482373
# 8      170.508469  Right Hand Released          SugarJarSimple_C_2147482373
# 9      173.170395      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 10     181.939835  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 11     182.161819      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 12     184.516357  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 13     185.116714      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 14     187.093399  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 15     187.393051      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 16     188.672516  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
# 17     189.581909      Right Hand Grab  NewMeasuringCupSimple2_C_2147482378
# 18     190.594116  Right Hand Released  NewMeasuringCupSimple2_C_2147482378
#
#      Missed Interactions Completed Step
# 276                  NaN     Pour Broth
# 277                  NaN       Add Beef
# 278                  NaN       Add Beef
# 279                  NaN       Add Beef
# 280                  NaN       Add Beef
# 0                    1.0            NaN
# 1                    0.0            NaN
# 281                  NaN       Add Beef
# 282                  NaN       Add Beef
# 283                  NaN       Add Beef
# 284                  NaN       Add Beef
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    0.0            NaN
# 285                  NaN      Add Onion
# 286                  NaN      Add Onion
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN

# %%
df.to_csv('act_step_C022B.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        122
# Right Hand Released     90
# Chopped                 30
# Left Hand Grab          19
# Left Hand Released      15
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      55.200000
# std       48.048933
# min       15.000000
# 25%       19.000000
# 50%       30.000000
# 75%       90.000000
# max      122.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 276

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# NewMeasuringCupSimple2_C_2147482378       42
# PieBowlSimple_C_2147482366                24
# Knife_C_4                                 16
# ApplePieCookbook_C_0                      15
# StirSpoonPieSImple_C_2147482371           14
# PiePanSimple_C_2147482369                 14
# WaterPitcherSimple_C_2147482372           12
# Apple_Half_C_2147482361                   11
# oven_C_1                                   8
# Apple_Slice2_C_2147482352                  6
# Apple_Slice4_C_2147482346                  5
# PillsberryDoughGirlSimple_C_2147482336     5
# Apple_Slice4_C_2147482358                  5
# Butter_C_2147482368                        5
# Apple_Slice3_C_2147482343                  5
# ButterHolderSimple_C_2147482375            4
# Apple_Slice4_C_2147482342                  4
# Apple_Slice3_C_2147482351                  4
# CinnyShakerGrabable_C_2147482376           4
# SaucePotSimple2_C_2147482377               4
# Apple_Slice_C_2147482345                   4
# Apple_Slice_C_2147482341                   4
# Apple_C_2147482363                         4
# Apple_C_2147482365                         3
# Apple_Half_C_2147482355                    3
# Apple_Slice2_C_2147482340                  3
# Apple_C_2147482386                         3
# Apple_Slice4_C_2147482350                  3
# Apple_C_2147482388                         3
# Apple_Slice3_C_2147482359                  3
# Apple_C_2147482364                         3
# Apple_Slice_C_2147482353                   3
# Apple_Slice3_C_2147482347                  2
# SugarJarSimple_C_2147482373                2
# Apple_Half2_C_2147482356                   2
# Apple_Slice2_C_2147482344                  2
# Apple_Slice_C_2147482339                   2
# Butter_C_2147482374                        2
# Apple_Slice2_C_2147482338                  2
# PillsberryDoughBoySimple_C_2147482337      1
# Apple_Half_C_2147482349                    1
# Apple_Half2_C_2147482360                   1
# Apple_Half_C_2147482357                    1
# Apple_Half2_C_2147482348                   1
# Apple_Half2_C_2147482354                   1
# Name: count, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef      8
# Add Onion     2
# Pour Broth    1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              0    0.000000                  0.0
# 1         Add Beef              0    0.000000                  0.0
# 2         Add Beef              0    0.000000                  0.0
# 3         Add Beef              0    0.000000                  0.0
# 4         Add Beef              0    0.000000                  0.0
# 5         Add Beef              2    8.311631                  1.0
# 6         Add Beef              0    0.000000                  0.0
# 7         Add Beef              0    0.000000                  0.0
# 8         Add Beef              0    0.000000                  0.0
# 9        Add Onion              5   22.599747                  4.0
# 10       Add Onion              0    0.000000                  0.0
# 11  Post last step            269  571.517624                  5.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 276

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C022',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C022            276        602.429002                       10.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      12.000000   12.000000            12.000000
# mean       23.000000   50.202417             0.833333
# std        77.484309  164.308146             1.749459
# min         0.000000    0.000000             0.000000
# 25%         0.000000    0.000000             0.000000
# 50%         0.000000    0.000000             0.000000
# 75%         0.500000    2.077908             0.250000
# max       269.000000  571.517624             5.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8    8.311631
# 1      Add Onion      2   22.599747
# 2     Pour Broth      1    0.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#            ApplePieCookbook  Interacted Objects
# Add Beef                  1                   1
# Add Onion                 1                   1

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type          Interacted Object  \
# 0       51.871471                  NaN                        NaN
# 1       87.670967                  NaN                        NaN
# 2       90.958092                  NaN                        NaN
# 3       93.802597                  NaN                        NaN
# 4      100.327698                  NaN                        NaN
# ..            ...                  ...                        ...
# 282    727.076477      Right Hand Grab  PiePanSimple_C_2147482369
# 283    733.726501  Right Hand Released  PiePanSimple_C_2147482369
# 284    735.348450      Right Hand Grab                        NaN
# 285    737.074646      Right Hand Grab                   oven_C_1
# 286    740.377991      Right Hand Grab       ApplePieCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    NaN     Pour Broth
# 1                    NaN       Add Beef
# 2                    NaN       Add Beef
# 3                    NaN       Add Beef
# 4                    NaN       Add Beef
# ..                   ...            ...
# 282                  0.0            NaN
# 283                  0.0            NaN
# 284                  1.0            NaN
# 285                  0.0            NaN
# 286                  0.0            NaN
#
# [287 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        122
# Right Hand Released     90
# Chopped                 30
# Left Hand Grab          19
# Left Hand Released      15
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        9.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           122                        9.0
# 4  Right Hand Released            90                        0.0
# 0              Chopped            30                        0.0
# 1       Left Hand Grab            19                        1.0
# 2   Left Hand Released            15                        0.0
