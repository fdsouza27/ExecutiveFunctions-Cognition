# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C031 C/'
file_name = 'C031_ComplexStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type              Interacted Object
# 0     19.258781  Right Hand Grab                            NaN
# 1     20.885752  Right Hand Grab                            NaN
# 2     22.240891  Right Hand Grab           BeefStewCookbook_C_0
# 3     56.352726  Right Hand Grab                            NaN
# 4     57.375160  Right Hand Grab  Carrot_Choppable_C_2147482392

# %%
df1.shape
# Out:
# (303, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    257
# 1     46
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       19.258781  Right Hand Grab               NaN                    1
# 1       20.885752  Right Hand Grab               NaN                    1
# 3       56.352726  Right Hand Grab               NaN                    1
# 6      108.526871   Left Hand Grab               NaN                    1
# 7      109.393425   Left Hand Grab               NaN                    1
# 8      115.326767   Left Hand Grab               NaN                    1
# 9      116.525627   Left Hand Grab               NaN                    1
# 10     117.481354   Left Hand Grab               NaN                    1
# 11     120.235168   Left Hand Grab               NaN                    1
# 12     121.253624   Left Hand Grab               NaN                    1
# 13     121.880325   Left Hand Grab               NaN                    1
# 14     122.791672   Left Hand Grab               NaN                    1
# 15     125.167603   Left Hand Grab               NaN                    1
# 16     126.634186   Left Hand Grab               NaN                    1
# 17     128.168640   Left Hand Grab               NaN                    1
# 18     132.278214   Left Hand Grab               NaN                    1
# 19     132.901428   Left Hand Grab               NaN                    1
# 20     133.612213   Left Hand Grab               NaN                    1
# 21     137.840500   Left Hand Grab               NaN                    1
# 24     163.700485   Left Hand Grab               NaN                    1
# 31     202.286301  Right Hand Grab               NaN                    1
# 32     203.662262  Right Hand Grab               NaN                    1
# 33     205.508698  Right Hand Grab               NaN                    1
# 34     207.042801  Right Hand Grab               NaN                    1
# 35     210.438629  Right Hand Grab               NaN                    1
# 36     212.030853  Right Hand Grab               NaN                    1
# 37     213.186646  Right Hand Grab               NaN                    1
# 38     214.544968  Right Hand Grab               NaN                    1
# 59     249.914322  Right Hand Grab               NaN                    1
# 95     308.085052  Right Hand Grab               NaN                    1
# 134    364.530579  Right Hand Grab               NaN                    1
# 135    365.902710  Right Hand Grab               NaN                    1
# 136    369.303741  Right Hand Grab               NaN                    1
# 138    376.453308  Right Hand Grab               NaN                    1
# 139    378.053833  Right Hand Grab               NaN                    1
# 140    379.432129  Right Hand Grab               NaN                    1
# 143    382.303070  Right Hand Grab               NaN                    1
# 162    411.405884  Right Hand Grab               NaN                    1
# 174    428.088165  Right Hand Grab               NaN                    1
# 175    429.290405  Right Hand Grab               NaN                    1
# 187    453.955475  Right Hand Grab               NaN                    1
# 222    514.480164  Right Hand Grab               NaN                    1
# 242    540.918335  Right Hand Grab               NaN                    1
# 243    542.030334  Right Hand Grab               NaN                    1
# 244    543.208984  Right Hand Grab               NaN                    1
# 245    544.455933  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type              Interacted Object  \
# 0     19.258781  Right Hand Grab                            NaN
# 1     20.885752  Right Hand Grab                            NaN
# 2     22.240891  Right Hand Grab           BeefStewCookbook_C_0
# 3     56.352726  Right Hand Grab                            NaN
# 4     57.375160  Right Hand Grab  Carrot_Choppable_C_2147482392
#
#    Missed Interactions
# 0                    1
# 1                    1
# 2                    0
# 3                    1
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C031 C/'
file_name = 'C031_ComplexStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    186.874023     Pour Broth
# 1    252.706375       Add Beef
# 2    256.155182       Add Beef
# 3    298.318054       Add Beef
# 4    302.888336       Add Beef
# 5    306.615723       Add Beef
# 6    331.149109       Add Beef
# 7    333.915649       Add Beef
# 8    360.223846       Add Beef
# 9    409.644836      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (335, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0       19.258781      Right Hand Grab                            NaN
# 1       20.885752      Right Hand Grab                            NaN
# 2       22.240891      Right Hand Grab           BeefStewCookbook_C_0
# 3       56.352726      Right Hand Grab                            NaN
# 4       57.375160      Right Hand Grab  Carrot_Choppable_C_2147482392
# 5       60.835728  Right Hand Released  Carrot_Choppable_C_2147482392
# 6      108.526871       Left Hand Grab                            NaN
# 7      109.393425       Left Hand Grab                            NaN
# 8      115.326767       Left Hand Grab                            NaN
# 9      116.525627       Left Hand Grab                            NaN
# 10     117.481354       Left Hand Grab                            NaN
# 11     120.235168       Left Hand Grab                            NaN
# 12     121.253624       Left Hand Grab                            NaN
# 13     121.880325       Left Hand Grab                            NaN
# 14     122.791672       Left Hand Grab                            NaN
# 15     125.167603       Left Hand Grab                            NaN
# 16     126.634186       Left Hand Grab                            NaN
# 17     128.168640       Left Hand Grab                            NaN
# 18     132.278214       Left Hand Grab                            NaN
# 19     132.901428       Left Hand Grab                            NaN
# 20     133.612213       Left Hand Grab                            NaN
# 21     137.840500       Left Hand Grab                            NaN
# 22     138.753372       Left Hand Grab  Carrot_Choppable_C_2147482388
# 23     139.932693   Left Hand Released  Carrot_Choppable_C_2147482388
# 24     163.700485       Left Hand Grab                            NaN
# 25     173.731705      Right Hand Grab       BrothParent_C_2147482365
# 303    186.874023                  NaN                            NaN
# 26     187.453903  Right Hand Released       BrothParent_C_2147482365
# 27     189.490524      Right Hand Grab       BrothParent_C_2147482365
# 28     190.334885  Right Hand Released       BrothParent_C_2147482365
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    1.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    1.0            NaN
# 10                   1.0            NaN
# 11                   1.0            NaN
# 12                   1.0            NaN
# 13                   1.0            NaN
# 14                   1.0            NaN
# 15                   1.0            NaN
# 16                   1.0            NaN
# 17                   1.0            NaN
# 18                   1.0            NaN
# 19                   1.0            NaN
# 20                   1.0            NaN
# 21                   1.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   1.0            NaN
# 25                   0.0            NaN
# 303                  NaN     Pour Broth
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C031C.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        134
# Right Hand Released     95
# Chopped                 55
# Left Hand Grab          18
# Left Hand Released       1
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.00000
# mean      60.60000
# std       54.70192
# min        1.00000
# 25%       18.00000
# 50%       55.00000
# 75%       95.00000
# max      134.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum() 
total_actions
# Out:
# 303

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_1                               38
# BeefStewCookbook_C_0                    10
# Meat_QuarterLeft2_C_2147482336           9
# Potato_Choppable_C_2147482393            7
# BrothParent_C_2147482365                 6
#                                         ..
# Onion_Peeled_C_2147482304                1
# Meat_HalfLeft_Choppable_C_2147482350     1
# Onion_Peeled_C_2147482316                1
# Meat_HalfLeft_Choppable_C_2147482323     1
# CarrotBotton_Choppable_C_2147482280      1
# Name: count, Length: 82, dtype: int64

# %%
# Frequency of completed steps
completed_steps = df['Completed Step'].value_counts(dropna=True)
completed_steps
# Out:
# Completed Step
# Add Beef       8
# Add Carrot     8
# Add Onion      4
# Add Tomtato    4
# Add Potato     4
# Pour Broth     1
# Add Salt       1
# Add pepper     1
# Stir Stew      1
# Name: count, dtype: int64

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             26  167.615242                 20.0
# 1         Add Beef             36   65.252472                  9.0
# 2         Add Beef              2    2.003906                  0.0
# 3         Add Beef             27   41.225921                  0.0
# 4         Add Beef              2    3.633301                  0.0
# 5         Add Beef              2    2.530823                  0.0
# 6         Add Beef             18   23.064057                  1.0
# 7         Add Beef              2    2.100799                  0.0
# 8         Add Beef             19   25.076110                  0.0
# 9        Add Onion             28   45.114257                  7.0
# 10       Add Onion             10   11.936706                  1.0
# 11       Add Onion             12   20.331756                  2.0
# 12       Add Onion              2    2.499755                  0.0
# 13     Add Tomtato              9   16.634766                  1.0
# 14     Add Tomtato              2    1.746490                  0.0
# 15     Add Tomtato              7    8.773620                  0.0
# 16     Add Tomtato              2    1.932983                  0.0
# 17      Add Potato             14   21.557190                  0.0
# 18      Add Potato             10   13.592254                  1.0
# 19      Add Potato              2    2.034057                  0.0
# 20      Add Potato              7    7.108155                  0.0
# 21      Add Carrot             17   26.175049                  4.0
# 22      Add Carrot              2    2.000000                  0.0
# 23      Add Carrot              4    4.208923                  0.0
# 24      Add Carrot              2    2.068542                  0.0
# 25      Add Carrot              9   12.169617                  0.0
# 26      Add Carrot              2    1.861938                  0.0
# 27      Add Carrot              3    2.666016                  0.0
# 28      Add Carrot              2    1.834168                  0.0
# 29        Add Salt              9   43.124207                  0.0
# 30      Add pepper              4    6.873901                  0.0
# 31       Stir Stew              4   16.665955                  0.0
# 32  Post last step              6   25.699279                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 303

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C031',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C031            303        631.112215                       46.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        9.181818   19.124613             1.393939
# std         9.183731   30.898870             3.912635
# min         2.000000    1.746490             0.000000
# 25%         2.000000    2.100799             0.000000
# 50%         6.000000    8.773620             0.000000
# 75%        12.000000   23.064057             1.000000
# max        36.000000  167.615242            20.000000

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8  164.887389
# 1     Add Carrot      8   52.984253
# 2      Add Onion      4   79.882474
# 3    Add Tomtato      4   29.087859
# 4     Add Potato      4   44.291656
# 5     Pour Broth      1  167.615242
# 6       Add Salt      1   43.124207
# 7     Add pepper      1    6.873901
# 8      Stir Stew      1   16.665955

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       4                     0
# Add Beef                    1            5       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  2            0       6                     4
# Add Salt                    2            0       0                     0
# Add pepper                  0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             2          3                  6
# Add Salt                        0             0          0                  0
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabable  \
# Pour Broth                   0      0     0      0                     0
# Add Beef                     0     18    72      0                     0
# Add Onion                    0      6     6     29                     0
# Add Tomtato                  0      4     0      0                     0
# Add Potato                   0      6     0      0                     0
# Add Carrot                   4      4     0      0                     0
# Add Salt                     0      0     0      0                     2
# Add pepper                   0      0     0      0                     1
# Stir Stew                    0      0     0      0                     3
#
#              Potato  SaltShakerGrabable  StaticMeshActor  StirSpoon  Tomato  \
# Pour Broth        0                   0                0          0       0
# Add Beef          0                   0                2          0       0
# Add Onion         0                   0                0          0       0
# Add Tomtato       0                   0                0          0      14
# Add Potato       23                   0                2          0       0
# Add Carrot        2                   0                0          0       0
# Add Salt          0                   5                0          0       0
# Add pepper        0                   1                2          0       0
# Stir Stew         0                   0                0          1       0
#
#              Interacted Objects
# Pour Broth                    6
# Add Beef                     98
# Add Onion                    42
# Add Tomtato                  19
# Add Potato                   32
# Add Carrot                   37
# Add Salt                      9
# Add pepper                    4
# Stir Stew                     4

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0       19.258781      Right Hand Grab                            NaN
# 1       20.885752      Right Hand Grab                            NaN
# 2       22.240891      Right Hand Grab           BeefStewCookbook_C_0
# 3       56.352726      Right Hand Grab                            NaN
# 4       57.375160      Right Hand Grab  Carrot_Choppable_C_2147482392
# ..            ...                  ...                            ...
# 330    677.021057      Right Hand Grab           BeefStewCookbook_C_0
# 331    682.282837      Right Hand Grab          NewLadle_C_2147482262
# 332    690.014771  Right Hand Released          NewLadle_C_2147482262
# 333    695.511963      Right Hand Grab          StewBowl_C_2147482260
# 334    700.446899  Right Hand Released          StewBowl_C_2147482260
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 330                  0.0            NaN
# 331                  0.0            NaN
# 332                  0.0            NaN
# 333                  0.0            NaN
# 334                  0.0            NaN
#
# [335 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        134
# Right Hand Released     95
# Chopped                 55
# Left Hand Grab          18
# Left Hand Released       1
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         17.0
# Left Hand Released      0.0
# Right Hand Grab        29.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           134                       29.0
# 4  Right Hand Released            95                        0.0
# 0              Chopped            55                        0.0
# 1       Left Hand Grab            18                       17.0
# 2   Left Hand Released             1                        0.0
