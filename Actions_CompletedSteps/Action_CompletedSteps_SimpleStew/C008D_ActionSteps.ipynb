# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C008 D/'
file_name = 'C008_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type         Interacted Object
# 0     10.057713  Right Hand Grab      BeefStewCookbook_C_0
# 1     34.401684  Right Hand Grab                       NaN
# 2     34.465092   Left Hand Grab                       NaN
# 3     35.797756  Right Hand Grab  BrothParent_C_2147482366
# 4     36.009037   Left Hand Grab  BrothParent_C_2147482366

# %%
df1.shape
# Out:
# (290, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    281
# 1      9
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       34.401684  Right Hand Grab               NaN                    1
# 2       34.465092   Left Hand Grab               NaN                    1
# 27      75.057938   Left Hand Grab               NaN                    1
# 102    148.743439   Left Hand Grab               NaN                    1
# 105    150.474991  Right Hand Grab               NaN                    1
# 167    203.843872  Right Hand Grab               NaN                    1
# 189    231.415619  Right Hand Grab               NaN                    1
# 266    328.236694  Right Hand Grab               NaN                    1
# 283    372.966980  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type         Interacted Object  \
# 0     10.057713  Right Hand Grab      BeefStewCookbook_C_0
# 1     34.401684  Right Hand Grab                       NaN
# 2     34.465092   Left Hand Grab                       NaN
# 3     35.797756  Right Hand Grab  BrothParent_C_2147482366
# 4     36.009037   Left Hand Grab  BrothParent_C_2147482366
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C008 D/'
file_name = 'C008_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     49.320362     Pour Broth
# 1     88.827782       Add Beef
# 2     91.632935       Add Beef
# 3     94.688255       Add Beef
# 4     98.191216       Add Beef
# 5    112.020660       Add Beef
# 6    114.194054       Add Beef
# 7    119.983139       Add Beef
# 8    119.994614       Add Beef
# 9    149.752808      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      10.057713      Right Hand Grab                   BeefStewCookbook_C_0
# 1      34.401684      Right Hand Grab                                    NaN
# 2      34.465092       Left Hand Grab                                    NaN
# 3      35.797756      Right Hand Grab               BrothParent_C_2147482366
# 4      36.009037       Left Hand Grab               BrothParent_C_2147482366
# 5      41.610878   Left Hand Released               BrothParent_C_2147482366
# 6      51.780731  Right Hand Released               BrothParent_C_2147482366
# 7      55.494484      Right Hand Grab                   BeefStewCookbook_C_0
# 8      61.047878      Right Hand Grab            Meat_Choppable_C_2147482388
# 9      61.059082       Left Hand Grab            Meat_Choppable_C_2147482388
# 10     62.424351   Left Hand Released            Meat_Choppable_C_2147482388
# 11     62.604477  Right Hand Released            Meat_Choppable_C_2147482388
# 12     64.458900       Left Hand Grab                              Knife_C_4
# 13     64.713928      Right Hand Grab                              Knife_C_4
# 14     65.670204   Left Hand Released                              Knife_C_4
# 15     66.270500              Chopped            Meat_Choppable_C_2147482388
# 16     68.204002              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 17     68.920807              Chopped         Meat_QuarterLeft1_C_2147482357
# 18     69.599518              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 19     70.591988              Chopped         Meat_QuarterLeft2_C_2147482356
# 20     71.246948              Chopped         Meat_QuarterLeft1_C_2147482357
# 21     72.303253              Chopped        Meat_QuarterRight2_C_2147482354
# 22     72.447334  Right Hand Released                              Knife_C_4
# 23     73.114227       Left Hand Grab        Meat_QuarterRight1_C_2147482355
# 24     73.158348      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
# 25     74.418465  Right Hand Released         Meat_QuarterLeft1_C_2147482357
# 26     74.568771   Left Hand Released        Meat_QuarterRight1_C_2147482355
# 27     75.057938       Left Hand Grab                                    NaN
# 28     75.090904      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
# 29     75.447044  Right Hand Released         Meat_QuarterLeft1_C_2147482357
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  1.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (322, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       10.057713      Right Hand Grab                   BeefStewCookbook_C_0
# 1       34.401684      Right Hand Grab                                    NaN
# 2       34.465092       Left Hand Grab                                    NaN
# 3       35.797756      Right Hand Grab               BrothParent_C_2147482366
# 4       36.009037       Left Hand Grab               BrothParent_C_2147482366
# 5       41.610878   Left Hand Released               BrothParent_C_2147482366
# 290     49.320362                  NaN                                    NaN
# 6       51.780731  Right Hand Released               BrothParent_C_2147482366
# 7       55.494484      Right Hand Grab                   BeefStewCookbook_C_0
# 8       61.047878      Right Hand Grab            Meat_Choppable_C_2147482388
# 9       61.059082       Left Hand Grab            Meat_Choppable_C_2147482388
# 10      62.424351   Left Hand Released            Meat_Choppable_C_2147482388
# 11      62.604477  Right Hand Released            Meat_Choppable_C_2147482388
# 12      64.458900       Left Hand Grab                              Knife_C_4
# 13      64.713928      Right Hand Grab                              Knife_C_4
# 14      65.670204   Left Hand Released                              Knife_C_4
# 15      66.270500              Chopped            Meat_Choppable_C_2147482388
# 16      68.204002              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 17      68.920807              Chopped         Meat_QuarterLeft1_C_2147482357
# 18      69.599518              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 19      70.591988              Chopped         Meat_QuarterLeft2_C_2147482356
# 20      71.246948              Chopped         Meat_QuarterLeft1_C_2147482357
# 21      72.303253              Chopped        Meat_QuarterRight2_C_2147482354
# 22      72.447334  Right Hand Released                              Knife_C_4
# 23      73.114227       Left Hand Grab        Meat_QuarterRight1_C_2147482355
# 24      73.158348      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
# 25      74.418465  Right Hand Released         Meat_QuarterLeft1_C_2147482357
# 26      74.568771   Left Hand Released        Meat_QuarterRight1_C_2147482355
# 27      75.057938       Left Hand Grab                                    NaN
# 28      75.090904      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 290                  NaN     Pour Broth
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   1.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C008D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        111
# Right Hand Released     74
# Left Hand Grab          38
# Chopped                 38
# Left Hand Released      29
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      58.000000
# std       34.300146
# min       29.000000
# 25%       38.000000
# 50%       38.000000
# 75%       74.000000
# max      111.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 290

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                   50
# BeefStewCookbook_C_0                        27
# Meat_QuarterLeft1_C_2147482357               8
# Meat_QuarterRight2_C_2147482354              7
# Meat_QuarterRight1_C_2147482355              7
#                                             ..
# Meat_HalfLeft_Choppable_C_2147482351         1
# Meat_HalfLeft_Choppable_C_2147482359         1
# Potato_TopHalf_Choppable_C_2147482322        1
# Potato_BottomHalf_Choppable_C_2147482321     1
# Potato_TopHalf_Choppable_C_2147482324        1
# Name: count, Length: 62, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 281

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              6   39.262649                  2.0
# 1         Add Beef             37   37.047051                  1.0
# 2         Add Beef              2    1.425110                  0.0
# 3         Add Beef              2    2.056518                  0.0
# 4         Add Beef              4    2.713952                  0.0
# 5         Add Beef             16   12.755516                  0.0
# 6         Add Beef              4    1.053429                  0.0
# 7         Add Beef              7    4.787788                  0.0
# 8         Add Beef              0    0.000000                  0.0
# 9        Add Onion             26   26.760224                  1.0
# 10       Add Onion              7    2.791855                  1.0
# 11       Add Onion             18   10.025985                  0.0
# 12       Add Onion              4    1.020325                  0.0
# 13     Add Tomtato             13   13.287491                  0.0
# 14     Add Tomtato              4    1.110595                  0.0
# 15     Add Tomtato             12    5.478409                  0.0
# 16     Add Tomtato              5    2.915054                  0.0
# 17      Add Potato             14   11.569046                  1.0
# 18      Add Potato              1    1.445175                  0.0
# 19      Add Potato              1    1.514206                  0.0
# 20      Add Potato              1    0.850784                  0.0
# 21      Add Carrot             28   28.261688                  1.0
# 22      Add Carrot              2    0.956665                  0.0
# 23      Add Carrot              9    5.510376                  0.0
# 24      Add Carrot              2    1.167511                  0.0
# 25      Add Carrot             10    6.699158                  0.0
# 26      Add Carrot              1    0.211181                  0.0
# 27      Add Carrot             17   13.906891                  0.0
# 28      Add Carrot              1    0.899140                  0.0
# 29        Add Salt              5   10.810608                  0.0
# 30      Add pepper              2    3.401886                  0.0
# 31       Stir Stew             18   35.785950                  1.0
# 32  Post last step             11   29.400054                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 290

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C008',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C008            290         316.88227                        9.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        8.787879    9.602493             0.272727
# std         8.939930   11.984619             0.516764
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.167511             0.000000
# 50%         5.000000    3.401886             0.000000
# 75%        13.000000   12.755516             0.000000
# max        37.000000   39.262649             2.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            3       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   2            0       0                     0
# Add Tomtato                 4            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  2            0       9                     6
# Add Salt                    2            0       0                     0
# Stir Stew                  11            0       0                     0
# Add pepper                  0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                     13             8          8                  2
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add pepper                      0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0     14    55      0
# Add Onion                    0     12     0     39
# Add Tomtato                  0      6     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   5     16     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
# Add pepper                   0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      13                         0
# Add Carrot                            0       0                         0
# Add Salt                              0       0                         3
# Stir Stew                             3       0                         0
# Add pepper                            1       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   4
# Add Beef                   0       0                  71
# Add Onion                  0       0                  53
# Add Tomtato                0      24                  34
# Add Potato                 0       0                  16
# Add Carrot                 0       0                  69
# Add Salt                   0       0                   5
# Stir Stew                  3       0                  17
# Add pepper                 0       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   61.839364
# 1     Add Carrot      8   57.612610
# 2      Add Onion      4   40.598389
# 3    Add Tomtato      4   22.791549
# 4     Add Potato      4   15.379211
# 5     Pour Broth      1   39.262649
# 6       Add Salt      1   10.810608
# 7     Add pepper      1    3.401886
# 8      Stir Stew      1   35.785950

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0       10.057713      Right Hand Grab         BeefStewCookbook_C_0
# 1       34.401684      Right Hand Grab                          NaN
# 2       34.465092       Left Hand Grab                          NaN
# 3       35.797756      Right Hand Grab     BrothParent_C_2147482366
# 4       36.009037       Left Hand Grab     BrothParent_C_2147482366
# ..            ...                  ...                          ...
# 317    381.110687  Right Hand Released  NewLadleSimple_C_2147482301
# 318    382.543793      Right Hand Grab  StewBowlSimple_C_2147482299
# 319    382.632812       Left Hand Grab  StewBowlSimple_C_2147482299
# 320    383.197906  Right Hand Released  StewBowlSimple_C_2147482299
# 321    383.197906   Left Hand Released  StewBowlSimple_C_2147482299
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 317                  0.0            NaN
# 318                  0.0            NaN
# 319                  0.0            NaN
# 320                  0.0            NaN
# 321                  0.0            NaN
#
# [322 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        111
# Right Hand Released     74
# Left Hand Grab          38
# Chopped                 38
# Left Hand Released      29
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         3.0
# Left Hand Released     0.0
# Right Hand Grab        6.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           111                        6.0
# 4  Right Hand Released            74                        0.0
# 0              Chopped            38                        0.0
# 1       Left Hand Grab            38                        3.0
# 2   Left Hand Released            29                        0.0
