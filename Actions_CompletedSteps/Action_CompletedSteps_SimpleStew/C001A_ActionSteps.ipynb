# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C001 A/'
file_name = 'C001_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object
# 0      7.805719      Right Hand Grab           BeefStewCookbook_C_0
# 1     23.002619      Right Hand Grab  Carrot_Choppable_C_2147482402
# 2     24.613819  Right Hand Released  Carrot_Choppable_C_2147482402
# 3     25.691275      Right Hand Grab                            NaN
# 4     27.113485      Right Hand Grab  Carrot_Choppable_C_2147482405

# %%
df1.shape
# Out:
# (180, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    177
# 1      3
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 3       25.691275  Right Hand Grab               NaN                    1
# 134    215.522263  Right Hand Grab               NaN                    1
# 178    285.455078   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object  \
# 0      7.805719      Right Hand Grab           BeefStewCookbook_C_0
# 1     23.002619      Right Hand Grab  Carrot_Choppable_C_2147482402
# 2     24.613819  Right Hand Released  Carrot_Choppable_C_2147482402
# 3     25.691275      Right Hand Grab                            NaN
# 4     27.113485      Right Hand Grab  Carrot_Choppable_C_2147482405
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C001 A/'
file_name = 'C001_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     65.583656     Pour Broth
# 1    108.896194       Add Beef
# 2    111.273827       Add Beef
# 3    118.717575       Add Beef
# 4    121.018181       Add Beef
# 5    149.455902      Add Onion
# 6    152.745804      Add Onion
# 7    160.943710      Add Onion
# 8    163.177673      Add Onion
# 9    185.461792    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0       7.805719      Right Hand Grab                   BeefStewCookbook_C_0
# 1      23.002619      Right Hand Grab          Carrot_Choppable_C_2147482402
# 2      24.613819  Right Hand Released          Carrot_Choppable_C_2147482402
# 3      25.691275      Right Hand Grab                                    NaN
# 4      27.113485      Right Hand Grab          Carrot_Choppable_C_2147482405
# 5      28.590691  Right Hand Released          Carrot_Choppable_C_2147482405
# 6      33.389347      Right Hand Grab           Onion_Choppable_C_2147482389
# 7      37.055222  Right Hand Released           Onion_Choppable_C_2147482389
# 8      49.619789      Right Hand Grab           StirSpoonSimple_C_2147482380
# 9      50.507992  Right Hand Released           StirSpoonSimple_C_2147482380
# 10     51.041027      Right Hand Grab               BrothParent_C_2147482378
# 11     53.109173  Right Hand Released               BrothParent_C_2147482378
# 12     54.254333      Right Hand Grab               BrothParent_C_2147482378
# 13     65.650612  Right Hand Released               BrothParent_C_2147482378
# 14     66.450851      Right Hand Grab                   BeefStewCookbook_C_0
# 15     67.284828      Right Hand Grab                   BeefStewCookbook_C_0
# 16     68.338783      Right Hand Grab               BrothParent_C_2147482378
# 17     70.913216  Right Hand Released               BrothParent_C_2147482378
# 18     76.080887      Right Hand Grab           Onion_Choppable_C_2147482392
# 19     80.136101  Right Hand Released           Onion_Choppable_C_2147482392
# 20     82.125748      Right Hand Grab                   BeefStewCookbook_C_0
# 21     84.568413      Right Hand Grab           Onion_Choppable_C_2147482392
# 22     85.635498  Right Hand Released           Onion_Choppable_C_2147482392
# 23     89.766624      Right Hand Grab            Meat_Choppable_C_2147482398
# 24     92.812363  Right Hand Released            Meat_Choppable_C_2147482398
# 25     93.510483      Right Hand Grab                              Knife_C_4
# 26     94.198090              Chopped            Meat_Choppable_C_2147482398
# 27     94.689301  Right Hand Released                              Knife_C_4
# 28     95.433762      Right Hand Grab                              Knife_C_4
# 29     96.022034              Chopped  Meat_HalfRight_Choppable_C_2147482365
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   1.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (208, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0        7.805719      Right Hand Grab           BeefStewCookbook_C_0
# 1       23.002619      Right Hand Grab  Carrot_Choppable_C_2147482402
# 2       24.613819  Right Hand Released  Carrot_Choppable_C_2147482402
# 3       25.691275      Right Hand Grab                            NaN
# 4       27.113485      Right Hand Grab  Carrot_Choppable_C_2147482405
# 5       28.590691  Right Hand Released  Carrot_Choppable_C_2147482405
# 6       33.389347      Right Hand Grab   Onion_Choppable_C_2147482389
# 7       37.055222  Right Hand Released   Onion_Choppable_C_2147482389
# 8       49.619789      Right Hand Grab   StirSpoonSimple_C_2147482380
# 9       50.507992  Right Hand Released   StirSpoonSimple_C_2147482380
# 10      51.041027      Right Hand Grab       BrothParent_C_2147482378
# 11      53.109173  Right Hand Released       BrothParent_C_2147482378
# 12      54.254333      Right Hand Grab       BrothParent_C_2147482378
# 180     65.583656                  NaN                            NaN
# 13      65.650612  Right Hand Released       BrothParent_C_2147482378
# 14      66.450851      Right Hand Grab           BeefStewCookbook_C_0
# 15      67.284828      Right Hand Grab           BeefStewCookbook_C_0
# 16      68.338783      Right Hand Grab       BrothParent_C_2147482378
# 17      70.913216  Right Hand Released       BrothParent_C_2147482378
# 18      76.080887      Right Hand Grab   Onion_Choppable_C_2147482392
# 19      80.136101  Right Hand Released   Onion_Choppable_C_2147482392
# 20      82.125748      Right Hand Grab           BeefStewCookbook_C_0
# 21      84.568413      Right Hand Grab   Onion_Choppable_C_2147482392
# 22      85.635498  Right Hand Released   Onion_Choppable_C_2147482392
# 23      89.766624      Right Hand Grab    Meat_Choppable_C_2147482398
# 24      92.812363  Right Hand Released    Meat_Choppable_C_2147482398
# 25      93.510483      Right Hand Grab                      Knife_C_4
# 26      94.198090              Chopped    Meat_Choppable_C_2147482398
# 27      94.689301  Right Hand Released                      Knife_C_4
# 28      95.433762      Right Hand Grab                      Knife_C_4
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 180                  NaN     Pour Broth
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C001A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        69
# Right Hand Released    58
# Chopped                19
# Left Hand Grab         18
# Left Hand Released     16
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     36.000000
# std      25.426364
# min      16.000000
# 25%      18.000000
# 50%      19.000000
# 75%      58.000000
# max      69.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 180

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      28
# Carrot_Choppable_C_2147482402                  11
# BeefStewCookbook_C_0                           10
# Carrot_Choppable_C_2147482405                   9
# BrothParent_C_2147482378                        8
# Onion_Choppable_C_2147482389                    5
# Meat_Choppable_C_2147482399                     4
# StirSpoonSimple_C_2147482380                    4
# Onion_Choppable_C_2147482392                    4
# Tomato_BottomHalf_Choppable_C_2147482349        4
# Meat_QuarterRight2_C_2147482363                 4
# Onion_Choppable_C_2147482368                    3
# Carrot_Choppable_C_2147482374                   3
# CarrotTopQuarter2_Choppable_C_2147482326        3
# Potato_Choppable_C_2147482410                   3
# Potato_Choppable_C_2147482408                   3
# Meat_HalfLeft_Choppable_C_2147482366            3
# Tomato_Choppable_C_2147482397                   3
# Meat_Choppable_C_2147482398                     3
# Tomato_Choppable_C_2147482352                   3
# CarrotBotton_Choppable_C_2147482337             2
# CarrotBottomQuarter1_Choppable_C_2147482336     2
# CarrotTop_Choppable_C_2147482340                2
# CarrotBottomQuarter2_Choppable_C_2147482328     2
# CarrotBottomQuarter2_Choppable_C_2147482335     2
# CarrotTopQuarter1_Choppable_C_2147482334        2
# CarrotTopQuarter2_Choppable_C_2147482333        2
# Potato_TopHalf_Choppable_C_2147482344           2
# CarrotBottomQuarter1_Choppable_C_2147482329     2
# CarrotTopQuarter1_Choppable_C_2147482327        2
# PepperShakerGrabableSimple_C_2147482376         2
# SaltShakerGrabableSimple_C_2147482377           2
# Potato_TopHalf_Choppable_C_2147482342           2
# Tomato_TopHalf_Choppable_C_2147482350           2
# Potato_BottomHalf_Choppable_C_2147482341        2
# Onion_Half2_C_2147482353                        2
# Meat_QuarterRight1_C_2147482364                 2
# Meat_QuarterLeft2_C_2147482361                  2
# Meat_QuarterLeft1_C_2147482362                  2
# Onion_Half2_C_2147482357                        2
# Potato_BottomHalf_Choppable_C_2147482343        2
# Onion_Half_C_2147482358                         2
# Onion_Half_C_2147482354                         2
# Tomato_BottomHalf_Choppable_C_2147482347        2
# Tomato_TopHalf_Choppable_C_2147482348           2
# NewLadleSimple_C_2147482325                     2
# Onion_Peeled_C_2147482355                       1
# CarrotBotton_Choppable_C_2147482330             1
# CarrotTop_Choppable_C_2147482331                1
# Onion_Peeled_C_2147482359                       1
# CarrotTop_Choppable_C_2147482338                1
# CarrotBotton_Choppable_C_2147482339             1
# Meat_HalfRight_Choppable_C_2147482365           1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 177

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             13   57.777937                  1.0
# 1         Add Beef             24   43.245582                  0.0
# 2         Add Beef              2    1.273232                  0.0
# 3         Add Beef              7    6.464691                  0.0
# 4         Add Beef              2    1.288384                  0.0
# 5        Add Onion             15   17.395553                  0.0
# 6        Add Onion              4    2.178040                  0.0
# 7        Add Onion             12    7.064605                  0.0
# 8        Add Onion              2    1.222747                  0.0
# 9      Add Tomtato             21   19.529907                  0.0
# 10     Add Tomtato              0    0.000000                  0.0
# 11     Add Tomtato              4    1.191330                  0.0
# 12     Add Tomtato              0    0.000000                  0.0
# 13      Add Potato             16   11.453980                  0.0
# 14      Add Potato              1    0.167023                  0.0
# 15      Add Potato              4    1.355133                  0.0
# 16      Add Potato              2    1.321854                  0.0
# 17      Add Carrot             18   21.907151                  1.0
# 18      Add Carrot              0    0.000000                  0.0
# 19      Add Carrot              3    1.510544                  0.0
# 20      Add Carrot              1    0.066819                  0.0
# 21      Add Carrot             11    8.210541                  0.0
# 22      Add Carrot              1    0.200699                  0.0
# 23      Add Carrot              6    2.866455                  0.0
# 24      Add Carrot              0    0.000000                  0.0
# 25      Add pepper              2    6.710511                  0.0
# 26        Add Salt              2    7.010834                  0.0
# 27       Stir Stew              2    7.912109                  0.0
# 28  Post last step              5   12.488311                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 180

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C001',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C001            180        241.813972                        3.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        6.206897    8.338413             0.103448
# std         6.909514   13.341952             0.309934
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.191330             0.000000
# 50%         3.000000    2.178040             0.000000
# 75%        11.000000    8.210541             0.000000
# max        24.000000   57.777937             1.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            3       4                     0
# Add Beef                    3            3       0                     0
# Add Onion                   1            2       2                     0
# Add Tomtato                 1            0       6                     0
# Add Carrot                  1            0       5                     4
# Add Potato                  1            0       6                     0
# Stir Stew                   0            0       0                     0
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Carrot                      4             4          4                  4
# Add Potato                      0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      2
# Add Beef                     0      8    17      4
# Add Onion                    0     10     2     16
# Add Tomtato                  0      2     0      0
# Add Carrot                   5      6     2      0
# Add Potato                   0      2     0      0
# Stir Stew                    0      0     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Carrot                            0       0                         0
# Add Potato                            0      14                         0
# Stir Stew                             0       0                         1
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 2       0                  12
# Add Beef                   0       0                  35
# Add Onion                  0       0                  33
# Add Tomtato                0      16                  25
# Add Carrot                 0       0                  39
# Add Potato                 0       0                  23
# Stir Stew                  1       0                   2
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   34.762209
# 1       Add Beef      4   52.271889
# 2      Add Onion      4   27.860945
# 3    Add Tomtato      4   20.721237
# 4     Add Potato      4   14.297990
# 5     Pour Broth      1   57.777937
# 6     Add pepper      1    6.710511
# 7       Add Salt      1    7.010834
# 8      Stir Stew      1    7.912109

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0        7.805719      Right Hand Grab           BeefStewCookbook_C_0
# 1       23.002619      Right Hand Grab  Carrot_Choppable_C_2147482402
# 2       24.613819  Right Hand Released  Carrot_Choppable_C_2147482402
# 3       25.691275      Right Hand Grab                            NaN
# 4       27.113485      Right Hand Grab  Carrot_Choppable_C_2147482405
# ..            ...                  ...                            ...
# 203    276.711304  Right Hand Released   StirSpoonSimple_C_2147482380
# 204    277.689545      Right Hand Grab           BeefStewCookbook_C_0
# 205    282.675964      Right Hand Grab    NewLadleSimple_C_2147482325
# 206    285.455078       Left Hand Grab                            NaN
# 207    289.199615  Right Hand Released    NewLadleSimple_C_2147482325
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 203                  0.0            NaN
# 204                  0.0            NaN
# 205                  0.0            NaN
# 206                  1.0            NaN
# 207                  0.0            NaN
#
# [208 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        69
# Right Hand Released    58
# Chopped                19
# Left Hand Grab         18
# Left Hand Released     16
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        2.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            69                        2.0
# 4  Right Hand Released            58                        0.0
# 0              Chopped            19                        0.0
# 1       Left Hand Grab            18                        1.0
# 2   Left Hand Released            16                        0.0
