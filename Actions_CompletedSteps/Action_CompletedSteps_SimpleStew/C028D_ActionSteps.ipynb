# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C028 D/'
file_name = 'C028_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     13.408334      Right Hand Grab      BeefStewCookbook_C_0
# 1     25.994856      Right Hand Grab  BrothParent_C_2147482366
# 2     42.980118  Right Hand Released  BrothParent_C_2147482366
# 3     45.512474      Right Hand Grab                       NaN
# 4     46.423794      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (180, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    177
# 1      3
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 3       45.512474  Right Hand Grab               NaN                    1
# 82     165.979370  Right Hand Grab               NaN                    1
# 104    202.040131  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     13.408334      Right Hand Grab      BeefStewCookbook_C_0
# 1     25.994856      Right Hand Grab  BrothParent_C_2147482366
# 2     42.980118  Right Hand Released  BrothParent_C_2147482366
# 3     45.512474      Right Hand Grab                       NaN
# 4     46.423794      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C028 D/'
file_name = 'C028_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     39.081676     Pour Broth
# 1     68.663773       Add Beef
# 2     75.685669       Add Beef
# 3     78.729073       Add Beef
# 4     81.462791       Add Beef
# 5     93.782440       Add Beef
# 6     96.793243       Add Beef
# 7     99.714363       Add Beef
# 8    102.491348       Add Beef
# 9    134.519516      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      13.408334      Right Hand Grab                   BeefStewCookbook_C_0
# 1      25.994856      Right Hand Grab               BrothParent_C_2147482366
# 2      42.980118  Right Hand Released               BrothParent_C_2147482366
# 3      45.512474      Right Hand Grab                                    NaN
# 4      46.423794      Right Hand Grab                   BeefStewCookbook_C_0
# 5      49.711079      Right Hand Grab            Meat_Choppable_C_2147482388
# 6      51.267719  Right Hand Released            Meat_Choppable_C_2147482388
# 7      53.033936      Right Hand Grab                              Knife_C_4
# 8      54.533962              Chopped            Meat_Choppable_C_2147482388
# 9      55.556019              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 10     56.311089              Chopped         Meat_QuarterLeft1_C_2147482357
# 11     56.944065              Chopped         Meat_QuarterLeft1_C_2147482357
# 12     57.644333              Chopped         Meat_QuarterLeft1_C_2147482357
# 13     59.898434              Chopped         Meat_QuarterLeft1_C_2147482357
# 14     60.899052              Chopped         Meat_QuarterLeft1_C_2147482357
# 15     61.577473              Chopped         Meat_QuarterLeft1_C_2147482357
# 16     62.643425              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 17     63.431400  Right Hand Released                              Knife_C_4
# 18     64.498421      Right Hand Grab        Meat_QuarterRight2_C_2147482354
# 19     68.529991  Right Hand Released        Meat_QuarterRight2_C_2147482354
# 20     69.664101      Right Hand Grab        Meat_QuarterRight1_C_2147482355
# 21     71.409584  Right Hand Released        Meat_QuarterRight1_C_2147482355
# 22     73.874321      Right Hand Grab        Meat_QuarterRight1_C_2147482355
# 23     75.530388  Right Hand Released        Meat_QuarterRight1_C_2147482355
# 24     76.907288      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
# 25     78.596588  Right Hand Released         Meat_QuarterLeft1_C_2147482357
# 26     79.861877      Right Hand Grab         Meat_QuarterLeft2_C_2147482356
# 27     81.384544  Right Hand Released         Meat_QuarterLeft2_C_2147482356
# 28     82.828896      Right Hand Grab            Meat_Choppable_C_2147482360
# 29     84.261986  Right Hand Released            Meat_Choppable_C_2147482360
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   1.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (212, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       13.408334      Right Hand Grab                   BeefStewCookbook_C_0
# 1       25.994856      Right Hand Grab               BrothParent_C_2147482366
# 180     39.081676                  NaN                                    NaN
# 2       42.980118  Right Hand Released               BrothParent_C_2147482366
# 3       45.512474      Right Hand Grab                                    NaN
# 4       46.423794      Right Hand Grab                   BeefStewCookbook_C_0
# 5       49.711079      Right Hand Grab            Meat_Choppable_C_2147482388
# 6       51.267719  Right Hand Released            Meat_Choppable_C_2147482388
# 7       53.033936      Right Hand Grab                              Knife_C_4
# 8       54.533962              Chopped            Meat_Choppable_C_2147482388
# 9       55.556019              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 10      56.311089              Chopped         Meat_QuarterLeft1_C_2147482357
# 11      56.944065              Chopped         Meat_QuarterLeft1_C_2147482357
# 12      57.644333              Chopped         Meat_QuarterLeft1_C_2147482357
# 13      59.898434              Chopped         Meat_QuarterLeft1_C_2147482357
# 14      60.899052              Chopped         Meat_QuarterLeft1_C_2147482357
# 15      61.577473              Chopped         Meat_QuarterLeft1_C_2147482357
# 16      62.643425              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 17      63.431400  Right Hand Released                              Knife_C_4
# 18      64.498421      Right Hand Grab        Meat_QuarterRight2_C_2147482354
# 19      68.529991  Right Hand Released        Meat_QuarterRight2_C_2147482354
# 181     68.663773                  NaN                                    NaN
# 20      69.664101      Right Hand Grab        Meat_QuarterRight1_C_2147482355
# 21      71.409584  Right Hand Released        Meat_QuarterRight1_C_2147482355
# 22      73.874321      Right Hand Grab        Meat_QuarterRight1_C_2147482355
# 23      75.530388  Right Hand Released        Meat_QuarterRight1_C_2147482355
# 182     75.685669                  NaN                                    NaN
# 24      76.907288      Right Hand Grab         Meat_QuarterLeft1_C_2147482357
# 25      78.596588  Right Hand Released         Meat_QuarterLeft1_C_2147482357
# 183     78.729073                  NaN                                    NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 180                  NaN     Pour Broth
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 181                  NaN       Add Beef
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 182                  NaN       Add Beef
# 24                   0.0            NaN
# 25                   0.0            NaN
# 183                  NaN       Add Beef

# %%
#df.to_csv('act_step_C028D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Right Hand Released    65
# Chopped                39
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     3.0
# mean     60.0
# std      19.0
# min      39.0
# 25%      52.0
# 50%      65.0
# 75%      70.5
# max      76.0
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 180

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                26
# BeefStewCookbook_C_0                      8
# Meat_QuarterLeft1_C_2147482357            8
# Meat_QuarterLeft2_C_2147482347            4
# StirSpoonSimple_C_2147482368              4
#                                          ..
# Onion_Peeled_C_2147482344                 1
# CarrotTop_Choppable_C_2147482307          1
# Meat_HalfRight_Choppable_C_2147482351     1
# Meat_HalfRight_Choppable_C_2147482358     1
# Meat_HalfLeft_Choppable_C_2147482359      1
# Name: count, Length: 64, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 177

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              2   25.673342                  0.0
# 1         Add Beef             18   25.683655                  1.0
# 2         Add Beef              4    6.021568                  0.0
# 3         Add Beef              2    1.821785                  0.0
# 4         Add Beef              2    1.600914                  0.0
# 5         Add Beef             13   10.953544                  0.0
# 6         Add Beef              2    1.634117                  0.0
# 7         Add Beef              2    1.734321                  0.0
# 8         Add Beef              2    1.556305                  0.0
# 9        Add Onion             14   28.906342                  0.0
# 10       Add Onion              2    1.500122                  0.0
# 11       Add Onion              8   10.467545                  0.0
# 12       Add Onion             10    8.611741                  0.0
# 13     Add Tomtato             11   12.942902                  1.0
# 14     Add Tomtato              2    1.132476                  0.0
# 15     Add Tomtato              7    8.388779                  0.0
# 16     Add Tomtato              2    1.377258                  0.0
# 17      Add Potato              9   15.131241                  1.0
# 18      Add Potato              2    1.209229                  0.0
# 19      Add Potato              7    7.565171                  0.0
# 20      Add Potato              2    1.275772                  0.0
# 21      Add Carrot             19   36.616730                  0.0
# 22      Add Carrot              2    1.357513                  0.0
# 23      Add Carrot              2    1.256378                  0.0
# 24      Add Carrot              2    1.065888                  0.0
# 25      Add Carrot             12   14.143249                  0.0
# 26      Add Carrot              2    1.701233                  0.0
# 27      Add Carrot              2    1.445282                  0.0
# 28      Add Carrot              2    1.322998                  0.0
# 29      Add pepper              2    7.899353                  0.0
# 30        Add Salt              2    4.601318                  0.0
# 31       Stir Stew              4   17.653564                  0.0
# 32  Post last step              6   18.825531                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 180

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C028',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C028            180        283.077166                        3.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        5.454545    8.578096             0.090909
# std         5.062675    9.543259             0.291937
# min         2.000000    1.065888             0.000000
# 25%         2.000000    1.445282             0.000000
# 50%         2.000000    4.601318             0.000000
# 75%         8.000000   12.942902             0.000000
# max        19.000000   36.616730             1.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       9                     4
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             5          4                  4
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      4    38      0
# Add Onion                    0      6     0     27
# Add Tomtato                  0      4     0      2
# Add Potato                   0      4     0      0
# Add Carrot                   4      8     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      14                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  44
# Add Onion                  0       0                  34
# Add Tomtato                0      14                  21
# Add Potato                 0       0                  19
# Add Carrot                 0       0                  43
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2
# Stir Stew                  3       0                   4

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   51.006209
# 1     Add Carrot      8   58.909271
# 2      Add Onion      4   49.485750
# 3    Add Tomtato      4   23.841415
# 4     Add Potato      4   25.181413
# 5     Pour Broth      1   25.673342
# 6     Add pepper      1    7.899353
# 7       Add Salt      1    4.601318
# 8      Stir Stew      1   17.653564

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0       13.408334      Right Hand Grab         BeefStewCookbook_C_0
# 1       25.994856      Right Hand Grab     BrothParent_C_2147482366
# 2       39.081676                  NaN                          NaN
# 3       42.980118  Right Hand Released     BrothParent_C_2147482366
# 4       45.512474      Right Hand Grab                          NaN
# ..            ...                  ...                          ...
# 207    349.013794      Right Hand Grab         BeefStewCookbook_C_0
# 208    356.056549      Right Hand Grab  NewLadleSimple_C_2147482301
# 209    362.033142  Right Hand Released  NewLadleSimple_C_2147482301
# 210    364.708862      Right Hand Grab  StewBowlSimple_C_2147482299
# 211    366.439728  Right Hand Released  StewBowlSimple_C_2147482299
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    NaN     Pour Broth
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 207                  0.0            NaN
# 208                  0.0            NaN
# 209                  0.0            NaN
# 210                  0.0            NaN
# 211                  0.0            NaN
#
# [212 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Right Hand Released    65
# Chopped                39
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Right Hand Grab        3.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab            76                        3.0
# 2  Right Hand Released            65                        0.0
# 0              Chopped            39                        0.0
