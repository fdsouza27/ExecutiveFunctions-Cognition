# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C021 A/'
file_name = 'C021_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type Interacted Object
# 0    107.829689      Right Hand Grab               NaN
# 1    109.251297      Right Hand Grab         Knife_C_4
# 2    109.529922  Right Hand Released         Knife_C_4
# 3    110.684769      Right Hand Grab         Knife_C_4
# 4    114.073799  Right Hand Released         Knife_C_4

# %%
df1.shape
# Out:
# (310, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    296
# 1     14
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0      107.829689  Right Hand Grab               NaN                    1
# 8      231.494797  Right Hand Grab               NaN                    1
# 12     239.324799  Right Hand Grab               NaN                    1
# 23     256.877869  Right Hand Grab               NaN                    1
# 139    376.990417  Right Hand Grab               NaN                    1
# 225    486.491028  Right Hand Grab               NaN                    1
# 226    487.323853  Right Hand Grab               NaN                    1
# 227    488.246338  Right Hand Grab               NaN                    1
# 228    488.379028   Left Hand Grab               NaN                    1
# 242    504.253967   Left Hand Grab               NaN                    1
# 260    517.588013  Right Hand Grab               NaN                    1
# 261    518.366272  Right Hand Grab               NaN                    1
# 277    550.579285  Right Hand Grab               NaN                    1
# 279    552.046265   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type Interacted Object  Missed Interactions
# 0    107.829689      Right Hand Grab               NaN                    1
# 1    109.251297      Right Hand Grab         Knife_C_4                    0
# 2    109.529922  Right Hand Released         Knife_C_4                    0
# 3    110.684769      Right Hand Grab         Knife_C_4                    0
# 4    114.073799  Right Hand Released         Knife_C_4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C021 A/'
file_name = 'C021_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    220.907913     Pour Broth
# 1    314.533417       Add Beef
# 2    316.377167       Add Beef
# 3    318.957428       Add Beef
# 4    321.567719       Add Beef
# 5    353.307373      Add Onion
# 6    355.004242      Add Onion
# 7    373.656006      Add Onion
# 8    375.367950      Add Onion
# 9    402.463776    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type            Interacted Object  \
# 0     107.829689      Right Hand Grab                          NaN
# 1     109.251297      Right Hand Grab                    Knife_C_4
# 2     109.529922  Right Hand Released                    Knife_C_4
# 3     110.684769      Right Hand Grab                    Knife_C_4
# 4     114.073799  Right Hand Released                    Knife_C_4
# 5     160.316071      Right Hand Grab         BeefStewCookbook_C_0
# 6     200.879089      Right Hand Grab     BrothParent_C_2147482378
# 7     223.795883  Right Hand Released     BrothParent_C_2147482378
# 8     231.494797      Right Hand Grab                          NaN
# 9     232.851120      Right Hand Grab         BeefStewCookbook_C_0
# 10    238.857117      Right Hand Grab  Meat_Choppable_C_2147482400
# 11    239.235077  Right Hand Released  Meat_Choppable_C_2147482400
# 12    239.324799      Right Hand Grab                          NaN
# 13    240.358109      Right Hand Grab  Meat_Choppable_C_2147482400
# 14    242.003098  Right Hand Released  Meat_Choppable_C_2147482400
# 15    244.103928      Right Hand Grab  Meat_Choppable_C_2147482400
# 16    245.302628  Right Hand Released  Meat_Choppable_C_2147482400
# 17    246.312622      Right Hand Grab  Meat_Choppable_C_2147482372
# 18    247.801743  Right Hand Released  Meat_Choppable_C_2147482372
# 19    250.608185      Right Hand Grab                    Knife_C_4
# 20    253.473846  Right Hand Released                    Knife_C_4
# 21    254.396408      Right Hand Grab     BrothParent_C_2147482378
# 22    255.810028  Right Hand Released     BrothParent_C_2147482378
# 23    256.877869      Right Hand Grab                          NaN
# 24    258.245941      Right Hand Grab  Meat_Choppable_C_2147482372
# 25    259.333221  Right Hand Released  Meat_Choppable_C_2147482372
# 26    259.867004      Right Hand Grab  Meat_Choppable_C_2147482372
# 27    260.412292  Right Hand Released  Meat_Choppable_C_2147482372
# 28    260.967316      Right Hand Grab  Meat_Choppable_C_2147482372
# 29    262.197021  Right Hand Released  Meat_Choppable_C_2147482372
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   1.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  1.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  1.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (338, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0      107.829689      Right Hand Grab                          NaN
# 1      109.251297      Right Hand Grab                    Knife_C_4
# 2      109.529922  Right Hand Released                    Knife_C_4
# 3      110.684769      Right Hand Grab                    Knife_C_4
# 4      114.073799  Right Hand Released                    Knife_C_4
# 5      160.316071      Right Hand Grab         BeefStewCookbook_C_0
# 6      200.879089      Right Hand Grab     BrothParent_C_2147482378
# 310    220.907913                  NaN                          NaN
# 7      223.795883  Right Hand Released     BrothParent_C_2147482378
# 8      231.494797      Right Hand Grab                          NaN
# 9      232.851120      Right Hand Grab         BeefStewCookbook_C_0
# 10     238.857117      Right Hand Grab  Meat_Choppable_C_2147482400
# 11     239.235077  Right Hand Released  Meat_Choppable_C_2147482400
# 12     239.324799      Right Hand Grab                          NaN
# 13     240.358109      Right Hand Grab  Meat_Choppable_C_2147482400
# 14     242.003098  Right Hand Released  Meat_Choppable_C_2147482400
# 15     244.103928      Right Hand Grab  Meat_Choppable_C_2147482400
# 16     245.302628  Right Hand Released  Meat_Choppable_C_2147482400
# 17     246.312622      Right Hand Grab  Meat_Choppable_C_2147482372
# 18     247.801743  Right Hand Released  Meat_Choppable_C_2147482372
# 19     250.608185      Right Hand Grab                    Knife_C_4
# 20     253.473846  Right Hand Released                    Knife_C_4
# 21     254.396408      Right Hand Grab     BrothParent_C_2147482378
# 22     255.810028  Right Hand Released     BrothParent_C_2147482378
# 23     256.877869      Right Hand Grab                          NaN
# 24     258.245941      Right Hand Grab  Meat_Choppable_C_2147482372
# 25     259.333221  Right Hand Released  Meat_Choppable_C_2147482372
# 26     259.867004      Right Hand Grab  Meat_Choppable_C_2147482372
# 27     260.412292  Right Hand Released  Meat_Choppable_C_2147482372
# 28     260.967316      Right Hand Grab  Meat_Choppable_C_2147482372
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 310                  NaN     Pour Broth
# 7                    0.0            NaN
# 8                    1.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   1.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   1.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C021A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        142
# Right Hand Released     91
# Chopped                 50
# Left Hand Grab          17
# Left Hand Released      10
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      62.000000
# std       55.031809
# min       10.000000
# 25%       17.000000
# 50%       50.000000
# 75%       91.000000
# max      142.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 310

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      48
# BeefStewCookbook_C_0                           39
# Meat_Choppable_C_2147482372                    13
# BrothParent_C_2147482378                       10
# Meat_QuarterLeft1_C_2147482368                 10
# Onion_Choppable_C_2147482388                    9
# Onion_Peeled_C_2147482357                       9
# Meat_QuarterRight1_C_2147482366                 8
# Meat_Choppable_C_2147482400                     7
# Meat_QuarterRight2_C_2147482365                 7
# PepperShakerGrabableSimple_C_2147482376         6
# Meat_QuarterLeft2_C_2147482367                  6
# CarrotTop_Choppable_C_2147482336                5
# Potato_Choppable_C_2147482410                   5
# CarrotBottomQuarter1_Choppable_C_2147482332     5
# Meat_QuarterRight1_C_2147482362                 5
# Meat_HalfRight_Choppable_C_2147482363           5
# Meat_QuarterLeft2_C_2147482359                  4
# Potato_TopHalf_Choppable_C_2147482342           4
# SaltShakerGrabableSimple_C_2147482377           4
# StirSpoonSimple_C_2147482380                    4
# NewLadleSimple_C_2147482324                     4
# Carrot_Choppable_C_2147482401                   3
# Potato_BottomHalf_Choppable_C_2147482341        3
# Potato_Choppable_C_2147482406                   3
# Tomato_BottomHalf_Choppable_C_2147482348        3
# CarrotBottomQuarter1_Choppable_C_2147482330     3
# Tomato_Choppable_C_2147482395                   3
# Tomato_Choppable_C_2147482397                   3
# CarrotTopQuarter1_Choppable_C_2147482328        3
# CarrotTopQuarter1_Choppable_C_2147482326        3
# CarrotTopQuarter2_Choppable_C_2147482325        3
# CarrotBotton_Choppable_C_2147482333             3
# Carrot_Choppable_C_2147482405                   3
# Onion_Choppable_C_2147482392                    3
# Potato_BottomHalf_Choppable_C_2147482339        3
# Meat_Choppable_C_2147482398                     2
# CarrotBottomQuarter2_Choppable_C_2147482329     2
# CarrotTopQuarter2_Choppable_C_2147482327        2
# CarrotBottomQuarter2_Choppable_C_2147482331     2
# Tomato_TopHalf_Choppable_C_2147482346           2
# CarrotBotton_Choppable_C_2147482335             2
# Tomato_TopHalf_Choppable_C_2147482349           2
# Tomato_BottomHalf_Choppable_C_2147482345        2
# Onion_Half2_C_2147482351                        2
# Onion_Half_C_2147482352                         2
# Onion_Peeled_C_2147482353                       2
# Onion_Half_C_2147482356                         2
# Onion_Half2_C_2147482355                        2
# Meat_QuarterRight2_C_2147482361                 2
# Meat_QuarterLeft1_C_2147482360                  2
# Meat_HalfRight_Choppable_C_2147482369           2
# Potato_TopHalf_Choppable_C_2147482340           1
# CarrotTop_Choppable_C_2147482334                1
# Meat_HalfLeft_Choppable_C_2147482364            1
# Meat_HalfLeft_Choppable_C_2147482370            1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 296

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              7  113.078224                  1.0
# 1         Add Beef             76   90.737534                  3.0
# 2         Add Beef              2    0.842926                  0.0
# 3         Add Beef              1    1.869049                  0.0
# 4         Add Beef              4    1.722016                  0.0
# 5        Add Onion             28   29.708679                  0.0
# 6        Add Onion              2    0.953705                  0.0
# 7        Add Onion             17   17.718811                  0.0
# 8        Add Onion              2    0.956298                  0.0
# 9      Add Tomtato             22   25.473359                  1.0
# 10     Add Tomtato              2    0.804565                  0.0
# 11     Add Tomtato              2    0.817963                  0.0
# 12     Add Tomtato              3    4.009644                  0.0
# 13      Add Potato             25   24.834534                  0.0
# 14      Add Potato              2    1.767883                  0.0
# 15      Add Potato              2    0.970153                  0.0
# 16      Add Potato              1    1.811432                  0.0
# 17      Add Carrot             46   59.154663                  5.0
# 18      Add Carrot              2    1.544006                  0.0
# 19      Add Carrot              6    3.568115                  0.0
# 20      Add Carrot              0    0.000000                  0.0
# 21      Add Carrot              3    1.444702                  0.0
# 22      Add Carrot              1    0.155335                  0.0
# 23      Add Carrot              4    1.236695                  0.0
# 24      Add Carrot              0    0.000000                  0.0
# 25        Add Salt              8   11.177124                  2.0
# 26      Add pepper              8   11.198792                  0.0
# 27       Stir Stew             24   34.894287                  2.0
# 28  Post last step             10   38.892822                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 310

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C021',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C021            310        481.343316                       14.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean       10.689655   16.598045             0.482759
# std        16.619918   28.046647             1.153278
# min         0.000000    0.000000             0.000000
# 25%         2.000000    0.956298             0.000000
# 50%         3.000000    1.811432             0.000000
# 75%        10.000000   24.834534             0.000000
# max        76.000000  113.078224             5.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            3       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 9            0       0                     0
# Add Potato                  7            0       0                     0
# Add Carrot                  1            0       6                     8
# Add Salt                    3            0       0                     0
# Stir Stew                  14            4       0                     0
# Add pepper                  0            2       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             5          6                  6
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add pepper                      0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      4     0      0
# Add Beef                     0     10    66      0
# Add Onion                    0     10     7     31
# Add Tomtato                  0      4     0      0
# Add Potato                   0      4     0      0
# Add Carrot                   5     14     2      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
# Add pepper                   0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      19                         0
# Add Carrot                            0       0                         0
# Add Salt                              2       0                         1
# Stir Stew                             1       0                         0
# Add pepper                            3       0                         3
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   6
# Add Beef                   0       0                  80
# Add Onion                  0       0                  49
# Add Tomtato                0      15                  28
# Add Potato                 0       0                  30
# Add Carrot                 0       0                  57
# Add Salt                   0       0                   6
# Stir Stew                  3       0                  22
# Add pepper                 0       0                   8

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   67.103516
# 1       Add Beef      4   95.171525
# 2      Add Onion      4   49.337493
# 3    Add Tomtato      4   31.105531
# 4     Add Potato      4   29.384002
# 5     Pour Broth      1  113.078224
# 6       Add Salt      1   11.177124
# 7     Add pepper      1   11.198792
# 8      Stir Stew      1   34.894287

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0      107.829689      Right Hand Grab                          NaN
# 1      109.251297      Right Hand Grab                    Knife_C_4
# 2      109.529922  Right Hand Released                    Knife_C_4
# 3      110.684769      Right Hand Grab                    Knife_C_4
# 4      114.073799  Right Hand Released                    Knife_C_4
# ..            ...                  ...                          ...
# 333    606.080811  Right Hand Released  NewLadleSimple_C_2147482324
# 334    606.614990      Right Hand Grab                    Knife_C_4
# 335    607.505554  Right Hand Released                    Knife_C_4
# 336    608.634338      Right Hand Grab         BeefStewCookbook_C_0
# 337    623.400818      Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 333                  0.0            NaN
# 334                  0.0            NaN
# 335                  0.0            NaN
# 336                  0.0            NaN
# 337                  0.0            NaN
#
# [338 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        142
# Right Hand Released     91
# Chopped                 50
# Left Hand Grab          17
# Left Hand Released      10
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          3.0
# Left Hand Released      0.0
# Right Hand Grab        11.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           142                       11.0
# 4  Right Hand Released            91                        0.0
# 0              Chopped            50                        0.0
# 1       Left Hand Grab            17                        3.0
# 2   Left Hand Released            10                        0.0
