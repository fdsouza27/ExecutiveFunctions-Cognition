# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C006 D/'
file_name = 'C006_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0     34.581631      Right Hand Grab                       NaN
# 1     35.537132      Right Hand Grab      BeefStewCookbook_C_0
# 2     43.135536      Right Hand Grab                       NaN
# 3     44.013454      Right Hand Grab  BrothParent_C_2147482378
# 4     59.011059  Right Hand Released  BrothParent_C_2147482378

# %%
df1.shape
# Out:
# (216, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    171
# 1     45
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       34.581631  Right Hand Grab               NaN                    1
# 2       43.135536  Right Hand Grab               NaN                    1
# 40     105.335442  Right Hand Grab               NaN                    1
# 63     128.742767  Right Hand Grab               NaN                    1
# 65     131.197510  Right Hand Grab               NaN                    1
# 87     151.638504  Right Hand Grab               NaN                    1
# 88     152.371231  Right Hand Grab               NaN                    1
# 111    174.121796  Right Hand Grab               NaN                    1
# 114    178.455124  Right Hand Grab               NaN                    1
# 127    188.542145   Left Hand Grab               NaN                    1
# 130    192.230835   Left Hand Grab               NaN                    1
# 131    193.219910   Left Hand Grab               NaN                    1
# 132    194.031219   Left Hand Grab               NaN                    1
# 137    197.617706   Left Hand Grab               NaN                    1
# 138    198.695786   Left Hand Grab               NaN                    1
# 140    200.718811  Right Hand Grab               NaN                    1
# 141    201.773605  Right Hand Grab               NaN                    1
# 142    202.439774  Right Hand Grab               NaN                    1
# 143    203.629318  Right Hand Grab               NaN                    1
# 146    206.650040  Right Hand Grab               NaN                    1
# 153    212.382767  Right Hand Grab               NaN                    1
# 154    213.760422  Right Hand Grab               NaN                    1
# 155    214.837250  Right Hand Grab               NaN                    1
# 156    215.303360  Right Hand Grab               NaN                    1
# 157    216.059937  Right Hand Grab               NaN                    1
# 158    216.503418  Right Hand Grab               NaN                    1
# 159    217.059204  Right Hand Grab               NaN                    1
# 162    220.359375  Right Hand Grab               NaN                    1
# 165    221.658524  Right Hand Grab               NaN                    1
# 166    222.324844  Right Hand Grab               NaN                    1
# 167    223.136124  Right Hand Grab               NaN                    1
# 168    223.936035  Right Hand Grab               NaN                    1
# 169    226.279663  Right Hand Grab               NaN                    1
# 170    226.780365  Right Hand Grab               NaN                    1
# 171    227.457611  Right Hand Grab               NaN                    1
# 172    229.790665   Left Hand Grab               NaN                    1
# 184    243.120239   Left Hand Grab               NaN                    1
# 193    253.897263  Right Hand Grab               NaN                    1
# 194    254.764755  Right Hand Grab               NaN                    1
# 195    255.508255  Right Hand Grab               NaN                    1
# 205    280.104279  Right Hand Grab               NaN                    1
# 206    284.824890  Right Hand Grab               NaN                    1
# 209    300.221985  Right Hand Grab               NaN                    1
# 210    300.822144  Right Hand Grab               NaN                    1
# 211    301.655609  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0     34.581631      Right Hand Grab                       NaN
# 1     35.537132      Right Hand Grab      BeefStewCookbook_C_0
# 2     43.135536      Right Hand Grab                       NaN
# 3     44.013454      Right Hand Grab  BrothParent_C_2147482378
# 4     59.011059  Right Hand Released  BrothParent_C_2147482378
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C006 D/'
file_name = 'C006_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     56.523010     Pour Broth
# 1     91.516365       Add Beef
# 2     95.670662       Add Beef
# 3     97.436638       Add Beef
# 4     98.948273       Add Beef
# 5    116.066437      Add Onion
# 6    117.700691      Add Onion
# 7    126.009941      Add Onion
# 8    127.331352      Add Onion
# 9    146.616989    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      34.581631      Right Hand Grab                                    NaN
# 1      35.537132      Right Hand Grab                   BeefStewCookbook_C_0
# 2      43.135536      Right Hand Grab                                    NaN
# 3      44.013454      Right Hand Grab               BrothParent_C_2147482378
# 4      59.011059  Right Hand Released               BrothParent_C_2147482378
# 5      60.109215      Right Hand Grab                   BeefStewCookbook_C_0
# 6      64.277321      Right Hand Grab            Meat_Choppable_C_2147482400
# 7      65.175629  Right Hand Released            Meat_Choppable_C_2147482400
# 8      66.031174       Left Hand Grab            Meat_Choppable_C_2147482400
# 9      66.531570   Left Hand Released            Meat_Choppable_C_2147482400
# 10     69.064255       Left Hand Grab            Meat_Choppable_C_2147482372
# 11     70.719742   Left Hand Released            Meat_Choppable_C_2147482372
# 12     71.762466      Right Hand Grab                              Knife_C_4
# 13     73.485664              Chopped            Meat_Choppable_C_2147482400
# 14     74.151787              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 15     75.040634              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 16     75.829834              Chopped         Meat_QuarterLeft1_C_2147482368
# 17     76.474304              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 18     77.007561              Chopped        Meat_QuarterRight2_C_2147482365
# 19     77.574020              Chopped         Meat_QuarterLeft1_C_2147482368
# 20     78.084831              Chopped            Meat_Choppable_C_2147482372
# 21     78.996185              Chopped  Meat_HalfRight_Choppable_C_2147482363
# 22     79.895927              Chopped         Meat_QuarterLeft2_C_2147482367
# 23     80.461937              Chopped        Meat_QuarterRight1_C_2147482366
# 24     81.595436  Right Hand Released                              Knife_C_4
# 25     85.929337      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482363
# 26     87.584114  Right Hand Released  Meat_HalfRight_Choppable_C_2147482363
# 27     88.605446      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482364
# 28     89.604477  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482364
# 29     90.349602      Right Hand Grab        Meat_QuarterRight1_C_2147482366
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (244, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       34.581631      Right Hand Grab                                    NaN
# 1       35.537132      Right Hand Grab                   BeefStewCookbook_C_0
# 2       43.135536      Right Hand Grab                                    NaN
# 3       44.013454      Right Hand Grab               BrothParent_C_2147482378
# 216     56.523010                  NaN                                    NaN
# 4       59.011059  Right Hand Released               BrothParent_C_2147482378
# 5       60.109215      Right Hand Grab                   BeefStewCookbook_C_0
# 6       64.277321      Right Hand Grab            Meat_Choppable_C_2147482400
# 7       65.175629  Right Hand Released            Meat_Choppable_C_2147482400
# 8       66.031174       Left Hand Grab            Meat_Choppable_C_2147482400
# 9       66.531570   Left Hand Released            Meat_Choppable_C_2147482400
# 10      69.064255       Left Hand Grab            Meat_Choppable_C_2147482372
# 11      70.719742   Left Hand Released            Meat_Choppable_C_2147482372
# 12      71.762466      Right Hand Grab                              Knife_C_4
# 13      73.485664              Chopped            Meat_Choppable_C_2147482400
# 14      74.151787              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 15      75.040634              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 16      75.829834              Chopped         Meat_QuarterLeft1_C_2147482368
# 17      76.474304              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 18      77.007561              Chopped        Meat_QuarterRight2_C_2147482365
# 19      77.574020              Chopped         Meat_QuarterLeft1_C_2147482368
# 20      78.084831              Chopped            Meat_Choppable_C_2147482372
# 21      78.996185              Chopped  Meat_HalfRight_Choppable_C_2147482363
# 22      79.895927              Chopped         Meat_QuarterLeft2_C_2147482367
# 23      80.461937              Chopped        Meat_QuarterRight1_C_2147482366
# 24      81.595436  Right Hand Released                              Knife_C_4
# 25      85.929337      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482363
# 26      87.584114  Right Hand Released  Meat_HalfRight_Choppable_C_2147482363
# 27      88.605446      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482364
# 28      89.604477  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482364
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 216                  NaN     Pour Broth
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C006D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        99
# Right Hand Released    52
# Chopped                38
# Left Hand Grab         18
# Left Hand Released      9
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     43.200000
# std      35.435858
# min       9.000000
# 25%      18.000000
# 50%      38.000000
# 75%      52.000000
# max      99.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 216

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      18
# BeefStewCookbook_C_0                           10
# PepperShakerGrabableSimple_C_2147482376         6
# Meat_Choppable_C_2147482400                     5
# CarrotBottomQuarter2_Choppable_C_2147482334     5
# Potato_TopHalf_Choppable_C_2147482345           5
# Meat_QuarterLeft1_C_2147482368                  4
# Potato_BottomHalf_Choppable_C_2147482342        3
# Tomato_BottomHalf_Choppable_C_2147482351        3
# Tomato_Choppable_C_2147482397                   3
# Potato_Choppable_C_2147482410                   3
# CarrotBottomQuarter1_Choppable_C_2147482331     3
# Carrot_Choppable_C_2147482402                   3
# Carrot_Choppable_C_2147482341                   3
# Onion_Choppable_C_2147482361                    3
# Carrot_Choppable_C_2147482405                   3
# Carrot_Choppable_C_2147482329                   3
# Tomato_Choppable_C_2147482395                   3
# Potato_Choppable_C_2147482347                   3
# Meat_HalfRight_Choppable_C_2147482363           3
# Meat_QuarterRight2_C_2147482365                 3
# Meat_QuarterLeft2_C_2147482367                  3
# Meat_Choppable_C_2147482372                     3
# Meat_QuarterRight1_C_2147482366                 3
# Onion_Choppable_C_2147482392                    3
# CarrotBotton_Choppable_C_2147482327             2
# CarrotTopQuarter1_Choppable_C_2147482337        2
# CarrotTopQuarter2_Choppable_C_2147482336        2
# CarrotBottomQuarter1_Choppable_C_2147482335     2
# CarrotBottomQuarter2_Choppable_C_2147482330     2
# Onion_Peeled_C_2147482356                       2
# Meat_Choppable_C_2147482398                     2
# CarrotBottomQuarter1_Choppable_C_2147482326     2
# Meat_HalfRight_Choppable_C_2147482369           2
# CarrotBottomQuarter2_Choppable_C_2147482320     2
# SaltShakerGrabableSimple_C_2147482377           2
# StirSpoonSimple_C_2147482380                    2
# NewLadleSimple_C_2147482319                     2
# CarrotBottomQuarter2_Choppable_C_2147482325     2
# Meat_Choppable_C_2147482362                     2
# Onion_Half2_C_2147482354                        2
# CarrotBotton_Choppable_C_2147482332             2
# Onion_Half_C_2147482355                         2
# Onion_Half_C_2147482359                         2
# Onion_Half2_C_2147482358                        2
# Onion_Peeled_C_2147482360                       2
# Tomato_BottomHalf_Choppable_C_2147482348        2
# Tomato_TopHalf_Choppable_C_2147482349           2
# Tomato_TopHalf_Choppable_C_2147482352           2
# BrothParent_C_2147482378                        2
# Meat_Choppable_C_2147482371                     2
# Meat_HalfLeft_Choppable_C_2147482364            2
# Potato_TopHalf_Choppable_C_2147482343           2
# Potato_BottomHalf_Choppable_C_2147482344        2
# CarrotBotton_Choppable_C_2147482338             2
# Meat_HalfLeft_Choppable_C_2147482370            1
# CarrotBotton_Choppable_C_2147482322             1
# CarrotTop_Choppable_C_2147482339                1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 171

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              4   21.941379                  2.0
# 1         Add Beef             27   32.505306                  0.0
# 2         Add Beef              2    3.131928                  0.0
# 3         Add Beef              2    0.921295                  0.0
# 4         Add Beef              2    0.855530                  0.0
# 5        Add Onion             13   16.429543                  1.0
# 6        Add Onion              2    1.023201                  0.0
# 7        Add Onion              9    7.055572                  0.0
# 8        Add Onion              2    0.811203                  0.0
# 9      Add Tomtato             18   17.874222                  2.0
# 10     Add Tomtato              4    1.512741                  0.0
# 11     Add Tomtato              0    0.000000                  0.0
# 12     Add Tomtato              2    0.745606                  0.0
# 13      Add Potato             17   15.141342                  2.0
# 14      Add Potato              4    1.156128                  0.0
# 15      Add Potato              0    0.000000                  0.0
# 16      Add Potato              2    0.839905                  0.0
# 17      Add Carrot             30   29.106445                  8.0
# 18      Add Carrot              6    5.198196                  4.0
# 19      Add Carrot              5    3.466079                  1.0
# 20      Add Carrot              2    0.977402                  0.0
# 21      Add Carrot              9    6.775924                  7.0
# 22      Add Carrot             20   19.151398                  9.0
# 23      Add Carrot              2    1.110794                  0.0
# 24      Add Carrot              9    8.099442                  1.0
# 25        Add Salt              7   13.575149                  3.0
# 26      Add pepper              2    5.944031                  0.0
# 27       Stir Stew              6   18.320770                  2.0
# 28  Post last step              8   24.938690                  3.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 216

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C006',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C006            216        258.609221                       45.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.448276    8.917559             1.551724
# std         7.890257    9.750825             2.515469
# min         0.000000    0.000000             0.000000
# 25%         2.000000    0.977402             0.000000
# 50%         4.000000    5.198196             0.000000
# 75%         9.000000   16.429543             2.000000
# max        30.000000   32.505306             9.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 3            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0      12                     7
# Add Salt                    1            0       0                     0
# Add pepper                  0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                     11             7          1                  2
# Add Salt                        0             0          0                  0
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      2    29      0
# Add Onion                    0      4     2     18
# Add Tomtato                  0      4     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   2      6     4      0
# Add Salt                     0      0     0      0
# Add pepper                   0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      18                         0
# Add Carrot                            0       0                         0
# Add Salt                              2       0                         1
# Add pepper                            1       0                         1
# Stir Stew                             3       0                         0
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  33
# Add Onion                  0       0                  25
# Add Tomtato                0      15                  22
# Add Potato                 0       0                  21
# Add Carrot                 0       0                  53
# Add Salt                   0       0                   4
# Add pepper                 0       0                   2
# Stir Stew                  1       0                   4

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   73.885680
# 1       Add Beef      4   37.414059
# 2      Add Onion      4   25.319519
# 3    Add Tomtato      4   20.132569
# 4     Add Potato      4   17.137375
# 5     Pour Broth      1   21.941379
# 6       Add Salt      1   13.575149
# 7     Add pepper      1    5.944031
# 8      Stir Stew      1   18.320770

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0       34.581631      Right Hand Grab                          NaN
# 1       35.537132      Right Hand Grab         BeefStewCookbook_C_0
# 2       43.135536      Right Hand Grab                          NaN
# 3       44.013454      Right Hand Grab     BrothParent_C_2147482378
# 4       56.523010                  NaN                          NaN
# ..            ...                  ...                          ...
# 239    301.655609      Right Hand Grab                          NaN
# 240    302.288971      Right Hand Grab         BeefStewCookbook_C_0
# 241    306.842743      Right Hand Grab  NewLadleSimple_C_2147482319
# 242    316.605743  Right Hand Released  NewLadleSimple_C_2147482319
# 243    323.851044      Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    NaN     Pour Broth
# ..                   ...            ...
# 239                  1.0            NaN
# 240                  0.0            NaN
# 241                  0.0            NaN
# 242                  0.0            NaN
# 243                  0.0            NaN
#
# [244 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        99
# Right Hand Released    52
# Chopped                38
# Left Hand Grab         18
# Left Hand Released      9
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          8.0
# Left Hand Released      0.0
# Right Hand Grab        37.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            99                       37.0
# 4  Right Hand Released            52                        0.0
# 0              Chopped            38                        0.0
# 1       Left Hand Grab            18                        8.0
# 2   Left Hand Released             9                        0.0
