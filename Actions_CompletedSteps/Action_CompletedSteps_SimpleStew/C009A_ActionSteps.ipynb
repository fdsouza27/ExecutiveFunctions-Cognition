# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C009 A/'
file_name = 'C009_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object
# 0     11.630137      Right Hand Grab           BeefStewCookbook_C_0
# 1     25.549326      Right Hand Grab                            NaN
# 2     25.571157       Left Hand Grab                            NaN
# 3     26.293394      Right Hand Grab  Carrot_Choppable_C_2147482390
# 4     27.483513  Right Hand Released  Carrot_Choppable_C_2147482390

# %%
df1.shape
# Out:
# (344, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    328
# 1     16
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       25.549326  Right Hand Grab               NaN                    1
# 2       25.571157   Left Hand Grab               NaN                    1
# 7       32.958195  Right Hand Grab               NaN                    1
# 32      71.898613   Left Hand Grab               NaN                    1
# 94     199.073441   Left Hand Grab               NaN                    1
# 108    206.614563  Right Hand Grab               NaN                    1
# 174    248.586929   Left Hand Grab               NaN                    1
# 333    493.617279  Right Hand Grab               NaN                    1
# 334    495.228271  Right Hand Grab               NaN                    1
# 335    496.602692  Right Hand Grab               NaN                    1
# 336    497.842255  Right Hand Grab               NaN                    1
# 337    498.735504  Right Hand Grab               NaN                    1
# 339    505.018921  Right Hand Grab               NaN                    1
# 340    505.757050  Right Hand Grab               NaN                    1
# 341    506.693298  Right Hand Grab               NaN                    1
# 342    508.240906  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object  \
# 0     11.630137      Right Hand Grab           BeefStewCookbook_C_0
# 1     25.549326      Right Hand Grab                            NaN
# 2     25.571157       Left Hand Grab                            NaN
# 3     26.293394      Right Hand Grab  Carrot_Choppable_C_2147482390
# 4     27.483513  Right Hand Released  Carrot_Choppable_C_2147482390
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C009 A/'
file_name = 'C009_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    132.931732     Pour Broth
# 1    167.333527       Add Beef
# 2    181.775299       Add Beef
# 3    186.030533       Add Beef
# 4    194.727142       Add Beef
# 5    219.048080       Add Beef
# 6    221.667404       Add Beef
# 7    259.994415       Add Beef
# 8    264.727051       Add Beef
# 9    280.281830    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type              Interacted Object  \
# 0      11.630137      Right Hand Grab           BeefStewCookbook_C_0
# 1      25.549326      Right Hand Grab                            NaN
# 2      25.571157       Left Hand Grab                            NaN
# 3      26.293394      Right Hand Grab  Carrot_Choppable_C_2147482390
# 4      27.483513  Right Hand Released  Carrot_Choppable_C_2147482390
# 5      29.180662      Right Hand Grab  Carrot_Choppable_C_2147482362
# 6      30.393549  Right Hand Released  Carrot_Choppable_C_2147482362
# 7      32.958195      Right Hand Grab                            NaN
# 8      33.843800      Right Hand Grab   Onion_Choppable_C_2147482377
# 9      34.902565  Right Hand Released   Onion_Choppable_C_2147482377
# 10     35.948563      Right Hand Grab   Onion_Choppable_C_2147482360
# 11     36.970200  Right Hand Released   Onion_Choppable_C_2147482360
# 12     40.727089       Left Hand Grab  Potato_Choppable_C_2147482398
# 13     40.727089      Right Hand Grab           BeefStewCookbook_C_0
# 14     41.959503      Right Hand Grab           BeefStewCookbook_C_0
# 15     42.837021      Right Hand Grab           BeefStewCookbook_C_0
# 16     43.908356      Right Hand Grab  Potato_Choppable_C_2147482396
# 17     45.725399  Right Hand Released  Potato_Choppable_C_2147482396
# 18     45.758987   Left Hand Released  Potato_Choppable_C_2147482398
# 19     49.479607       Left Hand Grab           BeefStewCookbook_C_0
# 20     49.490475      Right Hand Grab  Tomato_Choppable_C_2147482385
# 21     51.002472       Left Hand Grab           BeefStewCookbook_C_0
# 22     51.957211       Left Hand Grab           BeefStewCookbook_C_0
# 23     52.611168  Right Hand Released  Tomato_Choppable_C_2147482385
# 24     53.646328       Left Hand Grab           BeefStewCookbook_C_0
# 25     53.713421      Right Hand Grab  Tomato_Choppable_C_2147482385
# 26     55.577000  Right Hand Released  Tomato_Choppable_C_2147482385
# 27     56.544498       Left Hand Grab           BeefStewCookbook_C_0
# 28     57.573566       Left Hand Grab  Tomato_Choppable_C_2147482356
# 29     58.932465   Left Hand Released  Tomato_Choppable_C_2147482356
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   1.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (372, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type              Interacted Object  \
# 0      11.630137      Right Hand Grab           BeefStewCookbook_C_0
# 1      25.549326      Right Hand Grab                            NaN
# 2      25.571157       Left Hand Grab                            NaN
# 3      26.293394      Right Hand Grab  Carrot_Choppable_C_2147482390
# 4      27.483513  Right Hand Released  Carrot_Choppable_C_2147482390
# 5      29.180662      Right Hand Grab  Carrot_Choppable_C_2147482362
# 6      30.393549  Right Hand Released  Carrot_Choppable_C_2147482362
# 7      32.958195      Right Hand Grab                            NaN
# 8      33.843800      Right Hand Grab   Onion_Choppable_C_2147482377
# 9      34.902565  Right Hand Released   Onion_Choppable_C_2147482377
# 10     35.948563      Right Hand Grab   Onion_Choppable_C_2147482360
# 11     36.970200  Right Hand Released   Onion_Choppable_C_2147482360
# 12     40.727089       Left Hand Grab  Potato_Choppable_C_2147482398
# 13     40.727089      Right Hand Grab           BeefStewCookbook_C_0
# 14     41.959503      Right Hand Grab           BeefStewCookbook_C_0
# 15     42.837021      Right Hand Grab           BeefStewCookbook_C_0
# 16     43.908356      Right Hand Grab  Potato_Choppable_C_2147482396
# 17     45.725399  Right Hand Released  Potato_Choppable_C_2147482396
# 18     45.758987   Left Hand Released  Potato_Choppable_C_2147482398
# 19     49.479607       Left Hand Grab           BeefStewCookbook_C_0
# 20     49.490475      Right Hand Grab  Tomato_Choppable_C_2147482385
# 21     51.002472       Left Hand Grab           BeefStewCookbook_C_0
# 22     51.957211       Left Hand Grab           BeefStewCookbook_C_0
# 23     52.611168  Right Hand Released  Tomato_Choppable_C_2147482385
# 24     53.646328       Left Hand Grab           BeefStewCookbook_C_0
# 25     53.713421      Right Hand Grab  Tomato_Choppable_C_2147482385
# 26     55.577000  Right Hand Released  Tomato_Choppable_C_2147482385
# 27     56.544498       Left Hand Grab           BeefStewCookbook_C_0
# 28     57.573566       Left Hand Grab  Tomato_Choppable_C_2147482356
# 29     58.932465   Left Hand Released  Tomato_Choppable_C_2147482356
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   1.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
#df.to_csv('act_step_C009A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        127
# Right Hand Released     99
# Left Hand Grab          48
# Chopped                 37
# Left Hand Released      33
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.00000
# mean      68.80000
# std       41.90704
# min       33.00000
# 25%       37.00000
# 50%       48.00000
# 75%       99.00000
# max      127.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 344

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                68
# BeefStewCookbook_C_0                     23
# Onion_Peeled_C_2147482330                12
# Tomato_TopHalf_Choppable_C_2147482346    10
# Tomato_Choppable_C_2147482385             9
#                                          ..
# Meat_HalfLeft_Choppable_C_2147482337      1
# Meat_Choppable_C_2147482327               1
# CarrotTop_Choppable_C_2147482301          1
# Tomato_TopHalf_Choppable_C_2147482314     1
# Meat_HalfLeft_Choppable_C_2147482329      1
# Name: count, Length: 72, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 328

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             42  121.301595                  4.0
# 1         Add Beef             22   33.768998                  0.0
# 2         Add Beef              9   13.363830                  0.0
# 3         Add Beef              8    3.304444                  0.0
# 4         Add Beef              8    6.597854                  0.0
# 5         Add Beef             39   22.309967                  2.0
# 6         Add Beef              4    1.110000                  0.0
# 7         Add Beef             58   37.281219                  1.0
# 8         Add Beef              5    3.277619                  0.0
# 9      Add Tomtato              3   11.055054                  0.0
# 10     Add Tomtato              2    1.266144                  0.0
# 11     Add Tomtato             17   10.329284                  0.0
# 12     Add Tomtato             10    7.088409                  0.0
# 13      Add Potato             10   11.530487                  0.0
# 14      Add Potato              4    4.199829                  0.0
# 15      Add Potato             11    9.070374                  0.0
# 16      Add Potato              2    2.216034                  0.0
# 17      Add Carrot             18   16.860077                  0.0
# 18      Add Carrot              2    1.241425                  0.0
# 19      Add Carrot             19   23.846528                  0.0
# 20      Add Carrot              2    1.200043                  0.0
# 21      Add Carrot              9    9.740997                  0.0
# 22      Add Carrot              2    1.466980                  0.0
# 23      Add Carrot              9    7.699524                  0.0
# 24      Add Carrot              2    1.097778                  0.0
# 25        Add Salt              2    9.573608                  0.0
# 26      Add pepper              6    8.732483                  0.0
# 27       Stir Stew              2   15.163849                  0.0
# 28  Post last step             17   55.182984                  9.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 344

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C009',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C009            344        450.877417                       16.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean       11.862069   15.547497             0.551724
# std        13.550762   23.868704             1.824167
# min         2.000000    1.097778             0.000000
# 25%         2.000000    3.277619             0.000000
# 50%         8.000000    9.070374             0.000000
# 75%        17.000000   15.163849             0.000000
# max        58.000000  121.301595             9.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                 14            2       4                     0
# Add Beef                    3            2       0                     0
# Add Tomtato                 2            0       0                     0
# Add Potato                  1            0       4                     0
# Add Carrot                  1            0       8                     4
# Add Salt                    1            0       0                     0
# Stir Stew                   0            0       0                     0
# Add pepper                  0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             8          6                  4
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add pepper                      0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      2     0      4
# Add Beef                     0     38    87      5
# Add Tomtato                  0      6     0      6
# Add Potato                   0      8     0      0
# Add Carrot                   6     14     0      2
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
# Add pepper                   0      0     0      4
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       4                         0
# Add Beef                              0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      14                         0
# Add Carrot                            0       0                         2
# Add Salt                              0       0                         1
# Stir Stew                             1       0                         0
# Add pepper                            1       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 2       6                  38
# Add Beef                   0      15                 150
# Add Tomtato                0      18                  32
# Add Potato                 0       0                  27
# Add Carrot                 4       0                  63
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   2
# Add pepper                 0       0                   6

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8  121.013931
# 1     Add Carrot      8   63.153352
# 2    Add Tomtato      4   29.738891
# 3     Add Potato      4   27.016724
# 4     Pour Broth      1  121.301595
# 5       Add Salt      1    9.573608
# 6     Add pepper      1    8.732483
# 7      Stir Stew      1   15.163849

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0       11.630137      Right Hand Grab           BeefStewCookbook_C_0
# 1       25.549326      Right Hand Grab                            NaN
# 2       25.571157       Left Hand Grab                            NaN
# 3       26.293394      Right Hand Grab  Carrot_Choppable_C_2147482390
# 4       27.483513  Right Hand Released  Carrot_Choppable_C_2147482390
# ..            ...                  ...                            ...
# 367    505.018921      Right Hand Grab                            NaN
# 368    505.757050      Right Hand Grab                            NaN
# 369    506.693298      Right Hand Grab                            NaN
# 370    508.240906      Right Hand Grab                            NaN
# 371    509.974518      Right Hand Grab                       oven_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 367                  1.0            NaN
# 368                  1.0            NaN
# 369                  1.0            NaN
# 370                  1.0            NaN
# 371                  0.0            NaN
#
# [372 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        127
# Right Hand Released     99
# Left Hand Grab          48
# Chopped                 37
# Left Hand Released      33
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          4.0
# Left Hand Released      0.0
# Right Hand Grab        12.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           127                       12.0
# 4  Right Hand Released            99                        0.0
# 1       Left Hand Grab            48                        4.0
# 0              Chopped            37                        0.0
# 2   Left Hand Released            33                        0.0
