# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C017 A/'
file_name = 'C017_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object
# 0     72.244995      Right Hand Grab                            NaN
# 1     72.755096       Left Hand Grab                            NaN
# 2    105.258324      Right Hand Grab           BeefStewCookbook_C_0
# 3    120.988869      Right Hand Grab  Carrot_Choppable_C_2147482402
# 4    121.533417  Right Hand Released  Carrot_Choppable_C_2147482402

# %%
df1.shape
# Out:
# (218, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    206
# 1     12
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       72.244995  Right Hand Grab               NaN                    1
# 1       72.755096   Left Hand Grab               NaN                    1
# 5      129.465332  Right Hand Grab               NaN                    1
# 13     153.816269  Right Hand Grab               NaN                    1
# 33     181.523376   Left Hand Grab               NaN                    1
# 78     229.577667  Right Hand Grab               NaN                    1
# 79     231.668930  Right Hand Grab               NaN                    1
# 118    282.356812  Right Hand Grab               NaN                    1
# 126    294.643494   Left Hand Grab               NaN                    1
# 148    317.875549   Left Hand Grab               NaN                    1
# 161    329.429535  Right Hand Grab               NaN                    1
# 163    334.182098   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type              Interacted Object  \
# 0     72.244995      Right Hand Grab                            NaN
# 1     72.755096       Left Hand Grab                            NaN
# 2    105.258324      Right Hand Grab           BeefStewCookbook_C_0
# 3    120.988869      Right Hand Grab  Carrot_Choppable_C_2147482402
# 4    121.533417  Right Hand Released  Carrot_Choppable_C_2147482402
#
#    Missed Interactions
# 0                    1
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C017 A/'
file_name = 'C017_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    146.096603     Pour Broth
# 1    178.255646       Add Beef
# 2    193.464767       Add Beef
# 3    195.537949       Add Beef
# 4    197.150955       Add Beef
# 5    260.241211      Add Onion
# 6    260.319519      Add Onion
# 7    274.315613      Add Onion
# 8    274.337921      Add Onion
# 9    297.226074    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      72.244995      Right Hand Grab                                    NaN
# 1      72.755096       Left Hand Grab                                    NaN
# 2     105.258324      Right Hand Grab                   BeefStewCookbook_C_0
# 3     120.988869      Right Hand Grab          Carrot_Choppable_C_2147482402
# 4     121.533417  Right Hand Released          Carrot_Choppable_C_2147482402
# 5     129.465332      Right Hand Grab                                    NaN
# 6     130.395279      Right Hand Grab               BrothParent_C_2147482378
# 7     133.101151  Right Hand Released               BrothParent_C_2147482378
# 8     135.330948      Right Hand Grab               BrothParent_C_2147482378
# 9     147.085709  Right Hand Released               BrothParent_C_2147482378
# 10    147.518921      Right Hand Grab                   BeefStewCookbook_C_0
# 11    148.341156      Right Hand Grab               BrothParent_C_2147482378
# 12    152.005295  Right Hand Released               BrothParent_C_2147482378
# 13    153.816269      Right Hand Grab                                    NaN
# 14    158.949265       Left Hand Grab            Meat_Choppable_C_2147482400
# 15    160.165710   Left Hand Released            Meat_Choppable_C_2147482400
# 16    161.257355      Right Hand Grab                              Knife_C_4
# 17    165.772064              Chopped            Meat_Choppable_C_2147482400
# 18    166.105042  Right Hand Released                              Knife_C_4
# 19    167.125870      Right Hand Grab                              Knife_C_4
# 20    168.014481              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 21    169.411346              Chopped        Meat_QuarterRight2_C_2147482368
# 22    170.021011  Right Hand Released                              Knife_C_4
# 23    171.209381      Right Hand Grab                              Knife_C_4
# 24    172.638046  Right Hand Released                              Knife_C_4
# 25    175.421097      Right Hand Grab        Meat_QuarterRight1_C_2147482369
# 26    176.252380       Left Hand Grab   Meat_HalfLeft_Choppable_C_2147482371
# 27    178.067276  Right Hand Released        Meat_QuarterRight1_C_2147482369
# 28    178.088684   Left Hand Released   Meat_HalfLeft_Choppable_C_2147482371
# 29    179.089508      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482371
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   1.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   1.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  1.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (245, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       72.244995      Right Hand Grab                                    NaN
# 1       72.755096       Left Hand Grab                                    NaN
# 2      105.258324      Right Hand Grab                   BeefStewCookbook_C_0
# 3      120.988869      Right Hand Grab          Carrot_Choppable_C_2147482402
# 4      121.533417  Right Hand Released          Carrot_Choppable_C_2147482402
# 5      129.465332      Right Hand Grab                                    NaN
# 6      130.395279      Right Hand Grab               BrothParent_C_2147482378
# 7      133.101151  Right Hand Released               BrothParent_C_2147482378
# 8      135.330948      Right Hand Grab               BrothParent_C_2147482378
# 218    146.096603                  NaN                                    NaN
# 9      147.085709  Right Hand Released               BrothParent_C_2147482378
# 10     147.518921      Right Hand Grab                   BeefStewCookbook_C_0
# 11     148.341156      Right Hand Grab               BrothParent_C_2147482378
# 12     152.005295  Right Hand Released               BrothParent_C_2147482378
# 13     153.816269      Right Hand Grab                                    NaN
# 14     158.949265       Left Hand Grab            Meat_Choppable_C_2147482400
# 15     160.165710   Left Hand Released            Meat_Choppable_C_2147482400
# 16     161.257355      Right Hand Grab                              Knife_C_4
# 17     165.772064              Chopped            Meat_Choppable_C_2147482400
# 18     166.105042  Right Hand Released                              Knife_C_4
# 19     167.125870      Right Hand Grab                              Knife_C_4
# 20     168.014481              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 21     169.411346              Chopped        Meat_QuarterRight2_C_2147482368
# 22     170.021011  Right Hand Released                              Knife_C_4
# 23     171.209381      Right Hand Grab                              Knife_C_4
# 24     172.638046  Right Hand Released                              Knife_C_4
# 25     175.421097      Right Hand Grab        Meat_QuarterRight1_C_2147482369
# 26     176.252380       Left Hand Grab   Meat_HalfLeft_Choppable_C_2147482371
# 27     178.067276  Right Hand Released        Meat_QuarterRight1_C_2147482369
# 28     178.088684   Left Hand Released   Meat_HalfLeft_Choppable_C_2147482371
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    1.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 218                  NaN     Pour Broth
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   1.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C017A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        77
# Right Hand Released    60
# Left Hand Grab         30
# Chopped                27
# Left Hand Released     24
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     43.600000
# std      23.607202
# min      24.000000
# 25%      27.000000
# 50%      30.000000
# 75%      60.000000
# max      77.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 218

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      44
# Meat_HalfLeft_Choppable_C_2147482371           11
# BeefStewCookbook_C_0                           10
# BrothParent_C_2147482378                        6
# Meat_QuarterRight2_C_2147482368                 5
# Meat_QuarterLeft1_C_2147482367                  5
# NewLadleSimple_C_2147482322                     4
# Meat_QuarterLeft2_C_2147482366                  4
# CarrotTopQuarter1_Choppable_C_2147482324        4
# PepperShakerGrabableSimple_C_2147482376         4
# Meat_QuarterLeft1_C_2147482360                  4
# Onion_Choppable_C_2147482392                    4
# Potato_Choppable_C_2147482410                   3
# Carrot_Choppable_C_2147482401                   3
# Carrot_Choppable_C_2147482403                   3
# Tomato_BottomHalf_Choppable_C_2147482343        3
# Tomato_Choppable_C_2147482348                   3
# CarrotBotton_Choppable_C_2147482333             3
# Tomato_Choppable_C_2147482397                   3
# CarrotTop_Choppable_C_2147482334                3
# Onion_Choppable_C_2147482358                    3
# Onion_Choppable_C_2147482388                    3
# Meat_QuarterLeft2_C_2147482359                  3
# Meat_Choppable_C_2147482398                     3
# Meat_Choppable_C_2147482400                     3
# Potato_Choppable_C_2147482408                   3
# CarrotTopQuarter2_Choppable_C_2147482327        2
# CarrotBottomQuarter2_Choppable_C_2147482325     2
# CarrotBottomQuarter2_Choppable_C_2147482329     2
# CarrotTopQuarter1_Choppable_C_2147482328        2
# CarrotBottomQuarter1_Choppable_C_2147482330     2
# Potato_BottomHalf_Choppable_C_2147482337        2
# CarrotBottomQuarter1_Choppable_C_2147482326     2
# CarrotTopQuarter2_Choppable_C_2147482323        2
# CarrotBotton_Choppable_C_2147482331             2
# SaltShakerGrabableSimple_C_2147482377           2
# StirSpoonSimple_C_2147482380                    2
# Potato_TopHalf_Choppable_C_2147482338           2
# Tomato_BottomHalf_Choppable_C_2147482346        2
# Potato_TopHalf_Choppable_C_2147482341           2
# Onion_Half2_C_2147482350                        2
# Meat_QuarterRight1_C_2147482369                 2
# Meat_QuarterRight1_C_2147482362                 2
# Meat_QuarterRight2_C_2147482361                 2
# Onion_Half_C_2147482355                         2
# Potato_BottomHalf_Choppable_C_2147482340        2
# Onion_Half2_C_2147482354                        2
# Onion_Half_C_2147482351                         2
# Onion_Choppable_C_2147482357                    2
# Carrot_Choppable_C_2147482402                   2
# Tomato_TopHalf_Choppable_C_2147482347           2
# Tomato_TopHalf_Choppable_C_2147482344           2
# Onion_Peeled_C_2147482352                       1
# CarrotTop_Choppable_C_2147482332                1
# Onion_Peeled_C_2147482356                       1
# Meat_HalfLeft_Choppable_C_2147482364            1
# Meat_HalfRight_Choppable_C_2147482363           1
# Meat_HalfRight_Choppable_C_2147482370           1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 206

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              9   73.851608                  3.0
# 1         Add Beef             20   31.169937                  1.0
# 2         Add Beef             25   14.375259                  1.0
# 3         Add Beef              2    1.106354                  0.0
# 4         Add Beef              2    1.247833                  0.0
# 5        Add Onion             41   57.337326                  2.0
# 6        Add Onion              0    0.000000                  0.0
# 7        Add Onion             16   11.431275                  0.0
# 8        Add Onion              0    0.000000                  0.0
# 9      Add Tomtato             16   21.813354                  2.0
# 10     Add Tomtato              0    0.000000                  0.0
# 11     Add Tomtato             10    6.954315                  0.0
# 12     Add Tomtato              0    0.000000                  0.0
# 13      Add Potato             11   12.745178                  1.0
# 14      Add Potato              0    0.000000                  0.0
# 15      Add Potato              9    5.359101                  0.0
# 16      Add Potato              0    0.000000                  0.0
# 17      Add Carrot             26   28.717560                  2.0
# 18      Add Carrot              0    0.000000                  0.0
# 19      Add Carrot              4    1.368500                  0.0
# 20      Add Carrot              0    0.000000                  0.0
# 21      Add Carrot              4    1.545014                  0.0
# 22      Add Carrot              4    1.921997                  0.0
# 23      Add Carrot              0    0.000000                  0.0
# 24      Add Carrot              2    1.678559                  0.0
# 25      Add pepper              4    9.508789                  0.0
# 26        Add Salt              4    7.267639                  0.0
# 27       Stir Stew              2    9.513427                  0.0
# 28  Post last step              7   36.816712                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 218

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C017',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C017            218        335.729737                       12.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.517241   11.576887             0.413793
# std         9.970029   18.231269             0.824502
# min         0.000000    0.000000             0.000000
# 25%         0.000000    0.000000             0.000000
# 50%         4.000000    1.921997             0.000000
# 75%        10.000000   12.745178             0.000000
# max        41.000000   73.851608             3.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            3       2                     0
# Add Beef                    1            3       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 3            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             5          4                  6
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0     12    31      0
# Add Onion                    0     18    16     20
# Add Tomtato                  0      4     0      2
# Add Potato                   0      4     0      0
# Add Carrot                   4      4     0      0
# Add pepper                   0      2     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      14                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              3       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   6
# Add Beef                   0       0                  47
# Add Onion                  0       0                  55
# Add Tomtato                0      15                  24
# Add Potato                 0       0                  19
# Add Carrot                 0       0                  38
# Add pepper                 0       0                   4
# Add Salt                   0       0                   4
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   35.231630
# 1       Add Beef      4   47.899383
# 2      Add Onion      4   68.768601
# 3    Add Tomtato      4   28.767669
# 4     Add Potato      4   18.104279
# 5     Pour Broth      1   73.851608
# 6     Add pepper      1    9.508789
# 7       Add Salt      1    7.267639
# 8      Stir Stew      1    9.513427

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0       72.244995      Right Hand Grab                            NaN
# 1       72.755096       Left Hand Grab                            NaN
# 2      105.258324      Right Hand Grab           BeefStewCookbook_C_0
# 3      120.988869      Right Hand Grab  Carrot_Choppable_C_2147482402
# 4      121.533417  Right Hand Released  Carrot_Choppable_C_2147482402
# ..            ...                  ...                            ...
# 240    413.613464      Right Hand Grab    NewLadleSimple_C_2147482322
# 241    422.844971  Right Hand Released    NewLadleSimple_C_2147482322
# 242    423.877045      Right Hand Grab    NewLadleSimple_C_2147482322
# 243    427.687317  Right Hand Released    NewLadleSimple_C_2147482322
# 244    443.628693      Right Hand Grab                       Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 240                  0.0            NaN
# 241                  0.0            NaN
# 242                  0.0            NaN
# 243                  0.0            NaN
# 244                  0.0            NaN
#
# [245 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        77
# Right Hand Released    60
# Left Hand Grab         30
# Chopped                27
# Left Hand Released     24
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         5.0
# Left Hand Released     0.0
# Right Hand Grab        7.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            77                        7.0
# 4  Right Hand Released            60                        0.0
# 1       Left Hand Grab            30                        5.0
# 0              Chopped            27                        0.0
# 2   Left Hand Released            24                        0.0
