# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C020 D/'
file_name = 'C020_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time         Action Type              Interacted Object
# 0     66.685890     Right Hand Grab           BeefStewCookbook_C_0
# 1     73.096657      Left Hand Grab  Carrot_Choppable_C_2147482401
# 2     75.129433  Left Hand Released  Carrot_Choppable_C_2147482401
# 3     77.962234      Left Hand Grab  Carrot_Choppable_C_2147482401
# 4     81.206512  Left Hand Released  Carrot_Choppable_C_2147482401

# %%
df1.shape
# Out:
# (212, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    211
# 1      1
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 210    427.779327  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time         Action Type              Interacted Object  \
# 0     66.685890     Right Hand Grab           BeefStewCookbook_C_0
# 1     73.096657      Left Hand Grab  Carrot_Choppable_C_2147482401
# 2     75.129433  Left Hand Released  Carrot_Choppable_C_2147482401
# 3     77.962234      Left Hand Grab  Carrot_Choppable_C_2147482401
# 4     81.206512  Left Hand Released  Carrot_Choppable_C_2147482401
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C020 D/'
file_name = 'C020_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    107.356644     Pour Broth
# 1    142.849701       Add Beef
# 2    146.192139       Add Beef
# 3    148.481567       Add Beef
# 4    150.724609       Add Beef
# 5    194.341553      Add Onion
# 6    197.972504      Add Onion
# 7    212.956406      Add Onion
# 8    214.922836      Add Onion
# 9    237.488068    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      66.685890      Right Hand Grab                   BeefStewCookbook_C_0
# 1      73.096657       Left Hand Grab          Carrot_Choppable_C_2147482401
# 2      75.129433   Left Hand Released          Carrot_Choppable_C_2147482401
# 3      77.962234       Left Hand Grab          Carrot_Choppable_C_2147482401
# 4      81.206512   Left Hand Released          Carrot_Choppable_C_2147482401
# 5      95.040543      Right Hand Grab               BrothParent_C_2147482378
# 6     112.743607  Right Hand Released               BrothParent_C_2147482378
# 7     116.321327      Right Hand Grab                   BeefStewCookbook_C_0
# 8     121.486229       Left Hand Grab            Meat_Choppable_C_2147482400
# 9     124.296211      Right Hand Grab                              Knife_C_4
# 10    124.440254   Left Hand Released            Meat_Choppable_C_2147482400
# 11    126.718506              Chopped            Meat_Choppable_C_2147482400
# 12    127.568871              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 13    128.222687              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 14    128.866577              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 15    129.438400              Chopped         Meat_QuarterLeft2_C_2147482365
# 16    130.054138              Chopped         Meat_QuarterLeft2_C_2147482365
# 17    130.642990              Chopped         Meat_QuarterLeft2_C_2147482365
# 18    131.393661              Chopped         Meat_QuarterLeft2_C_2147482365
# 19    132.784454  Right Hand Released                              Knife_C_4
# 20    134.029190      Right Hand Grab                              Knife_C_4
# 21    134.818192  Right Hand Released                              Knife_C_4
# 22    135.716492      Right Hand Grab                              Knife_C_4
# 23    136.395721              Chopped         Meat_QuarterLeft1_C_2147482366
# 24    136.951019              Chopped         Meat_QuarterLeft1_C_2147482366
# 25    138.250824  Right Hand Released                              Knife_C_4
# 26    139.728226      Right Hand Grab                              Knife_C_4
# 27    140.092209       Left Hand Grab         Meat_QuarterLeft2_C_2147482365
# 28    142.826645   Left Hand Released         Meat_QuarterLeft2_C_2147482365
# 29    142.904816  Right Hand Released                              Knife_C_4
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (240, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       66.685890      Right Hand Grab                   BeefStewCookbook_C_0
# 1       73.096657       Left Hand Grab          Carrot_Choppable_C_2147482401
# 2       75.129433   Left Hand Released          Carrot_Choppable_C_2147482401
# 3       77.962234       Left Hand Grab          Carrot_Choppable_C_2147482401
# 4       81.206512   Left Hand Released          Carrot_Choppable_C_2147482401
# 5       95.040543      Right Hand Grab               BrothParent_C_2147482378
# 212    107.356644                  NaN                                    NaN
# 6      112.743607  Right Hand Released               BrothParent_C_2147482378
# 7      116.321327      Right Hand Grab                   BeefStewCookbook_C_0
# 8      121.486229       Left Hand Grab            Meat_Choppable_C_2147482400
# 9      124.296211      Right Hand Grab                              Knife_C_4
# 10     124.440254   Left Hand Released            Meat_Choppable_C_2147482400
# 11     126.718506              Chopped            Meat_Choppable_C_2147482400
# 12     127.568871              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 13     128.222687              Chopped  Meat_HalfRight_Choppable_C_2147482369
# 14     128.866577              Chopped   Meat_HalfLeft_Choppable_C_2147482370
# 15     129.438400              Chopped         Meat_QuarterLeft2_C_2147482365
# 16     130.054138              Chopped         Meat_QuarterLeft2_C_2147482365
# 17     130.642990              Chopped         Meat_QuarterLeft2_C_2147482365
# 18     131.393661              Chopped         Meat_QuarterLeft2_C_2147482365
# 19     132.784454  Right Hand Released                              Knife_C_4
# 20     134.029190      Right Hand Grab                              Knife_C_4
# 21     134.818192  Right Hand Released                              Knife_C_4
# 22     135.716492      Right Hand Grab                              Knife_C_4
# 23     136.395721              Chopped         Meat_QuarterLeft1_C_2147482366
# 24     136.951019              Chopped         Meat_QuarterLeft1_C_2147482366
# 25     138.250824  Right Hand Released                              Knife_C_4
# 26     139.728226      Right Hand Grab                              Knife_C_4
# 27     140.092209       Left Hand Grab         Meat_QuarterLeft2_C_2147482365
# 28     142.826645   Left Hand Released         Meat_QuarterLeft2_C_2147482365
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 212                  NaN     Pour Broth
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C020D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    58
# Chopped                40
# Left Hand Grab         17
# Left Hand Released     17
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     42.400000
# std      27.171676
# min      17.000000
# 25%      17.000000
# 50%      40.000000
# 75%      58.000000
# max      80.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 212

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      42
# BeefStewCookbook_C_0                           19
# NewLadleSimple_C_2147482324                     6
# Meat_QuarterLeft2_C_2147482365                  6
# Tomato_Choppable_C_2147482397                   5
# Potato_Choppable_C_2147482409                   5
# Carrot_Choppable_C_2147482401                   5
# Potato_BottomHalf_Choppable_C_2147482327        4
# StirSpoonSimple_C_2147482380                    4
# Meat_QuarterLeft1_C_2147482361                  4
# Potato_TopHalf_Choppable_C_2147482326           4
# CarrotBottomQuarter2_Choppable_C_2147482339     4
# Meat_QuarterLeft1_C_2147482366                  4
# BrothParent_C_2147482378                        4
# Tomato_BottomHalf_Choppable_C_2147482344        3
# Onion_Half_C_2147482355                         3
# Tomato_Choppable_C_2147482349                   3
# Carrot_Choppable_C_2147482405                   3
# CarrotTopQuarter2_Choppable_C_2147482331        3
# Onion_Choppable_C_2147482357                    3
# Onion_Choppable_C_2147482392                    3
# Onion_Peeled_C_2147482356                       3
# CarrotTop_Choppable_C_2147482336                3
# Potato_Choppable_C_2147482330                   3
# Meat_HalfRight_Choppable_C_2147482362           3
# Meat_Choppable_C_2147482398                     3
# Meat_Choppable_C_2147482400                     3
# CarrotBottomQuarter2_Choppable_C_2147482333     3
# SaltShakerGrabableSimple_C_2147482377           2
# PepperShakerGrabableSimple_C_2147482376         2
# CarrotBottomQuarter1_Choppable_C_2147482334     2
# CarrotTopQuarter2_Choppable_C_2147482337        2
# CarrotBottomQuarter1_Choppable_C_2147482340     2
# Potato_TopHalf_Choppable_C_2147482328           2
# Potato_BottomHalf_Choppable_C_2147482325        2
# CarrotTopQuarter1_Choppable_C_2147482338        2
# CarrotTopQuarter1_Choppable_C_2147482332        2
# Tomato_TopHalf_Choppable_C_2147482348           2
# CarrotBotton_Choppable_C_2147482335             2
# Onion_Half2_C_2147482354                        2
# Meat_HalfRight_Choppable_C_2147482369           2
# Meat_QuarterRight2_C_2147482367                 2
# Meat_QuarterRight1_C_2147482368                 2
# Meat_HalfLeft_Choppable_C_2147482363            2
# Meat_QuarterRight2_C_2147482358                 2
# Meat_QuarterLeft2_C_2147482360                  2
# Meat_QuarterRight1_C_2147482359                 2
# Onion_Peeled_C_2147482352                       2
# Onion_Half2_C_2147482350                        2
# Onion_Half_C_2147482351                         2
# Tomato_BottomHalf_Choppable_C_2147482347        2
# Tomato_TopHalf_Choppable_C_2147482345           2
# CarrotBotton_Choppable_C_2147482341             2
# CarrotTop_Choppable_C_2147482342                1
# Meat_HalfLeft_Choppable_C_2147482370            1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 211

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              6   40.670754                  0.0
# 1         Add Beef             23   30.106094                  0.0
# 2         Add Beef              3    3.287323                  0.0
# 3         Add Beef              2    1.356552                  0.0
# 4         Add Beef              2    1.354187                  0.0
# 5        Add Onion             39   40.782913                  0.0
# 6        Add Onion              1    2.277787                  0.0
# 7        Add Onion             12   13.007141                  0.0
# 8        Add Onion              2    1.264282                  0.0
# 9      Add Tomtato             11   19.530701                  0.0
# 10     Add Tomtato              2    1.438782                  0.0
# 11     Add Tomtato              8    5.921189                  0.0
# 12     Add Tomtato              2    1.369141                  0.0
# 13      Add Carrot             19   20.791230                  0.0
# 14      Add Carrot              9    4.566681                  0.0
# 15      Add Carrot              0    0.000000                  0.0
# 16      Add Carrot              4    1.663849                  0.0
# 17      Add Carrot              4    2.543335                  0.0
# 18      Add Carrot              0    0.000000                  0.0
# 19      Add Carrot              4    2.228943                  0.0
# 20      Add Carrot              0    0.000000                  0.0
# 21      Add pepper              2    8.524994                  0.0
# 22        Add Salt              4    8.633484                  0.0
# 23       Stir Stew              2   13.947266                  0.0
# 24      Add Potato             29   46.514312                  0.0
# 25      Add Potato              0    0.000000                  0.0
# 26      Add Potato              4    2.217194                  0.0
# 27      Add Potato              0    0.000000                  0.0
# 28  Post last step             18   46.342560                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 212

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C020',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C020            212        320.340694                        1.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.310345   11.046231             0.034483
# std         9.618076   15.143700             0.185695
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.356552             0.000000
# 50%         4.000000    2.543335             0.000000
# 75%         9.000000   13.947266             0.000000
# max        39.000000   46.514312             1.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       4                     0
# Add Carrot                  0            0       4                     4
# Add Beef                    1            1       0                     0
# Add Onion                   2            0       0                     0
# Add Tomtato                 2            0       0                     0
# Add pepper                  1            0       0                     0
# Add Potato                  6            2       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Carrot                      7             4          4                  4
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add pepper                      0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Carrot                   5      8     0      0
# Add Beef                     0      8    20      0
# Add Onion                    0     14    18     20
# Add Tomtato                  0      4     0      0
# Add pepper                   0      0     0      0
# Add Potato                   0      4     0      0
# Add Salt                     0      2     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Carrot                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add pepper                            1       0                         0
# Add Potato                            0      20                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   6
# Add Carrot                 0       0                  40
# Add Beef                   0       0                  30
# Add Onion                  0       0                  54
# Add Tomtato                0      17                  23
# Add pepper                 0       0                   2
# Add Potato                 1       0                  33
# Add Salt                   0       0                   4
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   31.794038
# 1       Add Beef      4   36.104156
# 2      Add Onion      4   57.332123
# 3    Add Tomtato      4   28.259813
# 4     Add Potato      4   48.731506
# 5     Pour Broth      1   40.670754
# 6     Add pepper      1    8.524994
# 7       Add Salt      1    8.633484
# 8      Stir Stew      1   13.947266

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type              Interacted Object  \
# 0       66.685890      Right Hand Grab           BeefStewCookbook_C_0
# 1       73.096657       Left Hand Grab  Carrot_Choppable_C_2147482401
# 2       75.129433   Left Hand Released  Carrot_Choppable_C_2147482401
# 3       77.962234       Left Hand Grab  Carrot_Choppable_C_2147482401
# 4       81.206512   Left Hand Released  Carrot_Choppable_C_2147482401
# ..            ...                  ...                            ...
# 235    412.384094      Right Hand Grab    NewLadleSimple_C_2147482324
# 236    413.117615  Right Hand Released    NewLadleSimple_C_2147482324
# 237    417.016388      Right Hand Grab           BeefStewCookbook_C_0
# 238    427.779327      Right Hand Grab                            NaN
# 239    428.603363      Right Hand Grab                       Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 235                  0.0            NaN
# 236                  0.0            NaN
# 237                  0.0            NaN
# 238                  1.0            NaN
# 239                  0.0            NaN
#
# [240 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    58
# Chopped                40
# Left Hand Grab         17
# Left Hand Released     17
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         0.0
# Left Hand Released     0.0
# Right Hand Grab        1.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            80                        1.0
# 4  Right Hand Released            58                        0.0
# 0              Chopped            40                        0.0
# 1       Left Hand Grab            17                        0.0
# 2   Left Hand Released            17                        0.0
