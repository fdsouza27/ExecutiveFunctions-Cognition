# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C003 A/'
file_name = 'C003_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type                      Interacted Object
# 0    152.206833      Right Hand Grab                   BeefStewCookbook_C_0
# 1    160.182022      Right Hand Grab               BrothParent_C_2147482378
# 2    170.604950  Right Hand Released               BrothParent_C_2147482378
# 3    172.978958      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 4    173.781204  Right Hand Released  SaltShakerGrabableSimple_C_2147482377

# %%
df1.shape
# Out:
# (212, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    199
# 1     13
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 11     194.475967  Right Hand Grab               NaN                    1
# 12     195.651642  Right Hand Grab               NaN                    1
# 18     233.725601   Left Hand Grab               NaN                    1
# 21     239.823166   Left Hand Grab               NaN                    1
# 22     240.789856   Left Hand Grab               NaN                    1
# 30     258.267700   Left Hand Grab               NaN                    1
# 53     293.537659   Left Hand Grab               NaN                    1
# 62     307.367432   Left Hand Grab               NaN                    1
# 78     336.761108  Right Hand Grab               NaN                    1
# 123    401.903625  Right Hand Grab               NaN                    1
# 141    430.511261   Left Hand Grab               NaN                    1
# 154    445.684113   Left Hand Grab               NaN                    1
# 179    480.067017  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type                      Interacted Object  \
# 0    152.206833      Right Hand Grab                   BeefStewCookbook_C_0
# 1    160.182022      Right Hand Grab               BrothParent_C_2147482378
# 2    170.604950  Right Hand Released               BrothParent_C_2147482378
# 3    172.978958      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 4    173.781204  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C003 A/'
file_name = 'C003_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    256.432800     Pour Broth
# 1    340.627350       Add Beef
# 2    342.682739       Add Beef
# 3    345.118011       Add Beef
# 4    346.960968       Add Beef
# 5    385.895416      Add Onion
# 6    388.096100      Add Onion
# 7    390.030975      Add Onion
# 8    391.716614      Add Onion
# 9    416.357239    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0     152.206833      Right Hand Grab                   BeefStewCookbook_C_0
# 1     160.182022      Right Hand Grab               BrothParent_C_2147482378
# 2     170.604950  Right Hand Released               BrothParent_C_2147482378
# 3     172.978958      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 4     173.781204  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
# 5     174.335724      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 6     175.412857  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
# 7     178.978119      Right Hand Grab               BrothParent_C_2147482378
# 8     185.312347  Right Hand Released               BrothParent_C_2147482378
# 9     187.202881      Right Hand Grab               BrothParent_C_2147482378
# 10    191.532272  Right Hand Released               BrothParent_C_2147482378
# 11    194.475967      Right Hand Grab                                    NaN
# 12    195.651642      Right Hand Grab                                    NaN
# 13    207.319153      Right Hand Grab               BrothParent_C_2147482378
# 14    215.096695  Right Hand Released               BrothParent_C_2147482378
# 15    219.806946      Right Hand Grab                   BeefStewCookbook_C_0
# 16    221.383575      Right Hand Grab                   BeefStewCookbook_C_0
# 17    223.728134      Right Hand Grab                   BeefStewCookbook_C_0
# 18    233.725601       Left Hand Grab                                    NaN
# 19    235.112854       Left Hand Grab               BrothParent_C_2147482378
# 20    237.325592   Left Hand Released               BrothParent_C_2147482378
# 21    239.823166       Left Hand Grab                                    NaN
# 22    240.789856       Left Hand Grab                                    NaN
# 23    243.078156       Left Hand Grab               BrothParent_C_2147482378
# 24    244.524033   Left Hand Released               BrothParent_C_2147482378
# 25    245.455826      Right Hand Grab                   BeefStewCookbook_C_0
# 26    246.512100      Right Hand Grab                   BeefStewCookbook_C_0
# 27    246.734787       Left Hand Grab               BrothParent_C_2147482378
# 28    256.744751   Left Hand Released               BrothParent_C_2147482378
# 29    258.222778      Right Hand Grab                   BeefStewCookbook_C_0
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  1.0            NaN
# 12                  1.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  1.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  1.0            NaN
# 22                  1.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (240, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0      152.206833      Right Hand Grab                   BeefStewCookbook_C_0
# 1      160.182022      Right Hand Grab               BrothParent_C_2147482378
# 2      170.604950  Right Hand Released               BrothParent_C_2147482378
# 3      172.978958      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 4      173.781204  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
# 5      174.335724      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 6      175.412857  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
# 7      178.978119      Right Hand Grab               BrothParent_C_2147482378
# 8      185.312347  Right Hand Released               BrothParent_C_2147482378
# 9      187.202881      Right Hand Grab               BrothParent_C_2147482378
# 10     191.532272  Right Hand Released               BrothParent_C_2147482378
# 11     194.475967      Right Hand Grab                                    NaN
# 12     195.651642      Right Hand Grab                                    NaN
# 13     207.319153      Right Hand Grab               BrothParent_C_2147482378
# 14     215.096695  Right Hand Released               BrothParent_C_2147482378
# 15     219.806946      Right Hand Grab                   BeefStewCookbook_C_0
# 16     221.383575      Right Hand Grab                   BeefStewCookbook_C_0
# 17     223.728134      Right Hand Grab                   BeefStewCookbook_C_0
# 18     233.725601       Left Hand Grab                                    NaN
# 19     235.112854       Left Hand Grab               BrothParent_C_2147482378
# 20     237.325592   Left Hand Released               BrothParent_C_2147482378
# 21     239.823166       Left Hand Grab                                    NaN
# 22     240.789856       Left Hand Grab                                    NaN
# 23     243.078156       Left Hand Grab               BrothParent_C_2147482378
# 24     244.524033   Left Hand Released               BrothParent_C_2147482378
# 25     245.455826      Right Hand Grab                   BeefStewCookbook_C_0
# 26     246.512100      Right Hand Grab                   BeefStewCookbook_C_0
# 27     246.734787       Left Hand Grab               BrothParent_C_2147482378
# 212    256.432800                  NaN                                    NaN
# 28     256.744751   Left Hand Released               BrothParent_C_2147482378
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   1.0            NaN
# 12                   1.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   1.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   1.0            NaN
# 22                   1.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 212                  NaN     Pour Broth
# 28                   0.0            NaN

# %%
df.to_csv('act_step_C003A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        83
# Right Hand Released    53
# Left Hand Grab         37
# Chopped                25
# Left Hand Released     14
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.00000
# mean     42.40000
# std      26.92211
# min      14.00000
# 25%      25.00000
# 50%      37.00000
# 75%      53.00000
# max      83.00000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 212

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# BeefStewCookbook_C_0                           39
# Knife_C_4                                      26
# BrothParent_C_2147482378                       20
# SaltShakerGrabableSimple_C_2147482377           6
# Onion_Choppable_C_2147482365                    5
# NewLadleSimple_C_2147482327                     4
# Onion_Choppable_C_2147482392                    3
# Tomato_Choppable_C_2147482397                   3
# Onion_Half2_C_2147482360                        3
# Tomato_Choppable_C_2147482353                   3
# Onion_Choppable_C_2147482389                    3
# Carrot_Choppable_C_2147482403                   3
# Carrot_Choppable_C_2147482402                   3
# CarrotBottomQuarter1_Choppable_C_2147482335     3
# Potato_Choppable_C_2147482408                   3
# Meat_QuarterLeft2_C_2147482368                  3
# Potato_Choppable_C_2147482347                   3
# Meat_HalfRight_Choppable_C_2147482370           3
# Meat_Choppable_C_2147482400                     3
# CarrotTopQuarter1_Choppable_C_2147482331        3
# CarrotBotton_Choppable_C_2147482336             2
# CarrotTopQuarter1_Choppable_C_2147482329        2
# CarrotBottomQuarter2_Choppable_C_2147482332     2
# CarrotBottomQuarter1_Choppable_C_2147482333     2
# Potato_TopHalf_Choppable_C_2147482343           2
# CarrotBottomQuarter2_Choppable_C_2147482334     2
# CarrotTopQuarter2_Choppable_C_2147482328        2
# CarrotTopQuarter2_Choppable_C_2147482330        2
# PepperShakerGrabableSimple_C_2147482376         2
# StirSpoonSimple_C_2147482380                    2
# Potato_BottomHalf_Choppable_C_2147482342        2
# Tomato_BottomHalf_Choppable_C_2147482348        2
# Potato_TopHalf_Choppable_C_2147482345           2
# Onion_Half_C_2147482355                         2
# Carrot_Choppable_C_2147482401                   2
# Meat_QuarterRight2_C_2147482366                 2
# Meat_QuarterRight1_C_2147482367                 2
# Meat_QuarterLeft1_C_2147482369                  2
# Onion_Peeled_C_2147482356                       2
# Potato_BottomHalf_Choppable_C_2147482344        2
# Onion_Half2_C_2147482354                        2
# Onion_Half2_C_2147482358                        2
# Tomato_BottomHalf_Choppable_C_2147482350        2
# Tomato_TopHalf_Choppable_C_2147482351           2
# Tomato_TopHalf_Choppable_C_2147482349           2
# CarrotTop_Choppable_C_2147482337                1
# CarrotTop_Choppable_C_2147482339                1
# CarrotBotton_Choppable_C_2147482338             1
# Onion_Peeled_C_2147482362                       1
# Onion_Peeled_C_2147482363                       1
# Meat_HalfLeft_Choppable_C_2147482371            1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 199

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             28  104.225967                  5.0
# 1         Add Beef             53   83.882599                  4.0
# 2         Add Beef              2    1.243988                  0.0
# 3         Add Beef              2    1.401458                  0.0
# 4         Add Beef              2    0.956329                  0.0
# 5        Add Onion             29   37.514496                  0.0
# 6        Add Onion              2    1.224365                  0.0
# 7        Add Onion              2    1.056183                  0.0
# 8        Add Onion              2    0.989136                  0.0
# 9      Add Tomtato             12   16.119782                  1.0
# 10     Add Tomtato              2    1.111328                  0.0
# 11     Add Tomtato              2    1.420044                  0.0
# 12     Add Tomtato              2    1.365997                  0.0
# 13      Add Potato             12   18.175140                  1.0
# 14      Add Potato              2    0.989624                  0.0
# 15      Add Potato              4    2.134643                  1.0
# 16      Add Potato              1    0.099640                  0.0
# 17      Add Carrot             20   28.893189                  0.0
# 18      Add Carrot              5    3.611480                  1.0
# 19      Add Carrot              0    0.000000                  0.0
# 20      Add Carrot              4    1.337097                  0.0
# 21      Add Carrot              0    0.000000                  0.0
# 22      Add Carrot              4    1.500122                  0.0
# 23      Add Carrot              0    0.000000                  0.0
# 24      Add Carrot              2    1.042664                  0.0
# 25      Add pepper              2    7.587189                  0.0
# 26        Add Salt              2    6.854889                  0.0
# 27       Stir Stew              2    9.285584                  0.0
# 28  Post last step             12   34.916809                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 212

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C003',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C003            212        368.939742                       13.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        7.310345   12.722060             0.448276
# std        11.720262   24.989153             1.182800
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.042664             0.000000
# 50%         2.000000    1.401458             0.000000
# 75%         5.000000    9.285584             0.000000
# max        53.000000  104.225967             5.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  6           13       0                     0
# Add Beef                   26            7       2                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     5
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             3          2                  5
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      4    16      0
# Add Onion                    0     10     0     24
# Add Tomtato                  0      2     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   4      4     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         4
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      14                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                  23
# Add Beef                   0       0                  55
# Add Onion                  0       0                  35
# Add Tomtato                0      14                  17
# Add Potato                 0       0                  17
# Add Carrot                 0       0                  34
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   36.384552
# 1       Add Beef      4   87.484374
# 2      Add Onion      4   40.784180
# 3    Add Tomtato      4   20.017151
# 4     Add Potato      4   21.399047
# 5     Pour Broth      1  104.225967
# 6     Add pepper      1    7.587189
# 7       Add Salt      1    6.854889
# 8      Stir Stew      1    9.285584

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0      152.206833      Right Hand Grab                   BeefStewCookbook_C_0
# 1      160.182022      Right Hand Grab               BrothParent_C_2147482378
# 2      170.604950  Right Hand Released               BrothParent_C_2147482378
# 3      172.978958      Right Hand Grab  SaltShakerGrabableSimple_C_2147482377
# 4      173.781204  Right Hand Released  SaltShakerGrabableSimple_C_2147482377
# ..            ...                  ...                                    ...
# 235    537.224670  Right Hand Released                              Knife_C_4
# 236    537.743042      Right Hand Grab            NewLadleSimple_C_2147482327
# 237    544.079834  Right Hand Released            NewLadleSimple_C_2147482327
# 238    550.649780      Right Hand Grab                   BeefStewCookbook_C_0
# 239    559.764709      Right Hand Grab                               Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    0.0            NaN
# 4                    0.0            NaN
# ..                   ...            ...
# 235                  0.0            NaN
# 236                  0.0            NaN
# 237                  0.0            NaN
# 238                  0.0            NaN
# 239                  0.0            NaN
#
# [240 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        83
# Right Hand Released    53
# Left Hand Grab         37
# Chopped                25
# Left Hand Released     14
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         8.0
# Left Hand Released     0.0
# Right Hand Grab        5.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            83                        5.0
# 4  Right Hand Released            53                        0.0
# 1       Left Hand Grab            37                        8.0
# 0              Chopped            25                        0.0
# 2   Left Hand Released            14                        0.0
