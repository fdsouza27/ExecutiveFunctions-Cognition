# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C012 D/'
file_name = 'C012_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      3.830928      Right Hand Grab      BeefStewCookbook_C_0
# 1      3.885836       Left Hand Grab                       NaN
# 2     11.340806      Right Hand Grab  BrothParent_C_2147482366
# 3     26.103060  Right Hand Released  BrothParent_C_2147482366
# 4     27.861137      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (163, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    162
# 1      1
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#    Session Time     Action Type Interacted Object  Missed Interactions
# 1      3.885836  Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      3.830928      Right Hand Grab      BeefStewCookbook_C_0
# 1      3.885836       Left Hand Grab                       NaN
# 2     11.340806      Right Hand Grab  BrothParent_C_2147482366
# 3     26.103060  Right Hand Released  BrothParent_C_2147482366
# 4     27.861137      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C012 D/'
file_name = 'C012_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     23.805727     Pour Broth
# 1     63.853203       Add Beef
# 2     70.152657       Add Beef
# 3     74.572632       Add Beef
# 4     76.506424       Add Beef
# 5     78.683289       Add Beef
# 6     80.450706       Add Beef
# 7     87.536957       Add Beef
# 8     89.315132       Add Beef
# 9    123.841782      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0       3.830928      Right Hand Grab                   BeefStewCookbook_C_0
# 1       3.885836       Left Hand Grab                                    NaN
# 2      11.340806      Right Hand Grab               BrothParent_C_2147482366
# 3      26.103060  Right Hand Released               BrothParent_C_2147482366
# 4      27.861137      Right Hand Grab                   BeefStewCookbook_C_0
# 5      33.157024      Right Hand Grab            Meat_Choppable_C_2147482388
# 6      34.346046  Right Hand Released            Meat_Choppable_C_2147482388
# 7      36.704243      Right Hand Grab            Meat_Choppable_C_2147482386
# 8      38.132519  Right Hand Released            Meat_Choppable_C_2147482386
# 9      42.066799      Right Hand Grab                              Knife_C_4
# 10     43.777786              Chopped            Meat_Choppable_C_2147482386
# 11     45.622921              Chopped  Meat_HalfRight_Choppable_C_2147482357
# 12     46.822266              Chopped        Meat_QuarterRight2_C_2147482355
# 13     48.355301              Chopped        Meat_QuarterRight1_C_2147482356
# 14     50.776333              Chopped            Meat_Choppable_C_2147482388
# 15     51.398903              Chopped   Meat_HalfLeft_Choppable_C_2147482354
# 16     52.820190              Chopped   Meat_HalfLeft_Choppable_C_2147482354
# 17     53.777264              Chopped  Meat_HalfRight_Choppable_C_2147482353
# 18     56.465050  Right Hand Released                              Knife_C_4
# 19     59.476032      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 20     61.286945  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 21     61.997959      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 22     63.753548  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 23     64.831329      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482358
# 24     68.141869  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482358
# 25     68.819229      Right Hand Grab        Meat_QuarterRight1_C_2147482356
# 26     70.062836  Right Hand Released        Meat_QuarterRight1_C_2147482356
# 27     71.573708      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482358
# 28     72.295525  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482358
# 29     72.836731      Right Hand Grab         Meat_QuarterLeft2_C_2147482351
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (195, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        3.830928      Right Hand Grab                   BeefStewCookbook_C_0
# 1        3.885836       Left Hand Grab                                    NaN
# 2       11.340806      Right Hand Grab               BrothParent_C_2147482366
# 163     23.805727                  NaN                                    NaN
# 3       26.103060  Right Hand Released               BrothParent_C_2147482366
# 4       27.861137      Right Hand Grab                   BeefStewCookbook_C_0
# 5       33.157024      Right Hand Grab            Meat_Choppable_C_2147482388
# 6       34.346046  Right Hand Released            Meat_Choppable_C_2147482388
# 7       36.704243      Right Hand Grab            Meat_Choppable_C_2147482386
# 8       38.132519  Right Hand Released            Meat_Choppable_C_2147482386
# 9       42.066799      Right Hand Grab                              Knife_C_4
# 10      43.777786              Chopped            Meat_Choppable_C_2147482386
# 11      45.622921              Chopped  Meat_HalfRight_Choppable_C_2147482357
# 12      46.822266              Chopped        Meat_QuarterRight2_C_2147482355
# 13      48.355301              Chopped        Meat_QuarterRight1_C_2147482356
# 14      50.776333              Chopped            Meat_Choppable_C_2147482388
# 15      51.398903              Chopped   Meat_HalfLeft_Choppable_C_2147482354
# 16      52.820190              Chopped   Meat_HalfLeft_Choppable_C_2147482354
# 17      53.777264              Chopped  Meat_HalfRight_Choppable_C_2147482353
# 18      56.465050  Right Hand Released                              Knife_C_4
# 19      59.476032      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 20      61.286945  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 21      61.997959      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 22      63.753548  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 164     63.853203                  NaN                                    NaN
# 23      64.831329      Right Hand Grab   Meat_HalfLeft_Choppable_C_2147482358
# 24      68.141869  Right Hand Released   Meat_HalfLeft_Choppable_C_2147482358
# 25      68.819229      Right Hand Grab        Meat_QuarterRight1_C_2147482356
# 26      70.062836  Right Hand Released        Meat_QuarterRight1_C_2147482356
# 165     70.152657                  NaN                                    NaN
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 163                  NaN     Pour Broth
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 164                  NaN       Add Beef
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 165                  NaN       Add Beef

# %%
#df.to_csv('act_step_C012D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        64
# Right Hand Released    55
# Chopped                31
# Left Hand Grab          7
# Left Hand Released      6
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     32.600000
# std      26.707677
# min       6.000000
# 25%       7.000000
# 50%      31.000000
# 75%      55.000000
# max      64.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 163

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      20
# BeefStewCookbook_C_0                            9
# Potato_Choppable_C_2147482398                   7
# Meat_QuarterRight2_C_2147482355                 5
# Meat_HalfLeft_Choppable_C_2147482358            5
# PepperShakerGrabableSimple_C_2147482364         4
# Potato_BottomHalf_Choppable_C_2147482325        4
# Onion_Choppable_C_2147482378                    3
# Onion_Half2_C_2147482342                        3
# Onion_Half_C_2147482340                         3
# Onion_Half2_C_2147482339                        3
# Potato_Choppable_C_2147482328                   3
# Tomato_Choppable_C_2147482385                   3
# Onion_Choppable_C_2147482380                    3
# Carrot_Choppable_C_2147482389                   3
# Carrot_Choppable_C_2147482322                   3
# Onion_Choppable_C_2147482346                    3
# Tomato_Choppable_C_2147482384                   3
# Meat_QuarterLeft2_C_2147482347                  3
# Meat_Choppable_C_2147482386                     3
# Meat_Choppable_C_2147482388                     3
# Meat_QuarterRight1_C_2147482356                 3
# Meat_QuarterLeft1_C_2147482348                  2
# CarrotBottomQuarter2_Choppable_C_2147482313     2
# Potato_TopHalf_Choppable_C_2147482324           2
# CarrotBottomQuarter2_Choppable_C_2147482315     2
# CarrotBottomQuarter1_Choppable_C_2147482316     2
# CarrotBottomQuarter1_Choppable_C_2147482314     2
# CarrotTopQuarter2_Choppable_C_2147482309        2
# CarrotTopQuarter1_Choppable_C_2147482310        2
# CarrotTopQuarter1_Choppable_C_2147482312        2
# CarrotTopQuarter2_Choppable_C_2147482311        2
# SaltShakerGrabableSimple_C_2147482365           2
# StirSpoonSimple_C_2147482368                    2
# Potato_TopHalf_Choppable_C_2147482326           2
# Potato_BottomHalf_Choppable_C_2147482323        2
# Meat_HalfLeft_Choppable_C_2147482354            2
# Tomato_TopHalf_Choppable_C_2147482332           2
# Meat_QuarterRight1_C_2147482350                 2
# Meat_QuarterRight2_C_2147482349                 2
# Meat_QuarterLeft1_C_2147482352                  2
# Onion_Half2_C_2147482335                        2
# Onion_Half_C_2147482336                         2
# Meat_QuarterLeft2_C_2147482351                  2
# BrothParent_C_2147482366                        2
# Tomato_BottomHalf_Choppable_C_2147482331        2
# Tomato_BottomHalf_Choppable_C_2147482329        2
# Tomato_TopHalf_Choppable_C_2147482330           2
# NewLadleSimple_C_2147482308                     2
# CarrotTop_Choppable_C_2147482318                1
# Meat_HalfRight_Choppable_C_2147482353           1
# CarrotTop_Choppable_C_2147482320                1
# CarrotBotton_Choppable_C_2147482317             1
# CarrotBotton_Choppable_C_2147482319             1
# Onion_Peeled_C_2147482337                       1
# Meat_HalfRight_Choppable_C_2147482357           1
# Onion_Peeled_C_2147482344                       1
# Onion_Peeled_C_2147482341                       1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 162

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              3   19.974799                  1.0
# 1         Add Beef             20   37.750143                  0.0
# 2         Add Beef              4    5.321328                  0.0
# 3         Add Beef              4    2.998924                  0.0
# 4         Add Beef              2    1.089188                  0.0
# 5         Add Beef              2    1.289772                  0.0
# 6         Add Beef              2    1.045318                  0.0
# 7         Add Beef              6    5.820252                  0.0
# 8         Add Beef              2    1.021843                  0.0
# 9        Add Onion             22   30.183083                  0.0
# 10       Add Onion              2    1.024468                  0.0
# 11       Add Onion              2    1.043671                  0.0
# 12       Add Onion              2    1.011352                  0.0
# 13     Add Tomtato             14   19.151459                  0.0
# 14     Add Tomtato              2    0.911224                  0.0
# 15     Add Tomtato              2    0.878357                  0.0
# 16     Add Tomtato              2    0.988251                  0.0
# 17      Add Potato             16   22.697067                  0.0
# 18      Add Potato              2    0.932861                  0.0
# 19      Add Potato              2    1.077454                  0.0
# 20      Add Potato              2    0.877106                  0.0
# 21      Add Carrot             17   18.662384                  0.0
# 22      Add Carrot              4    3.200515                  0.0
# 23      Add Carrot              2    0.978149                  0.0
# 24      Add Carrot              2    0.854293                  0.0
# 25      Add Carrot              2    0.966461                  0.0
# 26      Add Carrot              2    0.878021                  0.0
# 27      Add Carrot              4    3.543854                  0.0
# 28      Add Carrot              2    1.100144                  0.0
# 29      Add pepper              4   11.340332                  0.0
# 30        Add Salt              2    4.000305                  0.0
# 31       Stir Stew              2   17.742645                  0.0
# 32  Post last step              5   20.272644                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 163

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C012',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C012            163        240.627667                        1.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        4.939394    7.291747             0.030303
# std         5.727889    9.989388             0.174078
# min         2.000000    0.854293             0.000000
# 25%         2.000000    0.988251             0.000000
# 50%         2.000000    1.100144             0.000000
# 75%         4.000000   11.340332             0.000000
# max        22.000000   37.750143             1.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 2            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Add Potato                  0            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Carrot                      4             2          2                  4
# Add pepper                      0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      4    36      0
# Add Onion                    0      4     0     23
# Add Tomtato                  0      4     0      0
# Add Carrot                   4      6     0      2
# Add pepper                   0      0     0      0
# Add Potato                   0      2     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Carrot                            0       0                         0
# Add pepper                            3       0                         0
# Add Potato                            0      20                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  42
# Add Onion                  0       0                  28
# Add Tomtato                0      14                  20
# Add Carrot                 0       0                  35
# Add pepper                 0       0                   4
# Add Potato                 0       0                  22
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   56.336768
# 1     Add Carrot      8   30.183821
# 2      Add Onion      4   33.262574
# 3    Add Tomtato      4   21.929291
# 4     Add Potato      4   25.584488
# 5     Pour Broth      1   19.974799
# 6     Add pepper      1   11.340332
# 7       Add Salt      1    4.000305
# 8      Stir Stew      1   17.742645

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type             Interacted Object  \
# 0        3.830928      Right Hand Grab          BeefStewCookbook_C_0
# 1        3.885836       Left Hand Grab                           NaN
# 2       11.340806      Right Hand Grab      BrothParent_C_2147482366
# 3       23.805727                  NaN                           NaN
# 4       26.103060  Right Hand Released      BrothParent_C_2147482366
# ..            ...                  ...                           ...
# 190    266.448242  Right Hand Released  StirSpoonSimple_C_2147482368
# 191    267.869720      Right Hand Grab          BeefStewCookbook_C_0
# 192    274.510498      Right Hand Grab   NewLadleSimple_C_2147482308
# 193    282.665955  Right Hand Released   NewLadleSimple_C_2147482308
# 194    286.720886      Right Hand Grab          BeefStewCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    NaN     Pour Broth
# 4                    0.0            NaN
# ..                   ...            ...
# 190                  0.0            NaN
# 191                  0.0            NaN
# 192                  0.0            NaN
# 193                  0.0            NaN
# 194                  0.0            NaN
#
# [195 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        64
# Right Hand Released    55
# Chopped                31
# Left Hand Grab          7
# Left Hand Released      6
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         1.0
# Left Hand Released     0.0
# Right Hand Grab        0.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            64                        0.0
# 4  Right Hand Released            55                        0.0
# 0              Chopped            31                        0.0
# 1       Left Hand Grab             7                        1.0
# 2   Left Hand Released             6                        0.0
