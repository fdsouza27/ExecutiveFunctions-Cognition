# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C029 A/'
file_name = 'C029_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object
# 0     26.509527  Right Hand Grab               NaN
# 1     26.776066  Right Hand Grab               NaN
# 2     41.927757  Right Hand Grab               NaN
# 3     42.428146  Right Hand Grab               NaN
# 4     42.816616  Right Hand Grab               NaN

# %%
df1.shape
# Out:
# (279, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    262
# 1     17
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0       26.509527  Right Hand Grab               NaN                    1
# 1       26.776066  Right Hand Grab               NaN                    1
# 2       41.927757  Right Hand Grab               NaN                    1
# 3       42.428146  Right Hand Grab               NaN                    1
# 4       42.816616  Right Hand Grab               NaN                    1
# 5       43.505550   Left Hand Grab               NaN                    1
# 6       43.606056  Right Hand Grab               NaN                    1
# 7       43.994595   Left Hand Grab               NaN                    1
# 8       44.294662   Left Hand Grab               NaN                    1
# 9       44.883778   Left Hand Grab               NaN                    1
# 10      45.250069   Left Hand Grab               NaN                    1
# 11      45.615673   Left Hand Grab               NaN                    1
# 12      45.904865   Left Hand Grab               NaN                    1
# 13      46.805058  Right Hand Grab               NaN                    1
# 14      47.259941  Right Hand Grab               NaN                    1
# 16      65.767807  Right Hand Grab               NaN                    1
# 137    406.850830   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type Interacted Object  Missed Interactions
# 0     26.509527  Right Hand Grab               NaN                    1
# 1     26.776066  Right Hand Grab               NaN                    1
# 2     41.927757  Right Hand Grab               NaN                    1
# 3     42.428146  Right Hand Grab               NaN                    1
# 4     42.816616  Right Hand Grab               NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C029 A/'
file_name = 'C029_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    476.405823     Add Carrot
# 1    576.890015      Stir Stew

# %%
df2.shape
# Out:
# (2, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      26.509527      Right Hand Grab                                    NaN
# 1      26.776066      Right Hand Grab                                    NaN
# 2      41.927757      Right Hand Grab                                    NaN
# 3      42.428146      Right Hand Grab                                    NaN
# 4      42.816616      Right Hand Grab                                    NaN
# 5      43.505550       Left Hand Grab                                    NaN
# 6      43.606056      Right Hand Grab                                    NaN
# 7      43.994595       Left Hand Grab                                    NaN
# 8      44.294662       Left Hand Grab                                    NaN
# 9      44.883778       Left Hand Grab                                    NaN
# 10     45.250069       Left Hand Grab                                    NaN
# 11     45.615673       Left Hand Grab                                    NaN
# 12     45.904865       Left Hand Grab                                    NaN
# 13     46.805058      Right Hand Grab                                    NaN
# 14     47.259941      Right Hand Grab                                    NaN
# 15     65.656754       Left Hand Grab                   BeefStewCookbook_C_0
# 16     65.767807      Right Hand Grab                                    NaN
# 17    109.540993      Right Hand Grab                   BeefStewCookbook_C_0
# 18    119.025406      Right Hand Grab            Meat_Choppable_C_2147482400
# 19    119.103004       Left Hand Grab            Meat_Choppable_C_2147482400
# 20    121.135559  Right Hand Released            Meat_Choppable_C_2147482400
# 21    121.157349   Left Hand Released            Meat_Choppable_C_2147482400
# 22    152.485901      Right Hand Grab                              Knife_C_4
# 23    154.785645              Chopped            Meat_Choppable_C_2147482400
# 24    155.530609  Right Hand Released                              Knife_C_4
# 25    208.209915      Right Hand Grab                              Knife_C_4
# 26    209.461472              Chopped  Meat_HalfRight_Choppable_C_2147482372
# 27    212.021210              Chopped        Meat_QuarterRight2_C_2147482370
# 28    214.119354              Chopped        Meat_QuarterRight1_C_2147482371
# 29    216.731140              Chopped        Meat_QuarterRight2_C_2147482370
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   1.0            NaN
# 6                   1.0            NaN
# 7                   1.0            NaN
# 8                   1.0            NaN
# 9                   1.0            NaN
# 10                  1.0            NaN
# 11                  1.0            NaN
# 12                  1.0            NaN
# 13                  1.0            NaN
# 14                  1.0            NaN
# 15                  0.0            NaN
# 16                  1.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (281, 5)

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      26.509527      Right Hand Grab                                    NaN
# 1      26.776066      Right Hand Grab                                    NaN
# 2      41.927757      Right Hand Grab                                    NaN
# 3      42.428146      Right Hand Grab                                    NaN
# 4      42.816616      Right Hand Grab                                    NaN
# 5      43.505550       Left Hand Grab                                    NaN
# 6      43.606056      Right Hand Grab                                    NaN
# 7      43.994595       Left Hand Grab                                    NaN
# 8      44.294662       Left Hand Grab                                    NaN
# 9      44.883778       Left Hand Grab                                    NaN
# 10     45.250069       Left Hand Grab                                    NaN
# 11     45.615673       Left Hand Grab                                    NaN
# 12     45.904865       Left Hand Grab                                    NaN
# 13     46.805058      Right Hand Grab                                    NaN
# 14     47.259941      Right Hand Grab                                    NaN
# 15     65.656754       Left Hand Grab                   BeefStewCookbook_C_0
# 16     65.767807      Right Hand Grab                                    NaN
# 17    109.540993      Right Hand Grab                   BeefStewCookbook_C_0
# 18    119.025406      Right Hand Grab            Meat_Choppable_C_2147482400
# 19    119.103004       Left Hand Grab            Meat_Choppable_C_2147482400
# 20    121.135559  Right Hand Released            Meat_Choppable_C_2147482400
# 21    121.157349   Left Hand Released            Meat_Choppable_C_2147482400
# 22    152.485901      Right Hand Grab                              Knife_C_4
# 23    154.785645              Chopped            Meat_Choppable_C_2147482400
# 24    155.530609  Right Hand Released                              Knife_C_4
# 25    208.209915      Right Hand Grab                              Knife_C_4
# 26    209.461472              Chopped  Meat_HalfRight_Choppable_C_2147482372
# 27    212.021210              Chopped        Meat_QuarterRight2_C_2147482370
# 28    214.119354              Chopped        Meat_QuarterRight1_C_2147482371
# 29    216.731140              Chopped        Meat_QuarterRight2_C_2147482370
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   1.0            NaN
# 6                   1.0            NaN
# 7                   1.0            NaN
# 8                   1.0            NaN
# 9                   1.0            NaN
# 10                  1.0            NaN
# 11                  1.0            NaN
# 12                  1.0            NaN
# 13                  1.0            NaN
# 14                  1.0            NaN
# 15                  0.0            NaN
# 16                  1.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
#df.to_csv('act_step_C029A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        114
# Right Hand Released     98
# Chopped                 40
# Left Hand Grab          18
# Left Hand Released       9
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      55.800000
# std       47.531042
# min        9.000000
# 25%       18.000000
# 50%       40.000000
# 75%       98.000000
# max      114.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 279

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      60
# Tomato_BottomHalf_Choppable_C_2147482347       46
# Carrot_Choppable_C_2147482329                  12
# BeefStewCookbook_C_0                            8
# PepperShakerGrabableSimple_C_2147482376         6
# Meat_Choppable_C_2147482400                     5
# Potato_Choppable_C_2147482343                   5
# Tomato_TopHalf_Choppable_C_2147482348           5
# Potato_Choppable_C_2147482410                   5
# Meat_QuarterRight2_C_2147482370                 4
# Meat_QuarterRight1_C_2147482362                 4
# CarrotBottomQuarter1_Choppable_C_2147482326     4
# Tomato_Choppable_C_2147482351                   3
# Carrot_Choppable_C_2147482405                   3
# Tomato_Choppable_C_2147482352                   3
# Tomato_Choppable_C_2147482394                   3
# Carrot_Choppable_C_2147482401                   3
# Onion_Choppable_C_2147482389                    3
# Onion_Half2_C_2147482357                        3
# Onion_Peeled_C_2147482359                       3
# Meat_QuarterLeft1_C_2147482364                  3
# Meat_QuarterRight1_C_2147482371                 3
# Meat_QuarterLeft2_C_2147482368                  3
# Meat_Choppable_C_2147482374                     3
# Onion_Choppable_C_2147482392                    3
# Potato_TopHalf_Choppable_C_2147482338           3
# Meat_HalfRight_Choppable_C_2147482365           3
# CarrotTop_Choppable_C_2147482328                3
# CarrotTopQuarter2_Choppable_C_2147482323        2
# CarrotTopQuarter1_Choppable_C_2147482331        2
# CarrotTopQuarter2_Choppable_C_2147482330        2
# CarrotBottomQuarter2_Choppable_C_2147482332     2
# CarrotBottomQuarter2_Choppable_C_2147482325     2
# SaltShakerGrabableSimple_C_2147482377           2
# Potato_BottomHalf_Choppable_C_2147482337        2
# CarrotBottomQuarter1_Choppable_C_2147482333     2
# Tomato_TopHalf_Choppable_C_2147482350           2
# Tomato_BottomHalf_Choppable_C_2147482344        2
# Onion_Half_C_2147482354                         2
# Meat_QuarterLeft1_C_2147482369                  2
# Meat_QuarterRight2_C_2147482361                 2
# Meat_QuarterLeft2_C_2147482363                  2
# Onion_Half_C_2147482358                         2
# Potato_BottomHalf_Choppable_C_2147482341        2
# StirSpoonSimple_C_2147482380                    2
# Onion_Half2_C_2147482353                        2
# Tomato_BottomHalf_Choppable_C_2147482349        2
# Tomato_TopHalf_Choppable_C_2147482345           2
# Potato_TopHalf_Choppable_C_2147482342           2
# Onion_Peeled_C_2147482355                       1
# CarrotTop_Choppable_C_2147482335                1
# CarrotBotton_Choppable_C_2147482334             1
# Meat_HalfLeft_Choppable_C_2147482366            1
# CarrotTopQuarter1_Choppable_C_2147482324        1
# Meat_HalfLeft_Choppable_C_2147482373            1
# Meat_HalfRight_Choppable_C_2147482372           1
# CarrotBotton_Choppable_C_2147482327             1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 262

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#    Completed Step  Actions Count  Time Spent  Missed Interactions
# 0      Add Carrot            191  449.896296                 17.0
# 1       Stir Stew             84   99.995545                  0.0
# 2  Post last step              4    5.957276                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 279

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C029',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C029            279        555.849117                       17.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count       3.000000    3.000000             3.000000
# mean       93.000000  185.283039             5.666667
# std        93.824304  233.935741             9.814955
# min         4.000000    5.957276             0.000000
# 25%        44.000000   52.976410             0.000000
# 50%        84.000000   99.995545             0.000000
# 75%       137.500000  274.945920             8.500000
# max       191.000000  449.896296            17.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#             BeefStewCookbook  Carrot  CarrotBottomQuarter1  \
# Add Carrot                 6       3                     0
# Stir Stew                  1      15                     6
#
#             CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Add Carrot                     2             1          1                  0
# Stir Stew                      2             1          3                  3
#
#             CarrotTopQuarter2  Knife  Meat  Onion  PepperShakerGrabableSimple  \
# Add Carrot                  0     46    37     19                           0
# Stir Stew                   4     14     0      0                           4
#
#             Potato  SaltShakerGrabableSimple  StirSpoonSimple  Tomato  \
# Add Carrot      19                         0                0      40
# Stir Stew        0                         2                1      28
#
#             Interacted Objects
# Add Carrot                 174
# Stir Stew                   84

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      1  449.896296
# 1      Stir Stew      1   99.995545

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type  \
# 0       26.509527      Right Hand Grab
# 1       26.776066      Right Hand Grab
# 2       41.927757      Right Hand Grab
# 3       42.428146      Right Hand Grab
# 4       42.816616      Right Hand Grab
# ..            ...                  ...
# 276    576.890015                  NaN
# 277    580.373840  Right Hand Released
# 278    581.196350      Right Hand Grab
# 279    582.216553  Right Hand Released
# 280    586.331116      Right Hand Grab
#
#                            Interacted Object  Missed Interactions  \
# 0                                        NaN                  1.0
# 1                                        NaN                  1.0
# 2                                        NaN                  1.0
# 3                                        NaN                  1.0
# 4                                        NaN                  1.0
# ..                                       ...                  ...
# 276                                      NaN                  NaN
# 277             StirSpoonSimple_C_2147482380                  0.0
# 278  PepperShakerGrabableSimple_C_2147482376                  0.0
# 279  PepperShakerGrabableSimple_C_2147482376                  0.0
# 280                     BeefStewCookbook_C_0                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 276      Stir Stew
# 277            NaN
# 278            NaN
# 279            NaN
# 280            NaN
#
# [281 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        114
# Right Hand Released     98
# Chopped                 40
# Left Hand Grab          18
# Left Hand Released       9
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         8.0
# Left Hand Released     0.0
# Right Hand Grab        9.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           114                        9.0
# 4  Right Hand Released            98                        0.0
# 0              Chopped            40                        0.0
# 1       Left Hand Grab            18                        8.0
# 2   Left Hand Released             9                        0.0
