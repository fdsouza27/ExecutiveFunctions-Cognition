# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C025 A/'
file_name = 'C025_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0    102.500168      Right Hand Grab      BeefStewCookbook_C_0
# 1    116.874474      Right Hand Grab  BrothParent_C_2147482378
# 2    134.913773  Right Hand Released  BrothParent_C_2147482378
# 3    138.969864      Right Hand Grab                       NaN
# 4    141.783066      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (160, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    148
# 1     12
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 3      138.969864  Right Hand Grab               NaN                    1
# 14     168.208908  Right Hand Grab               NaN                    1
# 19     173.241791  Right Hand Grab               NaN                    1
# 32     200.768616  Right Hand Grab               NaN                    1
# 33     202.056900  Right Hand Grab               NaN                    1
# 34     203.112427  Right Hand Grab               NaN                    1
# 46     219.833466  Right Hand Grab               NaN                    1
# 52     236.728577  Right Hand Grab               NaN                    1
# 57     251.047852  Right Hand Grab               NaN                    1
# 73     281.977051  Right Hand Grab               NaN                    1
# 93     313.836700  Right Hand Grab               NaN                    1
# 155    447.368408  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0    102.500168      Right Hand Grab      BeefStewCookbook_C_0
# 1    116.874474      Right Hand Grab  BrothParent_C_2147482378
# 2    134.913773  Right Hand Released  BrothParent_C_2147482378
# 3    138.969864      Right Hand Grab                       NaN
# 4    141.783066      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C025 A/'
file_name = 'C025_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0    131.351547     Pour Broth
# 1    176.319397       Add Beef
# 2    180.496872       Add Beef
# 3    191.072861       Add Beef
# 4    194.427551       Add Beef
# 5    265.179688      Add Onion
# 6    267.803375      Add Onion
# 7    271.680817      Add Onion
# 8    274.247559      Add Onion
# 9    296.974823    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0     102.500168      Right Hand Grab                   BeefStewCookbook_C_0
# 1     116.874474      Right Hand Grab               BrothParent_C_2147482378
# 2     134.913773  Right Hand Released               BrothParent_C_2147482378
# 3     138.969864      Right Hand Grab                                    NaN
# 4     141.783066      Right Hand Grab                   BeefStewCookbook_C_0
# 5     147.721573      Right Hand Grab            Meat_Choppable_C_2147482400
# 6     149.232864  Right Hand Released            Meat_Choppable_C_2147482400
# 7     153.390640      Right Hand Grab                              Knife_C_4
# 8     155.766998              Chopped            Meat_Choppable_C_2147482400
# 9     156.666992              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 10    157.600647              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 11    158.311874  Right Hand Released                              Knife_C_4
# 12    166.008865      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482370
# 13    167.388275  Right Hand Released  Meat_HalfRight_Choppable_C_2147482370
# 14    168.208908      Right Hand Grab                                    NaN
# 15    169.175995      Right Hand Grab         Meat_QuarterLeft2_C_2147482368
# 16    170.532608  Right Hand Released         Meat_QuarterLeft2_C_2147482368
# 17    171.819977      Right Hand Grab         Meat_QuarterLeft1_C_2147482369
# 18    172.609299  Right Hand Released         Meat_QuarterLeft1_C_2147482369
# 19    173.241791      Right Hand Grab                                    NaN
# 20    174.274872      Right Hand Grab         Meat_QuarterLeft2_C_2147482368
# 21    176.219101  Right Hand Released         Meat_QuarterLeft2_C_2147482368
# 22    177.451065      Right Hand Grab         Meat_QuarterLeft1_C_2147482369
# 23    182.426910      Right Hand Grab                              Knife_C_4
# 24    184.839920              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 25    187.106689  Right Hand Released                              Knife_C_4
# 26    188.572372      Right Hand Grab        Meat_QuarterRight1_C_2147482367
# 27    191.061874  Right Hand Released        Meat_QuarterRight1_C_2147482367
# 28    192.703461      Right Hand Grab        Meat_QuarterRight2_C_2147482366
# 29    194.370743  Right Hand Released        Meat_QuarterRight2_C_2147482366
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   1.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  1.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  1.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (188, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0      102.500168      Right Hand Grab                   BeefStewCookbook_C_0
# 1      116.874474      Right Hand Grab               BrothParent_C_2147482378
# 160    131.351547                  NaN                                    NaN
# 2      134.913773  Right Hand Released               BrothParent_C_2147482378
# 3      138.969864      Right Hand Grab                                    NaN
# 4      141.783066      Right Hand Grab                   BeefStewCookbook_C_0
# 5      147.721573      Right Hand Grab            Meat_Choppable_C_2147482400
# 6      149.232864  Right Hand Released            Meat_Choppable_C_2147482400
# 7      153.390640      Right Hand Grab                              Knife_C_4
# 8      155.766998              Chopped            Meat_Choppable_C_2147482400
# 9      156.666992              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 10     157.600647              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 11     158.311874  Right Hand Released                              Knife_C_4
# 12     166.008865      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482370
# 13     167.388275  Right Hand Released  Meat_HalfRight_Choppable_C_2147482370
# 14     168.208908      Right Hand Grab                                    NaN
# 15     169.175995      Right Hand Grab         Meat_QuarterLeft2_C_2147482368
# 16     170.532608  Right Hand Released         Meat_QuarterLeft2_C_2147482368
# 17     171.819977      Right Hand Grab         Meat_QuarterLeft1_C_2147482369
# 18     172.609299  Right Hand Released         Meat_QuarterLeft1_C_2147482369
# 19     173.241791      Right Hand Grab                                    NaN
# 20     174.274872      Right Hand Grab         Meat_QuarterLeft2_C_2147482368
# 21     176.219101  Right Hand Released         Meat_QuarterLeft2_C_2147482368
# 161    176.319397                  NaN                                    NaN
# 22     177.451065      Right Hand Grab         Meat_QuarterLeft1_C_2147482369
# 162    180.496872                  NaN                                    NaN
# 23     182.426910      Right Hand Grab                              Knife_C_4
# 24     184.839920              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 25     187.106689  Right Hand Released                              Knife_C_4
# 26     188.572372      Right Hand Grab        Meat_QuarterRight1_C_2147482367
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 160                  NaN     Pour Broth
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   1.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   1.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 161                  NaN       Add Beef
# 22                   0.0            NaN
# 162                  NaN       Add Beef
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN

# %%
#df.to_csv('act_step_C025A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Right Hand Released    54
# Chopped                29
# Left Hand Grab          1
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     4.000000
# mean     40.000000
# std      32.321304
# min       1.000000
# 25%      22.000000
# 50%      41.500000
# 75%      59.500000
# max      76.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 160

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      16
# BeefStewCookbook_C_0                            9
# Potato_Choppable_C_2147482410                   5
# Meat_QuarterLeft2_C_2147482368                  4
# CarrotTopQuarter1_Choppable_C_2147482334        4
# CarrotBottomQuarter1_Choppable_C_2147482328     4
# Meat_QuarterLeft1_C_2147482362                  4
# Onion_Choppable_C_2147482392                    3
# Carrot_Choppable_C_2147482405                   3
# Carrot_Choppable_C_2147482402                   3
# Tomato_Choppable_C_2147482394                   3
# Tomato_Choppable_C_2147482397                   3
# Onion_Choppable_C_2147482389                    3
# Potato_Choppable_C_2147482408                   3
# Meat_Choppable_C_2147482400                     3
# Meat_HalfRight_Choppable_C_2147482370           3
# Meat_Choppable_C_2147482372                     3
# Meat_QuarterLeft1_C_2147482369                  3
# CarrotTopQuarter2_Choppable_C_2147482325        2
# CarrotBotton_Choppable_C_2147482335             2
# Potato_TopHalf_Choppable_C_2147482340           2
# Potato_BottomHalf_Choppable_C_2147482339        2
# NewLadleSimple_C_2147482324                     2
# StirSpoonSimple_C_2147482380                    2
# SaltShakerGrabableSimple_C_2147482377           2
# CarrotBottomQuarter2_Choppable_C_2147482327     2
# CarrotBotton_Choppable_C_2147482329             2
# CarrotBottomQuarter2_Choppable_C_2147482331     2
# CarrotBottomQuarter1_Choppable_C_2147482332     2
# PepperShakerGrabableSimple_C_2147482376         2
# CarrotTopQuarter1_Choppable_C_2147482326        2
# Potato_TopHalf_Choppable_C_2147482342           2
# CarrotTopQuarter2_Choppable_C_2147482333        2
# Tomato_TopHalf_Choppable_C_2147482348           2
# Potato_BottomHalf_Choppable_C_2147482341        2
# Tomato_BottomHalf_Choppable_C_2147482345        2
# BrothParent_C_2147482378                        2
# Tomato_BottomHalf_Choppable_C_2147482347        2
# Onion_Half2_C_2147482353                        2
# Meat_HalfLeft_Choppable_C_2147482371            2
# Onion_Half_C_2147482354                         2
# Onion_Half2_C_2147482351                        2
# Onion_Half_C_2147482352                         2
# Meat_QuarterRight1_C_2147482367                 2
# Tomato_TopHalf_Choppable_C_2147482346           2
# Meat_QuarterRight2_C_2147482366                 2
# Meat_QuarterLeft2_C_2147482361                  2
# Meat_QuarterRight2_C_2147482359                 2
# Meat_QuarterRight1_C_2147482360                 2
# Meat_HalfLeft_Choppable_C_2147482364            1
# Onion_Peeled_C_2147482355                       1
# Meat_HalfRight_Choppable_C_2147482363           1
# Onion_Peeled_C_2147482356                       1
# CarrotTop_Choppable_C_2147482330                1
# CarrotTop_Choppable_C_2147482336                1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 148

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              2   28.851379                  0.0
# 1         Add Beef             20   41.405624                  3.0
# 2         Add Beef              1    3.045807                  0.0
# 3         Add Beef              5    8.645951                  0.0
# 4         Add Beef              2    1.724090                  0.0
# 5        Add Onion             36   67.523667                  6.0
# 6        Add Onion              2    1.633758                  0.0
# 7        Add Onion              2    2.856049                  0.0
# 8        Add Onion              2    1.600830                  0.0
# 9      Add Tomtato             12   18.852844                  1.0
# 10     Add Tomtato              2    1.489197                  0.0
# 11     Add Tomtato              2    1.357422                  0.0
# 12     Add Tomtato              2    1.355163                  0.0
# 13      Add Potato             14   23.473266                  1.0
# 14      Add Potato              2    1.611419                  0.0
# 15      Add Potato              2    1.476899                  0.0
# 16      Add Potato              2    1.346253                  0.0
# 17      Add Carrot             21   28.150147                  0.0
# 18      Add Carrot              2    1.321503                  0.0
# 19      Add Carrot              2    1.288208                  0.0
# 20      Add Carrot              2    1.379029                  0.0
# 21      Add Carrot              2    1.489441                  0.0
# 22      Add Carrot              2    1.176910                  0.0
# 23      Add Carrot              2    1.199463                  0.0
# 24      Add Carrot              2    1.377716                  0.0
# 25      Add pepper              2   13.755920                  0.0
# 26        Add Salt              2    5.454926                  0.0
# 27       Stir Stew              2   13.619903                  0.0
# 28  Post last step              9   38.601929                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 160

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C025',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C025            160        317.064713                       12.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        5.517241   10.933266             0.413793
# std         7.984900   16.210990             1.239736
# min         1.000000    1.176910             0.000000
# 25%         2.000000    1.377716             0.000000
# 50%         2.000000    1.633758             0.000000
# 75%         2.000000   13.755920             0.000000
# max        36.000000   67.523667             6.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     6
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             4          2                  6
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      4    19      0
# Add Onion                    0      4    15     16
# Add Tomtato                  0      2     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   4      2     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      16                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  25
# Add Onion                  0       0                  36
# Add Tomtato                0      14                  17
# Add Potato                 0       0                  19
# Add Carrot                 0       0                  35
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   37.382417
# 1       Add Beef      4   54.821472
# 2      Add Onion      4   73.614304
# 3    Add Tomtato      4   23.054626
# 4     Add Potato      4   27.907837
# 5     Pour Broth      1   28.851379
# 6     Add pepper      1   13.755920
# 7       Add Salt      1    5.454926
# 8      Stir Stew      1   13.619903

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0      102.500168      Right Hand Grab         BeefStewCookbook_C_0
# 1      116.874474      Right Hand Grab     BrothParent_C_2147482378
# 2      131.351547                  NaN                          NaN
# 3      134.913773  Right Hand Released     BrothParent_C_2147482378
# 4      138.969864      Right Hand Grab                          NaN
# ..            ...                  ...                          ...
# 183    447.368408      Right Hand Grab                          NaN
# 184    450.369293      Right Hand Grab  NewLadleSimple_C_2147482324
# 185    458.055664  Right Hand Released  NewLadleSimple_C_2147482324
# 186    463.030090      Right Hand Grab         BeefStewCookbook_C_0
# 187    472.151245      Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    0.0            NaN
# 2                    NaN     Pour Broth
# 3                    0.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 183                  1.0            NaN
# 184                  0.0            NaN
# 185                  0.0            NaN
# 186                  0.0            NaN
# 187                  0.0            NaN
#
# [188 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        76
# Right Hand Released    54
# Chopped                29
# Left Hand Grab          1
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab          0.0
# Right Hand Grab        12.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 2      Right Hand Grab            76                       12.0
# 3  Right Hand Released            54                        0.0
# 0              Chopped            29                        0.0
# 1       Left Hand Grab             1                        0.0
