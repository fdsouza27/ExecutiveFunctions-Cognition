# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C013 A/'
file_name = 'C013_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0      7.749941  Right Hand Grab  BeefStewCookbook_C_0
# 1     24.242456   Left Hand Grab                   NaN
# 2     25.510166   Left Hand Grab                   NaN
# 3     33.639210  Right Hand Grab                   NaN
# 4     35.833088  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (314, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    279
# 1     35
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 1       24.242456   Left Hand Grab               NaN                    1
# 2       25.510166   Left Hand Grab               NaN                    1
# 3       33.639210  Right Hand Grab               NaN                    1
# 4       35.833088  Right Hand Grab               NaN                    1
# 5       38.120834  Right Hand Grab               NaN                    1
# 6       40.614952  Right Hand Grab               NaN                    1
# 13      62.093410  Right Hand Grab               NaN                    1
# 14      68.367287  Right Hand Grab               NaN                    1
# 15      70.362038  Right Hand Grab               NaN                    1
# 16      73.036873  Right Hand Grab               NaN                    1
# 65     139.136200   Left Hand Grab               NaN                    1
# 73     152.732697  Right Hand Grab               NaN                    1
# 84     164.976913  Right Hand Grab               NaN                    1
# 85     166.876266  Right Hand Grab               NaN                    1
# 118    212.988098  Right Hand Grab               NaN                    1
# 132    227.341095  Right Hand Grab               NaN                    1
# 134    231.908035  Right Hand Grab               NaN                    1
# 139    237.370193  Right Hand Grab               NaN                    1
# 141    238.370224   Left Hand Grab               NaN                    1
# 162    263.179901   Left Hand Grab               NaN                    1
# 183    289.205933  Right Hand Grab               NaN                    1
# 226    343.122040   Left Hand Grab               NaN                    1
# 275    412.465454  Right Hand Grab               NaN                    1
# 276    415.898651  Right Hand Grab               NaN                    1
# 277    417.752625   Left Hand Grab               NaN                    1
# 278    420.638031   Left Hand Grab               NaN                    1
# 290    479.012817  Right Hand Grab               NaN                    1
# 298    503.952850  Right Hand Grab               NaN                    1
# 304    545.337585   Left Hand Grab               NaN                    1
# 305    546.627930   Left Hand Grab               NaN                    1
# 306    547.018738   Left Hand Grab               NaN                    1
# 307    548.834717   Left Hand Grab               NaN                    1
# 308    549.240417   Left Hand Grab               NaN                    1
# 309    555.856689   Left Hand Grab               NaN                    1
# 312    558.525513   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0      7.749941  Right Hand Grab  BeefStewCookbook_C_0                    0
# 1     24.242456   Left Hand Grab                   NaN                    1
# 2     25.510166   Left Hand Grab                   NaN                    1
# 3     33.639210  Right Hand Grab                   NaN                    1
# 4     35.833088  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C013 A/'
file_name = 'C013_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     54.208454     Pour Broth
# 1    137.958542       Add Beef
# 2    142.034592       Add Beef
# 3    145.523331       Add Beef
# 4    149.222183       Add Beef
# 5    152.087357       Add Beef
# 6    155.289383       Add Beef
# 7    160.043152       Add Beef
# 8    163.216827       Add Beef
# 9    206.553528      Add Onion

# %%
df2.shape
# Out:
# (30, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0       7.749941      Right Hand Grab                   BeefStewCookbook_C_0
# 1      24.242456       Left Hand Grab                                    NaN
# 2      25.510166       Left Hand Grab                                    NaN
# 3      33.639210      Right Hand Grab                                    NaN
# 4      35.833088      Right Hand Grab                                    NaN
# 5      38.120834      Right Hand Grab                                    NaN
# 6      40.614952      Right Hand Grab                                    NaN
# 7      41.787178      Right Hand Grab               BrothParent_C_2147482366
# 8      52.042561  Right Hand Released               BrothParent_C_2147482366
# 9      52.636375      Right Hand Grab               BrothParent_C_2147482366
# 10     54.619091  Right Hand Released               BrothParent_C_2147482366
# 11     55.651100      Right Hand Grab               BrothParent_C_2147482366
# 12     57.837322  Right Hand Released               BrothParent_C_2147482366
# 13     62.093410      Right Hand Grab                                    NaN
# 14     68.367287      Right Hand Grab                                    NaN
# 15     70.362038      Right Hand Grab                                    NaN
# 16     73.036873      Right Hand Grab                                    NaN
# 17     77.505684      Right Hand Grab                   BeefStewCookbook_C_0
# 18     82.331680       Left Hand Grab            Meat_Choppable_C_2147482388
# 19     83.586449   Left Hand Released            Meat_Choppable_C_2147482388
# 20     85.020096      Right Hand Grab                              Knife_C_4
# 21     86.730843              Chopped            Meat_Choppable_C_2147482388
# 22     88.694740  Right Hand Released                              Knife_C_4
# 23     90.530838      Right Hand Grab                              Knife_C_4
# 24     91.994629              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 25     92.703186              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 26     96.230270  Right Hand Released                              Knife_C_4
# 27     97.261772      Right Hand Grab                              Knife_C_4
# 28     97.939484  Right Hand Released                              Knife_C_4
# 29     98.828690      Right Hand Grab        Meat_QuarterRight2_C_2147482356
#
#     Missed Interactions Completed Step
# 0                   0.0            NaN
# 1                   1.0            NaN
# 2                   1.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   1.0            NaN
# 6                   1.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  1.0            NaN
# 14                  1.0            NaN
# 15                  1.0            NaN
# 16                  1.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (344, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        7.749941      Right Hand Grab                   BeefStewCookbook_C_0
# 1       24.242456       Left Hand Grab                                    NaN
# 2       25.510166       Left Hand Grab                                    NaN
# 3       33.639210      Right Hand Grab                                    NaN
# 4       35.833088      Right Hand Grab                                    NaN
# 5       38.120834      Right Hand Grab                                    NaN
# 6       40.614952      Right Hand Grab                                    NaN
# 7       41.787178      Right Hand Grab               BrothParent_C_2147482366
# 8       52.042561  Right Hand Released               BrothParent_C_2147482366
# 9       52.636375      Right Hand Grab               BrothParent_C_2147482366
# 314     54.208454                  NaN                                    NaN
# 10      54.619091  Right Hand Released               BrothParent_C_2147482366
# 11      55.651100      Right Hand Grab               BrothParent_C_2147482366
# 12      57.837322  Right Hand Released               BrothParent_C_2147482366
# 13      62.093410      Right Hand Grab                                    NaN
# 14      68.367287      Right Hand Grab                                    NaN
# 15      70.362038      Right Hand Grab                                    NaN
# 16      73.036873      Right Hand Grab                                    NaN
# 17      77.505684      Right Hand Grab                   BeefStewCookbook_C_0
# 18      82.331680       Left Hand Grab            Meat_Choppable_C_2147482388
# 19      83.586449   Left Hand Released            Meat_Choppable_C_2147482388
# 20      85.020096      Right Hand Grab                              Knife_C_4
# 21      86.730843              Chopped            Meat_Choppable_C_2147482388
# 22      88.694740  Right Hand Released                              Knife_C_4
# 23      90.530838      Right Hand Grab                              Knife_C_4
# 24      91.994629              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 25      92.703186              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 26      96.230270  Right Hand Released                              Knife_C_4
# 27      97.261772      Right Hand Grab                              Knife_C_4
# 28      97.939484  Right Hand Released                              Knife_C_4
#
#      Missed Interactions Completed Step
# 0                    0.0            NaN
# 1                    1.0            NaN
# 2                    1.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    1.0            NaN
# 6                    1.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 314                  NaN     Pour Broth
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   1.0            NaN
# 14                   1.0            NaN
# 15                   1.0            NaN
# 16                   1.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C013A.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        107
# Right Hand Released     74
# Left Hand Grab          56
# Chopped                 39
# Left Hand Released      38
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count      5.000000
# mean      62.800000
# std       28.752391
# min       38.000000
# 25%       39.000000
# 50%       56.000000
# 75%       74.000000
# max      107.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 314

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                  54
# PepperShakerGrabableSimple_C_2147482364    22
# BeefStewCookbook_C_0                       12
# StirSpoonSimple_C_2147482368               10
# Meat_QuarterLeft2_C_2147482354             10
#                                            ..
# Meat_HalfLeft_Choppable_C_2147482359        1
# Meat_HalfRight_Choppable_C_2147482358       1
# Meat_HalfLeft_Choppable_C_2147482352        1
# CarrotTop_Choppable_C_2147482312            1
# Exit_C_1                                    1
# Name: count, Length: 69, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 279

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth             10   46.458513                  6.0
# 1         Add Beef             55   83.339451                  4.0
# 2         Add Beef              2    2.898392                  1.0
# 3         Add Beef              2    2.089264                  0.0
# 4         Add Beef              2    2.433212                  0.0
# 5         Add Beef              2    1.421311                  0.0
# 6         Add Beef              3    2.556686                  1.0
# 7         Add Beef              6    3.987320                  0.0
# 8         Add Beef              2    1.968124                  0.0
# 9        Add Onion             32   41.576615                  2.0
# 10       Add Onion              0    0.000000                  0.0
# 11       Add Onion              2    1.393174                  0.0
# 12       Add Onion             14   12.162674                  1.0
# 13     Add Tomtato             23   23.937195                  4.0
# 14     Add Tomtato              2    1.192139                  0.0
# 15     Add Tomtato              2    1.045548                  0.0
# 16     Add Tomtato              2    1.295837                  0.0
# 17      Add Potato             16   20.218750                  1.0
# 18      Add Potato              2    1.117676                  0.0
# 19      Add Potato              2    1.201111                  0.0
# 20      Add Potato              2    1.110840                  0.0
# 21      Add Carrot             37   47.293823                  1.0
# 22      Add Carrot              2    1.801727                  0.0
# 23      Add Carrot              2    1.032226                  0.0
# 24      Add Carrot              5    5.021973                  1.0
# 25      Add Carrot              3    2.564057                  0.0
# 26      Add Carrot              2    1.256409                  0.0
# 27      Add Carrot              4    3.609161                  0.0
# 28      Add Carrot              9    8.016815                  0.0
# 29       Stir Stew             41   82.667084                  4.0
# 30  Post last step             26  124.227905                  9.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 314

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C013',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C013            314        530.895012                       35.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      31.000000   31.000000            31.000000
# mean       10.129032   17.125646             1.129032
# std        14.037431   30.301513             2.125119
# min         0.000000    0.000000             0.000000
# 25%         2.000000    1.276123             0.000000
# 50%         2.000000    2.556686             0.000000
# 75%        12.000000   16.190712             1.000000
# max        55.000000  124.227905             9.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            3       0                     0
# Add Beef                    1            3       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  2            0      15                     5
# Stir Stew                   2            0       0                     2
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      6            10          8                  4
# Stir Stew                       0             0          2                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0     18    46      0
# Add Onion                    0     18     0     26
# Add Tomtato                  0      6     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   4      8     0      0
# Stir Stew                    0      2     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      18                         0
# Add Carrot                            0       0                         0
# Stir Stew                            16       0                         6
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   4
# Add Beef                   0       0                  68
# Add Onion                  0       0                  45
# Add Tomtato                0      18                  25
# Add Potato                 0       0                  21
# Add Carrot                 0       0                  62
# Stir Stew                  7       0                  37

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8  100.693760
# 1     Add Carrot      8   70.596191
# 2      Add Onion      4   55.132463
# 3    Add Tomtato      4   27.470719
# 4     Add Potato      4   23.648377
# 5     Pour Broth      1   46.458513
# 6      Stir Stew      1   82.667084

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time      Action Type     Interacted Object  Missed Interactions  \
# 0        7.749941  Right Hand Grab  BeefStewCookbook_C_0                  0.0
# 1       24.242456   Left Hand Grab                   NaN                  1.0
# 2       25.510166   Left Hand Grab                   NaN                  1.0
# 3       33.639210  Right Hand Grab                   NaN                  1.0
# 4       35.833088  Right Hand Grab                   NaN                  1.0
# ..            ...              ...                   ...                  ...
# 339    555.856689   Left Hand Grab                   NaN                  1.0
# 340    555.923462  Right Hand Grab  BeefStewCookbook_C_0                  0.0
# 341    558.492493  Right Hand Grab  BeefStewCookbook_C_0                  0.0
# 342    558.525513   Left Hand Grab                   NaN                  1.0
# 343    578.394470  Right Hand Grab              Exit_C_1                  0.0
#
#     Completed Step
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 339            NaN
# 340            NaN
# 341            NaN
# 342            NaN
# 343            NaN
#
# [344 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        107
# Right Hand Released     74
# Left Hand Grab          56
# Chopped                 39
# Left Hand Released      38
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                 0.0
# Left Hand Grab         15.0
# Left Hand Released      0.0
# Right Hand Grab        20.0
# Right Hand Released     0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab           107                       20.0
# 4  Right Hand Released            74                        0.0
# 1       Left Hand Grab            56                       15.0
# 0              Chopped            39                        0.0
# 2   Left Hand Released            38                        0.0
