# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C024 D/'
file_name = 'C024_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      6.905308      Right Hand Grab                       NaN
# 1      7.860156      Right Hand Grab      BeefStewCookbook_C_0
# 2     12.021451      Right Hand Grab  BrothParent_C_2147482366
# 3     25.400614  Right Hand Released  BrothParent_C_2147482366
# 4     27.089031      Right Hand Grab      BeefStewCookbook_C_0

# %%
df1.shape
# Out:
# (156, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    152
# 1      4
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0        6.905308  Right Hand Grab               NaN                    1
# 105    134.493103  Right Hand Grab               NaN                    1
# 146    192.639023  Right Hand Grab               NaN                    1
# 149    204.500549  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      6.905308      Right Hand Grab                       NaN
# 1      7.860156      Right Hand Grab      BeefStewCookbook_C_0
# 2     12.021451      Right Hand Grab  BrothParent_C_2147482366
# 3     25.400614  Right Hand Released  BrothParent_C_2147482366
# 4     27.089031      Right Hand Grab      BeefStewCookbook_C_0
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C024 D/'
file_name = 'C024_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     23.192026     Pour Broth
# 1     50.197544       Add Beef
# 2     52.074524       Add Beef
# 3     53.771420       Add Beef
# 4     55.351456       Add Beef
# 5     63.758881       Add Beef
# 6     65.247513       Add Beef
# 7     66.794029       Add Beef
# 8     68.204056       Add Beef
# 9     84.723625      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0       6.905308      Right Hand Grab                                    NaN
# 1       7.860156      Right Hand Grab                   BeefStewCookbook_C_0
# 2      12.021451      Right Hand Grab               BrothParent_C_2147482366
# 3      25.400614  Right Hand Released               BrothParent_C_2147482366
# 4      27.089031      Right Hand Grab                   BeefStewCookbook_C_0
# 5      28.808149      Right Hand Grab            Meat_Choppable_C_2147482388
# 6      29.876293  Right Hand Released            Meat_Choppable_C_2147482388
# 7      30.587723      Right Hand Grab            Meat_Choppable_C_2147482360
# 8      31.806839  Right Hand Released            Meat_Choppable_C_2147482360
# 9      32.874062      Right Hand Grab                              Knife_C_4
# 10     33.675686              Chopped            Meat_Choppable_C_2147482388
# 11     34.442478              Chopped   Meat_HalfLeft_Choppable_C_2147482358
# 12     35.510761              Chopped  Meat_HalfRight_Choppable_C_2147482357
# 13     36.321812              Chopped            Meat_Choppable_C_2147482360
# 14     37.199623              Chopped   Meat_HalfLeft_Choppable_C_2147482358
# 15     38.183594              Chopped        Meat_QuarterRight2_C_2147482355
# 16     40.491245              Chopped         Meat_QuarterLeft2_C_2147482351
# 17     41.942356              Chopped        Meat_QuarterRight1_C_2147482356
# 18     43.375557              Chopped        Meat_QuarterRight2_C_2147482355
# 19     43.997444              Chopped         Meat_QuarterLeft2_C_2147482351
# 20     45.272392  Right Hand Released                              Knife_C_4
# 21     46.083984      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482353
# 22     47.163567  Right Hand Released  Meat_HalfRight_Choppable_C_2147482353
# 23     47.619453      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 24     50.041790  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 25     50.953255      Right Hand Grab        Meat_QuarterRight1_C_2147482356
# 26     51.962612  Right Hand Released        Meat_QuarterRight1_C_2147482356
# 27     52.541950      Right Hand Grab         Meat_QuarterLeft2_C_2147482351
# 28     53.705521  Right Hand Released         Meat_QuarterLeft2_C_2147482351
# 29     54.238754      Right Hand Grab         Meat_QuarterLeft1_C_2147482352
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   0.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (188, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        6.905308      Right Hand Grab                                    NaN
# 1        7.860156      Right Hand Grab                   BeefStewCookbook_C_0
# 2       12.021451      Right Hand Grab               BrothParent_C_2147482366
# 156     23.192026                  NaN                                    NaN
# 3       25.400614  Right Hand Released               BrothParent_C_2147482366
# 4       27.089031      Right Hand Grab                   BeefStewCookbook_C_0
# 5       28.808149      Right Hand Grab            Meat_Choppable_C_2147482388
# 6       29.876293  Right Hand Released            Meat_Choppable_C_2147482388
# 7       30.587723      Right Hand Grab            Meat_Choppable_C_2147482360
# 8       31.806839  Right Hand Released            Meat_Choppable_C_2147482360
# 9       32.874062      Right Hand Grab                              Knife_C_4
# 10      33.675686              Chopped            Meat_Choppable_C_2147482388
# 11      34.442478              Chopped   Meat_HalfLeft_Choppable_C_2147482358
# 12      35.510761              Chopped  Meat_HalfRight_Choppable_C_2147482357
# 13      36.321812              Chopped            Meat_Choppable_C_2147482360
# 14      37.199623              Chopped   Meat_HalfLeft_Choppable_C_2147482358
# 15      38.183594              Chopped        Meat_QuarterRight2_C_2147482355
# 16      40.491245              Chopped         Meat_QuarterLeft2_C_2147482351
# 17      41.942356              Chopped        Meat_QuarterRight1_C_2147482356
# 18      43.375557              Chopped        Meat_QuarterRight2_C_2147482355
# 19      43.997444              Chopped         Meat_QuarterLeft2_C_2147482351
# 20      45.272392  Right Hand Released                              Knife_C_4
# 21      46.083984      Right Hand Grab  Meat_HalfRight_Choppable_C_2147482353
# 22      47.163567  Right Hand Released  Meat_HalfRight_Choppable_C_2147482353
# 23      47.619453      Right Hand Grab        Meat_QuarterRight2_C_2147482355
# 24      50.041790  Right Hand Released        Meat_QuarterRight2_C_2147482355
# 157     50.197544                  NaN                                    NaN
# 25      50.953255      Right Hand Grab        Meat_QuarterRight1_C_2147482356
# 26      51.962612  Right Hand Released        Meat_QuarterRight1_C_2147482356
# 158     52.074524                  NaN                                    NaN
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 156                  NaN     Pour Broth
# 3                    0.0            NaN
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 157                  NaN       Add Beef
# 25                   0.0            NaN
# 26                   0.0            NaN
# 158                  NaN       Add Beef

# %%
#df.to_csv('act_step_C024D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        70
# Right Hand Released    56
# Chopped                29
# Left Hand Grab          1
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     4.000000
# mean     39.000000
# std      30.517754
# min       1.000000
# 25%      22.000000
# 50%      42.500000
# 75%      59.500000
# max      70.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 156

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      20
# BeefStewCookbook_C_0                            9
# Meat_QuarterRight2_C_2147482355                 4
# Meat_QuarterLeft2_C_2147482351                  4
# SaltShakerGrabableSimple_C_2147482365           4
# PepperShakerGrabableSimple_C_2147482364         4
# Potato_BottomHalf_Choppable_C_2147482327        3
# Potato_Choppable_C_2147482396                   3
# Carrot_Choppable_C_2147482391                   3
# Tomato_Choppable_C_2147482384                   3
# Tomato_Choppable_C_2147482381                   3
# Carrot_Choppable_C_2147482390                   3
# CarrotTopQuarter2_Choppable_C_2147482317        3
# Onion_Choppable_C_2147482376                    3
# Onion_Choppable_C_2147482380                    3
# Potato_Choppable_C_2147482332                   3
# Meat_QuarterRight1_C_2147482356                 3
# Meat_QuarterLeft2_C_2147482347                  3
# Meat_Choppable_C_2147482388                     3
# Meat_HalfRight_Choppable_C_2147482353           3
# Meat_Choppable_C_2147482360                     3
# NewLadleSimple_C_2147482312                     2
# Potato_TopHalf_Choppable_C_2147482330           2
# Potato_BottomHalf_Choppable_C_2147482329        2
# Potato_TopHalf_Choppable_C_2147482328           2
# CarrotTopQuarter2_Choppable_C_2147482313        2
# StirSpoonSimple_C_2147482368                    2
# CarrotBottomQuarter1_Choppable_C_2147482320     2
# CarrotBottomQuarter2_Choppable_C_2147482319     2
# CarrotBottomQuarter2_Choppable_C_2147482315     2
# CarrotTopQuarter1_Choppable_C_2147482318        2
# CarrotBottomQuarter1_Choppable_C_2147482316     2
# CarrotTopQuarter1_Choppable_C_2147482314        2
# Tomato_TopHalf_Choppable_C_2147482336           2
# Tomato_TopHalf_Choppable_C_2147482334           2
# Onion_Half_C_2147482340                         2
# Meat_HalfLeft_Choppable_C_2147482358            2
# Meat_QuarterLeft1_C_2147482352                  2
# Meat_QuarterRight2_C_2147482349                 2
# Meat_QuarterRight1_C_2147482350                 2
# Meat_QuarterLeft1_C_2147482348                  2
# Tomato_BottomHalf_Choppable_C_2147482333        2
# Onion_Half2_C_2147482341                        2
# Onion_Half_C_2147482342                         2
# Onion_Half2_C_2147482339                        2
# Tomato_BottomHalf_Choppable_C_2147482335        2
# BrothParent_C_2147482366                        2
# StewBowlSimple_C_2147482310                     2
# CarrotTop_Choppable_C_2147482324                1
# CarrotBotton_Choppable_C_2147482321             1
# Onion_Peeled_C_2147482343                       1
# Onion_Peeled_C_2147482344                       1
# CarrotTop_Choppable_C_2147482322                1
# CarrotBotton_Choppable_C_2147482323             1
# Meat_HalfLeft_Choppable_C_2147482354            1
# Meat_HalfRight_Choppable_C_2147482357           1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 152

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              3   16.286718                  1.0
# 1         Add Beef             22   24.796930                  0.0
# 2         Add Beef              2    1.121269                  0.0
# 3         Add Beef              2    1.229470                  0.0
# 4         Add Beef              2    1.112702                  0.0
# 5         Add Beef              9    7.751755                  0.0
# 6         Add Beef              2    0.967537                  0.0
# 7         Add Beef              2    1.101021                  0.0
# 8         Add Beef              2    0.877671                  0.0
# 9        Add Onion             13   14.729957                  0.0
# 10       Add Onion              2    1.356438                  0.0
# 11       Add Onion              2    0.871223                  0.0
# 12       Add Onion              2    1.141967                  0.0
# 13     Add Tomtato             11   11.587540                  0.0
# 14     Add Tomtato              2    1.011497                  0.0
# 15     Add Tomtato              2    0.966812                  0.0
# 16     Add Tomtato              2    0.867554                  0.0
# 17      Add Potato             16   16.386039                  0.0
# 18      Add Potato              2    0.910355                  0.0
# 19      Add Potato              2    0.819473                  0.0
# 20      Add Potato              2    0.724457                  0.0
# 21      Add Carrot             19   21.895233                  1.0
# 22      Add Carrot              2    1.027206                  0.0
# 23      Add Carrot              2    0.956161                  0.0
# 24      Add Carrot              2    0.888092                  0.0
# 25      Add Carrot              2    0.944290                  0.0
# 26      Add Carrot              2    1.034958                  0.0
# 27      Add Carrot              2    0.918152                  0.0
# 28      Add Carrot              2    0.936157                  0.0
# 29      Add pepper              2    4.981522                  0.0
# 30        Add Salt              2    4.679535                  0.0
# 31       Stir Stew              7   16.268890                  1.0
# 32  Post last step              8   27.659164                  1.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 156

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C024',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C024            156        188.807745                        4.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        4.727273    5.721447             0.121212
# std         5.455918    8.018634             0.331434
# min         2.000000    0.724457             0.000000
# 25%         2.000000    0.936157             0.000000
# 50%         2.000000    1.101021             0.000000
# 75%         3.000000    7.751755             0.000000
# max        22.000000   27.659164             1.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            1       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             2          2                  4
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      6    35      0
# Add Onion                    0      2     0     16
# Add Tomtato                  0      2     0      0
# Add Potato                   0      6     0      0
# Add Carrot                   5      4     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      15                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
# Stir Stew                             2       0                         3
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  43
# Add Onion                  0       0                  19
# Add Tomtato                0      14                  17
# Add Potato                 0       0                  22
# Add Carrot                 0       0                  32
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   6

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   38.958355
# 1     Add Carrot      8   28.600249
# 2      Add Onion      4   18.099585
# 3    Add Tomtato      4   14.433403
# 4     Add Potato      4   18.840324
# 5     Pour Broth      1   16.286718
# 6     Add pepper      1    4.981522
# 7       Add Salt      1    4.679535
# 8      Stir Stew      1   16.268890

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0        6.905308      Right Hand Grab                          NaN
# 1        7.860156      Right Hand Grab         BeefStewCookbook_C_0
# 2       12.021451      Right Hand Grab     BrothParent_C_2147482366
# 3       23.192026                  NaN                          NaN
# 4       25.400614  Right Hand Released     BrothParent_C_2147482366
# ..            ...                  ...                          ...
# 183    216.509155      Right Hand Grab  NewLadleSimple_C_2147482312
# 184    223.563690  Right Hand Released  NewLadleSimple_C_2147482312
# 185    225.644028      Right Hand Grab         BeefStewCookbook_C_0
# 186    230.096512      Right Hand Grab  StewBowlSimple_C_2147482310
# 187    230.108032       Left Hand Grab  StewBowlSimple_C_2147482310
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    0.0            NaN
# 3                    NaN     Pour Broth
# 4                    0.0            NaN
# ..                   ...            ...
# 183                  0.0            NaN
# 184                  0.0            NaN
# 185                  0.0            NaN
# 186                  0.0            NaN
# 187                  0.0            NaN
#
# [188 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        70
# Right Hand Released    56
# Chopped                29
# Left Hand Grab          1
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         0.0
# Right Hand Grab        4.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 2      Right Hand Grab            70                        4.0
# 3  Right Hand Released            56                        0.0
# 0              Chopped            29                        0.0
# 1       Left Hand Grab             1                        0.0
