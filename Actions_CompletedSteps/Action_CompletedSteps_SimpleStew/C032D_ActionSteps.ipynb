# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C032 D/'
file_name = 'C032_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object
# 0     35.578686  Right Hand Grab                   NaN
# 1     36.211849  Right Hand Grab                   NaN
# 2     39.739067  Right Hand Grab  BeefStewCookbook_C_0
# 3     46.720184  Right Hand Grab                   NaN
# 4     48.865776  Right Hand Grab                   NaN

# %%
df1.shape
# Out:
# (181, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    176
# 1      5
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#     Session Time      Action Type Interacted Object  Missed Interactions
# 0      35.578686  Right Hand Grab               NaN                    1
# 1      36.211849  Right Hand Grab               NaN                    1
# 3      46.720184  Right Hand Grab               NaN                    1
# 4      48.865776  Right Hand Grab               NaN                    1
# 65    119.985367  Right Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time      Action Type     Interacted Object  Missed Interactions
# 0     35.578686  Right Hand Grab                   NaN                    1
# 1     36.211849  Right Hand Grab                   NaN                    1
# 2     39.739067  Right Hand Grab  BeefStewCookbook_C_0                    0
# 3     46.720184  Right Hand Grab                   NaN                    1
# 4     48.865776  Right Hand Grab                   NaN                    1

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C032 D/'
file_name = 'C032_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     62.321751     Pour Broth
# 1    117.056831       Add Beef
# 2    119.076569       Add Beef
# 3    121.729149       Add Beef
# 4    125.916542       Add Beef
# 5    158.953995      Add Onion
# 6    160.433105      Add Onion
# 7    161.826584      Add Onion
# 8    163.629196      Add Onion
# 9    177.109039    Add Tomtato

# %%
df2.shape
# Out:
# (28, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0      35.578686      Right Hand Grab                                    NaN
# 1      36.211849      Right Hand Grab                                    NaN
# 2      39.739067      Right Hand Grab                   BeefStewCookbook_C_0
# 3      46.720184      Right Hand Grab                                    NaN
# 4      48.865776      Right Hand Grab                                    NaN
# 5      49.464867      Right Hand Grab               BrothParent_C_2147482378
# 6      63.947670  Right Hand Released               BrothParent_C_2147482378
# 7      64.625153      Right Hand Grab               BrothParent_C_2147482378
# 8      65.499130  Right Hand Released               BrothParent_C_2147482378
# 9      68.816528      Right Hand Grab                   BeefStewCookbook_C_0
# 10     74.462822      Right Hand Grab            Meat_Choppable_C_2147482400
# 11     75.382133  Right Hand Released            Meat_Choppable_C_2147482400
# 12     76.736267      Right Hand Grab                              Knife_C_4
# 13     77.713097              Chopped            Meat_Choppable_C_2147482400
# 14     78.272545              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 15     79.309456              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 16     79.910011              Chopped        Meat_QuarterRight1_C_2147482369
# 17     80.566826              Chopped        Meat_QuarterRight1_C_2147482369
# 18     81.154930              Chopped        Meat_QuarterRight1_C_2147482369
# 19     82.380013              Chopped        Meat_QuarterRight1_C_2147482369
# 20     82.647446  Right Hand Released                              Knife_C_4
# 21     85.228264      Right Hand Grab                              Knife_C_4
# 22     86.039474              Chopped        Meat_QuarterRight1_C_2147482369
# 23     86.680733              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 24     87.757347              Chopped        Meat_QuarterRight1_C_2147482369
# 25     88.168320  Right Hand Released                              Knife_C_4
# 26     88.646454      Right Hand Grab         Meat_QuarterLeft2_C_2147482366
# 27     89.490883  Right Hand Released         Meat_QuarterLeft2_C_2147482366
# 28     89.780006      Right Hand Grab        Meat_QuarterRight2_C_2147482368
# 29     90.380173  Right Hand Released        Meat_QuarterRight2_C_2147482368
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   1.0            NaN
# 2                   0.0            NaN
# 3                   1.0            NaN
# 4                   1.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   0.0            NaN
# 8                   0.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (209, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0       35.578686      Right Hand Grab                                    NaN
# 1       36.211849      Right Hand Grab                                    NaN
# 2       39.739067      Right Hand Grab                   BeefStewCookbook_C_0
# 3       46.720184      Right Hand Grab                                    NaN
# 4       48.865776      Right Hand Grab                                    NaN
# 5       49.464867      Right Hand Grab               BrothParent_C_2147482378
# 181     62.321751                  NaN                                    NaN
# 6       63.947670  Right Hand Released               BrothParent_C_2147482378
# 7       64.625153      Right Hand Grab               BrothParent_C_2147482378
# 8       65.499130  Right Hand Released               BrothParent_C_2147482378
# 9       68.816528      Right Hand Grab                   BeefStewCookbook_C_0
# 10      74.462822      Right Hand Grab            Meat_Choppable_C_2147482400
# 11      75.382133  Right Hand Released            Meat_Choppable_C_2147482400
# 12      76.736267      Right Hand Grab                              Knife_C_4
# 13      77.713097              Chopped            Meat_Choppable_C_2147482400
# 14      78.272545              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 15      79.309456              Chopped  Meat_HalfRight_Choppable_C_2147482370
# 16      79.910011              Chopped        Meat_QuarterRight1_C_2147482369
# 17      80.566826              Chopped        Meat_QuarterRight1_C_2147482369
# 18      81.154930              Chopped        Meat_QuarterRight1_C_2147482369
# 19      82.380013              Chopped        Meat_QuarterRight1_C_2147482369
# 20      82.647446  Right Hand Released                              Knife_C_4
# 21      85.228264      Right Hand Grab                              Knife_C_4
# 22      86.039474              Chopped        Meat_QuarterRight1_C_2147482369
# 23      86.680733              Chopped   Meat_HalfLeft_Choppable_C_2147482371
# 24      87.757347              Chopped        Meat_QuarterRight1_C_2147482369
# 25      88.168320  Right Hand Released                              Knife_C_4
# 26      88.646454      Right Hand Grab         Meat_QuarterLeft2_C_2147482366
# 27      89.490883  Right Hand Released         Meat_QuarterLeft2_C_2147482366
# 28      89.780006      Right Hand Grab        Meat_QuarterRight2_C_2147482368
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# 5                    0.0            NaN
# 181                  NaN     Pour Broth
# 6                    0.0            NaN
# 7                    0.0            NaN
# 8                    0.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C032D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    62
# Chopped                39
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     3.000000
# mean     60.333333
# std      20.550750
# min      39.000000
# 25%      50.500000
# 50%      62.000000
# 75%      71.000000
# max      80.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 181

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      22
# BeefStewCookbook_C_0                            9
# Meat_QuarterRight1_C_2147482369                 9
# Meat_QuarterRight1_C_2147482362                 7
# Meat_QuarterRight2_C_2147482368                 6
# Meat_QuarterLeft2_C_2147482366                  5
# Meat_Choppable_C_2147482372                     5
# BrothParent_C_2147482378                        4
# Meat_QuarterLeft2_C_2147482359                  4
# Meat_QuarterRight2_C_2147482361                 4
# Onion_Peeled_C_2147482353                       4
# Onion_Choppable_C_2147482388                    3
# Potato_Choppable_C_2147482344                   3
# CarrotTopQuarter1_Choppable_C_2147482330        3
# CarrotBottomQuarter1_Choppable_C_2147482332     3
# Carrot_Choppable_C_2147482403                   3
# Tomato_Choppable_C_2147482350                   3
# Tomato_Choppable_C_2147482393                   3
# Onion_Half_C_2147482356                         3
# Potato_Choppable_C_2147482407                   3
# Carrot_Choppable_C_2147482405                   3
# Onion_Half2_C_2147482355                        3
# Onion_Choppable_C_2147482392                    3
# Meat_HalfLeft_Choppable_C_2147482364            3
# Meat_Choppable_C_2147482400                     3
# Potato_TopHalf_Choppable_C_2147482340           2
# CarrotTopQuarter2_Choppable_C_2147482325        2
# CarrotBottomQuarter1_Choppable_C_2147482328     2
# CarrotBottomQuarter2_Choppable_C_2147482327     2
# CarrotTopQuarter1_Choppable_C_2147482326        2
# PepperShakerGrabableSimple_C_2147482376         2
# CarrotBottomQuarter2_Choppable_C_2147482331     2
# SaltShakerGrabableSimple_C_2147482377           2
# StirSpoonSimple_C_2147482380                    2
# NewLadleSimple_C_2147482324                     2
# CarrotTopQuarter2_Choppable_C_2147482329        2
# Tomato_BottomHalf_Choppable_C_2147482345        2
# Potato_BottomHalf_Choppable_C_2147482339        2
# Potato_BottomHalf_Choppable_C_2147482341        2
# Meat_HalfLeft_Choppable_C_2147482371            2
# Meat_HalfRight_Choppable_C_2147482363           2
# Meat_QuarterLeft1_C_2147482367                  2
# Onion_Peeled_C_2147482357                       2
# Onion_Half_C_2147482352                         2
# Onion_Half2_C_2147482351                        2
# Tomato_BottomHalf_Choppable_C_2147482347        2
# Tomato_TopHalf_Choppable_C_2147482346           2
# Tomato_TopHalf_Choppable_C_2147482348           2
# Potato_TopHalf_Choppable_C_2147482342           2
# CarrotTop_Choppable_C_2147482334                1
# Meat_QuarterLeft1_C_2147482360                  1
# CarrotBotton_Choppable_C_2147482333             1
# CarrotTop_Choppable_C_2147482336                1
# Meat_HalfRight_Choppable_C_2147482370           1
# CarrotBotton_Choppable_C_2147482335             1
# Exit_C_1                                        1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 176

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              6   26.743065                  4.0
# 1         Add Beef             57   53.109161                  0.0
# 2         Add Beef              2    1.058854                  0.0
# 3         Add Beef              3    1.743782                  1.0
# 4         Add Beef              2    3.009315                  0.0
# 5        Add Onion             28   29.953202                  0.0
# 6        Add Onion              2    0.723388                  0.0
# 7        Add Onion              2    0.756821                  0.0
# 8        Add Onion              2    1.097427                  0.0
# 9      Add Tomtato             11   12.785644                  0.0
# 10     Add Tomtato              2    0.889587                  0.0
# 11     Add Tomtato              2    0.854721                  0.0
# 12     Add Tomtato              2    1.581101                  0.0
# 13      Add Potato             11   12.492493                  0.0
# 14      Add Potato              2    0.935715                  0.0
# 15      Add Potato              2    0.744049                  0.0
# 16      Add Potato              2    1.607010                  0.0
# 17      Add Carrot             17   14.999054                  0.0
# 18      Add Carrot              2    0.944092                  0.0
# 19      Add Carrot              2    0.854920                  0.0
# 20      Add Carrot              2    1.211227                  0.0
# 21      Add Carrot              2    0.793564                  0.0
# 22      Add Carrot              2    0.968338                  0.0
# 23      Add Carrot              2    0.966278                  0.0
# 24      Add Carrot              2    0.937088                  0.0
# 25      Add pepper              2    8.424560                  0.0
# 26        Add Salt              2    3.323426                  0.0
# 27       Stir Stew              2    7.765777                  0.0
# 28  Post last step              6   23.193665                  0.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 181

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C032',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C032            181        214.467324                        5.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      29.000000   29.000000            29.000000
# mean        6.241379    7.395425             0.172414
# std        11.337848   12.103262             0.759180
# min         2.000000    0.723388             0.000000
# 25%         2.000000    0.935715             0.000000
# 50%         2.000000    1.211227             0.000000
# 75%         3.000000    8.424560             0.000000
# max        57.000000   53.109161             4.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            3       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 1            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     5
# Add pepper                  1            0       0                     0
# Add Salt                    0            0       0                     0
# Stir Stew                   0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             2          2                  5
# Add pepper                      0             0          0                  0
# Add Salt                        0             0          0                  0
# Stir Stew                       0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0     10    49      0
# Add Onion                    0      6     5     22
# Add Tomtato                  0      2     0      0
# Add Potato                   0      2     0      0
# Add Carrot                   4      2     0      0
# Add pepper                   0      0     0      0
# Add Salt                     0      0     0      0
# Stir Stew                    0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      14                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Add Salt                              1       0                         1
# Stir Stew                             0       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   0       0                  63
# Add Onion                  0       0                  34
# Add Tomtato                0      14                  17
# Add Potato                 0       0                  17
# Add Carrot                 0       0                  31
# Add pepper                 0       0                   2
# Add Salt                   0       0                   2
# Stir Stew                  1       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0     Add Carrot      8   21.674561
# 1       Add Beef      4   58.921112
# 2      Add Onion      4   32.530838
# 3    Add Tomtato      4   16.111053
# 4     Add Potato      4   15.779267
# 5     Pour Broth      1   26.743065
# 6     Add pepper      1    8.424560
# 7       Add Salt      1    3.323426
# 8      Stir Stew      1    7.765777

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0       35.578686      Right Hand Grab                          NaN
# 1       36.211849      Right Hand Grab                          NaN
# 2       39.739067      Right Hand Grab         BeefStewCookbook_C_0
# 3       46.720184      Right Hand Grab                          NaN
# 4       48.865776      Right Hand Grab                          NaN
# ..            ...                  ...                          ...
# 204    255.270218      Right Hand Grab         BeefStewCookbook_C_0
# 205    258.322357      Right Hand Grab  NewLadleSimple_C_2147482324
# 206    264.029083  Right Hand Released  NewLadleSimple_C_2147482324
# 207    269.217957      Right Hand Grab         BeefStewCookbook_C_0
# 208    276.298279      Right Hand Grab                     Exit_C_1
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    1.0            NaN
# 2                    0.0            NaN
# 3                    1.0            NaN
# 4                    1.0            NaN
# ..                   ...            ...
# 204                  0.0            NaN
# 205                  0.0            NaN
# 206                  0.0            NaN
# 207                  0.0            NaN
# 208                  0.0            NaN
#
# [209 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        80
# Right Hand Released    62
# Chopped                39
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Right Hand Grab        5.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 1      Right Hand Grab            80                        5.0
# 2  Right Hand Released            62                        0.0
# 0              Chopped            39                        0.0
