# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C016 D/'
file_name = 'C016_SimpleStew_ActionData.csv'

file_path = os.path.join(main_dir, file_name)

df1 = pd.read_csv(file_path)

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object
# 0      7.489102      Right Hand Grab                       NaN
# 1      8.331804      Right Hand Grab      BeefStewCookbook_C_0
# 2      9.463898      Right Hand Grab                       NaN
# 3     10.206573      Right Hand Grab  BrothParent_C_2147482366
# 4     23.438997  Right Hand Released  BrothParent_C_2147482366

# %%
df1.shape
# Out:
# (183, 3)

# %%
df1['Missed Interactions']=df1['Interacted Object'].isna().astype(int)

# %%
df1['Missed Interactions'].value_counts()
# Out:
# Missed Interactions
# 0    167
# 1     16
# Name: count, dtype: int64

# %%
# Filter the DataFrame for missed interactions
missed_int = df1[df1['Missed Interactions'] == 1]

# Display the relevant information
missed_info = missed_int[[ 'Action Type', 'Session Time']]
missed_int
# Out:
#      Session Time      Action Type Interacted Object  Missed Interactions
# 0        7.489102  Right Hand Grab               NaN                    1
# 2        9.463898  Right Hand Grab               NaN                    1
# 7       26.456541  Right Hand Grab               NaN                    1
# 8       27.758953  Right Hand Grab               NaN                    1
# 36      50.117970  Right Hand Grab               NaN                    1
# 66      76.846298   Left Hand Grab               NaN                    1
# 78      87.869553  Right Hand Grab               NaN                    1
# 81      91.837021  Right Hand Grab               NaN                    1
# 114    126.306549  Right Hand Grab               NaN                    1
# 131    142.015976   Left Hand Grab               NaN                    1
# 132    142.893036   Left Hand Grab               NaN                    1
# 171    194.638199   Left Hand Grab               NaN                    1
# 174    207.432404   Left Hand Grab               NaN                    1
# 175    208.198639   Left Hand Grab               NaN                    1
# 176    209.097733   Left Hand Grab               NaN                    1
# 177    209.886200   Left Hand Grab               NaN                    1

# %%
df1.head()
# Out:
#    Session Time          Action Type         Interacted Object  \
# 0      7.489102      Right Hand Grab                       NaN
# 1      8.331804      Right Hand Grab      BeefStewCookbook_C_0
# 2      9.463898      Right Hand Grab                       NaN
# 3     10.206573      Right Hand Grab  BrothParent_C_2147482366
# 4     23.438997  Right Hand Released  BrothParent_C_2147482366
#
#    Missed Interactions
# 0                    1
# 1                    0
# 2                    1
# 3                    0
# 4                    0

# %%
main_dir = 'C:/Users/FANNY MARIA D SOUZA/Capstone/VR Data/C016 D/'
file_name = 'C016_SimpleStew_CompletedStepsData.csv'

file_path = os.path.join(main_dir, file_name)

df2 = pd.read_csv(file_path)

# %%
df2.head(10)
# Out:
#    Session Time Completed Step
# 0     21.683277     Pour Broth
# 1     44.064873       Add Beef
# 2     45.452015       Add Beef
# 3     46.233425       Add Beef
# 4     47.487385       Add Beef
# 5     68.652435       Add Beef
# 6     69.804504       Add Beef
# 7     71.130180       Add Beef
# 8     72.385132       Add Beef
# 9     91.214973      Add Onion

# %%
df2.shape
# Out:
# (32, 2)

# %%
df = pd.merge(df1, df2, on='Session Time',how='outer')

# %%
df.head(30)
# Out:
#     Session Time          Action Type                      Interacted Object  \
# 0       7.489102      Right Hand Grab                                    NaN
# 1       8.331804      Right Hand Grab                   BeefStewCookbook_C_0
# 2       9.463898      Right Hand Grab                                    NaN
# 3      10.206573      Right Hand Grab               BrothParent_C_2147482366
# 4      23.438997  Right Hand Released               BrothParent_C_2147482366
# 5      24.405071      Right Hand Grab               BrothParent_C_2147482366
# 6      25.148676  Right Hand Released               BrothParent_C_2147482366
# 7      26.456541      Right Hand Grab                                    NaN
# 8      27.758953      Right Hand Grab                                    NaN
# 9      29.106363      Right Hand Grab                   BeefStewCookbook_C_0
# 10     30.882599       Left Hand Grab            Meat_Choppable_C_2147482388
# 11     32.403851      Right Hand Grab                              Knife_C_4
# 12     32.941620   Left Hand Released            Meat_Choppable_C_2147482388
# 13     33.452057              Chopped            Meat_Choppable_C_2147482388
# 14     34.155430              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 15     34.883202              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 16     35.834293  Right Hand Released                              Knife_C_4
# 17     36.111893       Left Hand Grab   Meat_HalfLeft_Choppable_C_2147482359
# 18     36.956795   Left Hand Released   Meat_HalfLeft_Choppable_C_2147482359
# 19     37.168312      Right Hand Grab                              Knife_C_4
# 20     37.646591              Chopped        Meat_QuarterRight1_C_2147482357
# 21     38.346134              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 22     38.922256              Chopped         Meat_QuarterLeft2_C_2147482354
# 23     39.725552              Chopped        Meat_QuarterRight1_C_2147482357
# 24     40.211636  Right Hand Released                              Knife_C_4
# 25     40.390095       Left Hand Grab         Meat_QuarterLeft1_C_2147482355
# 26     41.044422   Left Hand Released         Meat_QuarterLeft1_C_2147482355
# 27     41.424595       Left Hand Grab        Meat_QuarterRight1_C_2147482357
# 28     42.411148      Right Hand Grab        Meat_QuarterRight2_C_2147482356
# 29     43.865456  Right Hand Released        Meat_QuarterRight2_C_2147482356
#
#     Missed Interactions Completed Step
# 0                   1.0            NaN
# 1                   0.0            NaN
# 2                   1.0            NaN
# 3                   0.0            NaN
# 4                   0.0            NaN
# 5                   0.0            NaN
# 6                   0.0            NaN
# 7                   1.0            NaN
# 8                   1.0            NaN
# 9                   0.0            NaN
# 10                  0.0            NaN
# 11                  0.0            NaN
# 12                  0.0            NaN
# 13                  0.0            NaN
# 14                  0.0            NaN
# 15                  0.0            NaN
# 16                  0.0            NaN
# 17                  0.0            NaN
# 18                  0.0            NaN
# 19                  0.0            NaN
# 20                  0.0            NaN
# 21                  0.0            NaN
# 22                  0.0            NaN
# 23                  0.0            NaN
# 24                  0.0            NaN
# 25                  0.0            NaN
# 26                  0.0            NaN
# 27                  0.0            NaN
# 28                  0.0            NaN
# 29                  0.0            NaN

# %%
df = df.sort_values(by='Session Time')

# %%
df.shape
# Out:
# (215, 5)

# %%
df.head(30)
# Out:
#      Session Time          Action Type                      Interacted Object  \
# 0        7.489102      Right Hand Grab                                    NaN
# 1        8.331804      Right Hand Grab                   BeefStewCookbook_C_0
# 2        9.463898      Right Hand Grab                                    NaN
# 3       10.206573      Right Hand Grab               BrothParent_C_2147482366
# 183     21.683277                  NaN                                    NaN
# 4       23.438997  Right Hand Released               BrothParent_C_2147482366
# 5       24.405071      Right Hand Grab               BrothParent_C_2147482366
# 6       25.148676  Right Hand Released               BrothParent_C_2147482366
# 7       26.456541      Right Hand Grab                                    NaN
# 8       27.758953      Right Hand Grab                                    NaN
# 9       29.106363      Right Hand Grab                   BeefStewCookbook_C_0
# 10      30.882599       Left Hand Grab            Meat_Choppable_C_2147482388
# 11      32.403851      Right Hand Grab                              Knife_C_4
# 12      32.941620   Left Hand Released            Meat_Choppable_C_2147482388
# 13      33.452057              Chopped            Meat_Choppable_C_2147482388
# 14      34.155430              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 15      34.883202              Chopped  Meat_HalfRight_Choppable_C_2147482358
# 16      35.834293  Right Hand Released                              Knife_C_4
# 17      36.111893       Left Hand Grab   Meat_HalfLeft_Choppable_C_2147482359
# 18      36.956795   Left Hand Released   Meat_HalfLeft_Choppable_C_2147482359
# 19      37.168312      Right Hand Grab                              Knife_C_4
# 20      37.646591              Chopped        Meat_QuarterRight1_C_2147482357
# 21      38.346134              Chopped   Meat_HalfLeft_Choppable_C_2147482359
# 22      38.922256              Chopped         Meat_QuarterLeft2_C_2147482354
# 23      39.725552              Chopped        Meat_QuarterRight1_C_2147482357
# 24      40.211636  Right Hand Released                              Knife_C_4
# 25      40.390095       Left Hand Grab         Meat_QuarterLeft1_C_2147482355
# 26      41.044422   Left Hand Released         Meat_QuarterLeft1_C_2147482355
# 27      41.424595       Left Hand Grab        Meat_QuarterRight1_C_2147482357
# 28      42.411148      Right Hand Grab        Meat_QuarterRight2_C_2147482356
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 183                  NaN     Pour Broth
# 4                    0.0            NaN
# 5                    0.0            NaN
# 6                    0.0            NaN
# 7                    1.0            NaN
# 8                    1.0            NaN
# 9                    0.0            NaN
# 10                   0.0            NaN
# 11                   0.0            NaN
# 12                   0.0            NaN
# 13                   0.0            NaN
# 14                   0.0            NaN
# 15                   0.0            NaN
# 16                   0.0            NaN
# 17                   0.0            NaN
# 18                   0.0            NaN
# 19                   0.0            NaN
# 20                   0.0            NaN
# 21                   0.0            NaN
# 22                   0.0            NaN
# 23                   0.0            NaN
# 24                   0.0            NaN
# 25                   0.0            NaN
# 26                   0.0            NaN
# 27                   0.0            NaN
# 28                   0.0            NaN

# %%
#df.to_csv('act_step_C016D.csv')

# %%
action_counts = df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        53
# Left Hand Grab         36
# Right Hand Released    35
# Chopped                33
# Left Hand Released     26
# Name: count, dtype: int64

# %%
action_counts.describe()
# Out:
# count     5.000000
# mean     36.600000
# std       9.964939
# min      26.000000
# 25%      33.000000
# 50%      35.000000
# 75%      36.000000
# max      53.000000
# Name: count, dtype: float64

# %%
total_actions = action_counts.sum()
total_actions
# Out:
# 183

# %%
# Count of interactions with each object
object_interactions = df['Interacted Object'].value_counts()
object_interactions
# Out:
# Interacted Object
# Knife_C_4                                      20
# BeefStewCookbook_C_0                           11
# Potato_Choppable_C_2147482398                   5
# Meat_HalfLeft_Choppable_C_2147482352            5
# Meat_QuarterRight1_C_2147482350                 5
# Meat_QuarterRight1_C_2147482357                 4
# BrothParent_C_2147482366                        4
# Meat_QuarterLeft1_C_2147482355                  4
# StirSpoonSimple_C_2147482368                    4
# Meat_QuarterRight2_C_2147482349                 4
# Onion_Choppable_C_2147482376                    3
# Carrot_Choppable_C_2147482389                   3
# Carrot_Choppable_C_2147482393                   3
# Tomato_Choppable_C_2147482382                   3
# Onion_Half_C_2147482340                         3
# Onion_Choppable_C_2147482346                    3
# Tomato_Choppable_C_2147482338                   3
# Meat_QuarterLeft2_C_2147482347                  3
# Meat_QuarterLeft2_C_2147482354                  3
# Meat_Choppable_C_2147482387                     3
# Meat_HalfLeft_Choppable_C_2147482359            3
# Meat_Choppable_C_2147482388                     3
# Meat_HalfRight_Choppable_C_2147482358           2
# CarrotBotton_Choppable_C_2147482324             2
# CarrotBottomQuarter2_Choppable_C_2147482322     2
# CarrotBottomQuarter1_Choppable_C_2147482323     2
# CarrotTopQuarter2_Choppable_C_2147482320        2
# CarrotTopQuarter1_Choppable_C_2147482321        2
# Meat_QuarterLeft1_C_2147482348                  2
# Potato_BottomHalf_Choppable_C_2147482327        2
# CarrotBottomQuarter2_Choppable_C_2147482315     2
# CarrotTopQuarter2_Choppable_C_2147482313        2
# CarrotTopQuarter1_Choppable_C_2147482314        2
# CarrotBottomQuarter1_Choppable_C_2147482316     2
# PepperShakerGrabableSimple_C_2147482364         2
# SaltShakerGrabableSimple_C_2147482365           2
# NewLadleSimple_C_2147482312                     2
# CarrotBotton_Choppable_C_2147482317             2
# Potato_TopHalf_Choppable_C_2147482328           2
# Potato_Choppable_C_2147482332                   2
# Meat_QuarterRight2_C_2147482356                 2
# Onion_Half2_C_2147482339                        2
# Onion_Half2_C_2147482341                        2
# Onion_Half_C_2147482342                         2
# Tomato_Choppable_C_2147482385                   2
# Potato_BottomHalf_Choppable_C_2147482330        2
# StewBowlSimple_C_2147482310                     2
# Tomato_BottomHalf_Choppable_C_2147482335        2
# Tomato_TopHalf_Choppable_C_2147482336           2
# Tomato_BottomHalf_Choppable_C_2147482333        2
# Tomato_TopHalf_Choppable_C_2147482334           2
# Potato_TopHalf_Choppable_C_2147482331           2
# CarrotTop_Choppable_C_2147482325                1
# Onion_Peeled_C_2147482343                       1
# Onion_Peeled_C_2147482344                       1
# Meat_HalfRight_Choppable_C_2147482351           1
# CarrotTop_Choppable_C_2147482318                1
# Name: count, dtype: int64

# %%
object_interactions=object_interactions.sum()
object_interactions
# Out:
# 167

# %%
# Sort the DataFrame by 'Session Time'
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)

# Find indices where steps are completed
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize the actions_per_step, time_per_step, and missed_interactions_per_step lists
actions_per_step = []
time_per_step = []
missed_interactions_per_step = []

# Calculate actions performed, time spent, and missed interactions for each completed step
previous_index = 0
for current_index in completed_indices:
    if pd.notna(df_sorted.loc[current_index, 'Action Type']):
        actions_count = current_index - previous_index + 1  # Include the current action if it's not null
    else:
        actions_count = current_index - previous_index  # Do not include the current action if it's null
    actions_per_step.append(actions_count)

    # Calculate time spent on this step
    time_spent = df_sorted.loc[current_index, 'Session Time'] - df_sorted.loc[previous_index, 'Session Time']
    time_per_step.append(time_spent)
    
    # Calculate missed interactions
    missed_interactions_count = df_sorted.loc[previous_index:current_index, 'Missed Interactions'].sum()
    missed_interactions_per_step.append(missed_interactions_count)
    
    previous_index = current_index + 1  # Move to the next action after the completed step

# Append the actions, time, and missed interactions for the period after the last completed step
actions_per_step.append(len(df_sorted) - previous_index)
time_per_step.append(df_sorted['Session Time'].iloc[-1] - df_sorted.loc[previous_index, 'Session Time'])
missed_interactions_per_step.append(df_sorted.loc[previous_index:, 'Missed Interactions'].sum())

# Create a dataframe to display the results
result_df = pd.DataFrame({
    'Completed Step': df_sorted.loc[completed_indices, 'Completed Step'].tolist() + ['Post last step'],
    'Actions Count': actions_per_step,
    'Time Spent': time_per_step,
    'Missed Interactions': missed_interactions_per_step
})

result_df
# Out:
#     Completed Step  Actions Count  Time Spent  Missed Interactions
# 0       Pour Broth              4   14.194175                  2.0
# 1         Add Beef             26   20.625876                  2.0
# 2         Add Beef              2    0.842739                  0.0
# 3         Add Beef              1    0.177376                  0.0
# 4         Add Beef              2    0.766995                  0.0
# 5         Add Beef             23   19.621429                  1.0
# 6         Add Beef              2    0.742584                  0.0
# 7         Add Beef              2    0.914528                  0.0
# 8         Add Beef              2    0.833046                  0.0
# 9        Add Onion             17   17.411033                  2.0
# 10       Add Onion              4    3.141151                  1.0
# 11       Add Onion              1    0.200218                  0.0
# 12       Add Onion              2    1.286369                  0.0
# 13     Add Tomtato             15   15.665551                  0.0
# 14     Add Tomtato              2    1.219513                  0.0
# 15     Add Tomtato              2    1.068558                  0.0
# 16     Add Tomtato              2    1.152123                  0.0
# 17      Add Potato             12   11.098083                  1.0
# 18      Add Potato              1    0.211380                  0.0
# 19      Add Potato              7    4.443176                  0.0
# 20      Add Potato              1    0.244843                  0.0
# 21      Add Carrot             13   10.458664                  2.0
# 22      Add Carrot              2    1.144363                  0.0
# 23      Add Carrot              2    0.963791                  0.0
# 24      Add Carrot              2    1.049073                  0.0
# 25      Add Carrot             11    7.164993                  0.0
# 26      Add Carrot              1    0.265548                  0.0
# 27      Add Carrot              2    0.797378                  0.0
# 28      Add Carrot              2    0.888260                  0.0
# 29      Add pepper              2    6.174271                  0.0
# 30        Add Salt              2    4.457733                  0.0
# 31       Stir Stew              3   15.073944                  1.0
# 32  Post last step             11   21.229095                  4.0

# %%
total_actions = result_df['Actions Count'].sum()
total_actions
# Out:
# 183

# %%
# Calculate the total values
total_actions = result_df['Actions Count'].sum()
total_time_spent = result_df['Time Spent'].sum()
total_missed_interactions = result_df['Missed Interactions'].sum()

# Create a new DataFrame with these totals
totals_df = pd.DataFrame({
    'Participant' : 'C016',
    'Total Actions': [total_actions],
    'Total Time Spent': [total_time_spent],
    'Total Missed Interactions': [total_missed_interactions]
})

totals_df
# Out:
#   Participant  Total Actions  Total Time Spent  Total Missed Interactions
# 0        C016            183        185.527859                       16.0

# %%
df_grouped = result_df.groupby("Completed Step").agg({
    "Actions Count": "sum",
    "Time Spent": "sum"
}).reset_index()

# Plotting
fig, ax1 = plt.subplots(figsize=(20, 6))

color = 'tab:blue'
ax1.set_xlabel('Completed Step')
ax1.set_ylabel('Actions Count', color=color)
ax1.bar(df_grouped['Completed Step'], df_grouped['Actions Count'], color=color, alpha=0.6, label='Actions Count')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 250)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Time Spent', color=color)
ax2.plot(df_grouped['Completed Step'], df_grouped['Time Spent'], color=color, marker='o', label='Time Spent')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 250)

fig.tight_layout()
plt.xticks(rotation=45, ha='right')
plt.title('Visualization of Actions Count and Time Spent by Completed Step')
plt.show()

# %%
result_df.describe()
# Out:
#        Actions Count  Time Spent  Missed Interactions
# count      33.000000   33.000000            33.000000
# mean        5.545455    5.622056             0.484848
# std         6.657190    7.028508             0.939455
# min         1.000000    0.177376             0.000000
# 25%         2.000000    0.833046             0.000000
# 50%         2.000000    1.152123             0.000000
# 75%         7.000000   10.458664             1.000000
# max        26.000000   21.229095             4.000000

# %%
df_sorted = df.sort_values(by='Session Time').reset_index(drop=True)
completed_indices = df_sorted.index[df_sorted['Completed Step'].notna()].tolist()

# Initialize a dictionary to store the count of interactions per object under each step
interactions_per_step = {}


previous_index = 0

for current_index in completed_indices:
    step_name = df_sorted.loc[current_index, 'Completed Step']
    step_data = df_sorted.iloc[previous_index:current_index+1]
    object_counts = step_data['Interacted Object'].value_counts().to_dict()
    
    if step_name in interactions_per_step:
        # If the step is already in the dictionary, add the counts to existing values
        for obj, count in object_counts.items():
            if obj in interactions_per_step[step_name]:
                interactions_per_step[step_name][obj] += count
            else:
                interactions_per_step[step_name][obj] = count
    else:
        interactions_per_step[step_name] = object_counts
    
    previous_index = current_index + 1

interactions_df = pd.DataFrame.from_dict(interactions_per_step, orient='index').fillna(0)
interactions_df = interactions_df.rename(columns=lambda x: x.split('_')[0])
interactions_df = interactions_df.T.groupby(interactions_df.columns).sum().T
interactions_df = interactions_df.astype(int)
interactions_df['Interacted Objects']=interactions_df.sum(axis=1)
interactions_df
# Out:
#              BeefStewCookbook  BrothParent  Carrot  CarrotBottomQuarter1  \
# Pour Broth                  1            1       0                     0
# Add Beef                    1            3       0                     0
# Add Onion                   1            0       0                     0
# Add Tomtato                 3            0       0                     0
# Add Potato                  1            0       0                     0
# Add Carrot                  1            0       6                     4
# Add pepper                  1            0       0                     0
# Stir Stew                   0            0       0                     0
# Add Salt                    0            0       0                     0
#
#              CarrotBottomQuarter2  CarrotBotton  CarrotTop  CarrotTopQuarter1  \
# Pour Broth                      0             0          0                  0
# Add Beef                        0             0          0                  0
# Add Onion                       0             0          0                  0
# Add Tomtato                     0             0          0                  0
# Add Potato                      0             0          0                  0
# Add Carrot                      4             4          2                  4
# Add pepper                      0             0          0                  0
# Stir Stew                       0             0          0                  0
# Add Salt                        0             0          0                  0
#
#              CarrotTopQuarter2  Knife  Meat  Onion  \
# Pour Broth                   0      0     0      0
# Add Beef                     0      7    44      0
# Add Onion                    0      3     0     17
# Add Tomtato                  0      2     0      0
# Add Potato                   0      4     0      0
# Add Carrot                   4      4     0      0
# Add pepper                   0      0     0      0
# Stir Stew                    0      0     0      0
# Add Salt                     0      0     0      0
#
#              PepperShakerGrabableSimple  Potato  SaltShakerGrabableSimple  \
# Pour Broth                            0       0                         0
# Add Beef                              0       0                         0
# Add Onion                             0       0                         0
# Add Tomtato                           0       0                         0
# Add Potato                            0      15                         0
# Add Carrot                            0       0                         0
# Add pepper                            1       0                         0
# Stir Stew                             0       0                         1
# Add Salt                              1       0                         1
#
#              StirSpoonSimple  Tomato  Interacted Objects
# Pour Broth                 0       0                   2
# Add Beef                   2       0                  57
# Add Onion                  0       0                  21
# Add Tomtato                0      16                  21
# Add Potato                 0       0                  20
# Add Carrot                 0       0                  33
# Add pepper                 0       0                   2
# Stir Stew                  1       0                   2
# Add Salt                   0       0                   2

# %%
completed_steps = df['Completed Step'].value_counts(dropna=True)

steps_summary = pd.DataFrame({
    'Completed Step': completed_steps.index,
    'Count': completed_steps.values
})
time_spent = result_df.groupby('Completed Step')['Time Spent'].sum().reset_index()
steps_summary = steps_summary.merge(time_spent, on='Completed Step', how='left')
steps_summary = steps_summary.sort_values(by='Count', ascending=False)

steps_summary
# Out:
#   Completed Step  Count  Time Spent
# 0       Add Beef      8   44.524573
# 1     Add Carrot      8   22.732070
# 2      Add Onion      4   22.038771
# 3    Add Tomtato      4   19.105745
# 4     Add Potato      4   15.997482
# 5     Pour Broth      1   14.194175
# 6     Add pepper      1    6.174271
# 7       Add Salt      1    4.457733
# 8      Stir Stew      1   15.073944

# %%
feature_df = df_sorted.copy()

# %%
feature_df
# Out:
#      Session Time          Action Type            Interacted Object  \
# 0        7.489102      Right Hand Grab                          NaN
# 1        8.331804      Right Hand Grab         BeefStewCookbook_C_0
# 2        9.463898      Right Hand Grab                          NaN
# 3       10.206573      Right Hand Grab     BrothParent_C_2147482366
# 4       21.683277                  NaN                          NaN
# ..            ...                  ...                          ...
# 210    210.963318      Right Hand Grab  NewLadleSimple_C_2147482312
# 211    217.880783  Right Hand Released  NewLadleSimple_C_2147482312
# 212    219.043167      Right Hand Grab  StewBowlSimple_C_2147482310
# 213    220.022644  Right Hand Released  StewBowlSimple_C_2147482310
# 214    222.722595      Right Hand Grab         BeefStewCookbook_C_0
#
#      Missed Interactions Completed Step
# 0                    1.0            NaN
# 1                    0.0            NaN
# 2                    1.0            NaN
# 3                    0.0            NaN
# 4                    NaN     Pour Broth
# ..                   ...            ...
# 210                  0.0            NaN
# 211                  0.0            NaN
# 212                  0.0            NaN
# 213                  0.0            NaN
# 214                  0.0            NaN
#
# [215 rows x 5 columns]

# %%
action_counts = feature_df['Action Type'].value_counts()
action_counts
# Out:
# Action Type
# Right Hand Grab        53
# Left Hand Grab         36
# Right Hand Released    35
# Chopped                33
# Left Hand Released     26
# Name: count, dtype: int64

# %%
action_counts = action_counts.sort_index()

# %%
missed_interactions_by_action = feature_df.groupby('Action Type')['Missed Interactions'].sum()
missed_interactions_by_action
# Out:
# Action Type
# Chopped                0.0
# Left Hand Grab         8.0
# Left Hand Released     0.0
# Right Hand Grab        8.0
# Right Hand Released    0.0
# Name: Missed Interactions, dtype: float64

# %%
missed_interactions_by_action = missed_interactions_by_action.sort_index()

# %%
features_summary = pd.DataFrame({
    'Action Type': action_counts.index,
    'Action Count': action_counts.values,
    'Total Missed Interactions': missed_interactions_by_action.values
})
features_summary = features_summary.sort_values(by='Action Count', ascending=False)
features_summary
# Out:
#            Action Type  Action Count  Total Missed Interactions
# 3      Right Hand Grab            53                        8.0
# 1       Left Hand Grab            36                        8.0
# 4  Right Hand Released            35                        0.0
# 0              Chopped            33                        0.0
# 2   Left Hand Released            26                        0.0
