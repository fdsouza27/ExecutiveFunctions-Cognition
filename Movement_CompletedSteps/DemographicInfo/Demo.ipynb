# %%
import os
import pandas as pd

# %%
directory = 'C:/Users/FANNY MARIA D SOUZA/Capstone_Movement/DemographicInfo/'

# %%
df=pd.read_csv('blockdesignscore.csv')

# %% [markdown]
# #### Demographic Info - Complex Pie

# %%
demo_complexpie=pd.read_csv('Features_ComplexPie_Movement.csv')

# %%
demo_complexpie
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C001  Female                      36           3395.496127
# 1         C003  Female                      58           2441.226143
# 2         C006    Male                      42           4712.449120
# 3         C008  Female                      34           5700.541398
# 4         C009  Female                      24           6033.585268
# 5         C012  Female                      54           4288.495977
# 6         C013  Female                      48           6519.554198
# 7         C016    Male                      39           5183.757477
# 8         C017    Male                      36           2594.463613
# 9         C020  Female                      30           4712.449120
# 10        C021  Female                      29           4943.632318
# 11        C024  Female                      42           4172.296974
# 12        C025  Female                      24           3392.022940
# ...

# %%
df = df[['Q1','Q2.1']].rename(columns={'Q1': 'Participant', 'Q2.1': 'Age'})
df_complexpie = pd.merge( demo_complexpie, df , on='Participant', how='inner')
df_complexpie
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C001  Female                      36           3395.496127
# 1         C003  Female                      58           2441.226143
# 2         C006    Male                      42           4712.449120
# 3         C008  Female                      34           5700.541398
# 4         C009  Female                      24           6033.585268
# 5         C012  Female                      54           4288.495977
# 6         C013  Female                      48           6519.554198
# 7         C016    Male                      39           5183.757477
# 8         C017    Male                      36           2594.463613
# 9         C020  Female                      30           4712.449120
# 10        C021  Female                      29           4943.632318
# 11        C024  Female                      42           4172.296974
# 12        C025  Female                      24           3392.022940
# ...

# %%
df_complexpie['Age'] = pd.to_numeric(df_complexpie['Age'], errors='coerce')
age_summary_cp=df_complexpie['Age'].describe()
age_summary_cp
# Out:
# count    15.000000
# mean     25.400000
# std       3.756898
# min      18.000000
# 25%      24.000000
# 50%      25.000000
# 75%      27.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_complexpie['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    11
# Male       4
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Simple Pie

# %%
demo_simplepie=pd.read_csv('Features_SimplePie_Movement.csv')

# %%
demo_simplepie
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C002  Female                      28           3540.337685
# 1         C004    Male                      30           2577.946109
# 2         C005  Female                      46           3101.189815
# 3         C014  Female                      32           3352.784517
# 4         C015  Female                      33           3357.411882
# 5         C018    Male                      50           3157.765553
# 6         C019  Female                      40           1383.847297
# 7         C022  Female                      32           5723.482644
# 8         C023  Female                      52           3793.795816
# 9         C026  Female                      33           3712.412837
# 10        C027  Female                      41           3846.483754
# 11        C030  Female                      39           3157.765553
# 12        C031    Male                      61           3357.411882
#
# ...

# %%
df_simplepie = pd.merge( demo_simplepie, df , on='Participant', how='inner')
df_simplepie
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C002  Female                      28           3540.337685
# 1         C004    Male                      30           2577.946109
# 2         C005  Female                      46           3101.189815
# 3         C014  Female                      32           3352.784517
# 4         C015  Female                      33           3357.411882
# 5         C018    Male                      50           3157.765553
# 6         C019  Female                      40           1383.847297
# 7         C022  Female                      32           5723.482644
# 8         C023  Female                      52           3793.795816
# 9         C026  Female                      33           3712.412837
# 10        C027  Female                      41           3846.483754
# 11        C030  Female                      39           3157.765553
# 12        C031    Male                      61           3357.411882
#
# ...

# %%
df_simplepie['Age'] = pd.to_numeric(df_simplepie['Age'], errors='coerce')
age_summary_sp=df_simplepie['Age'].describe()
age_summary_sp
# Out:
# count    13.000000
# mean     24.692308
# std       1.250641
# min      22.000000
# 25%      24.000000
# 50%      25.000000
# 75%      26.000000
# max      26.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_simplepie['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    10
# Male       3
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Complex Stew

# %%
demo_complexstew=pd.read_csv('Features_ComplexStew_Movement.csv')

# %%
demo_complexstew
# Out:
#   Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0        C002  Female                      28           3204.066141
# 1        C004    Male                      30           2836.300561
# 2        C005  Female                      46          10539.595320
# 3        C015  Female                      33           7321.705980
# 4        C018    Male                      50           3278.754839
# 5        C019  Female                      40           3145.024030
# 6        C023  Female                      52           5663.025763
# 7        C026  Female                      33           2914.637327
# 8        C027  Female                      41           4099.889010
# 9        C031    Male                      61           7321.705980
#
#    HeadCamera Total Distance  LeftElbow Total Distance  \
# 0                4673.310178               2980.379981
# 1                5411.832758               8191.224968
# ...

# %%
df_complexstew = pd.merge( demo_complexstew, df , on='Participant', how='inner')
df_complexstew
# Out:
#   Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0        C002  Female                      28           3204.066141
# 1        C004    Male                      30           2836.300561
# 2        C005  Female                      46          10539.595320
# 3        C015  Female                      33           7321.705980
# 4        C018    Male                      50           3278.754839
# 5        C019  Female                      40           3145.024030
# 6        C023  Female                      52           5663.025763
# 7        C026  Female                      33           2914.637327
# 8        C027  Female                      41           4099.889010
# 9        C031    Male                      61           7321.705980
#
#    HeadCamera Total Distance  LeftElbow Total Distance  \
# 0                4673.310178               2980.379981
# 1                5411.832758               8191.224968
# ...

# %%
df_complexstew['Age'] = pd.to_numeric(df_complexstew['Age'], errors='coerce')
age_summary_cs=df_complexstew['Age'].describe()
age_summary_cs
# Out:
# count    10.000000
# mean     24.700000
# std       1.418136
# min      22.000000
# 25%      24.000000
# 50%      25.000000
# 75%      26.000000
# max      26.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_complexstew['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    7
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Simple Stew

# %%
demo_simplestew=pd.read_csv('Features_SimpleStew_Movement.csv')

# %%
demo_simplestew
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C001  Female                      36           3412.670879
# 1         C003  Female                      58           3924.459833
# 2         C006    Male                      42           1333.791569
# 3         C008  Female                      34           4242.098701
# 4         C009  Female                      24           6417.363081
# 5         C012  Female                      54           1885.463295
# 6         C013  Female                      48           6810.143228
# 7         C016    Male                      39           2344.234017
# 8         C017    Male                      36           3142.145291
# 9         C020  Female                      30           3334.669489
# 10        C021  Female                      29           3949.856691
# 11        C024  Female                      42           1566.527293
# 12        C025  Female                      24           3827.027365
# ...

# %%
df_simplestew = pd.merge( demo_simplestew, df , on='Participant', how='inner')
df_simplestew
# Out:
#    Participant  Gender  Block Design Raw Score  Chest Total Distance  \
# 0         C001  Female                      36           3412.670879
# 1         C003  Female                      58           3924.459833
# 2         C006    Male                      42           1333.791569
# 3         C008  Female                      34           4242.098701
# 4         C009  Female                      24           6417.363081
# 5         C012  Female                      54           1885.463295
# 6         C013  Female                      48           6810.143228
# 7         C016    Male                      39           2344.234017
# 8         C017    Male                      36           3142.145291
# 9         C020  Female                      30           3334.669489
# 10        C021  Female                      29           3949.856691
# 11        C024  Female                      42           1566.527293
# 12        C025  Female                      24           3827.027365
# ...

# %%
df_simplestew['Age'] = pd.to_numeric(df_simplestew['Age'], errors='coerce')
age_summary_ss=df_simplestew['Age'].describe()
age_summary_ss
# Out:
# count    15.000000
# mean     25.400000
# std       3.756898
# min      18.000000
# 25%      24.000000
# 50%      25.000000
# 75%      27.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_simplestew['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    11
# Male       4
# Name: count, dtype: int64

# %% [markdown]
# #### T-test between Simple Pie and Complex Pie

# %%
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(df_simplepie['Age'], df_complexpie['Age'], nan_policy='omit')
t_stat, p_value
# Out:
# (-0.6473984995057966, 0.5230497119740167)

# %% [markdown]
# #### T-test between Simple Stew and Complex Stew

# %%
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(df_simplestew['Age'], df_complexstew['Age'], nan_policy='omit')
t_stat, p_value
# Out:
# (0.5599026340947169, 0.5809585978036637)
